# %% [markdown]
# <a href="https://colab.research.google.com/github/tarvt/DeleSmell_SA_G5/blob/main/dataset_class/JavaStud/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install docx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting docx
#   Downloading docx-0.2.4.tar.gz (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 KB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from docx) (4.9.2)
# Requirement already satisfied: Pillow>=2.0 in /usr/local/lib/python3.8/dist-packages (from docx) (7.1.2)
# Building wheels for collected packages: docx
#   Building wheel for docx (setup.py) ... done
#   Created wheel for docx: filename=docx-0.2.4-py3-none-any.whl size=53924 sha256=639e2cb3a0cf748b3a29d4382632c59820d2056f003fef71f90ebe582ab1bfdc
#   Stored in directory: /root/.cache/pip/wheels/78/ae/2e/5ce789557ca59281a463dabe9d6522e429be240322148e5379
# Successfully built docx
# Installing collected packages: docx
# Successfully installed docx-0.2.4

# %%
# !pip install exceptions
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement exceptions (from versions: none)
# ERROR: No matching distribution found for exceptions

# %%
import pandas as pd
import os
import numpy as np
import re
from string import punctuation
import pandas as pd
import csv
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
save_file_csv = 'JavaStud2.csv'
file_csv =  'JavaStud.csv'
file_dir = '/content/drive/MyDrive/delesmell/dataset_class/JavaStud' #Newly stored class address

# %%
fileList = []
def file_name(file_dir):
    for root, dirs, files in os.walk(file_dir):
#       print(root) #current directory path
#       print(files) #All non-directory subfiles in the current path
         for file in files:
            if file[-4:] == '.txt':
                fileList.append(os.path.join(root, file))

# %%
file_name(file_dir)

# %%
fileList
# Out:
# ['/content/drive/MyDrive/delesmell/dataset_class/JavaStud/ActionEvent.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/ThrowTest.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/LoginScreenLayout.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Area.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/CalculatorConsole.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Bike.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Student.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/InterfaceImplTest.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/ButtonClick.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/User.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/ChangeStaticValue.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/NicAsia.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/JButtonTableExample.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/TableTest.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/InstanceOfUses.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Bus.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/JavaCourse.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/EmployeeOuter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Human.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/ButtonClickActionListener.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Calculation2.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/HelloConstTest.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Calculation.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/AmbigiousCalculation.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/SwingWindowsBuilderTest.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/ImageButton.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/StudentPojo.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Car.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/RetOb.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Address.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/PrintThisKeyword.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/OverloadingTypePromotionCalc.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/FinallyTest.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/AbstractClassTest.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Volume.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/WindowsBuilderFirst.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/TableWithSpinner.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/SwingComponets.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/BabyDog.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/MysqlConnection.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/FindMinPassArr.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Emp.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Splender.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/MultiTryCatch.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/EmployeePanNo.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Bank.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Nabil.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/StaticVariable.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/StudentMangement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/CustomExceptionTest.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Showable.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/InterfaceInheritenceTest.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/PassObjAsParam.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/FacebookLike.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Vehicle.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Tab.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/InvalidAgeException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Course.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/CounterWithoutStatic.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/RuntimeExceptionAutoPropagate.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/FinalParam.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/CounterWithStatic.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/SpinnerTest.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/EventHandlingListener.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/Printable.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/EventHandlingAdapter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/JavaStud/ExtendtedJFrame.txt']

# %%
# stopwords
stopwords = ['abstract', 'java','assert', 'boolean', 'break', 'byte', 'case', 'catch', 'class','char', 'continue', 'default', 'do', 'double', 'else', 'enum', 'extends', 'final', 'finally', 'float', 'for', 'if', 'implements', 'import', 'int', 'interface', 'long', 'native', 'new', 'package','private','public', 'protected',  'return', 'short', 'static', 'strictfp', 'super', 'switch', 'synchronized', 'this', 'throw', 'transient', 'try', 'void', 'volatile', 'while']
dicts = {'\n': '','!': '', '"': '','：':'', '#': '', '$': '', '%': '', '&': '', "'": '', '(': '', ')': '', '*': '', '+': '', ',': '', '-': '', '.': '', '/': '', ':': '', ';': '', '<': '', '=': '', '>': '', '?': '', '@': '', '[': '', '\\': '', ']': '', '^': '', '_': '', '`': '', '{': '', '|': '', '}': '', '~': ''}
# stopwords = {'abstract':'', 'java':'','assert':'', 'boolean':'', 'break':'', 'byte':'', 'case':'', 'catch':'', 'class':'','char':'', 'continue':'', 'default':'', 'do':'', 'double':'', 'else':'', 'enum':'', 'extends':'', 'final':'', 'finally':'', 'float':'', 'for':'', 'if':'', 'implements':'', 'import':'', 'int':'', 'interface':'', 'long':'', 'native':'', 'new':'', 'package':'','private':'','public':'', 'protected':'',  'return':'', 'short':'', 'static':'', 'strictfp':'', 'super':'', 'switch':'', 'synchronized':'', 'this':'', 'throw':'', 'transient':'', 'try':'','void':'', 'volatile':'', 'while':''}

# %%
def lm_find_unchinese(line):
    pattern = re.compile(r'[\u4e00-\u9fa5]')
    unchinese = re.sub(pattern,"",line) #排除汉字
    unchinese = re.sub('[{}]'.format(punctuation),"",unchinese) #排除中文符号
    #print("unchinese:",unchinese)
    return unchinese

# %%
def del_stopwords(line):
#     for line in file.readlines():
#     dicts = {i: '' for i in punctuation}
    punc_table = str.maketrans(dicts)
    new_line = line.translate(punc_table)

#     for word in stopwords:
#           new_line = new_line.replace(word, '')

    return new_line

# %%
index = []
index_all = []
class_name = []
Brain_Class = []
for i, f in enumerate(fileList):
    with open(f,encoding='gb18030',errors='ignore') as file:
        list = []
        list2 = []
        is_brain = 0
        filename = os.path.basename(file.name)
        name = filename[:-4]
        class_name.append(name)
        list.append(name)
        list2.append(name)
        
        for line in file.readlines():
            line = lm_find_unchinese(line)
            line = del_stopwords(line)
            values = line.split(' ')
            coefs = values[1:-1]
            coefs = [i for i in coefs if i != '']
            keyword_brain = 'hongshuai'            

            if  keyword_brain in line:
                is_brain = 1
#             if len(coefs) != 0:
#                 if coefs != ' ':
#                     if coefs != '\n':
            for i in coefs:
                list.append(i)

        index.append(list)
        
        if is_brain == 0:
            list2.append(False)
        else :
            list2.append(True)
            print('T')
        
#         print (list2)
        
        Brain_Class.append(list2)

# %%
for k in range(0,len(Brain_Class)):
    a = Brain_Class[k][0]
    if '_' in a:
        n = a.find('_')
        new_str = ''
        for i in range(0, n):
            new_str = new_str + a[i]
        Brain_Class[k][0] = new_str
    print(Brain_Class[k][0])
# Out:
# ActionEvent
# ThrowTest
# LoginScreenLayout
# Area
# CalculatorConsole
# Bike
# Student
# InterfaceImplTest
# ButtonClick
# User
# ChangeStaticValue
# NicAsia
# JButtonTableExample
# TableTest
# InstanceOfUses
# Bus
# JavaCourse
# EmployeeOuter
# Human
# ButtonClickActionListener
# Calculation2
# HelloConstTest
# Calculation
# AmbigiousCalculation
# SwingWindowsBuilderTest
# ImageButton
# StudentPojo
# Car
# RetOb
# Address
# PrintThisKeyword
# OverloadingTypePromotionCalc
# FinallyTest
# AbstractClassTest
# Volume
# WindowsBuilderFirst
# TableWithSpinner
# SwingComponets
# BabyDog
# MysqlConnection
# FindMinPassArr
# Emp
# Splender
# MultiTryCatch
# EmployeePanNo
# Bank
# Nabil
# StaticVariable
# StudentMangement
# CustomExceptionTest
# Showable
# InterfaceInheritenceTest
# PassObjAsParam
# FacebookLike
# Vehicle
# Tab
# InvalidAgeException
# Course
# CounterWithoutStatic
# RuntimeExceptionAutoPropagate
# FinalParam
# CounterWithStatic
# SpinnerTest
# EventHandlingListener
# Printable
# EventHandlingAdapter
# ExtendtedJFrame

# %%
Brain_Class = np.array(Brain_Class)
Brain_Class
# Out:
# array([['ActionEvent', 'False'],
#        ['ThrowTest', 'False'],
#        ['LoginScreenLayout', 'False'],
#        ['Area', 'False'],
#        ['CalculatorConsole', 'False'],
#        ['Bike', 'False'],
#        ['Student', 'False'],
#        ['InterfaceImplTest', 'False'],
#        ['ButtonClick', 'False'],
#        ['User', 'False'],
#        ['ChangeStaticValue', 'False'],
#        ['NicAsia', 'False'],
#        ['JButtonTableExample', 'False'],
#        ['TableTest', 'False'],
#        ['InstanceOfUses', 'False'],
#        ['Bus', 'False'],
#        ['JavaCourse', 'False'],
#        ['EmployeeOuter', 'False'],
#        ['Human', 'False'],
#        ['ButtonClickActionListener', 'False'],
#        ['Calculation2', 'False'],
#        ['HelloConstTest', 'False'],
#        ['Calculation', 'False'],
#        ['AmbigiousCalculation', 'False'],
#        ['SwingWindowsBuilderTest', 'False'],
#        ['ImageButton', 'False'],
#        ['StudentPojo', 'False'],
#        ['Car', 'False'],
#        ['RetOb', 'False'],
#        ['Address', 'False'],
#        ['PrintThisKeyword', 'False'],
#        ['OverloadingTypePromotionCalc', 'False'],
#        ['FinallyTest', 'False'],
#        ['AbstractClassTest', 'False'],
#        ['Volume', 'False'],
#        ['WindowsBuilderFirst', 'False'],
#        ['TableWithSpinner', 'False'],
#        ['SwingComponets', 'False'],
#        ['BabyDog', 'False'],
#        ['MysqlConnection', 'False'],
#        ['FindMinPassArr', 'False'],
#        ['Emp', 'False'],
#        ['Splender', 'False'],
#        ['MultiTryCatch', 'False'],
#        ['EmployeePanNo', 'False'],
#        ['Bank', 'False'],
#        ['Nabil', 'False'],
#        ['StaticVariable', 'False'],
#        ['StudentMangement', 'False'],
#        ['CustomExceptionTest', 'False'],
#        ['Showable', 'False'],
#        ['InterfaceInheritenceTest', 'False'],
#        ['PassObjAsParam', 'False'],
#        ['FacebookLike', 'False'],
#        ['Vehicle', 'False'],
#        ['Tab', 'False'],
#        ['InvalidAgeException', 'False'],
#        ['Course', 'False'],
#        ['CounterWithoutStatic', 'False'],
#        ['RuntimeExceptionAutoPropagate', 'False'],
#        ['FinalParam', 'False'],
#        ['CounterWithStatic', 'False'],
#        ['SpinnerTest', 'False'],
#        ['EventHandlingListener', 'False'],
#        ['Printable', 'False'],
#        ['EventHandlingAdapter', 'False'],
#        ['ExtendtedJFrame', 'False']], dtype='<U29')

# %%
len(index)
# Out:
# 67

# %%
def additem(list):
    if len(list)<3:
        q = len(list)-1
        str = '_1'
        str2 = '_2'
        item = ''.join([list[q], str])
        item_2 = ''.join([list[q], str2])
        # item = list[q]
        list.append(item)
        list.append(item_2)
        # print(list)
    return list

for item in index_all:
    # print(item)
    item = additem(item)
    # print(item)

# %%
news_df = np.array(index,dtype=object)
print(news_df)
# Out:
# [list(['ActionEvent', 'abstract', 'void'])
#  list(['ThrowTest', 'static', 'void', 'validateAgeint', 'if', 'age', '18', 'throw', 'new', 'ArithmeticExceptionAge', 'age', 'is', 'not', 'else', 'SystemoutprintlnYou', 'are', 'eligible', 'to'])
#  list(['LoginScreenLayout', 'void', 'JButton', 'if', 'btnCancel', 'null', 'btnCancelnew', 'btnCanceladdActionListenernew', 'Override', 'public', 'void', 'actionPerformed', 'ActionEvent', 'return', 'JButton', 'if', 'btnSignIn', 'null', 'btnSignInnew', 'JButtonSign', 'btnSignInsetFontnew', 'btnSignInaddActionListenernew', 'Override', 'public', 'void', 'actionPerformed', 'ActionEvent', 'try', 'Connection', 'Statement', 'ResultSet', 'rsstmtexecuteQueryselect', 'from', 'while', 'rsnext', 'SystemoutprintlnrsgetInt1', 'catch', 'ClassNotFoundExceptionSQLException', 'e1', 'return', 'JLabel', 'if', 'lblPassword', 'null', 'lblPasswordnew', 'lblPasswordsetFontnew', 'return', 'JLabel', 'if', 'lblUserName', 'null', 'lblUserNamenew', 'JLabelUser', 'lblUserNamesetFontnew', 'return', 'JPanel', 'if', 'loginPanel', 'null', 'loginPanelnew', 'loginPanelsetBordernew', 'TitledBorderUIManagergetBorderTitledBorderborderLoginTitledBorderLEADINGTitledBorderTOPnullnew', 'loginPanelsetLayoutnew', 'return', 'JPanel', 'if', 'panelCenter', 'null', 'panelCenternew', 'panelCentersetBackgroundnew', 'panelCentersetBordernew', 'panelCentersetLayoutnew', 'FormLayoutnew', '', 'panelCenteraddgetLoginPanel2', '2', '9', '8', 'fill', 'panelCenteraddgetStatus8', '10', '3', 'panelCenteraddgetBtnSignIn4', 'panelCenteraddgetBtnCancel10', 'return', 'JPanel', 'if', 'panelLeft', 'null', 'panelLeftnew', 'FlowLayout', 'return', 'JPanel', 'if', 'panelRight', 'null', 'panelRightnew', 'FlowLayout', 'return', 'JPanel', 'if', 'panelTop', 'null', 'panelTopnew', 'FlowLayout', 'return', 'JPanel', 'if', 'panelBottom', 'null', 'panelBottomnew', 'FlowLayout', 'return', 'JPasswordField', 'if', 'password', 'null', 'passwordnew', 'return', 'JLabel', 'if', 'status', 'null', 'statusnew', 'statussetForegroundnew', 'statussetFontnew', 'return', 'JTextField', 'if', 'username', 'null', 'usernamenew', 'return', 'Create', 'the', 'contentPanenew', 'contentPanesetBordernew', 'contentPanesetLayoutnew', 'void', 'StudentMangement', 'studMngWindownew', 'LoginScreenLayout'])
#  list(['Area', 'int', 'arealength', 'SystemoutprintlnArea', 'is'])
#  list(['CalculatorConsole', 'static', 'double', 'expreString', 'if', 'exprecontains', 'exprecontains', 'exprecontains', 'exprecontains', 'return', 'double', 'for', 'int', 'i0', 'i', 'exprelength', 'i', 'char', 'if', 'CharacterisDigitsymbol', 'double', 'symbol', 'resultoperand1', 'expreexpresubstringi', 'resultoperand1', 'expreexpresubstringi', 'expreexpresubstringi', 'expreexpresubstringi', 'static', 'void', 'mainString', 'Scanner', 'scnew', 'while', 'true', 'SystemoutprintType', 'arithmetic', 'Expression', 'String', 'if', 'expressionequalsIgnoreCaseexit', 'double', 'Systemoutprintlnexpression'])
#  list(['Bike', 'SystemoutprintlnConstrctor', 'void', 'SystemoutprintlnBike', 'Speed', 'SystemoutprintlnVehicle', 'Speed'])
#  list(['Student', 'String', 'return', 'String', 'return', 'double', 'return', 'void', 'setAddressString', 'void', 'setEmailString', 'void', 'setFeedouble'])
#  list(['InterfaceImplTest', 'static', 'void', 'printBankInfoBank', 'SystemoutprintlnBank', 'Name', 'bgetBankName', 'tInterest', 'Rate', 'bgetRate', 't', 'Service', 'Charge', 'Rate'])
#  list(['ButtonClick', 'void', 'addActionEventActionEvent'])
#  list(['User', 'public', 'String', 'return', 'id', 'name', 'Userint', 'idString', 'Userint', 'idString', 'nameString'])
#  list(['ChangeStaticValue', 'rollnoString', 'static', 'void', 'changeString'])
#  list(['NicAsia', 'public', 'String', 'return', 'NIC'])
#  list(['JButtonTableExample', 'ButtonEditorJCheckBox', 'buttonnew', 'buttonaddActionListenernew', 'public', 'void', 'actionPerformed', 'ActionEvent', 'void', 'Object', 'if', 'isPushed', 'JOptionPaneshowMessageDialogbuttonlabel', 'return', 'new', 'Component', 'getTableCellEditorComponentJTable', 'tableObject', 'valueboolean', 'isSelectedint', 'rowint', 'if', 'isSelected', 'else', 'labelvalue', 'null', 'return', 'Component', 'getTableCellRendererComponentJTable', 'tableObject', 'valueboolean', 'isSelectedboolean', 'hasFocusint', 'rowint', 'if', 'isSelected', 'else', 'setTextvalue', 'null', 'return', 'superJButtonTable', 'DefaultTableModel', 'dmnew', 'dmsetDataVectornew', 'Objectbutton', '1foobutton', '2barnew', 'JTable', 'tablenew', 'tablegetColumnButtonsetCellRenderernew', 'tablegetColumnButtonsetCellEditornew', 'ButtonEditornew', 'JScrollPane', 'scrollnew', 'boolean', 'return'])
#  list(['TableTest', 'void', 'EventQueueinvokeLaternew', 'Override', 'public', 'void', 'try', 'catch', 'ClassNotFoundExceptionInstantiationExceptionIllegalAccessExceptionUnsupportedLookAndFeelException', 'ex', 'MyTableModel', 'modelnew', 'modeladdRownew', 'modeladdRownew', 'modeladdRownew', 'modeladdRownew', 'JTable', 'tablenew', 'JFrame', 'framenew', 'frameaddnew'])
#  list(['InstanceOfUses', 'static', 'void', 'displayObjectTypeObject', 'if', 'o', 'instanceof', 'Integer', 'SystemoutprintlnParameter', 'is', 'Integer', 'else', 'if', 'o', 'instanceof', 'String', 'SystemoutprintlnParameter', 'is', 'String'])
#  list(['Bus', 'void', 'SystemoutprintlnColor', 'SystemoutprintlnSpeed', 'SystemoutprintlnSize', 'SystemoutprintlnCC', 'SystemoutprintlnGears', 'BusString', 'colorint', 'speedint', 'sizeint', 'ccint'])
#  list(['JavaCourse', 'void', 'SystemoutprintlnCourse', 'Name', 'is', 'SystemoutprintlnCourse', 'Name', 'is'])
#  list(['EmployeeOuter', 'EmployeeOuterint', 'idString'])
#  list(['Human', 'void', 'SystemoutprintlnHuman'])
#  list(['ButtonClickActionListener', 'void', 'addActionListenerActionListener', 'static', 'void', 'ActionListener', 'aEventnew', 'Override', 'public', 'void', 'SystemoutprintlnHELLO', 'From', 'actionPerformed', 'ButtonClickActionListener', 'button2new', 'static', 'void', 'ButtonClickActionListener', 'buttonnew', 'buttonaddActionListenernew', 'Override', 'public', 'void', 'SystemoutprintlnHELLO', 'From', 'actionPerformed'])
#  list(['Calculation2', 'sumdouble', 'adouble', 'int', 'rinta', 'return', 'sumint', 'aint', 'return', 'a', 'sumString', 'aString', 'int', 'rIntegervalueOfa', 'return'])
#  list(['HelloConstTest', 'void', 'printWeekDay', 'SystemoutprintlnDay', 'is', 'day', 'is', 'not'])
#  list(['Calculation', 'sumint', 'aint', 'bint', 'Systemoutprintlna', 'b'])
#  list(['AmbigiousCalculation', 'sumint', 'along', 'Systemoutprintlna', 'method', 'sumlong', 'aint', 'Systemoutprintlnb', 'method'])
#  list(['SwingWindowsBuilderTest', 'JButton', 'if', 'btnOk', 'null', 'btnOknew', 'btnOksetFontnew', 'btnOkaddActionListenernew', 'Override', 'public', 'void', 'actionPerformed', 'ActionEvent', 'String', 'msg', 'Your', 'Name', 'is', 'return', 'JCheckBox', 'if', 'chckbxAge', 'null', 'chckbxAgenew', 'return', 'JComboBox', 'if', 'comboBox', 'null', 'comboBoxnew', 'comboBoxsetModelnew', 'DefaultComboBoxModelnew', 'StringSelect', 'Age', 'return', 'JLabel', 'if', 'nameLabel', 'null', 'nameLabelnew', 'JLabelWrite', 'Your', 'nameLabelsetFontnew', 'return', 'JTextField', 'if', 'nameText', 'null', 'nameTextnew', 'nameTextaddFocusListenernew', 'Override', 'public', 'void', 'focusLost', 'FocusEvent', 'statusLabelsetTextFocus', 'Lost', 'Override', 'public', 'void', 'focusGained', 'FocusEvent', 'statusLabelsetTextFocus', 'Gained', 'return', 'JPasswordField', 'if', 'passwordField', 'null', 'passwordFieldnew', 'return', 'JRadioButton', 'if', 'rdbtnFemale', 'null', 'rdbtnFemalenew', 'return', 'JRadioButton', 'if', 'rdbtnMale', 'null', 'rdbtnMalenew', 'return', 'JLabel', 'if', 'statusLabel', 'null', 'statusLabelnew', 'return', 'Create', 'the', 'contentPanenew', 'contentPanesetBordernew'])
#  list(['ImageButton', 'JFrame', 'fnew', 'JButton', 'bnew', 'JButtonnew'])
#  list(['StudentPojo', 'int', 'return', 'String', 'return', 'void', 'setIdint', 'void', 'setNameString'])
#  list(['Car', 'void', 'SystemoutprintlnColor', 'SystemoutprintlnSpeed', 'SystemoutprintlnSize', 'SystemoutprintlnCC', 'SystemoutprintlnGears'])
#  list(['RetOb', 'Test', 'tempnew', 'Testa', 'return'])
#  list(['Address', 'AddressString', 'cityString', 'stateString'])
#  list(['PrintThisKeyword', 'void'])
#  list(['OverloadingTypePromotionCalc', 'sumlong', 'along', 'Systemoutprintlnlong', 'arg', 'method'])
#  list(['FinallyTest', 'void', 'Scanner', 'try', 'scnew', 'SystemoutprintlnInput', 'a', 'int', 'int', 'catch', 'ClassCastException', 'e', 'finally', 'SystemoutprintlnScanner', 'resource'])
#  list(['AbstractClassTest', 'static', 'void', 'displayBankInfoBank', 'SystemoutprintlnBank', 'Name', 'bankgetBankName', 'Rate', 'SystemoutprintlnService', 'Charge', 'bankserviceChargeRate', 'Dollar', 'Ex', 'Rate'])
#  list(['Volume', 'int', 'arealength', 'SystemoutprintlnArea', 'int', 'volthislength', 'thisbreadth', 'SystemoutprintlnVolume', 'lengthint', 'breadthint'])
#  list(['WindowsBuilderFirst', 'Create', 'the', 'contentPanenew', 'contentPanesetBordernew', 'contentPanesetLayoutnew'])
#  list(['TableWithSpinner', 'JScrollPane', 'if', 'scrollPane', 'null', 'scrollPanenew', 'return', 'DefaultTableModel', 'if', 'model', 'null', 'modelnew', 'modelsetDataVectornew', 'Objectnew', 'return', 'Create', 'the'])
#  list(['SwingComponets', 'JSeparator', 'if', 'separator', 'null', 'separatornew', 'return', 'Create', 'the', 'contentPanenew', 'contentPanesetBordernew'])
#  list(['BabyDog', 'SystemoutprintlnClass', 'BabyDog', 'drinking'])
#  list(['MysqlConnection', 'static', 'Connection', 'getConnection', 'throws', 'ClassNotFoundException', 'SQLException', 'Connection', 'return'])
#  list(['FindMinPassArr', 'void', 'minint', 'int', 'for', 'int', 'i0', 'i', 'arrlength', 'i', 'if', 'arri', 'min', 'SystemoutprintlnMin', 'Value'])
#  list(['Emp', 'Empint', 'idString', 'nameAddress'])
#  list(['Splender', 'public', 'void', 'SystemoutprintlnRunning', 'Splender'])
#  list(['MultiTryCatch', 'int', 'divideint', 'aint', 'return', 'a'])
#  list(['EmployeePanNo']) list(['Bank', 'double', 'return'])
#  list(['Nabil', 'protected', 'int', 'return'])
#  list(['StaticVariable', 'Systemoutprintlnrollno', 'name', 'college', 'rString'])
#  list(['StudentMangement', 'JLabel', 'if', 'activeUser', 'null', 'activeUsernew', 'activeUsersetBackgroundnew', 'activeUsersetForegroundnew', 'activeUsersetFontnew', 'return', 'JButton', 'if', 'btnExit', 'null', 'btnExitnew', 'btnExitsetFontnew', 'btnExitsetForegroundnew', 'btnExitaddActionListenernew', 'Override', 'public', 'void', 'actionPerformed', 'ActionEvent', 'return', 'JButton', 'if', 'btnLogout', 'null', 'btnLogoutnew', 'btnLogoutsetIconnew', 'btnLogoutaddActionListenernew', 'Override', 'public', 'void', 'actionPerformed', 'ActionEvent', 'return', 'JButton', 'if', 'btnSave', 'null', 'btnSavenew', 'return', 'JLabel', 'if', 'lblBirthDate', 'null', 'lblBirthDatenew', 'JLabelBirth', 'return', 'JLabel', 'if', 'lblCollegeName', 'null', 'lblCollegeNamenew', 'JLabelCollege', 'return', 'JLabel', 'if', 'lblFaculty', 'null', 'lblFacultynew', 'return', 'JLabel', 'if', 'lblRollNo', 'null', 'lblRollNonew', 'JLabelRoll', 'return', 'JLabel', 'if', 'lblSubject', 'null', 'lblSubjectnew', 'return', 'JLabel', 'if', 'lblUser', 'null', 'lblUsernew', 'JLabelActive', 'lblUsersetForegroundnew', 'lblUsersetFontnew', 'return', 'JPanel', 'if', 'mainPanel', 'null', 'mainPanelnew', 'return', 'JLabel', 'if', 'nameLbl', 'null', 'nameLblnew', 'return', 'JTextField', 'if', 'nameTxt', 'null', 'nameTxtnew', 'return', 'JRadioButton', 'if', 'rdbtnNewRadioButton', 'null', 'rdbtnNewRadioButtonnew', 'return', 'JRadioButton', 'if', 'rdbtnNewRadioButton1', 'null', 'rdbtnNewRadioButton1new', 'return', 'JPanel', 'if', 'sexPanel', 'null', 'sexPanelnew', 'sexPanelsetBordernew', 'return', 'JTable', 'if', 'studTable', 'null', 'studTablenew', 'return', 'JTextField', 'if', 'textField', 'null', 'textFieldnew', 'return', 'JTextField', 'if', 'textField1', 'null', 'textField1new', 'return', 'JTextField', 'if', 'textField2', 'null', 'textField2new', 'return', 'JTextField', 'if', 'textField3', 'null', 'textField3new', 'return', 'JTextField', 'if', 'textField4', 'null', 'textField4new', 'return', 'Create', 'the', 'contentPanenew', 'contentPanesetBordernew', 'StudentMangementString', 'void', 'LoginScreenLayout', 'StudentMangement'])
#  list(['CustomExceptionTest', 'void', 'checkEligibleAgeForVoteint', 'age', 'throws', 'InvalidAgeException', 'if', 'age', '18', 'throw', 'new', 'InvalidAgeExceptionYou', 'are', 'not', 'eligible', 'to', 'vote', 'Age', 'else', 'SystemoutprintlnYou', 'can', 'vote', 'Age'])
#  list(['Showable']) list(['InterfaceInheritenceTest', 'public', 'void'])
#  list(['PassObjAsParam', 'equalsStudent', 'if', 'thisid', 'oid', 'thisrollNo', 'orollNo', 'return', 'return', 'Studentint', 'idint'])
#  list(['FacebookLike', 'FacebookLikeInteger', 'void', 'SystemoutprintlnThreadcurrentThreadgetName', 'Likes', 'try', 'catch', 'InterruptedException', 'e'])
#  list(['Vehicle', 'String', 'return', 'void', 'setColorString', 'void', 'setVehiclePropString', 'colorint', 'speedint', 'VehicleString', 'colorint', 'speedint'])
#  list(['Tab', 'JTable', 'if', 'table', 'null', 'String', 'columnNamesFirst', 'NameLast', 'NameSport', 'of', 'Object', 'dataKathySmithSnowboardingnew', 'Integer5new', 'BooleanfalseJohnDoeRowingnew', 'Integer3new', 'BooleantrueSueBlackKnittingnew', 'Integer2new', 'BooleanfalseJaneWhiteSpeed', 'readingnew', 'Integer20new', 'BooleantrueJoeBrownPoolnew', 'Integer10new', 'tablenew', 'return', 'Create', 'the'])
#  list(['InvalidAgeException'])
#  list(['Course', 'void', 'SystemoutprintlnI', 'am', 'private', 'void', 'SystemoutprintlnI', 'am', 'public', 'void', 'SystemoutprintlnCourse', 'Name', 'is', 'int'])
#  list(['CounterWithoutStatic'])
#  list(['RuntimeExceptionAutoPropagate', 'void', 'try', 'catch', 'ArithmeticException', 'e', 'SystemoutprintlnArithmeticException', 'handled', 'void', 'void', 'int', 'a75'])
#  list(['FinalParam', 'void', 'areafinal', 'double', 'PIdouble', 'areaPI', 'r'])
#  list(['CounterWithStatic', 'void'])
#  list(['SpinnerTest', 'JPanel', 'if', 'panel', 'null', 'panelnew', 'return', 'JSpinner', 'if', 'spinner', 'null', 'spinnernew', 'return', 'Initialize', 'the', 'contents', 'of', 'the', 'void', 'framenew', 'Create', 'the'])
#  list(['EventHandlingListener', 'Create', 'the', 'contentPanenew'])
#  list(['Printable'])
#  list(['EventHandlingAdapter', 'Create', 'the', 'contentPanenew', 'JButton', 'if', 'okBtn', 'null', 'okBtnnew', 'okBtnaddActionListenernew', 'public', 'void', 'actionPerformed', 'ActionEvent', 'JOptionPaneshowMessageDialogcontentPaneYour', 'name', 'is', 'return', 'JLabel', 'if', 'statusTxt', 'null', 'statusTxtnew', 'return'])
#  list(['ExtendtedJFrame', 'thissetTitleJFrame', 'Extended', 'JButton', 'if', 'button', 'null', 'buttonnew', 'return', 'JLabel', 'if', 'label', 'null', 'labelnew', 'JLabelFirst', 'Java', 'Swing', 'return', 'void', 'JPanel', 'contentPanenew'])]

# %%
def f_lsa(news_df, n):
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(news_df)
 

    n_cap = 1
    svd_model = TruncatedSVD(n_components=n_cap)
    X2 = svd_model.fit_transform(X) 


    terms = vectorizer.get_feature_names()
   
    for i, comp in enumerate(svd_model.components_):
        terms_comp = zip(terms, comp)
        sorted_terms = sorted(terms_comp, key=lambda x: x[1], reverse=True)[:7]
        # print("Topic " + str(i) + ": ")
        for t in sorted_terms:
            print(t[0])
    print(" ")

    D = svd_model.components_
    T = X2
    S = np.diagflat(svd_model.singular_values_)

    X = np.dot(T, S)
    X = np.dot(X, D)
    c = np.dot(X, X.T)

    acsm = None
    sum = 0
    for i in c:
        for j in i:
            if j < 0:
                j = 0
            sum += j
        acsm = sum / n / n
    # print("-------------acsm----------------------")
    # print(acsm)

    return acsm

# %%
q = 0
acsm= []
for i in index:
    lists = []
    print("*************",i,"****************")
    # print("------------------------------------------------------------------")
    for j in i:
        lists.append(j)
    # lists = deleteDuplicatedElementFromList(lists)
    if len(lists) > 1:
        acsm.append(f_lsa(lists,len(i)))
    else :
        acsm.append(1)
#

# print(type(class_name))
# print(type(acsm))
# Out:
# ************* ['ActionEvent', 'abstract', 'void'] ****************
# void
# abstract
# actionevent
#
# ************* ['ThrowTest', 'static', 'void', 'validateAgeint', 'if', 'age', '18', 'throw', 'new', 'ArithmeticExceptionAge', 'age', 'is', 'not', 'else', 'SystemoutprintlnYou', 'are', 'eligible', 'to'] ****************
# age
# is
# void
# arithmeticexceptionage
# validateageint
# throw
# to
#
# ************* ['LoginScreenLayout', 'void', 'JButton', 'if', 'btnCancel', 'null', 'btnCancelnew', 'btnCanceladdActionListenernew', 'Override', 'public', 'void', 'actionPerformed', 'ActionEvent', 'return', 'JButton', 'if', 'btnSignIn', 'null', 'btnSignInnew', 'JButtonSign', 'btnSignInsetFontnew', 'btnSignInaddActionListenernew', 'Override', 'public', 'void', 'actionPerformed', 'ActionEvent', 'try', 'Connection', 'Statement', 'ResultSet', 'rsstmtexecuteQueryselect', 'from', 'while', 'rsnext', 'SystemoutprintlnrsgetInt1', 'catch', 'ClassNotFoundExceptionSQLException', 'e1', 'return', 'JLabel', 'if', 'lblPassword', 'null', 'lblPasswordnew', 'lblPasswordsetFontnew', 'return', 'JLabel', 'if', 'lblUserName', 'null', 'lblUserNamenew', 'JLabelUser', 'lblUserNamesetFontnew', 'return', 'JPanel', 'if', 'loginPanel', 'null', 'loginPanelnew', 'loginPanelsetBordernew', 'TitledBorderUIManagergetBorderTitledBorderborderLoginTitledBorderLEADINGTitledBorderTOPnullnew', 'loginPanelsetLayoutnew', 'return', 'JPanel', 'if', 'panelCenter', 'null', 'panelCenternew', 'panelCentersetBackgroundnew', 'panelCentersetBordernew', 'panelCentersetLayoutnew', 'FormLayoutnew', '', 'panelCenteraddgetLoginPanel2', '2', '9', '8', 'fill', 'panelCenteraddgetStatus8', '10', '3', 'panelCenteraddgetBtnSignIn4', 'panelCenteraddgetBtnCancel10', 'return', 'JPanel', 'if', 'panelLeft', 'null', 'panelLeftnew', 'FlowLayout', 'return', 'JPanel', 'if', 'panelRight', 'null', 'panelRightnew', 'FlowLayout', 'return', 'JPanel', 'if', 'panelTop', 'null', 'panelTopnew', 'FlowLayout', 'return', 'JPanel', 'if', 'panelBottom', 'null', 'panelBottomnew', 'FlowLayout', 'return', 'JPasswordField', 'if', 'password', 'null', 'passwordnew', 'return', 'JLabel', 'if', 'status', 'null', 'statusnew', 'statussetForegroundnew', 'statussetFontnew', 'return', 'JTextField', 'if', 'username', 'null', 'usernamenew', 'return', 'Create', 'the', 'contentPanenew', 'contentPanesetBordernew', 'contentPanesetLayoutnew', 'void', 'StudentMangement', 'studMngWindownew', 'LoginScreenLayout'] ****************
# if
# null
# loginscreenlayout
# public
# loginpanelsetlayoutnew
# formlayoutnew
# override
#
# ************* ['Area', 'int', 'arealength', 'SystemoutprintlnArea', 'is'] ****************
# int
# is
# area
# systemoutprintlnarea
# arealength
#
# ************* ['CalculatorConsole', 'static', 'double', 'expreString', 'if', 'exprecontains', 'exprecontains', 'exprecontains', 'exprecontains', 'return', 'double', 'for', 'int', 'i0', 'i', 'exprelength', 'i', 'char', 'if', 'CharacterisDigitsymbol', 'double', 'symbol', 'resultoperand1', 'expreexpresubstringi', 'resultoperand1', 'expreexpresubstringi', 'expreexpresubstringi', 'expreexpresubstringi', 'static', 'void', 'mainString', 'Scanner', 'scnew', 'while', 'true', 'SystemoutprintType', 'arithmetic', 'Expression', 'String', 'if', 'expressionequalsIgnoreCaseexit', 'double', 'Systemoutprintlnexpression'] ****************
# expreexpresubstringi
# double
# exprecontains
# for
# return
# int
# exprestring
#
# ************* ['Bike', 'SystemoutprintlnConstrctor', 'void', 'SystemoutprintlnBike', 'Speed', 'SystemoutprintlnVehicle', 'Speed'] ****************
# speed
# systemoutprintlnvehicle
# void
# bike
# systemoutprintlnbike
# systemoutprintlnconstrctor
#
# ************* ['Student', 'String', 'return', 'String', 'return', 'double', 'return', 'void', 'setAddressString', 'void', 'setEmailString', 'void', 'setFeedouble'] ****************
# return
# setfeedouble
# student
# setemailstring
# double
# string
# setaddressstring
#
# ************* ['InterfaceImplTest', 'static', 'void', 'printBankInfoBank', 'SystemoutprintlnBank', 'Name', 'bgetBankName', 'tInterest', 'Rate', 'bgetRate', 't', 'Service', 'Charge', 'Rate'] ****************
# rate
# bgetrate
# printbankinfobank
# static
# void
# name
# systemoutprintlnbank
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#
# ************* ['ButtonClick', 'void', 'addActionEventActionEvent'] ****************
# buttonclick
# void
# addactioneventactionevent
#
# ************* ['User', 'public', 'String', 'return', 'id', 'name', 'Userint', 'idString', 'Userint', 'idString', 'nameString'] ****************
# userint
# idstring
# name
# user
# public
# namestring
# id
#
# ************* ['ChangeStaticValue', 'rollnoString', 'static', 'void', 'changeString'] ****************
# rollnostring
# changestring
# changestaticvalue
# void
# static
#
# ************* ['NicAsia', 'public', 'String', 'return', 'NIC'] ****************
# nic
# nicasia
# public
# return
# string
#
# ************* ['JButtonTableExample', 'ButtonEditorJCheckBox', 'buttonnew', 'buttonaddActionListenernew', 'public', 'void', 'actionPerformed', 'ActionEvent', 'void', 'Object', 'if', 'isPushed', 'JOptionPaneshowMessageDialogbuttonlabel', 'return', 'new', 'Component', 'getTableCellEditorComponentJTable', 'tableObject', 'valueboolean', 'isSelectedint', 'rowint', 'if', 'isSelected', 'else', 'labelvalue', 'null', 'return', 'Component', 'getTableCellRendererComponentJTable', 'tableObject', 'valueboolean', 'isSelectedboolean', 'hasFocusint', 'rowint', 'if', 'isSelected', 'else', 'setTextvalue', 'null', 'return', 'superJButtonTable', 'DefaultTableModel', 'dmnew', 'dmsetDataVectornew', 'Objectbutton', '1foobutton', '2barnew', 'JTable', 'tablenew', 'tablegetColumnButtonsetCellRenderernew', 'tablegetColumnButtonsetCellEditornew', 'ButtonEditornew', 'JScrollPane', 'scrollnew', 'boolean', 'return'] ****************
# return
# jscrollpane
# buttonnew
# labelvalue
# hasfocusint
# actionperformed
# boolean
#
# ************* ['TableTest', 'void', 'EventQueueinvokeLaternew', 'Override', 'public', 'void', 'try', 'catch', 'ClassNotFoundExceptionInstantiationExceptionIllegalAccessExceptionUnsupportedLookAndFeelException', 'ex', 'MyTableModel', 'modelnew', 'modeladdRownew', 'modeladdRownew', 'modeladdRownew', 'modeladdRownew', 'JTable', 'tablenew', 'JFrame', 'framenew', 'frameaddnew'] ****************
# modeladdrownew
# try
# mytablemodel
# public
# jtable
# framenew
# eventqueueinvokelaternew
#
# ************* ['InstanceOfUses', 'static', 'void', 'displayObjectTypeObject', 'if', 'o', 'instanceof', 'Integer', 'SystemoutprintlnParameter', 'is', 'Integer', 'else', 'if', 'o', 'instanceof', 'String', 'SystemoutprintlnParameter', 'is', 'String'] ****************
# systemoutprintlnparameter
# instanceof
# string
# integer
# static
# void
# else
#
# ************* ['Bus', 'void', 'SystemoutprintlnColor', 'SystemoutprintlnSpeed', 'SystemoutprintlnSize', 'SystemoutprintlnCC', 'SystemoutprintlnGears', 'BusString', 'colorint', 'speedint', 'sizeint', 'ccint'] ****************
# void
# systemoutprintlnspeed
# systemoutprintlngears
# systemoutprintlncolor
# busstring
# speedint
# sizeint
#
# ************* ['JavaCourse', 'void', 'SystemoutprintlnCourse', 'Name', 'is', 'SystemoutprintlnCourse', 'Name', 'is'] ****************
# name
# javacourse
# void
# is
# systemoutprintlncourse
#
# ************* ['EmployeeOuter', 'EmployeeOuterint', 'idString'] ****************
# idstring
# employeeouter
# employeeouterint
#
# ************* ['Human', 'void', 'SystemoutprintlnHuman'] ****************
# systemoutprintlnhuman
# void
# human
#
# ************* ['ButtonClickActionListener', 'void', 'addActionListenerActionListener', 'static', 'void', 'ActionListener', 'aEventnew', 'Override', 'public', 'void', 'SystemoutprintlnHELLO', 'From', 'actionPerformed', 'ButtonClickActionListener', 'button2new', 'static', 'void', 'ButtonClickActionListener', 'buttonnew', 'buttonaddActionListenernew', 'Override', 'public', 'void', 'SystemoutprintlnHELLO', 'From', 'actionPerformed'] ****************
# void
# aeventnew
# buttonnew
# actionlistener
# buttonaddactionlistenernew
# from
# actionperformed
#
# ************* ['Calculation2', 'sumdouble', 'adouble', 'int', 'rinta', 'return', 'sumint', 'aint', 'return', 'a', 'sumString', 'aString', 'int', 'rIntegervalueOfa', 'return'] ****************
# return
# int
# sumdouble
# astring
# rintegervalueofa
# rinta
# adouble
#
# ************* ['HelloConstTest', 'void', 'printWeekDay', 'SystemoutprintlnDay', 'is', 'day', 'is', 'not'] ****************
# is
# helloconsttest
# systemoutprintlnday
# day
# printweekday
# not
# void
#
# ************* ['Calculation', 'sumint', 'aint', 'bint', 'Systemoutprintlna', 'b'] ****************
# sumint
# calculation
# systemoutprintlna
# aint
# bint
#
# ************* ['AmbigiousCalculation', 'sumint', 'along', 'Systemoutprintlna', 'method', 'sumlong', 'aint', 'Systemoutprintlnb', 'method'] ****************
# method
# sumint
# aint
# systemoutprintlnb
# ambigiouscalculation
# along
# systemoutprintlna
#
# ************* ['SwingWindowsBuilderTest', 'JButton', 'if', 'btnOk', 'null', 'btnOknew', 'btnOksetFontnew', 'btnOkaddActionListenernew', 'Override', 'public', 'void', 'actionPerformed', 'ActionEvent', 'String', 'msg', 'Your', 'Name', 'is', 'return', 'JCheckBox', 'if', 'chckbxAge', 'null', 'chckbxAgenew', 'return', 'JComboBox', 'if', 'comboBox', 'null', 'comboBoxnew', 'comboBoxsetModelnew', 'DefaultComboBoxModelnew', 'StringSelect', 'Age', 'return', 'JLabel', 'if', 'nameLabel', 'null', 'nameLabelnew', 'JLabelWrite', 'Your', 'nameLabelsetFontnew', 'return', 'JTextField', 'if', 'nameText', 'null', 'nameTextnew', 'nameTextaddFocusListenernew', 'Override', 'public', 'void', 'focusLost', 'FocusEvent', 'statusLabelsetTextFocus', 'Lost', 'Override', 'public', 'void', 'focusGained', 'FocusEvent', 'statusLabelsetTextFocus', 'Gained', 'return', 'JPasswordField', 'if', 'passwordField', 'null', 'passwordFieldnew', 'return', 'JRadioButton', 'if', 'rdbtnFemale', 'null', 'rdbtnFemalenew', 'return', 'JRadioButton', 'if', 'rdbtnMale', 'null', 'rdbtnMalenew', 'return', 'JLabel', 'if', 'statusLabel', 'null', 'statusLabelnew', 'return', 'Create', 'the', 'contentPanenew', 'contentPanesetBordernew'] ****************
# null
# return
# passwordfield
# contentpanesetbordernew
# rdbtnmale
# the
# is
#
# ************* ['ImageButton', 'JFrame', 'fnew', 'JButton', 'bnew', 'JButtonnew'] ****************
# fnew
# jbutton
# jbuttonnew
# imagebutton
# jframe
# bnew
#
# ************* ['StudentPojo', 'int', 'return', 'String', 'return', 'void', 'setIdint', 'void', 'setNameString'] ****************
# return
# studentpojo
# setidint
# string
# setnamestring
# int
# void
#
# ************* ['Car', 'void', 'SystemoutprintlnColor', 'SystemoutprintlnSpeed', 'SystemoutprintlnSize', 'SystemoutprintlnCC', 'SystemoutprintlnGears'] ****************
# car
# systemoutprintlncc
# systemoutprintlncolor
# systemoutprintlngears
# systemoutprintlnsize
# systemoutprintlnspeed
# void
#
# ************* ['RetOb', 'Test', 'tempnew', 'Testa', 'return'] ****************
# test
# testa
# tempnew
# retob
# return
#
# ************* ['Address', 'AddressString', 'cityString', 'stateString'] ****************
# statestring
# address
# addressstring
# citystring
#
# ************* ['PrintThisKeyword', 'void'] ****************
# printthiskeyword
# void
#
# ************* ['OverloadingTypePromotionCalc', 'sumlong', 'along', 'Systemoutprintlnlong', 'arg', 'method'] ****************
# sumlong
# systemoutprintlnlong
# arg
# along
# overloadingtypepromotioncalc
# method
#
# ************* ['FinallyTest', 'void', 'Scanner', 'try', 'scnew', 'SystemoutprintlnInput', 'a', 'int', 'int', 'catch', 'ClassCastException', 'e', 'finally', 'SystemoutprintlnScanner', 'resource'] ****************
# int
# scnew
# systemoutprintlninput
# scanner
# catch
# systemoutprintlnscanner
# try
#
# ************* ['AbstractClassTest', 'static', 'void', 'displayBankInfoBank', 'SystemoutprintlnBank', 'Name', 'bankgetBankName', 'Rate', 'SystemoutprintlnService', 'Charge', 'bankserviceChargeRate', 'Dollar', 'Ex', 'Rate'] ****************
# rate
# bankgetbankname
# ex
# static
# bankservicechargerate
# systemoutprintlnbank
# void
#
# ************* ['Volume', 'int', 'arealength', 'SystemoutprintlnArea', 'int', 'volthislength', 'thisbreadth', 'SystemoutprintlnVolume', 'lengthint', 'breadthint'] ****************
# int
# volthislength
# systemoutprintlnarea
# volume
# systemoutprintlnvolume
# arealength
# lengthint
#
# ************* ['WindowsBuilderFirst', 'Create', 'the', 'contentPanenew', 'contentPanesetBordernew', 'contentPanesetLayoutnew'] ****************
# the
# create
# contentpanesetbordernew
# contentpanenew
# contentpanesetlayoutnew
# windowsbuilderfirst
#
# ************* ['TableWithSpinner', 'JScrollPane', 'if', 'scrollPane', 'null', 'scrollPanenew', 'return', 'DefaultTableModel', 'if', 'model', 'null', 'modelnew', 'modelsetDataVectornew', 'Objectnew', 'return', 'Create', 'the'] ****************
# return
# if
# null
# the
# jscrollpane
# tablewithspinner
# scrollpane
#
# ************* ['SwingComponets', 'JSeparator', 'if', 'separator', 'null', 'separatornew', 'return', 'Create', 'the', 'contentPanenew', 'contentPanesetBordernew'] ****************
# separator
# the
# separatornew
# swingcomponets
# null
# return
# contentpanesetbordernew
#
# ************* ['BabyDog', 'SystemoutprintlnClass', 'BabyDog', 'drinking'] ****************
# babydog
# drinking
# systemoutprintlnclass
#
# ************* ['MysqlConnection', 'static', 'Connection', 'getConnection', 'throws', 'ClassNotFoundException', 'SQLException', 'Connection', 'return'] ****************
# connection
# sqlexception
# classnotfoundexception
# throws
# getconnection
# return
# mysqlconnection
#
# ************* ['FindMinPassArr', 'void', 'minint', 'int', 'for', 'int', 'i0', 'i', 'arrlength', 'i', 'if', 'arri', 'min', 'SystemoutprintlnMin', 'Value'] ****************
# int
# arrlength
# findminpassarr
# min
# i0
# value
# for
#
# ************* ['Emp', 'Empint', 'idString', 'nameAddress'] ****************
# nameaddress
# emp
# empint
# idstring
#
# ************* ['Splender', 'public', 'void', 'SystemoutprintlnRunning', 'Splender'] ****************
# splender
# void
# public
# systemoutprintlnrunning
#
# ************* ['MultiTryCatch', 'int', 'divideint', 'aint', 'return', 'a'] ****************
# divideint
# aint
# int
# multitrycatch
# return
#
# ************* ['EmployeePanNo'] ****************
# ************* ['Bank', 'double', 'return'] ****************
# bank
# double
# return
#
# ************* ['Nabil', 'protected', 'int', 'return'] ****************
# return
# protected
# int
# nabil
#
# ************* ['StaticVariable', 'Systemoutprintlnrollno', 'name', 'college', 'rString'] ****************
# college
# name
# rstring
# staticvariable
# systemoutprintlnrollno
#
# ************* ['StudentMangement', 'JLabel', 'if', 'activeUser', 'null', 'activeUsernew', 'activeUsersetBackgroundnew', 'activeUsersetForegroundnew', 'activeUsersetFontnew', 'return', 'JButton', 'if', 'btnExit', 'null', 'btnExitnew', 'btnExitsetFontnew', 'btnExitsetForegroundnew', 'btnExitaddActionListenernew', 'Override', 'public', 'void', 'actionPerformed', 'ActionEvent', 'return', 'JButton', 'if', 'btnLogout', 'null', 'btnLogoutnew', 'btnLogoutsetIconnew', 'btnLogoutaddActionListenernew', 'Override', 'public', 'void', 'actionPerformed', 'ActionEvent', 'return', 'JButton', 'if', 'btnSave', 'null', 'btnSavenew', 'return', 'JLabel', 'if', 'lblBirthDate', 'null', 'lblBirthDatenew', 'JLabelBirth', 'return', 'JLabel', 'if', 'lblCollegeName', 'null', 'lblCollegeNamenew', 'JLabelCollege', 'return', 'JLabel', 'if', 'lblFaculty', 'null', 'lblFacultynew', 'return', 'JLabel', 'if', 'lblRollNo', 'null', 'lblRollNonew', 'JLabelRoll', 'return', 'JLabel', 'if', 'lblSubject', 'null', 'lblSubjectnew', 'return', 'JLabel', 'if', 'lblUser', 'null', 'lblUsernew', 'JLabelActive', 'lblUsersetForegroundnew', 'lblUsersetFontnew', 'return', 'JPanel', 'if', 'mainPanel', 'null', 'mainPanelnew', 'return', 'JLabel', 'if', 'nameLbl', 'null', 'nameLblnew', 'return', 'JTextField', 'if', 'nameTxt', 'null', 'nameTxtnew', 'return', 'JRadioButton', 'if', 'rdbtnNewRadioButton', 'null', 'rdbtnNewRadioButtonnew', 'return', 'JRadioButton', 'if', 'rdbtnNewRadioButton1', 'null', 'rdbtnNewRadioButton1new', 'return', 'JPanel', 'if', 'sexPanel', 'null', 'sexPanelnew', 'sexPanelsetBordernew', 'return', 'JTable', 'if', 'studTable', 'null', 'studTablenew', 'return', 'JTextField', 'if', 'textField', 'null', 'textFieldnew', 'return', 'JTextField', 'if', 'textField1', 'null', 'textField1new', 'return', 'JTextField', 'if', 'textField2', 'null', 'textField2new', 'return', 'JTextField', 'if', 'textField3', 'null', 'textField3new', 'return', 'JTextField', 'if', 'textField4', 'null', 'textField4new', 'return', 'Create', 'the', 'contentPanenew', 'contentPanesetBordernew', 'StudentMangementString', 'void', 'LoginScreenLayout', 'StudentMangement'] ****************
# return
# null
# public
# jradiobutton
# studtablenew
# lblrollno
# sexpanelsetbordernew
#
# ************* ['CustomExceptionTest', 'void', 'checkEligibleAgeForVoteint', 'age', 'throws', 'InvalidAgeException', 'if', 'age', '18', 'throw', 'new', 'InvalidAgeExceptionYou', 'are', 'not', 'eligible', 'to', 'vote', 'Age', 'else', 'SystemoutprintlnYou', 'can', 'vote', 'Age'] ****************
# age
# to
# eligible
# checkeligibleageforvoteint
# if
# systemoutprintlnyou
# are
#
# ************* ['Showable'] ****************
# ************* ['InterfaceInheritenceTest', 'public', 'void'] ****************
# public
# interfaceinheritencetest
# void
#
# ************* ['PassObjAsParam', 'equalsStudent', 'if', 'thisid', 'oid', 'thisrollNo', 'orollNo', 'return', 'return', 'Studentint', 'idint'] ****************
# return
# studentint
# passobjasparam
# equalsstudent
# thisid
# oid
# idint
#
# ************* ['FacebookLike', 'FacebookLikeInteger', 'void', 'SystemoutprintlnThreadcurrentThreadgetName', 'Likes', 'try', 'catch', 'InterruptedException', 'e'] ****************
# systemoutprintlnthreadcurrentthreadgetname
# interruptedexception
# facebooklike
# try
# facebooklikeinteger
# catch
# void
#
# ************* ['Vehicle', 'String', 'return', 'void', 'setColorString', 'void', 'setVehiclePropString', 'colorint', 'speedint', 'VehicleString', 'colorint', 'speedint'] ****************
# void
# string
# setcolorstring
# setvehiclepropstring
# vehiclestring
# colorint
# vehicle
#
# ************* ['Tab', 'JTable', 'if', 'table', 'null', 'String', 'columnNamesFirst', 'NameLast', 'NameSport', 'of', 'Object', 'dataKathySmithSnowboardingnew', 'Integer5new', 'BooleanfalseJohnDoeRowingnew', 'Integer3new', 'BooleantrueSueBlackKnittingnew', 'Integer2new', 'BooleanfalseJaneWhiteSpeed', 'readingnew', 'Integer20new', 'BooleantrueJoeBrownPoolnew', 'Integer10new', 'tablenew', 'return', 'Create', 'the'] ****************
# integer5new
# tab
# booleanfalsejohndoerowingnew
# integer2new
# booleantruesueblackknittingnew
# tablenew
# namesport
#
# ************* ['InvalidAgeException'] ****************
# ************* ['Course', 'void', 'SystemoutprintlnI', 'am', 'private', 'void', 'SystemoutprintlnI', 'am', 'public', 'void', 'SystemoutprintlnCourse', 'Name', 'is', 'int'] ****************
# void
# int
# private
# name
# public
# systemoutprintlncourse
# am
#
# ************* ['CounterWithoutStatic'] ****************
# ************* ['RuntimeExceptionAutoPropagate', 'void', 'try', 'catch', 'ArithmeticException', 'e', 'SystemoutprintlnArithmeticException', 'handled', 'void', 'void', 'int', 'a75'] ****************
# void
# arithmeticexception
# handled
# a75
# systemoutprintlnarithmeticexception
# runtimeexceptionautopropagate
# try
#
# ************* ['FinalParam', 'void', 'areafinal', 'double', 'PIdouble', 'areaPI', 'r'] ****************
# double
# void
# areapi
# areafinal
# finalparam
# pidouble
#
# ************* ['CounterWithStatic', 'void'] ****************
# void
# counterwithstatic
#
# ************* ['SpinnerTest', 'JPanel', 'if', 'panel', 'null', 'panelnew', 'return', 'JSpinner', 'if', 'spinner', 'null', 'spinnernew', 'return', 'Initialize', 'the', 'contents', 'of', 'the', 'void', 'framenew', 'Create', 'the'] ****************
# the
# spinnertest
# jpanel
# panel
# create
# null
# of
#
# ************* ['EventHandlingListener', 'Create', 'the', 'contentPanenew'] ****************
# the
# contentpanenew
# eventhandlinglistener
# create
#
# ************* ['Printable'] ****************
# ************* ['EventHandlingAdapter', 'Create', 'the', 'contentPanenew', 'JButton', 'if', 'okBtn', 'null', 'okBtnnew', 'okBtnaddActionListenernew', 'public', 'void', 'actionPerformed', 'ActionEvent', 'JOptionPaneshowMessageDialogcontentPaneYour', 'name', 'is', 'return', 'JLabel', 'if', 'statusTxt', 'null', 'statusTxtnew', 'return'] ****************
# null
# if
# jlabel
# actionevent
# statustxtnew
# name
# okbtnaddactionlistenernew
#
# ************* ['ExtendtedJFrame', 'thissetTitleJFrame', 'Extended', 'JButton', 'if', 'button', 'null', 'buttonnew', 'return', 'JLabel', 'if', 'label', 'null', 'labelnew', 'JLabelFirst', 'Java', 'Swing', 'return', 'void', 'JPanel', 'contentPanenew'] ****************
# null
# if
# button
# jlabel
# label
# buttonnew
# extendtedjframe

# %%
c = []
for i in range(len(class_name)):
      for j in range(len(acsm)):
        if i==j:
            t=[class_name[i],acsm[j]]
            c.append(t)

# c = list(zip(class_name,acsm))
# print(type(c))
c = np.array(c)
# print(c)
# print(c[0][0])

# %%
df = pd.read_excel ("/content/drive/MyDrive/delesmell/dataset_class/JavaStud/JavaStud.xls")
df.to_csv ("Test.csv", 
                  index = None,
                  header=True)
# df =pd.read_csv("/content/drive/MyDrive/delesmell/dataset_class/JavaStud/JavaStud.xls")

# %%
x= df.iloc[:, 0]

# %%
Brain_Class
# Out:
# array([['ActionEvent', 'False'],
#        ['ThrowTest', 'False'],
#        ['LoginScreenLayout', 'False'],
#        ['Area', 'False'],
#        ['CalculatorConsole', 'False'],
#        ['Bike', 'False'],
#        ['Student', 'False'],
#        ['InterfaceImplTest', 'False'],
#        ['ButtonClick', 'False'],
#        ['User', 'False'],
#        ['ChangeStaticValue', 'False'],
#        ['NicAsia', 'False'],
#        ['JButtonTableExample', 'False'],
#        ['TableTest', 'False'],
#        ['InstanceOfUses', 'False'],
#        ['Bus', 'False'],
#        ['JavaCourse', 'False'],
#        ['EmployeeOuter', 'False'],
#        ['Human', 'False'],
#        ['ButtonClickActionListener', 'False'],
#        ['Calculation2', 'False'],
#        ['HelloConstTest', 'False'],
#        ['Calculation', 'False'],
#        ['AmbigiousCalculation', 'False'],
#        ['SwingWindowsBuilderTest', 'False'],
#        ['ImageButton', 'False'],
#        ['StudentPojo', 'False'],
#        ['Car', 'False'],
#        ['RetOb', 'False'],
#        ['Address', 'False'],
#        ['PrintThisKeyword', 'False'],
#        ['OverloadingTypePromotionCalc', 'False'],
#        ['FinallyTest', 'False'],
#        ['AbstractClassTest', 'False'],
#        ['Volume', 'False'],
#        ['WindowsBuilderFirst', 'False'],
#        ['TableWithSpinner', 'False'],
#        ['SwingComponets', 'False'],
#        ['BabyDog', 'False'],
#        ['MysqlConnection', 'False'],
#        ['FindMinPassArr', 'False'],
#        ['Emp', 'False'],
#        ['Splender', 'False'],
#        ['MultiTryCatch', 'False'],
#        ['EmployeePanNo', 'False'],
#        ['Bank', 'False'],
#        ['Nabil', 'False'],
#        ['StaticVariable', 'False'],
#        ['StudentMangement', 'False'],
#        ['CustomExceptionTest', 'False'],
#        ['Showable', 'False'],
#        ['InterfaceInheritenceTest', 'False'],
#        ['PassObjAsParam', 'False'],
#        ['FacebookLike', 'False'],
#        ['Vehicle', 'False'],
#        ['Tab', 'False'],
#        ['InvalidAgeException', 'False'],
#        ['Course', 'False'],
#        ['CounterWithoutStatic', 'False'],
#        ['RuntimeExceptionAutoPropagate', 'False'],
#        ['FinalParam', 'False'],
#        ['CounterWithStatic', 'False'],
#        ['SpinnerTest', 'False'],
#        ['EventHandlingListener', 'False'],
#        ['Printable', 'False'],
#        ['EventHandlingAdapter', 'False'],
#        ['ExtendtedJFrame', 'False']], dtype='<U29')

# %%
for i in range(0,len(Brain_Class)):
    if 'False' == Brain_Class[i][1]:
        q = 1
    else :
        print('*')

# %%
ngList=[] 

for index in x:
#     print(index)
    q = 1
    for i in range(0,len(c)):
        st = str(c[i][0])
        st = st[1:]
#         print(st)
        if index == st:
            ngList.append(c[i][1])
            q = 0
            break
#             print('*')
    if q==1 :
        ngList.append(1)

# %%
brainList=[] 

for index in x:
#     print(index)
    q = 1
    for i in range(0,len(c)):
        st = str(Brain_Class[i][0])
        st = st[1:]
        if index == st:
            brainList.append(Brain_Class[i][1])
            q = 0
            break
    if q==1 :
        brainList.append('0')
        
        
print(len(brainList))
print(len(x))
# Out:
# 234
# 234

# %%
column=df.columns.tolist()

# %%
df['acsm'] = ngList 
df['is_brain'] = brainList 
df.to_csv(save_file_csv,mode = 'a',index =False)

# %%
df.head()
# Out:
#                   NAME   AMW  ATDF  BOVM  BUR  CBO  CC  CM  CRIX  DAC  ...  \
# 0           VolumeTest  1.00     0     0    1    1   0   0   0.0    0  ...
# 1                 Bike  0.67     0     0    1    0   0   0   0.0    0  ...
# 2              Vehicle  1.00     0     0    1    0   0   0   0.0    0  ...
# 3  JButtonTableExample  1.00     0     0    1    2   0   0   0.0    0  ...
# 4                    1  1.00     0     0    1    0   0   0   0.0    0  ...
#
#    NOA  NOAM  NOD  NOM  NOPA  TCC  WMC  WOC  acsm  is_brain
# 0    0     0    0    1     0  1.0    1  1.0     1         0
# 1    0     0    0    3     0  0.0    2  1.0     1         0
# 2    0     0    1    1     0  1.0    1  1.0     1         0
# 3    0     0    0    2     0  1.0    2  1.0     1         0
# 4    0     0    0    1     0  1.0    1  1.0     1         0
#
# [5 rows x 27 columns]
