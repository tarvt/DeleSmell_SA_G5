# %% [markdown]
# <a href="https://colab.research.google.com/github/tarvt/DeleSmell_SA_G5/blob/main/dataset_class/SPECjbb/specjbb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
import numpy as np
import re
from string import punctuation
import pandas as pd
import csv
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
save_file_csv = 'SPECjbb2.csv'
file_csv =  'SPECjbb.csv'
file_dir = '/content/drive/MyDrive/delesmell/dataset_class/SPECjbb'

# %%
fileList = []
def file_name(file_dir):
    for root, dirs, files in os.walk(file_dir):
#       print(root) #current directory path
#       print(files) #All non-directory subfiles in the current path
         for file in files:
            if file[-4:] == '.txt':
                fileList.append(os.path.join(root, file))

# %%
file_name(file_dir)

# %%
# stopwords
stopwords = ['abstract', 'java','assert', 'boolean', 'break', 'byte', 'case', 'catch', 'class','char', 'continue', 'default', 'do', 'double', 'else', 'enum', 'extends', 'final', 'finally', 'float', 'for', 'if', 'implements', 'import', 'int', 'interface', 'long', 'native', 'new', 'package','private','public', 'protected',  'return', 'short', 'static', 'strictfp', 'super', 'switch', 'synchronized', 'this', 'throw', 'transient', 'try', 'void', 'volatile', 'while']
dicts = {'\n': '','!': '', '"': '','：':'', '#': '', '$': '', '%': '', '&': '', "'": '', '(': '', ')': '', '*': '', '+': '', ',': '', '-': '', '.': '', '/': '', ':': '', ';': '', '<': '', '=': '', '>': '', '?': '', '@': '', '[': '', '\\': '', ']': '', '^': '', '_': '', '`': '', '{': '', '|': '', '}': '', '~': ''}

# %%
def lm_find_unchinese(line):
    pattern = re.compile(r'[\u4e00-\u9fa5]')
    unchinese = re.sub(pattern,"",line) #Exclude Chinese characters
    unchinese = re.sub('[{}]'.format(punctuation),"",unchinese) #Exclude Chinese characters
    #print("unchinese:",unchinese)
    return unchinese

# %%
def del_stopwords(line):

    punc_table = str.maketrans(dicts)
    new_line = line.translate(punc_table)

    return new_line

# %%
index = []
index_all = []
class_name = []
Brain_Class = []
for i, f in enumerate(fileList):
    with open(f,encoding='gb18030',errors='ignore') as file:
        list = []
        list2 = []
        is_brain = 0
        filename = os.path.basename(file.name)
        name = filename[:-4]
        class_name.append(name)
        list.append(name)
        list2.append(name)
        
        for line in file.readlines():
            line = lm_find_unchinese(line)
            line = del_stopwords(line)
            values = line.split(' ')
            coefs = values[1:-1]
            coefs = [i for i in coefs if i != '']
            keyword_brain = 'hongshuai'            

            if  keyword_brain in line:
                is_brain = 1
            if len(coefs) != 0:
                if coefs != ' ':
                    if coefs != '\n':
                        for i in coefs:
                            list.append(i)

        index.append(list)
        
        if is_brain == 0:
            list2.append(False)
        else :
            list2.append(True)
            print('T')
        
#         print (list2)
        
        Brain_Class.append(list2)
# Out:
# T
# T

# %%
Brain_Class = np.array(Brain_Class)
Brain_Class
# Out:
# array([['OrderStatusTransaction', 'False'],
#        ['MultiVMTxtReport', 'False'],
#        ['Sub', 'False'],
#        ['Item', 'False'],
#        ['TemplateCompare', 'False'],
#        ['MapDataStorage', 'False'],
#        ['GraphImage', 'False'],
#        ['Check', 'False'],
#        ['Report', 'False'],
#        ['Warehouse', 'False'],
#        ['TableGroup', 'False'],
#        ['NewOrder', 'False'],
#        ['JBBmain', 'False'],
#        ['MultiVMReporter', 'False'],
#        ['History', 'False'],
#        ['Order', 'False'],
#        ['TextColumn', 'False'],
#        ['LoopBounds', 'False'],
#        ['NewOrderTransaction', 'False'],
#        ['TransactionLogBuffer', 'False'],
#        ['MultiVMReport', 'False'],
#        ['HTMLTableGraphGenerator3', 'False'],
#        ['TextBlock', 'False'],
#        ['CustomerReportTransaction', 'False'],
#        ['TimerData', 'False'],
#        ['Result', 'False'],
#        ['digestExpected', 'False'],
#        ['Table', 'False'],
#        ['TextMetrics', 'False'],
#        ['Customer', 'False'],
#        ['PaymentTransaction', 'False'],
#        ['Controller', 'False'],
#        ['ReportProps', 'False'],
#        ['PepTest', 'False'],
#        ['digest', 'False'],
#        ['TextiReport', 'False'],
#        ['StockLevelTransaction', 'False'],
#        ['Template', 'False'],
#        ['RunSequencer', 'False'],
#        ['TreeMapDataStorage', 'False'],
#        ['Transaction', 'False'],
#        ['Metrics', 'False'],
#        ['Orderline', 'False'],
#        ['Super', 'False'],
#        ['XMLTransactionLog', 'False'],
#        ['Stock', 'False'],
#        ['District', 'False'],
#        ['JBBLogFormatter', 'False'],
#        ['TableGroupCompare', 'False'],
#        ['TransactionManager', 'True'],
#        ['DeliveryTransaction', 'False'],
#        ['Company', 'True'],
#        ['DeliveryHandler', 'False'],
#        ['SaveOutput', 'False'],
#        ['Address', 'False'],
#        ['JBBProperties', 'False'],
#        ['Infrastructure', 'False'],
#        ['Title', 'False'],
#        ['Run', 'False'],
#        ['JBButil', 'False']], dtype='<U25')

# %%
len(index)
# Out:
# 60

# %%
news_df = np.array(index,dtype=object)
print(news_df)
# Out:
# [list(['OrderStatusTransaction', 'OrderStatusTransactionCompany', 'inCompanyshort', 'int', 'olsupplyingwarehousenew', 'olitemidnew', 'olitemnamenew', 'olquantitynew', 'olstocknew', 'olbgnew', 'olitempricenew', 'olamountnew', 'oldeliverydatenew', 'orderLognew', 'xmlOrderLognew', 'initLognew', 'void', 'orderLogputTextSupplyW', 'ItemId', 'Qty', 'Amount'])
#  list(['MultiVMTxtReport', 'void', 'int', 'int', 'long', 'long', 'long', 'long', 'long', 'long', 'long', 'long', 'for', 'int', 'n1', 'n', 'instances', 'n', 'if', 'count', 'metricsngetWarehousesTested', 'if', 'instancesChecked', 'instances', 'SystemoutprintlnINVALID', 'Instances', 'do', 'not', 'have', 'identical', 'test', 'else', 'for', 'int', 'i1', 'i', 'count', 'instanceChecksPassed', 'i', 'for', 'int', 'j0', 'j', 'instances', 'j', 'if', 'tmpStart', 'firststartmillis', 'if', 'tmpRampup', 'lastrampupmillis', 'if', 'tmpRampdown', 'firstrampdownmillis', 'if', 'tmpEnd', 'lastendmillis', 'if', 'firstrampdownmillis', 'lastendmillis', 'firststartmillis', 'lastrampupmillis', 'else', 'MultiVMTxtReportString', 'newsletterString', 'outputdirectoryboolean', 'MultiVMTxtReportString', 'newsletterString', 'outputdirectoryboolean', 'SPECInternalUseString', 'String', 'File', 'dirnew', 'if', 'direxists', 'SystemoutprintlnError', 'file', 'outputdirectory', 'doesnt', 'if', 'dirisDirectory', 'SystemoutprintlnError', 'file', 'outputdirectory', 'is', 'not', 'a', 'FilenameFilter', 'filternew', 'File', 'resultsnew', 'metricsnew', 'metricnew', 'double', 'boolean', 'for', 'int', 'i0', 'i', 'resultFileslength', 'i', 'resultsinew', 'try', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'reading', 'results', 'file', 'resultFilesi', 'metricsinew', 'try', 'catch', 'NumberFormatException', 'e', 'if', 'isMetricsDouble', 'metric2Metricsformatsum', 'thishardwaregetconfighwvendor', 'for', 'int', 'i0', 'i', 'metricslength', 'i', 'if', 'metricsivalid', 'thissoftwaregetconfigswvendor'])
#  list(['Sub', 'String', 'return', 'int', 'return', 'priv', 'int', 'return', 'prot', 'Subint', 'superblack', 'pubblack'])
#  list(['Item', 'String', 'return', 'BigDecimal', 'return', 'synchronized', 'void', 'setUsingRandomint', 'namenew', 'float', 'pricenew', 'brandInformationnew'])
#  list(['TemplateCompare', 'tTitle', 'Faken', 'Table', '0', '0', '0n', 'n', 'Title', 'Hardwaren', 'Table', '0', '0', '0n', 'confighwvendorn', 'confighwvendorurln', 'confighwmodeln', 'confighwprocessorn', 'confighwMHzn', 'confighwnchipsn', 'confighwncoresn', 'confighwncoresperchipn', 'confighwhwThreadsn', 'configswprocsAvailtoJavan', 'confighwmemoryn', 'confighwmemorydescriptionn', 'confighwprimaryCachen', 'confighwsecondaryCachen', 'confighwotherCachen', 'confighwfileSystemn', 'confighwdiskn', 'confighwothern', 'n', 'Title', 'Softwaren', 'Table', '0', '1', '0n', 'configswvendorn', 'configswvendorurln', 'configswJVMn', 'configswcommandlinen', 'configswJVMheapInitialn', 'configswJVMheapMaxn', 'configswOSn', 'configswothern', 'n', 'Title', 'AOT', 'Compilationn', 'Table', '1', '1', '1n', 'configswaotn', 'n', 'Title', 'Tuningn', 'Table', '1', '1', '1n', 'configswtuningn', 'n', 'Title', 'Test', 'Informationn', 'Table', '1', '0', '0n', 'configtesttestedByn', 'configtestspecLicensen', 'configtestlocationn', 'configtestdaten', 'confighwavailablen', 'configswJVMavailablen', 'configswOSavailablen', 'configswotherAvailablen', 'n', 'Title', 'Notesn', 'Table', '1', '1', '1n', 'configswnotesn'])
#  list(['MapDataStorage', 'boolean', 'containsKeyObject', 'return', 'Iterator', 'return', 'Object', 'getObject', 'return', 'thisnew', 'MapDataStorageMap', 'Object', 'putObject', 'keyObject', 'return', 'Object', 'removeObject', 'return'])
#  list(['GraphImage', 'void', 'drawLegendString', 'legenddouble', 'XOffsetdouble', 'YOffsetColor', 'symbolColorColor', 'legendColorString', 'FontMetrics', 'int', 'txgetLinearMapXscaleMINX', 'int', 'tygetLinearMapY0', 'intYOffset', 'AXISTICKRADIUS', 'int', 'int', 'rintMathroundp', 'if', 'legendTypeequalsLine', 'graphicsdrawLinetxty', 'fmgetAscent', '2tx', '20ty', 'fmgetAscent', 'graphicsdrawString', 'legendtx', 'else', 'if', 'legendTypeequalsDot', 'graphicsfillArctx', 'rty', 'r', 'fmgetAscent', 'graphicsdrawString', 'int', 'getLinearMapXdouble', 'return', 'intMathroundx', 'scaleMINX', 'int', 'getLinearMapYdouble', 'return', 'intMathroundscaleMAXY', 'y', 'synchronized', 'double', 'getSuggestedMinXScaledouble', 'maxxdouble', 'double', 'scalenew', 'setScalenew', 'FontMetrics', 'int', 'wfmstringWidthdfyformatmaxy', 'AXISTICKRADIUS', 'double', 'minxthisscaleMINX', 'w', 'return', 'synchronized', 'double', 'getSuggestedMinYScaledouble', 'maxxdouble', 'double', 'scalenew', 'setScalenew', 'FontMetrics', 'int', 'hAXISTICKRADIUS', 'fmgetHeight', 'double', 'minythisscaleMAXY', 'h', 'alphay', 'return', 'int', 'getSuggestedYAxisTickIntervalint', 'suggestedNumTicksdouble', 'double', 'tmaxy', 'int', 'llintMathlogt', 'int', 'lull', 'int', 'tinew', 'for', 'int', 'i0', 'i', 'tilength', '1', 'i', 'tii', '1tii', 'int', 'int', 'for', 'int', 'itilength', '1', 'i', '0', 'i', 'double', 'ddifftii', 'if', 'ddiff', '00', 'int', 'if', 'diff', 'delta', 'delta', '0', 'return', 'GraphImageint', 'widthint', 'void', 'void', 'void', 'makeString', 'if', 'filename', 'null', 'try', 'File', 'outfilenew', 'catch', 'Exception', 'e', 'JBButilgetLoglogLevelWARNINGException', 'void', 'plotFlatLinedouble', 'yColor', 'int', 'int', 'int', 'for', 'int', 'xpx', 'x', 'w', 'x2', 'DASHLENGTH', 'graphicsdrawLinexpyx', 'void', 'plotFlatLinedouble', 'x1double', 'x2double', 'yColor', 'int', 'int', 'int', 'for', 'int', 'xpx', 'x', 'ex', 'x2', 'DASHLENGTH', 'graphicsdrawLinexpyx', 'void', 'plotLinedouble', 'x1double', 'y1double', 'x2double', 'void', 'plotXAxisTicksdouble', 'stepColor', 'cString', 'int', 'FontMetrics', 'for', 'double', 'x00', 'x', 'scaleMAXX', 'xstep', 'int', 'graphicsdrawLinepxpy', 'AXISTICKRADIUS', 'x', '00', '2', '1pxpy', 'AXISTICKRADIUS', 'x', '00', '2', 'if', 'x', '00', 'String', 'int', 'swfmstringWidthsx', 'graphicsdrawStringsxpx', 'swpy', 'AXISTICKRADIUS', 'for', 'double', 'x00', 'x', 'scaleMINX', 'xstep', 'int', 'graphicsdrawLinepxpy', 'AXISTICKRADIUSpxpy', 'graphicsdrawStringlabelgetLinearMapXscaleMAXX', '2py', '3', 'AXISTICKRADIUS', 'void', 'plotXYAxesColor', 'int', 'int', 'void', 'plotYAxisTicksdouble', 'stepColor', 'cString', 'int', 'FontMetrics', 'for', 'double', 'y00', 'y', 'scaleMAXY', 'step', 'ystep', 'int', 'graphicsdrawLinepx', 'AXISTICKRADIUS', 'y', '00', '2', '1pypx', 'AXISTICKRADIUS', 'y', '00', '2', 'if', 'y', '00', 'String', 'graphicsdrawStringsypx', 'AXISTICKRADIUS', 'fmstringWidthsy', '2py', 'for', 'double', 'y00', 'y', 'scaleMINY', 'ystep', 'int', 'graphicsdrawLinepx', 'AXISTICKRADIUSpypx', 'graphicsdrawStringlabelpx', 'AXISTICKRADIUS', 'fmstringWidthlabelgetLinearMapYscaleMAXY', '4', 'void', 'plotdouble', 'xdouble', 'void', 'plotdouble', 'xdouble', 'yColor', 'void', 'plotdouble', 'xdouble', 'yint', 'pColor', 'if', 'connectPointsEnabled', 'if', 'prevSet', 'else', 'int', 'int', 'int', 'rintMathroundp', 'pixeltype', 'graphicsfillArcpx', 'rpy', 'rpy', 'void', 'void', 'setAxisLabelsPrecisionDecimalFormat', 'dfint', 'iint', 'void', 'setBackgroundColor', 'void', 'setConnectPointsEnabledboolean', 'void', 'setForegroundColor', 'void', 'setImageQualityfloat', 'if', 'quality', '00f', 'quality', '10f', 'void', 'setPixelSizeint', 'void', 'setPixelTypeint', 'void', 'setScaledouble', 'if', 'scale', 'null', 'scalelength', 'thisscalelength', 'alphaxthisscaleMAXX', 'thisscaleMINX', 'alphaythisscaleMAXY', 'thisscaleMINY', 'void', 'setXAxisLabelsPrecisionint', 'iint', 'void', 'setXYAxesLabelsPrecisionint', 'xint', 'void', 'setYAxisLabelsPrecisionint', 'iint'])
#  list(['Check', 'static', 'boolean', 'boolean', 'Super', 'supnew', 'Sub', 'subnew', 'SystemoutprintlnsupgetName', 'SystemoutprintlnsubgetName', 'if', 'suptoStringequalsClass', 'Super', 'public34', 'protected33', 'private32', 'if', 'subtoStringequalsClass', 'Super', 'public804', 'protected803', 'private802', 'SystemoutprintlnSuper', 'prot', 'supgetProtected', 'priv', 'SystemoutprintlnSub', 'prot', 'subgetProtected', 'priv', 'if', 'supgetProtected', '33', 'supgetPrivate', '32', 'if', 'subgetProtected', '111', 'subgetPrivate', '105', 'SystemoutprintlnSubclass', 'test', 'error', 'error', 'return', 'static', 'boolean', 'boolean', 'Document', 'DocumentBuilder', 'DocumentBuilderFactory', 'try', 'boolean', 'if', 'result', 'else', 'SystemoutprintlnXML', 'StrictErrorChecking', 'test', 'error', 'error', 'catch', 'ParserConfigurationException', 'pce', 'return', 'static', 'boolean', 'SystemoutprintlnnChecking', 'boolean', 'boolean', 'boolean', 'try', 'int', 'anew', 'for', 'int', 'i0', 'i', '10', 'i', 'SystemoutprintlnError', 'array', 'bounds', 'not', 'catch', 'ArrayIndexOutOfBoundsException', 'e', 'finally', 'if', 'caughtIndex', 'Systemoutprintln1st', 'bounds', 'test', 'errortindex', 'exception', 'not', 'if', 'gotToFinally', 'Systemoutprintln1st', 'bounds', 'test', 'errortfinally', 'clause', 'not', 'if', 'caughtIndex', 'gotToFinally', 'Systemoutprintln1st', 'bounds', 'if', 'checkSubclassing', 'if', 'checkXMLErrorChecking', 'LoopBounds', 'mulenew', 'if', 'LoopBoundsgotError', 'Systemoutprintln2nd', 'bounds', 'else', 'Systemoutprintln2nd', 'bounds', 'PepTest', 'horsenew', 'if', 'horsegotError', 'if', 'error', 'SystemoutprintlnnINVALID', 'JVM', 'Check', 'detected', 'else', 'SystemoutprintlnnJVM', 'Check', 'return'])
#  list(['Report', 'String', 'return', 'void', 'printOtherPropertiesPrintStream', 'outprintlnH4Optional', 'InformationH4n', 'IThis', 'information', 'is', 'for', 'internal', 'documentation', 'purposesn', 'and', 'is', 'not', 'required', 'for', 'SPEC', 'reportingn', 'for', 'Enumeration', 'eresultspropertyNames', 'ehasMoreElements', 'String', 'if', 'keystartsWithconfigtestx', 'keystartsWithconfiginitial', 'String', 'if', 'keyequalsconfigtestxinternalReference', 'valuestartsWithhttp', 'valuestartsWithfile', 'valueA', 'HREF', 'value', 'value', 'outprintlnBR', 'key', 'void', 'printPrintStream', 'try', 'outprintlnHTMLHEADn', 'META', 'NAMEGENERATOR', 'CONTENT', 'SPEC', 'Java', 'Reportern', 'TITLE', 'name', 'TITLEn', 'outprintBODY', 'if', 'metricsvalid', 'else', 'outprintTABLE', 'WIDTH100n', 'TRTD', 'if', 'issue', 'null', 'issueequals', 'else', 'outprintFONT', 'if', 'metricsvalid', 'outprintFONT', 'SIZE2', 'outprintFONT', 'SIZE2', 'name', '2005FONTTDn', 'TD', 'COLSPAN2', 'ALIGNRIGHT', 'bgcolorFFFF00', 'FONT', 'SIZE2', 'COLOR000000BSPECjbb2005', 'bops', 'metric', 'SPECjbb2005', 'bopsJVM', 'metric', 'BFONTTDTRn', 'TRTD', 'COLSPAN3FONT', 'SIZE1', 'hardware', 'if', 'software', 'null', 'outprintTRTD', 'COLSPAN3FONT', 'SIZE1', 'software', 'BufferedReader', 'BufferedReader', 'TableGroupCompare', 'if', 'metrics2', 'null', 'innew', 'BufferedReadernew', 'StringReadernew', 'in2new', 'BufferedReadernew', 'StringReadernew', 'mnew', 'else', 'innew', 'BufferedReadernew', 'StringReadernew', 'in2new', 'BufferedReadernew', 'StringReadernew', 'mnew', 'if', 'metrics2', 'null', 'if', 'verbose', 'outprintlnHRFONT', 'outprintlnSPECjbb2005', 'Version', 'resultsgetconfigbenchmarkversionNA', 'resultsgetconfigbenchmarkversionDate', 'if', 'issue', 'null', 'issueequals', 'metricsvalid', 'outprintlnPublished', 'by', 'SPEC', 'issue', 'outprintlnReporting', 'page', 'Copyright', 'copy', '2005', 'SPEC', 'All', 'rights', 'reservedn', 'outprintln', 'outprintlnReporting', 'Page', 'Generator', 'if', 'echoRaw', 'resultsstoreoutRaw', 'outprintln', 'catch', 'Exception', 'e', 'JBButilgetLoglogLevelWARNINGError', 'void', 'printString', 'try', 'printnew', 'PrintStreamnew', 'BufferedOutputStreamnew', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'creating', 'output', 'Reportboolean', 'echoRawboolean', 'SPECInternalUseString', 'newsletterString', 'resultFileboolean', 'verboseString', 'resultFile2String', 'labelboolean', 'useHtmlString', 'try', 'StringReader', 'tisnew', 'StringReadernew', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'loading', 'titles', 'for', 'try', 'if', 'resultFile', 'null', 'resultsloadnew', 'else', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'reading', 'results', 'file', 'resultFile', 'metricsnew', 'try', 'if', 'resultFile2', 'null', 'metrics2new', 'else', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'reading', 'comparison', 'results', 'file', 'resultFile2', 'if', 'metrics2', 'null', 'else', 'thishardwareresultsgetconfighwvendor', 'if', 'metric', 'null', 'metric', 'if', 'metricsvalid', 'if', 'SPECInternalUse', 'metricsresultsbufappendnValid', 'run', 'Score', 'is', 'metric', 'else', 'if', 'metricsprintscore', 'metricsresultsbufappendINVALID', 'run', 'Score', 'is', 'metric', 'else', 'metricsresultsbufappendINVALID', 'run', 'preventing', 'score', 'thissoftwareresultsgetconfigswvendor', 'void', 'testBarPrintStream', 'out', 'throws', 'IOException', 'String', 'String', 'String', 'outprintlnTABLE', 'WIDTH100', 'BORDER1', 'CELLSPACING2', 'CELLPADDING0trn', 'td', 'width33bSPEC', 'license', 'b', 'license', 'tdn', 'td', 'width33bTested', 'by', 'b', 'testedBy', 'tdn', 'tdbTest', 'date', 'b', 'testDate', 'tdn'])
#  list(['Warehouse', 'int', 'return', 'District', 'getDistrictPtrbyte', 'inDistrictIdboolean', 'District', 'if', 'inDistrictId', '0', 'if', 'inDistrictId', 'distCount', 'return', 'District', 'getDistrictint', 'District', 'if', 'distId', '0', 'if', 'distId', 'distCount', 'return', 'synchronized', 'JBBDataStorage', 'return', 'void', 'initWarehouseCompany', 'inCompanyJBBDataStorage', 'inItemTableshort', 'districtsnew', 'addressnew', 'synchronized', 'void', 'String', 'for', 'byte', 'districtId1', 'districtId', 'companygetMaxDistrictsPerWarehouse', 'districtId', 'for', 'short', 'customerId1', 'customerId', 'companygetMaxCustomersPerDistrict', 'customerId', 'long', 'Customer', 'BigDecimal', 'historyDatanew', 'Date', 'creationtimenew', 'History', 'newHistorynew', 'void', 'int', 'Item', 'Stock', 'for', 'int', 'i1', 'i', 'numItems', 'i', 'newStocknew', 'void', 'removeOldestHistorySynch', 'Item', 'retrieveItemint', 'return', 'Stock', 'retrieveStockint', 'return', 'synchronized', 'void', 'setUsingRandomshort', 'int', 'namenew', 'float', 'taxRatenew', 'for', 'i0', 'i', 'distCount', 'i', 'byte', 'newDistrictIdbytei', 'District', 'newDistrictnew', 'synchronized', 'void', 'int', 'int', 'synchronized', 'void', 'trimOrdersForSteadyStateint', 'initialOrdersint', 'int', 'int', 'District', 'for', 'distId1', 'distId', 'distCount', 'distId', 'if', 'TransactionsteadyStateMem', 'currentDistrictremoveOldNewOrdersinitialOrders', 'void', 'updateHistoryHistory', 'updateHistorySynch', 'boolean', 'validDistrictbyte', 'District', 'int', 'for', 'i0', 'i', 'distCount', 'i', 'if', 'currentDistrictgetId', 'inDistrictId', 'return', 'return', 'WarehouseCompany', 'inCompanyJBBDataStorage', 'districtsnew', 'addressnew'])
#  list(['TableGroup', 'inReportProps', 'propsReportProps', 'titles', 'throws', 'IllegalArgumentException', 'String', 'String', 'try', 'while', 'lineinreadLine', 'null', 'if', 'linestartsWithTitle', 'else', 'if', 'linestartsWithTable', 'StringTokenizer', 'tokennew', 'int', 'int', 'boolean', 'freeFormIntegerparseInttokennextToken', 'if', 'group', '0', 'group', 'MAXGROUPS', 'column', '0', 'column', 'MAXCOLUMNS', 'throw', 'new', 'int', 'if', 'row', '0', 'row', 'MAXROWS', 'throw', 'new', 'tablesgroupcolumnrownew', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError'])
#  list(['NewOrder', 'void', 'synchronized', 'Order', 'Order', 'return', 'void', 'initNewOrderOrder', 'inOrderPtrint', 'inOrderIdbyte', 'inDistrictIdshort', 'if', 'JBButilgetLogisLoggableLevelFINEST', 'JBButilgetLogfinestNewOrderinitNewOrder', 'orderId', 'orderId', 'districtId', 'districtId', 'warehouseId', 'NewOrderOrder', 'inOrderPtrint', 'inOrderIdbyte', 'inDistrictIdshort'])
#  list(['JBBmain', 'void', 'callReporterString', 'outputdirectoryString', 'outRawFilenameString', 'outRawPrefixString', 'String', 'msgCalling', 'boolean', 'boolean', 'String', 'String', 'boolean', 'String', 'String', 'optooutputdirectory', 'Fileseparator', 'outRawPrefix', 'sequenceNumber', 'String', 'fileAsciioutputdirectory', 'Fileseparator', 'outRawPrefix', 'sequenceNumber', 'String', 'String', 'boolean', 'specreporterReport', 'try', 'TextiReport', 'arnew', 'catch', 'Exception', 'e', 'try', 'rnew', 'catch', 'Exception', 'e', 'JBButilgetLogwarningProducing', 'html', 'chart', 'in', 'report', 'instead', 'of', 'JPEG', 'see', 'Users', 'rnew', 'javalangInternalError', 'e', 'JBButilgetLogwarningProducing', 'html', 'chart', 'in', 'report', 'instead', 'of', 'JPEG', 'see', 'Users', 'rnew', 'javalangUnsatisfiedLinkError', 'e', 'JBButilgetLogwarningProducing', 'html', 'chart', 'in', 'report', 'instead', 'of', 'JPEG', 'see', 'Users', 'rnew', 'javalangError', 'e', 'JBButilgetLogwarningProducing', 'html', 'chart', 'in', 'report', 'instead', 'of', 'JPEG', 'see', 'Users', 'rnew', 'try', 'BufferedReader', 'AscBrnew', 'BufferedReadernew', 'String', 'while', 'sAscBrreadLine', 'null', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'opening', 'ASCII', 'output', 'SystemoutprintlnOutput', 'files', 'fileAscii', 'outRawFilename', 'SystemoutprintlnReporter', 'String', 'commandLineParserString', 'String', 'if', 'argslength', '0', 'else', 'if', 'args0equalsid', 'else', 'if', 'args0equalspropfile', 'if', 'argslength', '2', 'else', 'if', 'argslength', '1', 'SystemoutprintlnMissing', 'properties', 'file', 'Systemoutprintln', 'Parameters', 'propfile', 'propertiesfilename', 'id', 'else', 'if', 'argslength', '4', 'args2equalsid', 'else', 'SystemoutprintlnToo', 'many', 'Systemoutprintln', 'Parameters', 'propfile', 'propertiesfilename', 'id', 'else', 'SystemoutprintlnUnrecognized', 'command', 'line', 'parameter', 'Systemoutprintln', 'Parameters', 'propfile', 'return', 'void', 'DoARunCompany', 'myCompanyshort', 'numberofwarehousesint', 'rampuptimeint', 'short', 'myCompanysetPropOutputPrefixresulttest', 'testnum', 'SystemoutprintlnStart', 'User', 'JBButilgetLoginfoStart', 'User', 'try', 'for', 'whID1', 'whID', 'numberofwarehouses', 'whID', 'String', 'msg', 'started', 'user', 'thread', 'for', 'Warehouse', 'catch', 'javalangThreadDeath', 'e', 'try', 'JBButilgetLoglogLevelWARNINGERROR', 'A', 'thread', 'died', 'probably', 'out', 'of', 'memory', 'Increase', 'the', 'heap', 'size', 'and', 'run', 'catch', 'OutOfMemoryError', 'oome', 'SystemoutprintlnERROR', 'A', 'thread', 'died', 'probably', 'out', 'of', 'memory', 'Increase', 'the', 'heap', 'size', 'and', 'run', 'javalangOutOfMemoryError', 'e', 'try', 'JBButilgetLoglogLevelWARNINGERROR', 'Out', 'of', 'memory', 'error', 'caught', 'Increase', 'the', 'heap', 'size', 'and', 'run', 'catch', 'OutOfMemoryError', 'oome', 'SystemoutprintlnERROR', 'Out', 'of', 'memory', 'error', 'caught', 'Increase', 'the', 'heap', 'size', 'and', 'run', 'boolean', 'DoAValidationRunCompany', 'short', 'TransactionManager', 'transMgrnew', 'return', 'void', 'float', 'minbtpsfloatpropminBTPSRatio', '1000', 'propwaitTimePercent', '23', 'myCompanynew', 'if', 'propdeterministicRandomSeed', 'true', 'int', 'int', 'if', 'propsequenceOfWarehouses', 'null', 'for', 'numwhpropstartingNumberWarehouses', 'numwh', 'propendingNumberWarehouses', 'numwhpropincrementNumberWarehouses', 'if', 'runWarehousecurwarehousesnumwhminbtps', 'else', 'for', 'int', 'seqndx0', 'seqndx', 'propsequenceOfWarehouseslength', 'seqndx', 'if', 'runWarehousecurwarehousesnumwhminbtps', 'boolean', 'myCompanynew', 'long', 'boolean', 'return', 'void', 'Handler', 'for', 'Handler', 'logHandler', 'handlers', 'void', 'increaseNumWarehousesint', 'currentint', 'nextint', 'for', 'int', 'icurrent', '1', 'i', 'next', 'i', 'boolean', 'initApplicationLoggingString', 'StreamHandler', 'try', 'handlernew', 'StreamHandlernew', 'FileOutputStreamlogFileNamenew', 'catch', 'FileNotFoundException' ...
#  list(['MultiVMReporter', 'static', 'boolean', 'getOptString', 'try', 'for', 'int', 'i0', 'i', 'argslength', 'i', 'if', 'argsiequalsa', 'else', 'if', 'argsiequalse', 'else', 'if', 'argsiequalss', 'else', 'if', 'argsiequalsn', 'else', 'if', 'argsiequalso', 'else', 'if', 'argsiequalsr', 'else', 'if', 'argsiequalsl', 'else', 'if', 'argsiequalsp', 'else', 'throw', 'new', 'catch', 'ArrayIndexOutOfBoundsException', 'e', 'return', 'if', 'optr', 'null', 'return', 'else', 'return', 'static', 'void', 'mainString', 'if', 'getOptargs', 'if', 'opta', 'if', 'opto', 'null', 'optooptr', 'Fileseparator', 'MultiVMTxtReport', 'rnew', 'else', 'if', 'opto', 'null', 'optooptr', 'Fileseparator', 'MultiVMReport', 'rnew', 'static', 'void', 'SystemoutprintlnUsage', 'java', 'specreporterMultiVMReporter', 'optionsn', 'Required', 'options', 'aren', 'r', 'ResultsDir', 'Directory', 'with', 'results', 'filesn', 'Other', 'options', 'aren', 'a', 'Plain', 'ASCII', 'text', 'outputn', 'default', 'generate', 'HTML', 'output', 'with', 'JPG', 'graphn', 'e', 'Do', 'NOT', 'echo', 'raw', 'results', 'properties', 'in', 'HTML', 'outputn', 'default', 'raw', 'results', 'inserted', 'as', 'HTML', 'commentsn', 'o', 'Output', 'Output', 'file', 'for', 'generated', 'HTML', 'or', 'TXTn', 'default', 'indexhtml', 'for', 'HTML', 'MultiVMReporttxt', 'for', 'TXTn', 'NB', 'html', 'links', 'are', 'generated', 'as', 'relative', 'to', 'then', 'directory', 'with', 'results'])
#  list(['History', 'synchronized', 'String', 'buildDataString', 'warehouseNameString', 'datanew', 'StringwarehouseName', 'String', 'return', 'short', 'short', 'return', 'Date', 'Date', 'return', 'Historyshort', 'inCustomerIdbyte', 'inCustomerDistrictIdshort', 'inCustomerWarehouseIdbyte', 'inDistrictIdshort', 'inWarehouseIdDate', 'inDateBigDecimal', 'inAmountString', 'void', 'initHistoryshort', 'inCustomerIdbyte', 'inCustomerDistrictIdshort', 'inCustomerWarehouseIdbyte', 'inDistrictIdshort', 'inWarehouseIdDate', 'inDateBigDecimal', 'inAmountString'])
#  list(['Order', 'synchronized', 'void', 'dateOrderlinesDate', 'int', 'Orderline', 'if', 'JBButilgetLogisLoggableLevelFINEST', 'JBButilgetLogfinestOrderdateOrderlines', 'orderlineList', 'orderlineList', 'orderlineCount', 'for', 'i0', 'i', 'orderLineCount', 'i', 'if', 'JBButilgetLogisLoggableLevelFINEST', 'JBButilgetLogfinest', 'orderline', 'orderline', 'orderline', 'synchronized', 'short', 'short', 'return', 'synchronized', 'Customer', 'Customer', 'return', 'synchronized', 'Date', 'Date', 'return', 'synchronized', 'int', 'int', 'return', 'synchronized', 'short', 'short', 'return', 'synchronized', 'Orderline', 'if', 'JBButilgetLogisLoggableLevelFINEST', 'JBButilgetLogfinestOrdergetOrderlineList', 'orderlineList', 'return', 'synchronized', 'BigDecimal', 'BigDecimal', 'return', 'void', 'initOrderCompany', 'inCompanyint', 'inOrderIdbyte', 'inDistrictIdshort', 'inWarehouseIdshort', 'inCustomerIdCustomer', 'inCustomerPtrBigDecimal', 'inDistrictTaxRateBigDecimal', 'inWarehouseTaxRateBigDecimal', 'orderlineListnew', 'OrderlineTransactionaveOrderlines', 'if', 'JBButilgetLogisLoggableLevelFINEST', 'JBButilgetLogfinestOrderinitOrder', 'orderlineList', 'entryDateTimenew', 'OrderCompany', 'inCompanyint', 'inOrderIdbyte', 'inDistrictIdshort', 'inWarehouseIdshort', 'inCustomerIdCustomer', 'inCustomerPtrBigDecimal', 'inDistrictTaxRateBigDecimal', 'inWarehouseTaxRateBigDecimal', 'synchronized', 'boolean', 'processLinesWarehouse', 'inWarehousePtrshort', 'numberoforderlinesboolean', 'short', 'boolean', 'BigDecimal', 'for', 'short', 'LineNumber1', 'LineNumber', 'numberoforderlines', 'LineNumber', 'Orderline', 'newOrderlinenew', 'if', 'JBButilrandom1100warehouseId', '1', 'companygetMaxWarehouses', '1', 'while', 'supplyWarehouseId', 'warehouseId', 'if', 'newOrderlinevalidateAndProcessinWarehousePtr', 'else', 'BigDecimal', 'return', 'synchronized', 'void', 'setAllLocalboolean', 'synchronized', 'void', 'setCarrierIdshort', 'synchronized', 'void', 'setEntryDateTimeDate'])
#  list(['TextColumn', 'void', 'addString', 'blocksaddElementnew', 'TextColumn', 'joinTextColumn', 'return', 'TextColumn', 'joinTextColumn', 'rightString', 'int', 'int', 'int', 'TextColumn', 'combinednew', 'TextColumnwidth', 'columnSeparatorlength', 'for', 'int', 'i0', 'i', 'n', 'i', 'if', 'nleft', 'nright', 'TextBlock', 'emptynew', 'for', 'int', 'in', 'i', 'nright', 'i', 'else', 'TextBlock', 'emptynew', 'for', 'int', 'in', 'i', 'nleft', 'i', 'return', 'TextBlock', 'TextBlock', 'mergednew', 'for', 'Enumeration', 'eblockselements', 'ehasMoreElements', 'return', 'int', 'return', 'TextColumnint', 'TextColumnint', 'widthString'])
#  list(['LoopBounds', 'int', 'constraintAtint', 'Object', 'if', 'o', 'instanceof', 'Integer', 'return', 'else', 'return', 'void', 'for', 'int', 'i0', 'i', 'size', 'i', 'SystemoutprintconstraintAti', 'vnew', 'int', 'int', 'for', 'int', 'i0', 'i', '20', 'i', 'int', 'ff0', 'static', 'void', 'new', 'String', 'try', 'Class', 'Object', 'if', 'o', 'instanceof', 'LoopBounds', 'Systemoutprintlnname', 'is', 'not', 'a', 'catch', 'Exception', 'e', 'SystemoutprintlnError'])
#  list(['NewOrderTransaction', 'NewOrderTransactionCompany', 'inCompanyshort', 'orderLognew', 'xmlOrderLognew', 'initLognew', 'synchronized', 'void', 'long', 'Customer', 'BigDecimal', 'thisOrdernew', 'Date', 'orderdatenew', 'if', 'orderId', 'companygetInitialOrders', 'companygetInitialNewOrders', 'byte', 'if', 'orderId', 'companygetInitialOrders', 'companygetInitialNewOrders', 'NewOrder', 'theNewOrdernew', 'synchronized', 'void', 'setDistrictandCustomerbyte', 'inDistrictIdshort'])
#  list(['TransactionLogBuffer', 'void', 'int', 'x', 'for', 'y0', 'y', 'rows', 'y', 'for', 'x0', 'x', 'cols', 'x', 'screenBufyx', 'synchronized', 'void', 'int', 'x', 'int', 'int', 'char', 'try', 'for', 'y0', 'y', 'rows', 'y', 'if', 'len', '0', 'for', 'x0', 'x', 'len', 'x', 'catch', 'IOException', 'e', 'SystemoutprintlnIOException', 'ScreenException', 'exceptnew', 'ScreenExceptionscreen', 'write', 'throw', 'void', 'displayPrintStream', 'int', 'x', 'int', 'char', 'try', 'for', 'y0', 'y', 'rows', 'y', 'if', 'len', '0', 'String', 'slinenew', 'else', 'catch', 'Exception', 'e', 'SystemoutprintlnIOException', 'ScreenException', 'exceptnew', 'ScreenExceptionfile', 'write', 'throw', 'int', 'return', 'String', 'getLineint', 'return', 'new', 'final', 'void', 'privCharFillchar', 'cint', 'xint', 'yint', 'int', 'for', 'ix', 'i', 'x', 'len', 'i', 'final', 'void', 'privCharchar', 'cint', 'xint', 'final', 'int', 'privIntLeadingZerosint', 'izint', 'xint', 'yint', 'int', 'i', 'dividend', 'char', 'for', 'ix', 'len', '1', 'i', 'x', 'i', 'dividendiz', 'remainderiz', 'dividend', 'screenLineichar0', 'return', 'final', 'int', 'privIntint', 'izchar', 'signint', 'xint', 'yint', 'int', 'i', 'dividend', 'char', 'ix', 'len', 'do', 'dividendiz', 'remainderiz', 'dividend', 'screenLineichar0', 'while', 'i', 'x', 'iz', 'if', 'i', 'x', 'else', 'if', 'sign', 'for', 'i', 'x', 'i', 'screenLinei', 'return', 'final', 'int', 'privIntint', 'izint', 'xint', 'yint', 'int', 'i', 'dividend', 'char', 'char', 'sign', 'if', 'iz', '0', 'ix', 'len', 'do', 'dividendiz', 'remainderiz', 'dividend', 'screenLineichar0', 'while', 'i', 'x', 'iz', 'if', 'i', 'x', 'else', 'if', 'sign', 'for', 'i', 'x', 'i', 'screenLinei', 'return', 'final', 'long', 'privLonglong', 'izint', 'xint', 'yint', 'int', 'long', 'dividend', 'char', 'char', 'sign', 'if', 'iz', '0', 'ix', 'len', 'do', 'dividendiz', 'remainderiz', 'dividend', 'screenLineichar0', 'while', 'i', 'x', 'iz', 'if', 'i', 'x', 'else', 'if', 'sign', 'for', 'i', 'x', 'i', 'screenLinei', 'return', 'final', 'void', 'privSubstringString', 'sint', 'xint', 'yint', 'offint', 'int', 'int', 'if', 'len', 'slength', 'off', 'slenslength', 'else', 'sgetCharsoffoff', 'if', 'slen', 'len', 'for', 'ix', 'slen', 'i', 'x', 'len', 'i', 'screenBufyi', 'final', 'void', 'privTextString', 'sint', 'xint', 'yint', 'int', 'int', 'if', 'len', 'slength', 'else', 'if', 'slen', 'len', 'for', 'ix', 'slen', 'i', 'x', 'len', 'i', 'screenBufyi', 'final', 'void', 'privTextString', 'sint', 'xint', 'yint', 'lenshort', 'int', 'i', 'int', 'if', 'len', 'slength', 'if', 'align', 'alignRight', 'firstx', 'len', 'else', 'if', 'align', 'alignCenter', 'firstx', 'len', 'slen', 'else', 'else', 'if', 'first', 'x', 'for', 'ix', 'i', 'first', 'i', 'screenBufyi', 'if', 'slen', 'len', 'for', 'ifirst', 'slen', 'i', 'x', 'len', 'i', 'screenBufyi', 'void', 'putCharFillchar', 'cint', 'xint', 'yint', 'int', 'if', 'y', '0', 'y', 'rows', 'ScreenException', 'enew', 'ScreenExceptionScreen', 'row', 'IntegertoStringy', 'out', 'of', 'throw', 'else', 'if', 'x', '0', 'x', 'cols', 'ScreenException', 'enew', 'ScreenExceptionScreen', 'column', 'IntegertoStringx', 'out', 'of', 'throw', 'else', 'if', 'x', 'len', 'cols', 'ScreenException', 'enew', 'ScreenExceptionScreen', 'length', 'IntegertoStringlen', 'exceeds', 'left', 'throw', 'else', 'if', 'x', 'len', 'lineEndy', 'lineEndyx', 'void', 'putCharchar', 'cint', 'xint', 'if', 'y', '0', 'y', 'rows', 'ScreenException', 'enew', 'ScreenExceptionScreen', 'row', 'IntegertoStringy', 'out', 'of', 'throw', 'else', 'if', 'x', '0', 'x', 'cols', 'ScreenException', 'enew', 'ScreenExceptionScreen', 'column', 'IntegertoStringx', 'out', 'of', 'throw', 'else', 'if', 'x', '1', 'lineEndy', 'lineEndyx', 'void', 'putDateDate', 'dint', 'xint', 'yint', 'if', 'y', '0', 'y', 'rows', 'ScreenException', 'enew', 'ScreenExceptionScreen', 'row', 'IntegertoStringy', 'out', 'of', 'throw', 'else', 'if', 'x', '0', 'x', 'cols', 'ScreenException', 'enew', 'ScreenExceptionScreen', 'column', 'Integerto ...
#  list(['MultiVMReport', 'boolean', 'acceptFile', 'dirString', 'return', 'namestartsWithfilePrefix', 'void', 'Enumeration', 'PrintStream', 'ReportProps', 'totalPropsnew', 'String', 'name', 'String', 'singleRawFileNameoutputdirectory', 'Fileseparator', 'File', 'singleRawFilenew', 'if', 'singleRawFileexists', 'for', 'Enumeration', 'eresults0propertyNames', 'ehasMoreElements', 'if', 'namestartsWithresult', 'totalPropsputglobal', 'for', 'int', 'i0', 'i', 'resultslength', 'i', 'for', 'Enumeration', 'eresultsipropertyNames', 'ehasMoreElements', 'if', 'namestartsWithresult', 'totalPropsputi', '1', 'try', 'outRawFilenew', 'Set', 'Vector', 'keyvecnew', 'for', 'int', 'i0', 'i', 'keyvecsize', 'i', 'String', 'String', 'outRawFileprintlnpropsKey', 'catch', 'FileNotFoundException', 'e', 'JBButilgetLoglogLevelWARNINGERROR', 'file', 'not', 'found', 'JBBReportFilenameFilterString', 'prefixString', 'fileSuffixStartfilePrefixLen', 'MultiVMReportString', 'outputdirectoryboolean', 'SPECInternalUseString', 'newsletterboolean', 'useHtmlboolean', 'MultiVMReportString', 'outputdirectoryboolean', 'SPECInternalUseString', 'newsletterboolean', 'useHtmlboolean', 'echoRawString', 'labelImgString', 'String', 'File', 'dirnew', 'if', 'direxists', 'SystemoutprintlnError', 'file', 'outputdirectory', 'doesnt', 'if', 'dirisDirectory', 'SystemoutprintlnError', 'file', 'outputdirectory', 'is', 'not', 'a', 'FilenameFilter', 'filternew', 'File', 'filternew', 'resultsnew', 'metricsnew', 'graphTablenew', 'metricnew', 'labelnew', 'try', 'StringReader', 'tisnew', 'StringReadernew', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'loading', 'titles', 'for', 'double', 'long', 'long', 'boolean', 'for', 'int', 'i0', 'i', 'resultFileslength', 'i', 'resultsinew', 'labeliresultFilesigetNamesubstringprefixlengthprefixlength', 'if', 'SPECInternalUse', 'labeliprefix', 'try', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'reading', 'results', 'file', 'resultFilesi', 'metricsinew', 'try', 'catch', 'NumberFormatException', 'e', 'try', 'catch', 'NumberFormatException', 'e', 'if', 'isMetricsDouble', 'metric2Metricsformatsum', 'thishardwareresults0getconfighwvendor', 'thissoftwareresults0getconfigswvendor'])
#  list(['HTMLTableGraphGenerator3', 'void', 'addXYPairdouble', 'if', 'xypair', 'null', 'xypairlength', 'DIM', 'String', 'String', 'if', 'xypairscontainsKeylmx', 'xypairsputlmxnew', 'void', 'void', 'String', 'StringBuffer', 'bufnew', 'bufappendTABLE', 'BORDER1', 'CELLSPACING0', 'bufappendTABLE', 'BORDER0', 'CELLSPACING', 'pad', 'CELLPADDING', 'pad', 'bgcolorEnabled', 'BGCOLOR', 'bgcolor', 'WIDTH', 'sizewidth', 'pixelsize', 'for', 'int', 'y0', 'y', 'sizeheight', 'y', 'if', 'y', '0', 'bufappendTD', 'ALIGNcenter', 'VALIGNmiddle', 'ROWSPAN', 'sizeheight', 'BGCOLORffffff', 'yaxis', 'if', 'y', '10', '0', 'double', 'String', 'labeldfyformatdreplace', 'String', 'colord', '0', 'COLORff0000', 'bufappendTD', 'BGCOLORwhite', 'NOWRAP', 'ROWSPAN10', 'ALIGNright', 'VALIGNtop', 'FONT', 'SIZE1', 'color', 'label', 'for', 'int', 'x0', 'x', 'sizewidth', 'x', 'String', 'String', 'String', 'if', 'xypairscontainsKeysx', 'Vector', 'Enumeration', 'while', 'ehasMoreElements', 'String', 'if', 'svyequalssy', 'bufappendTD', 'WIDTH', 'pixelsize', 'pixelcolorEnabled', 'plotequals', 'BGCOLOR', 'pixelcolor', 'plot', 'bufappendTRTD', 'BGCOLORffffff', 'COLSPAN2', 'for', 'int', 'x0', 'x', 'sizewidth', 'x', 'if', 'x', '10', '0', 'double', 'String', 'labeldfxformatdreplace', 'String', 'colord', '0', 'COLORff0000', 'bufappendTD', 'ALIGNleft', 'BGCOLORwhite', 'NOWRAP', 'COLSPAN10', 'VALIGNtop', 'FONT', 'SIZE1', 'color', 'label', 'bufappendTRTRTD', 'COLSPAN', 'sizewidth', 'ALIGNcenter', 'BGCOLORffffff', 'xaxis', 'return', 'void', 'generateString', 'if', 'filename', 'null', 'try', 'FileWriter', 'fwnew', 'catch', 'IOException', 'ioe', 'JBButilgetLoglogLevelWARNINGIOException', 'Exception', 'e', 'JBButilgetLoglogLevelWARNINGException', 'double', 'getInverseLinearMapXint', 'return', 'scaleMINX', 'x', 'double', 'getInverseLinearMapYint', 'return', 'scaleMAXY', 'y', 'boolean', 'return', 'boolean', 'return', 'void', 'setAxesLabelsPrecisionint', 'xint', 'void', 'setAxesLabelsString', 'xaxisString', 'if', 'yaxislength', '1', 'char', 'for', 'int', 'i0', 'i', 'clength', 'i', 'yaxisnbsp', 'ci', 'void', 'setBackgroundColorEnabledboolean', 'void', 'setBackgroundColorColor', 'if', 'c', 'null', 'void', 'setForegroundColorColor', 'if', 'c', 'null', 'void', 'setPixelBorderColorEnabledboolean', 'void', 'setPixelBorderColorColor', 'if', 'c', 'null', 'void', 'setPixelImageString', 'pixelIMG', 'SRC', 'pixel', 'WIDTH', 'pixelsize', 'HEIGHT', 'pixelsize', 'void', 'setPixelPadSizeint', 'void', 'setTableSizeDimension', 'if', 'size', 'null', 'void', 'setXYPairsdouble', 'if', 'xypairs', 'null', 'for', 'int', 'i0', 'i', 'xypairslength', 'i', 'void', 'setXYPairsVector', 'if', 'xypairs', 'null', 'Enumeration', 'while', 'ehasMoreElements', 'String', 'toHexStringColor', 'return', 'toHexStringcgetRed', 'toHexStringcgetGreen', 'String', 'toHexStringint', 'String', 'return', 'slength', '1', '0', 's'])
#  list(['TextBlock', 'void', 'addRightString', 'int', 'int', 'Outer', 'while', 'len', 'i', 'width', 'while', 'textcharAti', 'if', 'len', 'i', 'width', 'break', 'int', 'jtextlastIndexOf', 'while', 'j', 'i', 'width', 'jtextlastIndexOf', 'j', 'if', 'j', 'i', 'linesaddElementtextsubstringii', 'else', 'ij', 'void', 'addTextBlock', 'for', 'EnumerationString', 'eblocklineselements', 'ehasMoreElements', 'TextBlock', 'joinTextBlock', 'return', 'TextBlock', 'joinTextBlock', 'rightString', 'int', 'int', 'int', 'TextBlock', 'combinednew', 'TextBlockwidth', 'columnSeparatorlength', 'for', 'int', 'i0', 'i', 'n', 'i', 'combinedlinesaddElementStringlineselementAti', 'columnSeparator', 'if', 'nleft', 'nright', 'for', 'int', 'in', 'i', 'nright', 'i', 'combinedlinesaddElementspaces', 'columnSeparator', 'else', 'for', 'int', 'in', 'i', 'nleft', 'i', 'combinedlinesaddElementStringlineselementAti', 'columnSeparator', 'return', 'String', 'justifyLeftString', 'ss', 'return', 'static', 'String', 'justifyLeftString', 'sint', 'int', 'if', 'slen', 'width', 'return', 's', 'rep', 'width', 'else', 'return', 'String', 'justifyRightString', 'sspaces', 'int', 'return', 'ssubstringslen', 'static', 'String', 'justifyRightString', 'sint', 'int', 'if', 'slen', 'width', 'return', 'rep', 'width', 'slen', 'else', 'return', 'ssubstringslen', 'static', 'String', 'repString', 'sint', 'StringBuffer', 'bufnew', 'for', 'int', 'i0', 'i', 'n', 'i', 'return', 'TextBlockint', 'spacesrep', 'TextBlockint', 'widthString', 'spacesrep'])
#  list(['CustomerReportTransaction', 'CustomerReportTransactionCompany', 'inCompanyshort', 'customerLognew', 'xmlCustomerLognew', 'initLognew', 'void', 'customerLogputTextCUSTOMER', 'customerLogputTextLast', 'customerLogputTextLast'])
#  list(['TimerData', 'synchronized', 'void', 'accumulateTransactionStatslong', 'if', 'transactioncount', 'mintransactioncount', 'if', 'transactioncount', 'maxtransactioncount', 'void', 'timerLognew', 'timerLogputTextTOTALS', 'int', 'int', 'textlength1', 'versionlength', '1', '25', 'int', 'filllength79', 'textlength', 'timerLogputTextJBBmainVersionfilllength', 'timerLogputTextResults', 'time', 'in', 'secondsfilllength', '1', 'versionlength', 'timerLogputCharFillfilllength', '1', 'versionlength', '1', '25', 'timerLogputTextNew', 'timerLogputTextStock', 'timerLogputTextCust', 'timerLogputTextthroughput', 'timerLogputTextSPECjbb2005', 'synchronized', 'void', 'for', 'int', 'i0', 'i', 'TransactionmaxTxnTypes', 'i', 'if', 'transactionCounti', '0', 'averageTimeifloattotalTimei', 'floattransactionCounti', 'standardDeviationTimeiMathsqrtdoubletransactionCounti', 'doubletotalTimeSquarei', 'doubletotalTimei', 'doubletotalTimei', 'doubletransactionCounti', 'doubletransactionCounti', 'coefficientOfVariationTimei1000', 'standardDeviationTimei', 'doubletotalTimei', 'else', 'synchronized', 'void', 'displayResultsString', 'titlelong', 'totalMemlong', 'long', 'usedMemtotalMem', 'double', 'totalMBdoubletotalMem', 'double', 'usedMBdoubleusedMem', 'timerLogputTextHeap', 'timerLogputText', 'synchronized', 'void', 'long', 'diffmaxtransactioncount', 'float', 'diffpct100', 'floatdiff', 'void', 'formatResultsTransactionLogBuffer', 'timerLogputDoubletotalTimeTransactionneworder', 'timerLogputDoubleminimumTimeTransactionneworder', 'timerLogputDoublemaximumTimeTransactionneworder', 'timerLogputDoubletotalTimeTransactionpayment', 'timerLogputDoubleminimumTimeTransactionpayment', 'timerLogputDoublemaximumTimeTransactionpayment', 'timerLogputDoubletotalTimeTransactionorderstatus', 'timerLogputDoubleminimumTimeTransactionorderstatus', 'timerLogputDoublemaximumTimeTransactionorderstatus', 'timerLogputDoubletotalTimeTransactiondelivery', 'timerLogputDoubleminimumTimeTransactiondelivery', 'timerLogputDoublemaximumTimeTransactiondelivery', 'timerLogputDoubletotalTimeTransactionstocklevel', 'timerLogputDoubleminimumTimeTransactionstocklevel', 'timerLogputDoublemaximumTimeTransactionstocklevel', 'timerLogputDoubletotalTimeTransactioncustreport', 'timerLogputDoubleminimumTimeTransactioncustreport', 'timerLogputDoublemaximumTimeTransactioncustreport', 'synchronized', 'double', 'double', 'return', 'synchronized', 'long', 'getMaximumTimeint', 'long', 'return', 'synchronized', 'long', 'long', 'return', 'synchronized', 'long', 'getMenuWaitTimeint', 'long', 'return', 'synchronized', 'long', 'getMinimumTimeint', 'long', 'return', 'synchronized', 'long', 'long', 'return', 'synchronized', 'long', 'getThinkingWaitTimeint', 'long', 'return', 'synchronized', 'long', 'getTotalTimeSquareint', 'long', 'return', 'synchronized', 'long', 'getTotalTimeint', 'long', 'return', 'synchronized', 'double', 'double', 'return', 'synchronized', 'long', 'getTransactionCountint', 'long', 'return', 'synchronized', 'long', 'getTypingWaitTimeint', 'long', 'return', 'synchronized', 'long', 'long', 'tempnew', 'return', 'void', 'int', 'waittimesmenunew', 'waittimestypingnew', 'waittimesthinkingnew', 'transactionCountnew', 'totalTimenew', 'minimumTimenew', 'maximumTimenew', 'averageTimenew', 'totalTimeSquarenew', 'standardDeviationTimenew', 'coefficientOfVariationTimenew', 'for', 'i0', 'i', 'TransactionmaxTxnTypes', 'i', 'synchronized', 'void', 'propResultsString', 'prefixPrintStream', 'outprintlnprefix', 'newordercount', 'outprintlnprefix', 'newordertotaltime', 'totalTimeTransactionneworder', 'outprintlnprefix', 'neworderminimumtime', 'minimumTimeTransactionneworder', 'outprintlnprefix', 'newordermaximumtime', 'maximumTimeTransactionneworder', 'outprintlnprefix', 'neworderaveragetime', 'outprintlnprefix', 'neworderstddevtime', 'standardDeviationTimeTransactionneworder', 'outprintlnprefix', 'newordercoeffvartime', 'outprintlnprefix', 'paymentcount', 'outprintlnprefix', 'paymenttotaltime', 'totalTimeTrans ...
#  list(['Result', 'String', 'detailRowint', 'StringBuffer', 'bufnew', 'bufappend', 'TD', 'ALIGNRIGHT', 'Runtransactionn', 'bufappend', 'TD', 'ALIGNRIGHT', 'runncount', 'bufappend', 'TD', 'ALIGNRIGHT', 'Metricsformatrunntotaltime', 'bufappend', 'TD', 'ALIGNRIGHT', 'Metricsformatrunnmaximumtime', 'return', 'double', 'return', 'long', 'return', 'double', 'return', 'double', 'return', 'long', 'return', 'long', 'return', 'double', 'return', 'ResultString', 'nameReportProps', 'referenceTimepropsgetDoubleconfig', 'name', 'if', 'maxBarWidth', '0', 'VectorRun', 'rvnew', 'scorepropsgetDoubleresult', 'name', 'warehousespropsgetIntresult', 'name', 'elapsedpropsgetDoubleresult', 'name', 'heapsizepropsgetDoubleresult', 'name', 'heapusedpropsgetDoubleresult', 'name', 'if', 'jvminstances', '1', 'startrampuptimemillisecondspropsgetLongresult', 'name', 'endrampdowntimemillisecondspropsgetLongresult', 'name', 'starttimemillisecondspropsgetLongresult', 'name', 'endtimemillisecondspropsgetLongresult', 'name', 'minthreadtransactionspropsgetDoubleresult', 'name', 'maxthreadtransactionspropsgetDoubleresult', 'name', 'Run', 'for', 'int', 'i0', 'i', '6', 'i', 'rnew', 'runnew', 'if', 'runlength', '0', 'invalidReasonappendname', 'was', 'not', 'else', 'for', 'int', 'i0', 'i', 'runlength', 'i', 'double', 'return', 'String', 'shiftedtoRowint', 'StringBuffer', 'bufnew', 'bufappend', 'TD', 'ALIGNRIGHT', 'intwarehouses', 'bufappend', 'TD', 'bufappend', 'TD', 'bufappend', 'TD', 'ALIGNRIGHT', 'Metricsformatscore', 'if', 'whAtPeak', 'intwarehouses', 'intwarehouses', '2', 'whAtPeak', 'bufappend', 'TD', 'ALIGNRIGHT', 'else', 'bufappend', 'TD', 'ALIGNRIGHT', 'nbsp', 'return', 'long', 'return', 'String', 'StringBuffer', 'bufnew', 'if', 'runlength', '0', 'bufappend', 'TD', 'name', 'bufappend', 'TD', 'COLSPAN8Inot', 'else', 'bufappend', 'TD', 'VALIGNTOP', 'ALIGNRIGHT', 'ROWSPAN', 'runlength', 'intwarehouses', 'bufappend', 'TD', 'VALIGNTOP', 'ALIGNRIGHT', 'ROWSPAN', 'runlength', 'Metricsformatscore', 'bufappend', 'TD', 'VALIGNTOP', 'ALIGNRIGHT', 'ROWSPAN', 'runlength', 'Metricsformatheapsize', 'bufappend', 'TD', 'VALIGNTOP', 'ALIGNRIGHT', 'ROWSPAN', 'runlength', 'Metricsformatheapused', 'bufappend', 'TD', 'VALIGNTOP', 'ALIGNCENTER', 'ROWSPAN', 'runlength', 'Metricsformat100', 'maxthreadtransactions', 'minthreadtransactions', 'maxthreadtransactions', 'bufappend', 'TD', 'VALIGNTOP', 'ALIGNRIGHT', 'ROWSPAN', 'runlength', 'Metricsformat01', 'elapsed', '1000', 'measint', 'measint', 'for', 'int', 'i1', 'i', 'runlength', 'i', 'return', 'String', 'toFirstRowint', 'StringBuffer', 'bufnew', 'bufappend', 'TD', 'ALIGNRIGHT', 'intwarehouses', 'bufappend', 'TD', 'ALIGNRIGHT', 'Metricsformatscore', 'if', 'whAtPeak', 'intwarehouses', 'intwarehouses', '2', 'whAtPeak', 'bufappend', 'TD', 'ALIGNRIGHT', 'else', 'bufappend', 'TD', 'ALIGNRIGHT', 'nbsp', 'bufappend', 'TD', 'ALIGNRIGHT', 'nbsp', 'bufappend', 'TD', 'ALIGNRIGHT', 'nbsp', 'return', 'String', 'toRowint', 'StringBuffer', 'bufnew', 'bufappend', 'TD', 'ALIGNRIGHT', 'intwarehouses', 'bufappend', 'TD', 'ALIGNRIGHT', 'Metricsformatscore', 'if', 'whAtPeak', 'intwarehouses', 'intwarehouses', '2', 'whAtPeak', 'bufappend', 'TD', 'ALIGNRIGHT', 'else', 'bufappend', 'TD', 'ALIGNRIGHT', 'return', 'String', 'TwoRowResult', 'result2Metrics', 'metrics2int', 'whAtPeakint', 'StringBuffer', 'bufnew', 'bufappend', 'TD', 'ALIGNRIGHT', 'intwarehouses', 'bufappend', 'TD', 'ALIGNRIGHT', 'Metricsformatscore', 'if', 'whAtPeak', 'intwarehouses', 'intwarehouses', '2', 'whAtPeak', 'bufappend', 'TD', 'ALIGNRIGHT', 'else', 'bufappend', 'TD', 'ALIGNRIGHT', 'nbsp', 'bufappend', 'TD', 'ALIGNRIGHT', 'Metricsformatmetrics2scoreatwhintwarehouses', 'if', 'whAtPeak2', 'warehouses', 'warehouses', '2', 'whAtPeak2', 'bufappend', 'TD', 'ALIGNRIGHT', 'else', 'bufappend', 'TD', 'ALIGNRIGHT', 'nbsp', 'return', 'int', 'return'])
#  list(['digestExpected', 'byte', 'return'])
#  list(['Table', 'String', 'expandNString', 'StringBuffer', 'sbnew', 'char', 'nbnew', 'boolean', 'for', 'int', 'i0', 'i', 'nblength', '1', 'i', 'if', 'nbi', 'nbi', '1', 'n', 'else', 'if', 'sub', 'sbappendnbnblength', 'return', 'String', 'insertBreakAfterColonsString', 'StringBuffer', 'sbnew', 'char', 'cnew', 'for', 'int', 'i0', 'i', 'clength', 'i', 'if', 'i', '1', 'ci', 'ci', 'if', 'ci', '2', 'ci', '2', 'return', 'hBufferedReader', 'inReportProps', 'propsReportProps', 'titlesboolean', 'itemsnew', 'String', 'try', 'while', 'lineinreadLine', 'null', 'if', 'lineequals', 'catch', 'IOException', 'e'])
#  list(['TextMetrics', 'String', 'StringBuffer', 'bufnew', 'String', 'if', 'errormessages', 'null', 'bufappendValid', 'run', 'no', 'else', 'TextBlock', 'messagesnew', 'TextBlock', 'whnew', 'TextBlock', 'thrpnew', 'messagesaddn', 'SPEC', 'for', 'int', 'i0', 'i', 'resultlength', 'i', 'if', 'expectedPeakWh', 'resultiwarehouses', 'resultiwarehouses', '2', 'expectedPeakWh', 'whaddRight', 'else', 'whaddRight', 'messagesaddwhjointhrp', 'return', 'TextMetricsReportProps', 'propsboolean'])
#  list(['Customer', 'synchronized', 'void', 'adjustBalanceBigDecimal', 'addressnew', 'sincenew', 'synchronized', 'BigDecimal', 'BigDecimal', 'return', 'synchronized', 'BigDecimal', 'return', 'String', 'String', 'if', 'credit1', 'G', 'else', 'return', 'synchronized', 'String', 'String', 'return', 'BigDecimal', 'return', 'byte', 'return', 'String', 'return', 'String', 'return', 'synchronized', 'Order', 'Order', 'return', 'String', 'return', 'String', 'return', 'Date', 'return', 'short', 'return', 'synchronized', 'void', 'increaseYTDBigDecimal', 'synchronized', 'void', 'synchronized', 'void', 'synchronized', 'void', 'setUsingRandomshort', 'inCustomerIdshort', 'inWarehouseIdbyte', 'firstNamenew', 'middleNamenew', 'phonenew', 'if', 'JBButilrandom110warehouseId', '1', 'else', 'float', 'discountnew', 'datanew', 'synchronized', 'void', 'updateCustomerDataString', 'String', 'if', 'oldDatalength', 'newDatalength', '500', 'datanew', 'StringnewData', 'else', 'String', 'shiftDataoldDatasubstring0500', 'datanew', 'StringnewData'])
#  list(['PaymentTransaction', 'PaymentTransactionCompany', 'inCompanyshort', 'paymentLognew', 'xmlPaymentLognew', 'initLognew', 'void', 'paymentLogputTextAmount', 'paymentLogputTextNew', 'paymentLogputTextCredit'])
#  list(['Controller', 'static', 'boolean', 'initOutputDirString', 'File', 'outputdirectoryfilenew', 'if', 'outputdirectoryfileexists', 'if', 'outputdirectoryfileisDirectory', 'SystemoutprintlnERROR', 'Specified', 'inputoutputdirectory', 'is', 'not', 'a', 'directory', 'return', 'else', 'if', 'outputdirectoryfilemkdirs', 'SystemoutprintlnERROR', 'Cannot', 'create', 'inputoutputdirectory', 'return', 'return', 'static', 'void', 'JBBProperties', 'propnew', 'if', 'propgetProps', 'SystemoutprintlnERROR', 'Properties', 'File', 'error', 'please', 'start', 'if', 'outputDir', 'null', 'int', 'int', 'if', 'propsequenceOfWarehouses', 'null', 'seqLenpropendingNumberWarehouses', 'propstartingNumberWarehouses', 'propincrementNumberWarehouses', 'sequenceOfWarehousesnew', 'for', 'int', 'numwhpropstartingNumberWarehouses', 'numwh', 'propendingNumberWarehouses', 'numwhpropincrementNumberWarehouses', 'else', 'sequenceOfWarehousesnew', 'static', 'void', 'RunSequencer', 'subdirRsnew', 'runOutputSubDiroutputDir', 'Fileseparator', 'SPECjbbMultiJVM', 'if', 'initOutputDirrunOutputSubDir'])
# ...
#  list(['Company', 'synchronized', 'void', 'addWarehouseThreadTransactionManager', 'long', 'buildUniqueCustomerKeyshort', 'warehouseIdbyte', 'districtIdshort', 'long', 'keykey', 'keykey', 'return', 'SystemoutprintlnConstructing', 'the', 'company', 'now', 'warehouseContainersnew', 'warehouseTablenew', 'timerdataTablenew', 'companyTimerDatanew', 'initThreadsStateChangenew', 'initThreadsCountMonitornew', 'threadsDoneCountMonitornew', 'stopThreadsCountMonitornew', 'warehouseThreadsnew', 'void', 'displayResultTotalsboolean', 'short', 'TimerData', 'initThreadsStateChange', 'while', 'initThreadsCount', 'MaxWarehouses', 'try', 'catch', 'InterruptedException', 'e', 'if', 'JBBmainmultiJVMMode', 'SystemoutprintlnJBBmaininstanceId', 'JBBmainsocOutprintlnJBBmaininstanceId', 'String', 'String', 'needMsgJBBmaininstanceId', 'try', 'while', 'mesgmatchesneedMsg', 'catch', 'javaioIOException', 'excep', 'JBButilgetLoglogLevelWARNINGexcep', 'Unable', 'to', 'read', 'from', 'String', 'messageReceived', 'Got', 'Message', 'initThreadsCountMonitor', 'String', 'long', 'long', 'long', 'long', 'DecimalFormat', 'dfnew', 'long', 'if', 'JBBmainmultiJVMMode', 'msgUser', 'Thread', 'MultiJVM', 'Rampup', 'padding', 'began', 'new', 'DatetoString', 'for', 'tmpTime', 'if', 'rampuptime', '0', 'msgUser', 'Thread', 'Rampup', 'began', 'new', 'DatetoString', 'for', 'dfformatrampuptime', '60', 'if', 'measurementtime', '0', 'msgTiming', 'Measurement', 'began', 'new', 'DatetoString', 'for', 'dfformatmeasurementtime', '60', 'msgTiming', 'Measurement', 'ended', 'new', 'if', 'JBBmainmultiJVMMode', 'msgUser', 'Thread', 'MultiJVM', 'Rampdown', 'padding', 'began', 'new', 'DatetoString', 'for', 'tmpTime', 'elapsedtimeendtime', 'threadsDoneCountMonitor', 'while', 'threadsDoneCount', 'MaxWarehouses', 'try', 'catch', 'InterruptedException', 'e', 'stopThreadsCountMonitor', 'while', 'stopThreadsCount', 'MaxWarehouses', 'try', 'catch', 'InterruptedException', 'e', 'outPropFileprintlnpropPrefix', 'warehouses', 'if', 'JBBmainmultiJVMMode', 'outPropFileprintlnpropPrefix', 'startrampuptimemilliseconds', 'outPropFileprintlnpropPrefix', 'endrampdowntimemilliseconds', 'outPropFileprintlnpropPrefix', 'starttimemilliseconds', 'outPropFileprintlnpropPrefix', 'endtimemilliseconds', 'outPropFileprintlnpropPrefix', 'elapsedmilliseconds', 'int', 'long', 'long', 'for', 'warehouseId1', 'warehouseId', 'MaxWarehouses', 'warehouseId', 'if', 'showWarehouseDetail', 'warehouseTimerDatapropResultspropPrefix', 'warehouse', 'warehouseId', 'for', 'int', 'txntype0', 'txntype', 'TransactionmaxTxnTypes', 'txntype', 'if', 'totalwarehousetrans', 'mintransactioncount', 'if', 'totalwarehousetrans', 'maxtransactioncount', 'SystemoutprintlnCalculating', 'long', 'diffmaxtransactioncount', 'float', 'diffpct100', 'floatdiff', 'SystemoutprintlnMinimum', 'transactions', 'by', 'a', 'warehouse', 'SystemoutprintlnMaximum', 'transactions', 'by', 'a', 'warehouse', 'SystemoutprintlnDifference', 'thread', 'spread', 'diff', 'dfformatdiffpct', 'companyTimerDatadisplayResultsCOMPANY', 'with', 'MaxWarehouses', 'warehouses', 'companyTimerDatapropResultspropPrefix', 'companyTimerDatapropThreadResultspropPrefix', 'outPropFileprintlnpropPrefix', 'companyminwarehousetransactions', 'outPropFileprintlnpropPrefix', 'companymaxwarehousetransactions', 'if', 'TransactionsteadyStateMem', 'short', 'Warehouse', 'int', 'int', 'for', 'warehouseId1', 'warehouseId', 'MaxWarehouses', 'warehouseId', 'synchronized', 'void', 'synchronized', 'void', 'synchronized', 'void', 'Customer', 'getCustomerByLastNameshort', 'warehouseIdbyte', 'districtIdString', 'String', 'custKeyIntegertoStringintwarehouseId', 'IntegertoStringintdistrictId', 'String', 'lastCustKeycustKey', 'Long', 'return', 'Customer', 'getCustomerlong', 'customerIdboolean', 'Customer', 'if', 'JBButilgetLogisLoggableLevelFINEST', 'Logger', 'logfinest', 'customerId', 'logfinest', 'Customer', 'return', 'return', 'int', 'return', 'int', 'return', 'int', 'return', 'short', 'return', 'int', 'return', 'shor ...
#  list(['DeliveryHandler', 'DeliveryHandlerPrintStream', 'getClass', 'void', 'handleDeliveryDeliveryTransaction'])
#  list(['SaveOutput', 'static', 'void', 'startString', 'f', 'throws', 'IOException', 'logfilenew', 'PrintStreamnew', 'BufferedOutputStreamnew', 'SystemsetOutnew', 'SystemsetErrnew', 'static', 'void', 'try', 'catch', 'Exception', 'e', 'JBButilgetLoglogLevelWARNINGException', 'void', 'writebyte', 'bufint', 'offint', 'try', 'catch', 'Exception', 'e', 'JBButilgetLoglogLevelWARNINGException', 'void', 'writeint', 'try', 'catch', 'Exception', 'e', 'JBButilgetLoglogLevelWARNINGException'])
#  list(['Address', 'synchronized', 'String', 'String', 'return', 'synchronized', 'String', 'String', 'return', 'synchronized', 'String', 'String', 'return', 'synchronized', 'String', 'String', 'return', 'synchronized', 'String', 'String', 'return', 'synchronized', 'void', 'setUsingRandomRandom', 'street1new', 'street1new', 'street2new', 'citynew', 'statenew', 'zipnew'])
#  list(['JBBProperties', 'void', 'boolean', 'SystemoutprintlnnnChecking', 'whether', 'run', 'will', 'be', 'if', 'checkThroughput', 'else', 'compliantcheckCompliancewarehousePopulationBaseCOMPLIANTRATEwarehousePopulationBasewarehousepopulationbase', 'compliantcheckComplianceorderlinesPerOrderCOMPLIANTRATEorderlinesPerOrderorderlinesperorder', 'compliantcheckCompliancedeterministicRandomSeedCOMPLIANTRATEdeterministicRandomSeeddeterministicrandomseed', 'compliantcheckComplianceperjvmwarehouserampupCOMPLIANTRATEperjvmwarehouserampupperjvmwarehouserampup', 'compliantcheckComplianceperjvmwarehouserampdownCOMPLIANTRATEperjvmwarehouserampdownperjvmwarehouserampdown', 'compliantcheckCompliancerampupSecondsCOMPLIANTRATErampupSecondsrampupseconds', 'compliantcheckCompliancemeasurementSecondsCOMPLIANTRATEmeasurementSecondsmeasurementseconds', 'compliantcheckCompliancewaitTimePercentCOMPLIANTRATEwaitTimePercentwaittimepercent', 'compliantcheckCompliancesteadyStateFlagCOMPLIANTRATEsteadyStateFlagsteadystate', 'compliantcheckCompliancescreenWriteFlagCOMPLIANTRATEscreenWriteFlagscreenwrite', 'compliantcheckComplianceuniformRandomItemsCOMPLIANTRATEuniformRandomItemsuniformrandomitems', 'compliantcheckComplianceapplicationLoggingLevelCOMPLIANTRATEapplicationLoggingLevelloglevel', 'if', 'overrideItemTableSize', '0', 'compliantcheckComplianceoverrideItemTableSizeCOMPLIANTRATEoverrideItemTableSizeoverrideitemtablesize', 'if', 'compliant', 'SystemoutprintlnRun', 'will', 'be', 'else', 'SystemoutprintlnINVALID', 'Run', 'will', 'NOT', 'be', 'boolean', 'checkComplianceboolean', 'actualValueboolean', 'compliantValueString', 'if', 'actualValue', 'compliantValue', 'SystemoutprintlnINVALID', 'name', 'actualValue', 'must', 'be', 'return', 'return', 'boolean', 'checkCompliancefloat', 'actualValuefloat', 'compliantValueString', 'if', 'actualValue', 'compliantValue', 'SystemoutprintlnINVALID', 'name', 'actualValue', 'must', 'be', 'return', 'return', 'boolean', 'checkComplianceint', 'actualValueint', 'compliantValueString', 'if', 'actualValue', 'compliantValue', 'SystemoutprintlnINVALID', 'name', 'actualValue', 'must', 'be', 'return', 'return', 'boolean', 'checkComplianceLevel', 'actualValueLevel', 'compliantValueString', 'if', 'actualValueequalscompliantValue', 'false', 'SystemoutprintlnINVALID', 'name', 'actualValue', 'must', 'be', 'return', 'return', 'boolean', 'copyPropsToOutputPrintStream', 'boolean', 'String', 'int', 'for', 'Enumeration', 'ePropertiesForBatchpropertyNames', 'ehasMoreElements', 'String', 'if', 'namestartsWithconfig', 'else', 'if', 'namestartsWithinput', 'boolean', 'for', 'int', 'i0', 'i', 'inputpropslength', 'i', 'if', 'nameequalsinput', 'inputpropsi', 'if', 'found', 'else', 'if', 'nameequalsinputmincapacityratio', 'if', 'checkThroughput', 'else', 'SystemoutprintlnERROR', 'Property', 'file', 'Systemoutprintln', 'inputmincapacityratio', 'invalid', 'for', 'else', 'if', 'nameequalsinputshowwarehousedetail', 'if', 'PropertiesForBatchgetPropertyinputshowwarehousedetailequalsIgnoreCasetrue', 'else', 'SystemoutprintlnERROR', 'Property', 'file', 'Systemoutprintln', 'Unrecognized', 'property', 'else', 'SystemoutprintlnERROR', 'Property', 'file', 'Systemoutprintln', 'Unrecognized', 'property', 'if', 'retval', 'Vector', 'keyvecnew', 'for', 'int', 'i0', 'i', 'keyvecsize', 'i', 'String', 'String', 'outRawFileprintlnpropsKey', 'Integer', 'procsAvailnew', 'outRawFileprintlnconfigswprocsAvailtoJava', 'return', 'Level', 'return', 'String', 'getOptionalPropertyString', 'try', 'return', 'catch', 'NullPointerException', 'e', 'return', 'boolean', 'String', 'String', 'int', 'boolean', 'boolean', 'valgetRequiredPropertyprefix', 'if', 'val', 'null', 'if', 'valequalsSPECjbb', 'else', 'SystemoutprintlnERROR', 'Property', 'file', 'Systemoutprintln', 'suite', 'must', 'be', 'else', 'valgetRequiredPropertyprefix', 'if', 'val', 'null', 'try', 'catch', 'IllegalArgumentException', 'iae', 'else', 'if', 'checkThroughput', 'valgetRequiredPropertyprefix', 'if', 'val', 'null',  ...
#  list(['Infrastructure', 'static', 'JBBSortedStorage', 'return', 'new', 'static', 'JBBDataStorage', 'return', 'new', 'static', 'JBBDataStorage', 'createStorageboolean', 'JBBDataStorage', 'if', 'synch', 'return', 'static', 'JBBDataStorage', 'synchStorageJBBDataStorage', 'return', 'new'])
#  list(['Title', 'String', 'return', 'tspecinitialclientFileProperty', 'filen', 'specinitialserverFileServer', 'property', 'filen', 'specinitialmaxRows', 'of', 'fields', 'per', 'edit', 'paneln', 'confighwvendorHardware', 'Vendorn', 'confighwvendorurlVendor', 'URLn', 'confighwmodelModeln', 'confighwprocessorProcessorn', 'confighwMHzMHzn', 'confighwnchips', 'of', 'Chipsn', 'confighwncores', 'of', 'Coresn', 'confighwncoresperchip', 'of', 'CoresChipn', 'confighwhwThreadsHW', 'Threading', 'Enabledn', 'configswprocsAvailtoJavaProcs', 'Avail', 'to', 'Javan', 'confighwmemoryMemory', 'MBn', 'confighwmemorydescriptionMemory', 'Detailsn', 'confighwprimaryCachePrimary', 'cachen', 'confighwsecondaryCacheSecondary', 'cachen', 'confighwotherCacheOther', 'cachen', 'confighwfileSystemFilesystemn', 'confighwdiskDisksn', 'confighwotherOther', 'hardwaren', 'confighwavailableHw', 'availablen', 'configswvendorSoftware', 'Vendorn', 'configswvendorurlVendor', 'URLn', 'configswJVMJVM', 'Versionn', 'configswcommandlineJVM', 'Command', 'Linen', 'configswJVMavailableJVM', 'availablen', 'configswJVMheapInitialJVM', 'Initial', 'Heap', 'Memory', 'MBn', 'configswJVMheapMaxJVM', 'Maximum', 'Heap', 'Memory', 'MB', 'n', 'configswJVMbitnessJVM', 'Address', 'bits', 'n', 'javaclasspathJVM', 'CLASSPATHn', 'sunbootclasspathJVM', 'BOOTCLASSPATHn', 'configswOSOS', 'Versionn', 'configswOSavailableOS', 'availablen', 'configswotherOther', 'softwaren', 'configswotherAvailableOther', 'sw', 'availablen', 'configswnotesOther', 'Notesn', 'configtesttestedByTested', 'byn', 'configtestspecLicenseSPEC', 'license', 'n', 'configtestlocationTest', 'locationn', 'configtestdateTest', 'daten', 'configtestxemailToMail', 'test', 'results', 'ton', 'configtestxemailReturnYour', 'return', 'email', 'addressn', 'configtestxmailHostOutgoing', 'SMTP', 'mail', 'servern', 'configtestxtestedByNameTested', 'by', 'personn', 'configtestxinternalReferenceInternal', 'Referencen', 'specothertestTimeTest', 'timen', 'specotherversionSPEC', 'versionn', 'specotherversionDateSPEC', 'release', 'daten', 'specotherreportDateDate', 'report'])
#  list(['Run', 'double', 'double', 'if', 'time', '0', 'return', 'else', 'return', 'ref', 'RunReportProps', 'propsint', 'runNumberdouble', 'timeResult', 'String', 'prefixresult', 'resultname', 'company', 'countpropsgetIntprefix', 'totaltimepropsgetDoubleprefix', 'minimumtimepropsgetDoubleprefix', 'maximumtimepropsgetDoubleprefix', 'averagetimepropsgetDoubleprefix'])
#  list(['JBButil', 'static', 'String', 'chooserandomlastnameint', 'maxCustomersshort', 'short', 'String', 'return', 'static', 'char', 'createastringwithoriginalint', 'lengthloint', 'lengthhifloat', 'percenttosetInteger', 'long', 'int', 'actuallength', 'char', 'int', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'if', 'f', 'percenttoset', 'startposrandom0templength', 'return', 'static', 'char', 'createastringwithoriginalint', 'lengthloint', 'lengthhifloat', 'percenttosetInteger', 'hitshort', 'long', 'int', 'actuallength', 'char', 'int', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'if', 'f', 'percenttoset', 'startposrandom0templength', 'return', 'static', 'char', 'createrandomastringint', 'lengthloint', 'int', 'i', 'actuallength', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'if', 'aRandInt', '61', 'return', 'static', 'char', 'createrandomastringint', 'lengthloint', 'lengthhiRandom', 'int', 'i', 'actuallength', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'if', 'aRandInt', '61', 'return', 'static', 'char', 'createrandomastringint', 'lengthloint', 'lengthhishort', 'int', 'i', 'actuallength', 'Random', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'if', 'aRandInt', '61', 'return', 'static', 'short', 'createrandomcustomeridint', 'maxCustomersshort', 'int', 'acidJBButilACID', 'maxCustomers', 'int', 'ccidJBButilCCID', 'maxCustomers', 'short', 'return', 'static', 'float', 'createrandomfloatvalreturnfloat', 'vallofloat', 'valhifloat', 'float', 'f', 'ffloatrnextFloat', 'valhi', 'vallo', 'resultf', 'return', 'static', 'float', 'createrandomfloatvalreturnfloat', 'vallofloat', 'valhifloat', 'precisionRandom', 'float', 'f', 'ffloatrnextFloat', 'valhi', 'vallo', 'resultf', 'return', 'static', 'float', 'createrandomfloatvalreturnfloat', 'vallofloat', 'valhifloat', 'precisionshort', 'float', 'f', 'Random', 'ffloatrnextFloat', 'valhi', 'vallo', 'resultf', 'return', 'static', 'int', 'createrandomitemidint', 'maxItemsshort', 'int', 'aoliidJBButilAOLIID', 'maxItems', 'int', 'coliidJBButilCOLIID', 'maxItems', 'int', 'if', 'JBBmainuniformRandomItems', 'else', 'return', 'static', 'String', 'createrandomlastnameint', 'custnumshort', 'int', 'String', 'if', 'custnum', '0', 'custnum', '1000', 'else', 'randomnumcustnum', 'templastnamepartsrandomnum', 'temptemp', 'lastnamepartsrandomnum', 'temptemp', 'return', 'static', 'char', 'createrandomnstringint', 'lengthloint', 'int', 'i', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'return', 'static', 'char', 'createrandomnstringint', 'lengthloint', 'lengthhiRandom', 'int', 'i', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'return', 'static', 'char', 'createrandomnstringint', 'lengthloint', 'lengthhishort', 'int', 'i', 'Random', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'return', 'static', 'long', 'long', 'return', 'static', 'long', 'long', 'return', 'static', 'long', 'long', 'resultresult', 'return', 'static', 'Random', 'derivedrandominitshort', 'Random', 'r1new', 'r1setSeedlongrnextInt', '0x7fffffff', 'return', 'static', 'Logger', 'return', 'static', 'void', 'milliSecondsToSleeplong', 'try', 'catch', 'InterruptedException', 'e', 'JBButilgetLoglogLevelWARNING', 'Exception', 'SLEEP', 'static', 'double', 'negativeExpDistributiondouble', 'meanshort', 'Random', 'double', 'double', 'double', 'meanX10mean', 'tMathlogrf', 'if', 't', 'meanX10', 'return', 'static', 'int', 'NUrandvalint', 'Aint', 'xint', 'yint', 'CRandom', 'return', 'random0Ar', 'randomxyr', 'C', 'y', 'x', '1', 'static', 'int', 'NUrandvalint', 'Aint', 'xint', 'yint', 'Cshort', 'Random', 'return', 'random0Ar', 'randomxyr', 'C', 'y', 'x', '1', 'static', 'void', 'randominitint', 'rnew', 'warehouserandomstreamnew', 'static', 'int', 'randomint', 'lowint', 'return', 'rnextInt', '0x7fffffff', 'high', 'low', '1', 'static', 'int', 'randomint', 'lowint', 'highRandom', 'return', 'rnextInt', '0x7fffffff', 'high', 'low', '1', 'static', 'int', 'randomint', 'lowint', 'highshort', 'Ra ...

# %%
# #training phase
def f_lsa(news_df, n):
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(news_df)
    # print(vectorizer.get_feature_names())#Get the vocabulary found by the model directly analyzing the data（collection of words above）
    # print(X.toarray())# Printing X directly outputs the position of each word
    #     print(X)

    n_cap = 1
    svd_model = TruncatedSVD(n_components=n_cap)  # Latent semantic analysis, set 4 topics
    X2 = svd_model.fit_transform(X)  # train and convert

    # print("--------lsa Singular Value---------")
    # print(svd_model.singular_values_)
    # print("--------Representation of text in topic vector space Left singular matrix---------")
    # print(X2)

    terms = vectorizer.get_feature_names()
    # print("-------- Topics and keywords ---------")
    for i, comp in enumerate(svd_model.components_):
        terms_comp = zip(terms, comp)
        sorted_terms = sorted(terms_comp, key=lambda x: x[1], reverse=True)[:7]
        # print("Topic " + str(i) + ": ")
        for t in sorted_terms:
            print(t[0])
    print(" ")

    D = svd_model.components_
    T = X2
    S = np.diagflat(svd_model.singular_values_)

    X = np.dot(T, S)
    X = np.dot(X, D)
    c = np.dot(X, X.T)

    acsm = None
    sum = 0
    for i in c:
        for j in i:
            if j < 0:
                j = 0
            sum += j
        acsm = sum / n / n
    # print("-------------acsm----------------------")
    # print(acsm)

    return acsm

# %%
len(index[0:200])
# Out:
# 60

# %%
q = 0
acsm= []
for i in index[0:200]:
    lists = []
    print("*************",i,"****************")
    # print("------------------------------------------------------------------")
    for j in i:
        lists.append(j)
    # lists = deleteDuplicatedElementFromList(lists)
    if len(lists) > 1:
        acsm.append(f_lsa(lists,len(i)))
    else :
        acsm.append(1)
# Out:
# ************* ['OrderStatusTransaction', 'OrderStatusTransactionCompany', 'inCompanyshort', 'int', 'olsupplyingwarehousenew', 'olitemidnew', 'olitemnamenew', 'olquantitynew', 'olstocknew', 'olbgnew', 'olitempricenew', 'olamountnew', 'oldeliverydatenew', 'orderLognew', 'xmlOrderLognew', 'initLognew', 'void', 'orderLogputTextSupplyW', 'ItemId', 'Qty', 'Amount'] ****************
# olsupplyingwarehousenew
# int
# orderstatustransactioncompany
# olstocknew
# olitempricenew
# incompanyshort
# amount
#
# ************* ['MultiVMTxtReport', 'void', 'int', 'int', 'long', 'long', 'long', 'long', 'long', 'long', 'long', 'long', 'for', 'int', 'n1', 'n', 'instances', 'n', 'if', 'count', 'metricsngetWarehousesTested', 'if', 'instancesChecked', 'instances', 'SystemoutprintlnINVALID', 'Instances', 'do', 'not', 'have', 'identical', 'test', 'else', 'for', 'int', 'i1', 'i', 'count', 'instanceChecksPassed', 'i', 'for', 'int', 'j0', 'j', 'instances', 'j', 'if', 'tmpStart', 'firststartmillis', 'if', 'tmpRampup', 'lastrampupmillis', 'if', 'tmpRampdown', 'firstrampdownmillis', 'if', 'tmpEnd', 'lastendmillis', 'if', 'firstrampdownmillis', 'lastendmillis', 'firststartmillis', 'lastrampupmillis', 'else', 'MultiVMTxtReportString', 'newsletterString', 'outputdirectoryboolean', 'MultiVMTxtReportString', 'newsletterString', 'outputdirectoryboolean', 'SPECInternalUseString', 'String', 'File', 'dirnew', 'if', 'direxists', 'SystemoutprintlnError', 'file', 'outputdirectory', 'doesnt', 'if', 'dirisDirectory', 'SystemoutprintlnError', 'file', 'outputdirectory', 'is', 'not', 'a', 'FilenameFilter', 'filternew', 'File', 'resultsnew', 'metricsnew', 'metricnew', 'double', 'boolean', 'for', 'int', 'i0', 'i', 'resultFileslength', 'i', 'resultsinew', 'try', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'reading', 'results', 'file', 'resultFilesi', 'metricsinew', 'try', 'catch', 'NumberFormatException', 'e', 'if', 'isMetricsDouble', 'metric2Metricsformatsum', 'thishardwaregetconfighwvendor', 'for', 'int', 'i0', 'i', 'metricslength', 'i', 'if', 'metricsivalid', 'thissoftwaregetconfigswvendor'] ****************
# if
# lastendmillis
# systemoutprintlnerror
# try
# firststartmillis
# firstrampdownmillis
# not
#
# ************* ['Sub', 'String', 'return', 'int', 'return', 'priv', 'int', 'return', 'prot', 'Subint', 'superblack', 'pubblack'] ****************
# return
# subint
# pubblack
# prot
# int
# superblack
# priv
#
# ************* ['Item', 'String', 'return', 'BigDecimal', 'return', 'synchronized', 'void', 'setUsingRandomint', 'namenew', 'float', 'pricenew', 'brandInformationnew'] ****************
# return
# setusingrandomint
# void
# string
# pricenew
# bigdecimal
# synchronized
#
# ************* ['TemplateCompare', 'tTitle', 'Faken', 'Table', '0', '0', '0n', 'n', 'Title', 'Hardwaren', 'Table', '0', '0', '0n', 'confighwvendorn', 'confighwvendorurln', 'confighwmodeln', 'confighwprocessorn', 'confighwMHzn', 'confighwnchipsn', 'confighwncoresn', 'confighwncoresperchipn', 'confighwhwThreadsn', 'configswprocsAvailtoJavan', 'confighwmemoryn', 'confighwmemorydescriptionn', 'confighwprimaryCachen', 'confighwsecondaryCachen', 'confighwotherCachen', 'confighwfileSystemn', 'confighwdiskn', 'confighwothern', 'n', 'Title', 'Softwaren', 'Table', '0', '1', '0n', 'configswvendorn', 'configswvendorurln', 'configswJVMn', 'configswcommandlinen', 'configswJVMheapInitialn', 'configswJVMheapMaxn', 'configswOSn', 'configswothern', 'n', 'Title', 'AOT', 'Compilationn', 'Table', '1', '1', '1n', 'configswaotn', 'n', 'Title', 'Tuningn', 'Table', '1', '1', '1n', 'configswtuningn', 'n', 'Title', 'Test', 'Informationn', 'Table', '1', '0', '0n', 'configtesttestedByn', 'configtestspecLicensen', 'configtestlocationn', 'configtestdaten', 'confighwavailablen', 'configswJVMavailablen', 'configswOSavailablen', 'configswotherAvailablen', 'n', 'Title', 'Notesn', 'Table', '1', '1', '1n', 'configswnotesn'] ****************
# table
# confighwsecondarycachen
# configswotheravailablen
# configswnotesn
# confighwdiskn
# configswjvmn
# hardwaren
#
# ************* ['MapDataStorage', 'boolean', 'containsKeyObject', 'return', 'Iterator', 'return', 'Object', 'getObject', 'return', 'thisnew', 'MapDataStorageMap', 'Object', 'putObject', 'keyObject', 'return', 'Object', 'removeObject', 'return'] ****************
# return
# putobject
# mapdatastorage
# getobject
# keyobject
# object
# removeobject
#
# ************* ['GraphImage', 'void', 'drawLegendString', 'legenddouble', 'XOffsetdouble', 'YOffsetColor', 'symbolColorColor', 'legendColorString', 'FontMetrics', 'int', 'txgetLinearMapXscaleMINX', 'int', 'tygetLinearMapY0', 'intYOffset', 'AXISTICKRADIUS', 'int', 'int', 'rintMathroundp', 'if', 'legendTypeequalsLine', 'graphicsdrawLinetxty', 'fmgetAscent', '2tx', '20ty', 'fmgetAscent', 'graphicsdrawString', 'legendtx', 'else', 'if', 'legendTypeequalsDot', 'graphicsfillArctx', 'rty', 'r', 'fmgetAscent', 'graphicsdrawString', 'int', 'getLinearMapXdouble', 'return', 'intMathroundx', 'scaleMINX', 'int', 'getLinearMapYdouble', 'return', 'intMathroundscaleMAXY', 'y', 'synchronized', 'double', 'getSuggestedMinXScaledouble', 'maxxdouble', 'double', 'scalenew', 'setScalenew', 'FontMetrics', 'int', 'wfmstringWidthdfyformatmaxy', 'AXISTICKRADIUS', 'double', 'minxthisscaleMINX', 'w', 'return', 'synchronized', 'double', 'getSuggestedMinYScaledouble', 'maxxdouble', 'double', 'scalenew', 'setScalenew', 'FontMetrics', 'int', 'hAXISTICKRADIUS', 'fmgetHeight', 'double', 'minythisscaleMAXY', 'h', 'alphay', 'return', 'int', 'getSuggestedYAxisTickIntervalint', 'suggestedNumTicksdouble', 'double', 'tmaxy', 'int', 'llintMathlogt', 'int', 'lull', 'int', 'tinew', 'for', 'int', 'i0', 'i', 'tilength', '1', 'i', 'tii', '1tii', 'int', 'int', 'for', 'int', 'itilength', '1', 'i', '0', 'i', 'double', 'ddifftii', 'if', 'ddiff', '00', 'int', 'if', 'diff', 'delta', 'delta', '0', 'return', 'GraphImageint', 'widthint', 'void', 'void', 'void', 'makeString', 'if', 'filename', 'null', 'try', 'File', 'outfilenew', 'catch', 'Exception', 'e', 'JBButilgetLoglogLevelWARNINGException', 'void', 'plotFlatLinedouble', 'yColor', 'int', 'int', 'int', 'for', 'int', 'xpx', 'x', 'w', 'x2', 'DASHLENGTH', 'graphicsdrawLinexpyx', 'void', 'plotFlatLinedouble', 'x1double', 'x2double', 'yColor', 'int', 'int', 'int', 'for', 'int', 'xpx', 'x', 'ex', 'x2', 'DASHLENGTH', 'graphicsdrawLinexpyx', 'void', 'plotLinedouble', 'x1double', 'y1double', 'x2double', 'void', 'plotXAxisTicksdouble', 'stepColor', 'cString', 'int', 'FontMetrics', 'for', 'double', 'x00', 'x', 'scaleMAXX', 'xstep', 'int', 'graphicsdrawLinepxpy', 'AXISTICKRADIUS', 'x', '00', '2', '1pxpy', 'AXISTICKRADIUS', 'x', '00', '2', 'if', 'x', '00', 'String', 'int', 'swfmstringWidthsx', 'graphicsdrawStringsxpx', 'swpy', 'AXISTICKRADIUS', 'for', 'double', 'x00', 'x', 'scaleMINX', 'xstep', 'int', 'graphicsdrawLinepxpy', 'AXISTICKRADIUSpxpy', 'graphicsdrawStringlabelgetLinearMapXscaleMAXX', '2py', '3', 'AXISTICKRADIUS', 'void', 'plotXYAxesColor', 'int', 'int', 'void', 'plotYAxisTicksdouble', 'stepColor', 'cString', 'int', 'FontMetrics', 'for', 'double', 'y00', 'y', 'scaleMAXY', 'step', 'ystep', 'int', 'graphicsdrawLinepx', 'AXISTICKRADIUS', 'y', '00', '2', '1pypx', 'AXISTICKRADIUS', 'y', '00', '2', 'if', 'y', '00', 'String', 'graphicsdrawStringsypx', 'AXISTICKRADIUS', 'fmstringWidthsy', '2py', 'for', 'double', 'y00', 'y', 'scaleMINY', 'ystep', 'int', 'graphicsdrawLinepx', 'AXISTICKRADIUSpypx', 'graphicsdrawStringlabelpx', 'AXISTICKRADIUS', 'fmstringWidthlabelgetLinearMapYscaleMAXY', '4', 'void', 'plotdouble', 'xdouble', 'void', 'plotdouble', 'xdouble', 'yColor', 'void', 'plotdouble', 'xdouble', 'yint', 'pColor', 'if', 'connectPointsEnabled', 'if', 'prevSet', 'else', 'int', 'int', 'int', 'rintMathroundp', 'pixeltype', 'graphicsfillArcpx', 'rpy', 'rpy', 'void', 'void', 'setAxisLabelsPrecisionDecimalFormat', 'dfint', 'iint', 'void', 'setBackgroundColor', 'void', 'setConnectPointsEnabledboolean', 'void', 'setForegroundColor', 'void', 'setImageQualityfloat', 'if', 'quality', '00f', 'quality', '10f', 'void', 'setPixelSizeint', 'void', 'setPixelTypeint', 'void', 'setScaledouble', 'if', 'scale', 'null', 'scalelength', 'thisscalelength', 'alphaxthisscaleMAXX', 'thisscaleMINX', 'alphaythisscaleMAXY', 'thisscaleMINY', 'void', 'setXAxisLabelsPrecisionint', 'iint', 'void', 'setXYAxesLabelsPrecisionint', 'xint', 'void', 'setYAxisLabelsPrecisionint', 'ii ...
# int
# fmgetascent
# iint
# ycolor
# plotdouble
# xdouble
# xstep
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ************* ['Check', 'static', 'boolean', 'boolean', 'Super', 'supnew', 'Sub', 'subnew', 'SystemoutprintlnsupgetName', 'SystemoutprintlnsubgetName', 'if', 'suptoStringequalsClass', 'Super', 'public34', 'protected33', 'private32', 'if', 'subtoStringequalsClass', 'Super', 'public804', 'protected803', 'private802', 'SystemoutprintlnSuper', 'prot', 'supgetProtected', 'priv', 'SystemoutprintlnSub', 'prot', 'subgetProtected', 'priv', 'if', 'supgetProtected', '33', 'supgetPrivate', '32', 'if', 'subgetProtected', '111', 'subgetPrivate', '105', 'SystemoutprintlnSubclass', 'test', 'error', 'error', 'return', 'static', 'boolean', 'boolean', 'Document', 'DocumentBuilder', 'DocumentBuilderFactory', 'try', 'boolean', 'if', 'result', 'else', 'SystemoutprintlnXML', 'StrictErrorChecking', 'test', 'error', 'error', 'catch', 'ParserConfigurationException', 'pce', 'return', 'static', 'boolean', 'SystemoutprintlnnChecking', 'boolean', 'boolean', 'boolean', 'try', 'int', 'anew', 'for', 'int', 'i0', 'i', '10', 'i', 'SystemoutprintlnError', 'array', 'bounds', 'not', 'catch', 'ArrayIndexOutOfBoundsException', 'e', 'finally', 'if', 'caughtIndex', 'Systemoutprintln1st', 'bounds', 'test', 'errortindex', 'exception', 'not', 'if', 'gotToFinally', 'Systemoutprintln1st', 'bounds', 'test', 'errortfinally', 'clause', 'not', 'if', 'caughtIndex', 'gotToFinally', 'Systemoutprintln1st', 'bounds', 'if', 'checkSubclassing', 'if', 'checkXMLErrorChecking', 'LoopBounds', 'mulenew', 'if', 'LoopBoundsgotError', 'Systemoutprintln2nd', 'bounds', 'else', 'Systemoutprintln2nd', 'bounds', 'PepTest', 'horsenew', 'if', 'horsegotError', 'if', 'error', 'SystemoutprintlnnINVALID', 'JVM', 'Check', 'detected', 'else', 'SystemoutprintlnnJVM', 'Check', 'return'] ****************
# if
# systemoutprintln2nd
# static
# not
# try
# int
# catch
#
# ************* ['Report', 'String', 'return', 'void', 'printOtherPropertiesPrintStream', 'outprintlnH4Optional', 'InformationH4n', 'IThis', 'information', 'is', 'for', 'internal', 'documentation', 'purposesn', 'and', 'is', 'not', 'required', 'for', 'SPEC', 'reportingn', 'for', 'Enumeration', 'eresultspropertyNames', 'ehasMoreElements', 'String', 'if', 'keystartsWithconfigtestx', 'keystartsWithconfiginitial', 'String', 'if', 'keyequalsconfigtestxinternalReference', 'valuestartsWithhttp', 'valuestartsWithfile', 'valueA', 'HREF', 'value', 'value', 'outprintlnBR', 'key', 'void', 'printPrintStream', 'try', 'outprintlnHTMLHEADn', 'META', 'NAMEGENERATOR', 'CONTENT', 'SPEC', 'Java', 'Reportern', 'TITLE', 'name', 'TITLEn', 'outprintBODY', 'if', 'metricsvalid', 'else', 'outprintTABLE', 'WIDTH100n', 'TRTD', 'if', 'issue', 'null', 'issueequals', 'else', 'outprintFONT', 'if', 'metricsvalid', 'outprintFONT', 'SIZE2', 'outprintFONT', 'SIZE2', 'name', '2005FONTTDn', 'TD', 'COLSPAN2', 'ALIGNRIGHT', 'bgcolorFFFF00', 'FONT', 'SIZE2', 'COLOR000000BSPECjbb2005', 'bops', 'metric', 'SPECjbb2005', 'bopsJVM', 'metric', 'BFONTTDTRn', 'TRTD', 'COLSPAN3FONT', 'SIZE1', 'hardware', 'if', 'software', 'null', 'outprintTRTD', 'COLSPAN3FONT', 'SIZE1', 'software', 'BufferedReader', 'BufferedReader', 'TableGroupCompare', 'if', 'metrics2', 'null', 'innew', 'BufferedReadernew', 'StringReadernew', 'in2new', 'BufferedReadernew', 'StringReadernew', 'mnew', 'else', 'innew', 'BufferedReadernew', 'StringReadernew', 'in2new', 'BufferedReadernew', 'StringReadernew', 'mnew', 'if', 'metrics2', 'null', 'if', 'verbose', 'outprintlnHRFONT', 'outprintlnSPECjbb2005', 'Version', 'resultsgetconfigbenchmarkversionNA', 'resultsgetconfigbenchmarkversionDate', 'if', 'issue', 'null', 'issueequals', 'metricsvalid', 'outprintlnPublished', 'by', 'SPEC', 'issue', 'outprintlnReporting', 'page', 'Copyright', 'copy', '2005', 'SPEC', 'All', 'rights', 'reservedn', 'outprintln', 'outprintlnReporting', 'Page', 'Generator', 'if', 'echoRaw', 'resultsstoreoutRaw', 'outprintln', 'catch', 'Exception', 'e', 'JBButilgetLoglogLevelWARNINGError', 'void', 'printString', 'try', 'printnew', 'PrintStreamnew', 'BufferedOutputStreamnew', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'creating', 'output', 'Reportboolean', 'echoRawboolean', 'SPECInternalUseString', 'newsletterString', 'resultFileboolean', 'verboseString', 'resultFile2String', 'labelboolean', 'useHtmlString', 'try', 'StringReader', 'tisnew', 'StringReadernew', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'loading', 'titles', 'for', 'try', 'if', 'resultFile', 'null', 'resultsloadnew', 'else', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'reading', 'results', 'file', 'resultFile', 'metricsnew', 'try', 'if', 'resultFile2', 'null', 'metrics2new', 'else', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'reading', 'comparison', 'results', 'file', 'resultFile2', 'if', 'metrics2', 'null', 'else', 'thishardwareresultsgetconfighwvendor', 'if', 'metric', 'null', 'metric', 'if', 'metricsvalid', 'if', 'SPECInternalUse', 'metricsresultsbufappendnValid', 'run', 'Score', 'is', 'metric', 'else', 'if', 'metricsprintscore', 'metricsresultsbufappendINVALID', 'run', 'Score', 'is', 'metric', 'else', 'metricsresultsbufappendINVALID', 'run', 'preventing', 'score', 'thissoftwareresultsgetconfigswvendor', 'void', 'testBarPrintStream', 'out', 'throws', 'IOException', 'String', 'String', 'String', 'outprintlnTABLE', 'WIDTH100', 'BORDER1', 'CELLSPACING2', 'CELLPADDING0trn', 'td', 'width33bSPEC', 'license', 'b', 'license', 'tdn', 'td', 'width33bTested', 'by', 'b', 'testedBy', 'tdn', 'tdbTest', 'date', 'b', 'testDate', 'tdn'] ****************
# if
# jbbutilgetlogloglevelwarningerror
# metrics2
# outprintfont
# in2new
# name
# file
#
# ************* ['Warehouse', 'int', 'return', 'District', 'getDistrictPtrbyte', 'inDistrictIdboolean', 'District', 'if', 'inDistrictId', '0', 'if', 'inDistrictId', 'distCount', 'return', 'District', 'getDistrictint', 'District', 'if', 'distId', '0', 'if', 'distId', 'distCount', 'return', 'synchronized', 'JBBDataStorage', 'return', 'void', 'initWarehouseCompany', 'inCompanyJBBDataStorage', 'inItemTableshort', 'districtsnew', 'addressnew', 'synchronized', 'void', 'String', 'for', 'byte', 'districtId1', 'districtId', 'companygetMaxDistrictsPerWarehouse', 'districtId', 'for', 'short', 'customerId1', 'customerId', 'companygetMaxCustomersPerDistrict', 'customerId', 'long', 'Customer', 'BigDecimal', 'historyDatanew', 'Date', 'creationtimenew', 'History', 'newHistorynew', 'void', 'int', 'Item', 'Stock', 'for', 'int', 'i1', 'i', 'numItems', 'i', 'newStocknew', 'void', 'removeOldestHistorySynch', 'Item', 'retrieveItemint', 'return', 'Stock', 'retrieveStockint', 'return', 'synchronized', 'void', 'setUsingRandomshort', 'int', 'namenew', 'float', 'taxRatenew', 'for', 'i0', 'i', 'distCount', 'i', 'byte', 'newDistrictIdbytei', 'District', 'newDistrictnew', 'synchronized', 'void', 'int', 'int', 'synchronized', 'void', 'trimOrdersForSteadyStateint', 'initialOrdersint', 'int', 'int', 'District', 'for', 'distId1', 'distId', 'distCount', 'distId', 'if', 'TransactionsteadyStateMem', 'currentDistrictremoveOldNewOrdersinitialOrders', 'void', 'updateHistoryHistory', 'updateHistorySynch', 'boolean', 'validDistrictbyte', 'District', 'int', 'for', 'i0', 'i', 'distCount', 'i', 'if', 'currentDistrictgetId', 'inDistrictId', 'return', 'return', 'WarehouseCompany', 'inCompanyJBBDataStorage', 'districtsnew', 'addressnew'] ****************
# int
# districtid
# districtsnew
# byte
# distcount
# distid
# initwarehousecompany
#
# ************* ['TableGroup', 'inReportProps', 'propsReportProps', 'titles', 'throws', 'IllegalArgumentException', 'String', 'String', 'try', 'while', 'lineinreadLine', 'null', 'if', 'linestartsWithTitle', 'else', 'if', 'linestartsWithTable', 'StringTokenizer', 'tokennew', 'int', 'int', 'boolean', 'freeFormIntegerparseInttokennextToken', 'if', 'group', '0', 'group', 'MAXGROUPS', 'column', '0', 'column', 'MAXCOLUMNS', 'throw', 'new', 'int', 'if', 'row', '0', 'row', 'MAXROWS', 'throw', 'new', 'tablesgroupcolumnrownew', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError'] ****************
# if
# catch
# while
# tokennew
# boolean
# maxcolumns
# tablegroup
#
# ************* ['NewOrder', 'void', 'synchronized', 'Order', 'Order', 'return', 'void', 'initNewOrderOrder', 'inOrderPtrint', 'inOrderIdbyte', 'inDistrictIdshort', 'if', 'JBButilgetLogisLoggableLevelFINEST', 'JBButilgetLogfinestNewOrderinitNewOrder', 'orderId', 'orderId', 'districtId', 'districtId', 'warehouseId', 'NewOrderOrder', 'inOrderPtrint', 'inOrderIdbyte', 'inDistrictIdshort'] ****************
# indistrictidshort
# void
# inorderidbyte
# synchronized
# neworderorder
# return
# jbbutilgetlogisloggablelevelfinest
#
# ************* ['JBBmain', 'void', 'callReporterString', 'outputdirectoryString', 'outRawFilenameString', 'outRawPrefixString', 'String', 'msgCalling', 'boolean', 'boolean', 'String', 'String', 'boolean', 'String', 'String', 'optooutputdirectory', 'Fileseparator', 'outRawPrefix', 'sequenceNumber', 'String', 'fileAsciioutputdirectory', 'Fileseparator', 'outRawPrefix', 'sequenceNumber', 'String', 'String', 'boolean', 'specreporterReport', 'try', 'TextiReport', 'arnew', 'catch', 'Exception', 'e', 'try', 'rnew', 'catch', 'Exception', 'e', 'JBButilgetLogwarningProducing', 'html', 'chart', 'in', 'report', 'instead', 'of', 'JPEG', 'see', 'Users', 'rnew', 'javalangInternalError', 'e', 'JBButilgetLogwarningProducing', 'html', 'chart', 'in', 'report', 'instead', 'of', 'JPEG', 'see', 'Users', 'rnew', 'javalangUnsatisfiedLinkError', 'e', 'JBButilgetLogwarningProducing', 'html', 'chart', 'in', 'report', 'instead', 'of', 'JPEG', 'see', 'Users', 'rnew', 'javalangError', 'e', 'JBButilgetLogwarningProducing', 'html', 'chart', 'in', 'report', 'instead', 'of', 'JPEG', 'see', 'Users', 'rnew', 'try', 'BufferedReader', 'AscBrnew', 'BufferedReadernew', 'String', 'while', 'sAscBrreadLine', 'null', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'opening', 'ASCII', 'output', 'SystemoutprintlnOutput', 'files', 'fileAscii', 'outRawFilename', 'SystemoutprintlnReporter', 'String', 'commandLineParserString', 'String', 'if', 'argslength', '0', 'else', 'if', 'args0equalsid', 'else', 'if', 'args0equalspropfile', 'if', 'argslength', '2', 'else', 'if', 'argslength', '1', 'SystemoutprintlnMissing', 'properties', 'file', 'Systemoutprintln', 'Parameters', 'propfile', 'propertiesfilename', 'id', 'else', 'if', 'argslength', '4', 'args2equalsid', 'else', 'SystemoutprintlnToo', 'many', 'Systemoutprintln', 'Parameters', 'propfile', 'propertiesfilename', 'id', 'else', 'SystemoutprintlnUnrecognized', 'command', 'line', 'parameter', 'Systemoutprintln', 'Parameters', 'propfile', 'return', 'void', 'DoARunCompany', 'myCompanyshort', 'numberofwarehousesint', 'rampuptimeint', 'short', 'myCompanysetPropOutputPrefixresulttest', 'testnum', 'SystemoutprintlnStart', 'User', 'JBButilgetLoginfoStart', 'User', 'try', 'for', 'whID1', 'whID', 'numberofwarehouses', 'whID', 'String', 'msg', 'started', 'user', 'thread', 'for', 'Warehouse', 'catch', 'javalangThreadDeath', 'e', 'try', 'JBButilgetLoglogLevelWARNINGERROR', 'A', 'thread', 'died', 'probably', 'out', 'of', 'memory', 'Increase', 'the', 'heap', 'size', 'and', 'run', 'catch', 'OutOfMemoryError', 'oome', 'SystemoutprintlnERROR', 'A', 'thread', 'died', 'probably', 'out', 'of', 'memory', 'Increase', 'the', 'heap', 'size', 'and', 'run', 'javalangOutOfMemoryError', 'e', 'try', 'JBButilgetLoglogLevelWARNINGERROR', 'Out', 'of', 'memory', 'error', 'caught', 'Increase', 'the', 'heap', 'size', 'and', 'run', 'catch', 'OutOfMemoryError', 'oome', 'SystemoutprintlnERROR', 'Out', 'of', 'memory', 'error', 'caught', 'Increase', 'the', 'heap', 'size', 'and', 'run', 'boolean', 'DoAValidationRunCompany', 'short', 'TransactionManager', 'transMgrnew', 'return', 'void', 'float', 'minbtpsfloatpropminBTPSRatio', '1000', 'propwaitTimePercent', '23', 'myCompanynew', 'if', 'propdeterministicRandomSeed', 'true', 'int', 'int', 'if', 'propsequenceOfWarehouses', 'null', 'for', 'numwhpropstartingNumberWarehouses', 'numwh', 'propendingNumberWarehouses', 'numwhpropincrementNumberWarehouses', 'if', 'runWarehousecurwarehousesnumwhminbtps', 'else', 'for', 'int', 'seqndx0', 'seqndx', 'propsequenceOfWarehouseslength', 'seqndx', 'if', 'runWarehousecurwarehousesnumwhminbtps', 'boolean', 'myCompanynew', 'long', 'boolean', 'return', 'void', 'Handler', 'for', 'Handler', 'logHandler', 'handlers', 'void', 'increaseNumWarehousesint', 'currentint', 'nextint', 'for', 'int', 'icurrent', '1', 'i', 'next', 'i', 'boolean', 'initApplicationLoggingString', 'StreamHandler', 'try', 'handlernew', 'StreamHandlernew', 'FileOutputStreamlogFileNamenew', 'catch', 'FileNotFoundEx ...
# if
# void
# return
# thread
# out
# string
# jbbutilgetlogloglevelwarningerror
#
# ************* ['MultiVMReporter', 'static', 'boolean', 'getOptString', 'try', 'for', 'int', 'i0', 'i', 'argslength', 'i', 'if', 'argsiequalsa', 'else', 'if', 'argsiequalse', 'else', 'if', 'argsiequalss', 'else', 'if', 'argsiequalsn', 'else', 'if', 'argsiequalso', 'else', 'if', 'argsiequalsr', 'else', 'if', 'argsiequalsl', 'else', 'if', 'argsiequalsp', 'else', 'throw', 'new', 'catch', 'ArrayIndexOutOfBoundsException', 'e', 'return', 'if', 'optr', 'null', 'return', 'else', 'return', 'static', 'void', 'mainString', 'if', 'getOptargs', 'if', 'opta', 'if', 'opto', 'null', 'optooptr', 'Fileseparator', 'MultiVMTxtReport', 'rnew', 'else', 'if', 'opto', 'null', 'optooptr', 'Fileseparator', 'MultiVMReport', 'rnew', 'static', 'void', 'SystemoutprintlnUsage', 'java', 'specreporterMultiVMReporter', 'optionsn', 'Required', 'options', 'aren', 'r', 'ResultsDir', 'Directory', 'with', 'results', 'filesn', 'Other', 'options', 'aren', 'a', 'Plain', 'ASCII', 'text', 'outputn', 'default', 'generate', 'HTML', 'output', 'with', 'JPG', 'graphn', 'e', 'Do', 'NOT', 'echo', 'raw', 'results', 'properties', 'in', 'HTML', 'outputn', 'default', 'raw', 'results', 'inserted', 'as', 'HTML', 'commentsn', 'o', 'Output', 'Output', 'file', 'for', 'generated', 'HTML', 'or', 'TXTn', 'default', 'indexhtml', 'for', 'HTML', 'MultiVMReporttxt', 'for', 'TXTn', 'NB', 'html', 'links', 'are', 'generated', 'as', 'relative', 'to', 'then', 'directory', 'with', 'results'] ****************
# if
# static
# null
# directory
# txtn
# default
# options
#
# ************* ['History', 'synchronized', 'String', 'buildDataString', 'warehouseNameString', 'datanew', 'StringwarehouseName', 'String', 'return', 'short', 'short', 'return', 'Date', 'Date', 'return', 'Historyshort', 'inCustomerIdbyte', 'inCustomerDistrictIdshort', 'inCustomerWarehouseIdbyte', 'inDistrictIdshort', 'inWarehouseIdDate', 'inDateBigDecimal', 'inAmountString', 'void', 'initHistoryshort', 'inCustomerIdbyte', 'inCustomerDistrictIdshort', 'inCustomerWarehouseIdbyte', 'inDistrictIdshort', 'inWarehouseIdDate', 'inDateBigDecimal', 'inAmountString'] ****************
# return
# datanew
# warehousenamestring
# incustomerwarehouseidbyte
# short
# inithistoryshort
# date
#
# ************* ['Order', 'synchronized', 'void', 'dateOrderlinesDate', 'int', 'Orderline', 'if', 'JBButilgetLogisLoggableLevelFINEST', 'JBButilgetLogfinestOrderdateOrderlines', 'orderlineList', 'orderlineList', 'orderlineCount', 'for', 'i0', 'i', 'orderLineCount', 'i', 'if', 'JBButilgetLogisLoggableLevelFINEST', 'JBButilgetLogfinest', 'orderline', 'orderline', 'orderline', 'synchronized', 'short', 'short', 'return', 'synchronized', 'Customer', 'Customer', 'return', 'synchronized', 'Date', 'Date', 'return', 'synchronized', 'int', 'int', 'return', 'synchronized', 'short', 'short', 'return', 'synchronized', 'Orderline', 'if', 'JBButilgetLogisLoggableLevelFINEST', 'JBButilgetLogfinestOrdergetOrderlineList', 'orderlineList', 'return', 'synchronized', 'BigDecimal', 'BigDecimal', 'return', 'void', 'initOrderCompany', 'inCompanyint', 'inOrderIdbyte', 'inDistrictIdshort', 'inWarehouseIdshort', 'inCustomerIdCustomer', 'inCustomerPtrBigDecimal', 'inDistrictTaxRateBigDecimal', 'inWarehouseTaxRateBigDecimal', 'orderlineListnew', 'OrderlineTransactionaveOrderlines', 'if', 'JBButilgetLogisLoggableLevelFINEST', 'JBButilgetLogfinestOrderinitOrder', 'orderlineList', 'entryDateTimenew', 'OrderCompany', 'inCompanyint', 'inOrderIdbyte', 'inDistrictIdshort', 'inWarehouseIdshort', 'inCustomerIdCustomer', 'inCustomerPtrBigDecimal', 'inDistrictTaxRateBigDecimal', 'inWarehouseTaxRateBigDecimal', 'synchronized', 'boolean', 'processLinesWarehouse', 'inWarehousePtrshort', 'numberoforderlinesboolean', 'short', 'boolean', 'BigDecimal', 'for', 'short', 'LineNumber1', 'LineNumber', 'numberoforderlines', 'LineNumber', 'Orderline', 'newOrderlinenew', 'if', 'JBButilrandom1100warehouseId', '1', 'companygetMaxWarehouses', '1', 'while', 'supplyWarehouseId', 'warehouseId', 'if', 'newOrderlinevalidateAndProcessinWarehousePtr', 'else', 'BigDecimal', 'return', 'synchronized', 'void', 'setAllLocalboolean', 'synchronized', 'void', 'setCarrierIdshort', 'synchronized', 'void', 'setEntryDateTimeDate'] ****************
# synchronized
# for
# incustomerptrbigdecimal
# indistricttaxratebigdecimal
# linenumber
# jbbutilgetlogisloggablelevelfinest
# inwarehousetaxratebigdecimal
#
# ************* ['TextColumn', 'void', 'addString', 'blocksaddElementnew', 'TextColumn', 'joinTextColumn', 'return', 'TextColumn', 'joinTextColumn', 'rightString', 'int', 'int', 'int', 'TextColumn', 'combinednew', 'TextColumnwidth', 'columnSeparatorlength', 'for', 'int', 'i0', 'i', 'n', 'i', 'if', 'nleft', 'nright', 'TextBlock', 'emptynew', 'for', 'int', 'in', 'i', 'nright', 'i', 'else', 'TextBlock', 'emptynew', 'for', 'int', 'in', 'i', 'nleft', 'i', 'return', 'TextBlock', 'TextBlock', 'mergednew', 'for', 'Enumeration', 'eblockselements', 'ehasMoreElements', 'return', 'int', 'return', 'TextColumnint', 'TextColumnint', 'widthString'] ****************
# int
# ehasmoreelements
# enumeration
# blocksaddelementnew
# void
# columnseparatorlength
# addstring
#
# ************* ['LoopBounds', 'int', 'constraintAtint', 'Object', 'if', 'o', 'instanceof', 'Integer', 'return', 'else', 'return', 'void', 'for', 'int', 'i0', 'i', 'size', 'i', 'SystemoutprintconstraintAti', 'vnew', 'int', 'int', 'for', 'int', 'i0', 'i', '20', 'i', 'int', 'ff0', 'static', 'void', 'new', 'String', 'try', 'Class', 'Object', 'if', 'o', 'instanceof', 'LoopBounds', 'Systemoutprintlnname', 'is', 'not', 'a', 'catch', 'Exception', 'e', 'SystemoutprintlnError'] ****************
# int
# new
# constraintatint
# class
# is
# size
# not
#
# ************* ['NewOrderTransaction', 'NewOrderTransactionCompany', 'inCompanyshort', 'orderLognew', 'xmlOrderLognew', 'initLognew', 'synchronized', 'void', 'long', 'Customer', 'BigDecimal', 'thisOrdernew', 'Date', 'orderdatenew', 'if', 'orderId', 'companygetInitialOrders', 'companygetInitialNewOrders', 'byte', 'if', 'orderId', 'companygetInitialOrders', 'companygetInitialNewOrders', 'NewOrder', 'theNewOrdernew', 'synchronized', 'void', 'setDistrictandCustomerbyte', 'inDistrictIdshort'] ****************
# synchronized
# companygetinitialneworders
# xmlorderlognew
# newordertransactioncompany
# initlognew
# bigdecimal
# thenewordernew
#
# ************* ['TransactionLogBuffer', 'void', 'int', 'x', 'for', 'y0', 'y', 'rows', 'y', 'for', 'x0', 'x', 'cols', 'x', 'screenBufyx', 'synchronized', 'void', 'int', 'x', 'int', 'int', 'char', 'try', 'for', 'y0', 'y', 'rows', 'y', 'if', 'len', '0', 'for', 'x0', 'x', 'len', 'x', 'catch', 'IOException', 'e', 'SystemoutprintlnIOException', 'ScreenException', 'exceptnew', 'ScreenExceptionscreen', 'write', 'throw', 'void', 'displayPrintStream', 'int', 'x', 'int', 'char', 'try', 'for', 'y0', 'y', 'rows', 'y', 'if', 'len', '0', 'String', 'slinenew', 'else', 'catch', 'Exception', 'e', 'SystemoutprintlnIOException', 'ScreenException', 'exceptnew', 'ScreenExceptionfile', 'write', 'throw', 'int', 'return', 'String', 'getLineint', 'return', 'new', 'final', 'void', 'privCharFillchar', 'cint', 'xint', 'yint', 'int', 'for', 'ix', 'i', 'x', 'len', 'i', 'final', 'void', 'privCharchar', 'cint', 'xint', 'final', 'int', 'privIntLeadingZerosint', 'izint', 'xint', 'yint', 'int', 'i', 'dividend', 'char', 'for', 'ix', 'len', '1', 'i', 'x', 'i', 'dividendiz', 'remainderiz', 'dividend', 'screenLineichar0', 'return', 'final', 'int', 'privIntint', 'izchar', 'signint', 'xint', 'yint', 'int', 'i', 'dividend', 'char', 'ix', 'len', 'do', 'dividendiz', 'remainderiz', 'dividend', 'screenLineichar0', 'while', 'i', 'x', 'iz', 'if', 'i', 'x', 'else', 'if', 'sign', 'for', 'i', 'x', 'i', 'screenLinei', 'return', 'final', 'int', 'privIntint', 'izint', 'xint', 'yint', 'int', 'i', 'dividend', 'char', 'char', 'sign', 'if', 'iz', '0', 'ix', 'len', 'do', 'dividendiz', 'remainderiz', 'dividend', 'screenLineichar0', 'while', 'i', 'x', 'iz', 'if', 'i', 'x', 'else', 'if', 'sign', 'for', 'i', 'x', 'i', 'screenLinei', 'return', 'final', 'long', 'privLonglong', 'izint', 'xint', 'yint', 'int', 'long', 'dividend', 'char', 'char', 'sign', 'if', 'iz', '0', 'ix', 'len', 'do', 'dividendiz', 'remainderiz', 'dividend', 'screenLineichar0', 'while', 'i', 'x', 'iz', 'if', 'i', 'x', 'else', 'if', 'sign', 'for', 'i', 'x', 'i', 'screenLinei', 'return', 'final', 'void', 'privSubstringString', 'sint', 'xint', 'yint', 'offint', 'int', 'int', 'if', 'len', 'slength', 'off', 'slenslength', 'else', 'sgetCharsoffoff', 'if', 'slen', 'len', 'for', 'ix', 'slen', 'i', 'x', 'len', 'i', 'screenBufyi', 'final', 'void', 'privTextString', 'sint', 'xint', 'yint', 'int', 'int', 'if', 'len', 'slength', 'else', 'if', 'slen', 'len', 'for', 'ix', 'slen', 'i', 'x', 'len', 'i', 'screenBufyi', 'final', 'void', 'privTextString', 'sint', 'xint', 'yint', 'lenshort', 'int', 'i', 'int', 'if', 'len', 'slength', 'if', 'align', 'alignRight', 'firstx', 'len', 'else', 'if', 'align', 'alignCenter', 'firstx', 'len', 'slen', 'else', 'else', 'if', 'first', 'x', 'for', 'ix', 'i', 'first', 'i', 'screenBufyi', 'if', 'slen', 'len', 'for', 'ifirst', 'slen', 'i', 'x', 'len', 'i', 'screenBufyi', 'void', 'putCharFillchar', 'cint', 'xint', 'yint', 'int', 'if', 'y', '0', 'y', 'rows', 'ScreenException', 'enew', 'ScreenExceptionScreen', 'row', 'IntegertoStringy', 'out', 'of', 'throw', 'else', 'if', 'x', '0', 'x', 'cols', 'ScreenException', 'enew', 'ScreenExceptionScreen', 'column', 'IntegertoStringx', 'out', 'of', 'throw', 'else', 'if', 'x', 'len', 'cols', 'ScreenException', 'enew', 'ScreenExceptionScreen', 'length', 'IntegertoStringlen', 'exceeds', 'left', 'throw', 'else', 'if', 'x', 'len', 'lineEndy', 'lineEndyx', 'void', 'putCharchar', 'cint', 'xint', 'if', 'y', '0', 'y', 'rows', 'ScreenException', 'enew', 'ScreenExceptionScreen', 'row', 'IntegertoStringy', 'out', 'of', 'throw', 'else', 'if', 'x', '0', 'x', 'cols', 'ScreenException', 'enew', 'ScreenExceptionScreen', 'column', 'IntegertoStringx', 'out', 'of', 'throw', 'else', 'if', 'x', '1', 'lineEndy', 'lineEndyx', 'void', 'putDateDate', 'dint', 'xint', 'yint', 'if', 'y', '0', 'y', 'rows', 'ScreenException', 'enew', 'ScreenExceptionScreen', 'row', 'IntegertoStringy', 'out', 'of', 'throw', 'else', 'if', 'x', '0', 'x', 'cols', 'ScreenException', 'enew', 'ScreenExceptionScreen', 'column', 'I ...
# if
# yint
# else
# length
# integertostringy
# integertostringx
# row
#
# ************* ['MultiVMReport', 'boolean', 'acceptFile', 'dirString', 'return', 'namestartsWithfilePrefix', 'void', 'Enumeration', 'PrintStream', 'ReportProps', 'totalPropsnew', 'String', 'name', 'String', 'singleRawFileNameoutputdirectory', 'Fileseparator', 'File', 'singleRawFilenew', 'if', 'singleRawFileexists', 'for', 'Enumeration', 'eresults0propertyNames', 'ehasMoreElements', 'if', 'namestartsWithresult', 'totalPropsputglobal', 'for', 'int', 'i0', 'i', 'resultslength', 'i', 'for', 'Enumeration', 'eresultsipropertyNames', 'ehasMoreElements', 'if', 'namestartsWithresult', 'totalPropsputi', '1', 'try', 'outRawFilenew', 'Set', 'Vector', 'keyvecnew', 'for', 'int', 'i0', 'i', 'keyvecsize', 'i', 'String', 'String', 'outRawFileprintlnpropsKey', 'catch', 'FileNotFoundException', 'e', 'JBButilgetLoglogLevelWARNINGERROR', 'file', 'not', 'found', 'JBBReportFilenameFilterString', 'prefixString', 'fileSuffixStartfilePrefixLen', 'MultiVMReportString', 'outputdirectoryboolean', 'SPECInternalUseString', 'newsletterboolean', 'useHtmlboolean', 'MultiVMReportString', 'outputdirectoryboolean', 'SPECInternalUseString', 'newsletterboolean', 'useHtmlboolean', 'echoRawString', 'labelImgString', 'String', 'File', 'dirnew', 'if', 'direxists', 'SystemoutprintlnError', 'file', 'outputdirectory', 'doesnt', 'if', 'dirisDirectory', 'SystemoutprintlnError', 'file', 'outputdirectory', 'is', 'not', 'a', 'FilenameFilter', 'filternew', 'File', 'filternew', 'resultsnew', 'metricsnew', 'graphTablenew', 'metricnew', 'labelnew', 'try', 'StringReader', 'tisnew', 'StringReadernew', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'loading', 'titles', 'for', 'double', 'long', 'long', 'boolean', 'for', 'int', 'i0', 'i', 'resultFileslength', 'i', 'resultsinew', 'labeliresultFilesigetNamesubstringprefixlengthprefixlength', 'if', 'SPECInternalUse', 'labeliprefix', 'try', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'reading', 'results', 'file', 'resultFilesi', 'metricsinew', 'try', 'catch', 'NumberFormatException', 'e', 'try', 'catch', 'NumberFormatException', 'e', 'if', 'isMetricsDouble', 'metric2Metricsformatsum', 'thishardwareresults0getconfighwvendor', 'thissoftwareresults0getconfigswvendor'] ****************
# file
# if
# systemoutprintlnerror
# enumeration
# namestartswithresult
# not
# outputdirectory
#
# ************* ['HTMLTableGraphGenerator3', 'void', 'addXYPairdouble', 'if', 'xypair', 'null', 'xypairlength', 'DIM', 'String', 'String', 'if', 'xypairscontainsKeylmx', 'xypairsputlmxnew', 'void', 'void', 'String', 'StringBuffer', 'bufnew', 'bufappendTABLE', 'BORDER1', 'CELLSPACING0', 'bufappendTABLE', 'BORDER0', 'CELLSPACING', 'pad', 'CELLPADDING', 'pad', 'bgcolorEnabled', 'BGCOLOR', 'bgcolor', 'WIDTH', 'sizewidth', 'pixelsize', 'for', 'int', 'y0', 'y', 'sizeheight', 'y', 'if', 'y', '0', 'bufappendTD', 'ALIGNcenter', 'VALIGNmiddle', 'ROWSPAN', 'sizeheight', 'BGCOLORffffff', 'yaxis', 'if', 'y', '10', '0', 'double', 'String', 'labeldfyformatdreplace', 'String', 'colord', '0', 'COLORff0000', 'bufappendTD', 'BGCOLORwhite', 'NOWRAP', 'ROWSPAN10', 'ALIGNright', 'VALIGNtop', 'FONT', 'SIZE1', 'color', 'label', 'for', 'int', 'x0', 'x', 'sizewidth', 'x', 'String', 'String', 'String', 'if', 'xypairscontainsKeysx', 'Vector', 'Enumeration', 'while', 'ehasMoreElements', 'String', 'if', 'svyequalssy', 'bufappendTD', 'WIDTH', 'pixelsize', 'pixelcolorEnabled', 'plotequals', 'BGCOLOR', 'pixelcolor', 'plot', 'bufappendTRTD', 'BGCOLORffffff', 'COLSPAN2', 'for', 'int', 'x0', 'x', 'sizewidth', 'x', 'if', 'x', '10', '0', 'double', 'String', 'labeldfxformatdreplace', 'String', 'colord', '0', 'COLORff0000', 'bufappendTD', 'ALIGNleft', 'BGCOLORwhite', 'NOWRAP', 'COLSPAN10', 'VALIGNtop', 'FONT', 'SIZE1', 'color', 'label', 'bufappendTRTRTD', 'COLSPAN', 'sizewidth', 'ALIGNcenter', 'BGCOLORffffff', 'xaxis', 'return', 'void', 'generateString', 'if', 'filename', 'null', 'try', 'FileWriter', 'fwnew', 'catch', 'IOException', 'ioe', 'JBButilgetLoglogLevelWARNINGIOException', 'Exception', 'e', 'JBButilgetLoglogLevelWARNINGException', 'double', 'getInverseLinearMapXint', 'return', 'scaleMINX', 'x', 'double', 'getInverseLinearMapYint', 'return', 'scaleMAXY', 'y', 'boolean', 'return', 'boolean', 'return', 'void', 'setAxesLabelsPrecisionint', 'xint', 'void', 'setAxesLabelsString', 'xaxisString', 'if', 'yaxislength', '1', 'char', 'for', 'int', 'i0', 'i', 'clength', 'i', 'yaxisnbsp', 'ci', 'void', 'setBackgroundColorEnabledboolean', 'void', 'setBackgroundColorColor', 'if', 'c', 'null', 'void', 'setForegroundColorColor', 'if', 'c', 'null', 'void', 'setPixelBorderColorEnabledboolean', 'void', 'setPixelBorderColorColor', 'if', 'c', 'null', 'void', 'setPixelImageString', 'pixelIMG', 'SRC', 'pixel', 'WIDTH', 'pixelsize', 'HEIGHT', 'pixelsize', 'void', 'setPixelPadSizeint', 'void', 'setTableSizeDimension', 'if', 'size', 'null', 'void', 'setXYPairsdouble', 'if', 'xypairs', 'null', 'for', 'int', 'i0', 'i', 'xypairslength', 'i', 'void', 'setXYPairsVector', 'if', 'xypairs', 'null', 'Enumeration', 'while', 'ehasMoreElements', 'String', 'toHexStringColor', 'return', 'toHexStringcgetRed', 'toHexStringcgetGreen', 'String', 'toHexStringint', 'String', 'return', 'slength', '1', '0', 's'] ****************
# void
# bufappendtd
# bgcolorffffff
# bgcolor
# sizewidth
# double
# width
#
# ************* ['TextBlock', 'void', 'addRightString', 'int', 'int', 'Outer', 'while', 'len', 'i', 'width', 'while', 'textcharAti', 'if', 'len', 'i', 'width', 'break', 'int', 'jtextlastIndexOf', 'while', 'j', 'i', 'width', 'jtextlastIndexOf', 'j', 'if', 'j', 'i', 'linesaddElementtextsubstringii', 'else', 'ij', 'void', 'addTextBlock', 'for', 'EnumerationString', 'eblocklineselements', 'ehasMoreElements', 'TextBlock', 'joinTextBlock', 'return', 'TextBlock', 'joinTextBlock', 'rightString', 'int', 'int', 'int', 'TextBlock', 'combinednew', 'TextBlockwidth', 'columnSeparatorlength', 'for', 'int', 'i0', 'i', 'n', 'i', 'combinedlinesaddElementStringlineselementAti', 'columnSeparator', 'if', 'nleft', 'nright', 'for', 'int', 'in', 'i', 'nright', 'i', 'combinedlinesaddElementspaces', 'columnSeparator', 'else', 'for', 'int', 'in', 'i', 'nleft', 'i', 'combinedlinesaddElementStringlineselementAti', 'columnSeparator', 'return', 'String', 'justifyLeftString', 'ss', 'return', 'static', 'String', 'justifyLeftString', 'sint', 'int', 'if', 'slen', 'width', 'return', 's', 'rep', 'width', 'else', 'return', 'String', 'justifyRightString', 'sspaces', 'int', 'return', 'ssubstringslen', 'static', 'String', 'justifyRightString', 'sint', 'int', 'if', 'slen', 'width', 'return', 'rep', 'width', 'slen', 'else', 'return', 'ssubstringslen', 'static', 'String', 'repString', 'sint', 'StringBuffer', 'bufnew', 'for', 'int', 'i0', 'i', 'n', 'i', 'return', 'TextBlockint', 'spacesrep', 'TextBlockint', 'widthString', 'spacesrep'] ****************
# int
# static
# textblockint
# in
# void
# nright
# len
#
# ************* ['CustomerReportTransaction', 'CustomerReportTransactionCompany', 'inCompanyshort', 'customerLognew', 'xmlCustomerLognew', 'initLognew', 'void', 'customerLogputTextCUSTOMER', 'customerLogputTextLast', 'customerLogputTextLast'] ****************
# customerlogputtextlast
# xmlcustomerlognew
# customerlogputtextcustomer
# customerreporttransactioncompany
# initlognew
# incompanyshort
# customerlognew
#
# ************* ['TimerData', 'synchronized', 'void', 'accumulateTransactionStatslong', 'if', 'transactioncount', 'mintransactioncount', 'if', 'transactioncount', 'maxtransactioncount', 'void', 'timerLognew', 'timerLogputTextTOTALS', 'int', 'int', 'textlength1', 'versionlength', '1', '25', 'int', 'filllength79', 'textlength', 'timerLogputTextJBBmainVersionfilllength', 'timerLogputTextResults', 'time', 'in', 'secondsfilllength', '1', 'versionlength', 'timerLogputCharFillfilllength', '1', 'versionlength', '1', '25', 'timerLogputTextNew', 'timerLogputTextStock', 'timerLogputTextCust', 'timerLogputTextthroughput', 'timerLogputTextSPECjbb2005', 'synchronized', 'void', 'for', 'int', 'i0', 'i', 'TransactionmaxTxnTypes', 'i', 'if', 'transactionCounti', '0', 'averageTimeifloattotalTimei', 'floattransactionCounti', 'standardDeviationTimeiMathsqrtdoubletransactionCounti', 'doubletotalTimeSquarei', 'doubletotalTimei', 'doubletotalTimei', 'doubletransactionCounti', 'doubletransactionCounti', 'coefficientOfVariationTimei1000', 'standardDeviationTimei', 'doubletotalTimei', 'else', 'synchronized', 'void', 'displayResultsString', 'titlelong', 'totalMemlong', 'long', 'usedMemtotalMem', 'double', 'totalMBdoubletotalMem', 'double', 'usedMBdoubleusedMem', 'timerLogputTextHeap', 'timerLogputText', 'synchronized', 'void', 'long', 'diffmaxtransactioncount', 'float', 'diffpct100', 'floatdiff', 'void', 'formatResultsTransactionLogBuffer', 'timerLogputDoubletotalTimeTransactionneworder', 'timerLogputDoubleminimumTimeTransactionneworder', 'timerLogputDoublemaximumTimeTransactionneworder', 'timerLogputDoubletotalTimeTransactionpayment', 'timerLogputDoubleminimumTimeTransactionpayment', 'timerLogputDoublemaximumTimeTransactionpayment', 'timerLogputDoubletotalTimeTransactionorderstatus', 'timerLogputDoubleminimumTimeTransactionorderstatus', 'timerLogputDoublemaximumTimeTransactionorderstatus', 'timerLogputDoubletotalTimeTransactiondelivery', 'timerLogputDoubleminimumTimeTransactiondelivery', 'timerLogputDoublemaximumTimeTransactiondelivery', 'timerLogputDoubletotalTimeTransactionstocklevel', 'timerLogputDoubleminimumTimeTransactionstocklevel', 'timerLogputDoublemaximumTimeTransactionstocklevel', 'timerLogputDoubletotalTimeTransactioncustreport', 'timerLogputDoubleminimumTimeTransactioncustreport', 'timerLogputDoublemaximumTimeTransactioncustreport', 'synchronized', 'double', 'double', 'return', 'synchronized', 'long', 'getMaximumTimeint', 'long', 'return', 'synchronized', 'long', 'long', 'return', 'synchronized', 'long', 'getMenuWaitTimeint', 'long', 'return', 'synchronized', 'long', 'getMinimumTimeint', 'long', 'return', 'synchronized', 'long', 'long', 'return', 'synchronized', 'long', 'getThinkingWaitTimeint', 'long', 'return', 'synchronized', 'long', 'getTotalTimeSquareint', 'long', 'return', 'synchronized', 'long', 'getTotalTimeint', 'long', 'return', 'synchronized', 'double', 'double', 'return', 'synchronized', 'long', 'getTransactionCountint', 'long', 'return', 'synchronized', 'long', 'getTypingWaitTimeint', 'long', 'return', 'synchronized', 'long', 'long', 'tempnew', 'return', 'void', 'int', 'waittimesmenunew', 'waittimestypingnew', 'waittimesthinkingnew', 'transactionCountnew', 'totalTimenew', 'minimumTimenew', 'maximumTimenew', 'averageTimenew', 'totalTimeSquarenew', 'standardDeviationTimenew', 'coefficientOfVariationTimenew', 'for', 'i0', 'i', 'TransactionmaxTxnTypes', 'i', 'synchronized', 'void', 'propResultsString', 'prefixPrintStream', 'outprintlnprefix', 'newordercount', 'outprintlnprefix', 'newordertotaltime', 'totalTimeTransactionneworder', 'outprintlnprefix', 'neworderminimumtime', 'minimumTimeTransactionneworder', 'outprintlnprefix', 'newordermaximumtime', 'maximumTimeTransactionneworder', 'outprintlnprefix', 'neworderaveragetime', 'outprintlnprefix', 'neworderstddevtime', 'standardDeviationTimeTransactionneworder', 'outprintlnprefix', 'newordercoeffvartime', 'outprintlnprefix', 'paymentcount', 'outprintlnprefix', 'paymenttotaltime', 'totalT ...
# outprintlnprefix
# transactionmaxtxntypes
# for
# i0
# if
# transactioncount
# totalmemlong
#
# ************* ['Result', 'String', 'detailRowint', 'StringBuffer', 'bufnew', 'bufappend', 'TD', 'ALIGNRIGHT', 'Runtransactionn', 'bufappend', 'TD', 'ALIGNRIGHT', 'runncount', 'bufappend', 'TD', 'ALIGNRIGHT', 'Metricsformatrunntotaltime', 'bufappend', 'TD', 'ALIGNRIGHT', 'Metricsformatrunnmaximumtime', 'return', 'double', 'return', 'long', 'return', 'double', 'return', 'double', 'return', 'long', 'return', 'long', 'return', 'double', 'return', 'ResultString', 'nameReportProps', 'referenceTimepropsgetDoubleconfig', 'name', 'if', 'maxBarWidth', '0', 'VectorRun', 'rvnew', 'scorepropsgetDoubleresult', 'name', 'warehousespropsgetIntresult', 'name', 'elapsedpropsgetDoubleresult', 'name', 'heapsizepropsgetDoubleresult', 'name', 'heapusedpropsgetDoubleresult', 'name', 'if', 'jvminstances', '1', 'startrampuptimemillisecondspropsgetLongresult', 'name', 'endrampdowntimemillisecondspropsgetLongresult', 'name', 'starttimemillisecondspropsgetLongresult', 'name', 'endtimemillisecondspropsgetLongresult', 'name', 'minthreadtransactionspropsgetDoubleresult', 'name', 'maxthreadtransactionspropsgetDoubleresult', 'name', 'Run', 'for', 'int', 'i0', 'i', '6', 'i', 'rnew', 'runnew', 'if', 'runlength', '0', 'invalidReasonappendname', 'was', 'not', 'else', 'for', 'int', 'i0', 'i', 'runlength', 'i', 'double', 'return', 'String', 'shiftedtoRowint', 'StringBuffer', 'bufnew', 'bufappend', 'TD', 'ALIGNRIGHT', 'intwarehouses', 'bufappend', 'TD', 'bufappend', 'TD', 'bufappend', 'TD', 'ALIGNRIGHT', 'Metricsformatscore', 'if', 'whAtPeak', 'intwarehouses', 'intwarehouses', '2', 'whAtPeak', 'bufappend', 'TD', 'ALIGNRIGHT', 'else', 'bufappend', 'TD', 'ALIGNRIGHT', 'nbsp', 'return', 'long', 'return', 'String', 'StringBuffer', 'bufnew', 'if', 'runlength', '0', 'bufappend', 'TD', 'name', 'bufappend', 'TD', 'COLSPAN8Inot', 'else', 'bufappend', 'TD', 'VALIGNTOP', 'ALIGNRIGHT', 'ROWSPAN', 'runlength', 'intwarehouses', 'bufappend', 'TD', 'VALIGNTOP', 'ALIGNRIGHT', 'ROWSPAN', 'runlength', 'Metricsformatscore', 'bufappend', 'TD', 'VALIGNTOP', 'ALIGNRIGHT', 'ROWSPAN', 'runlength', 'Metricsformatheapsize', 'bufappend', 'TD', 'VALIGNTOP', 'ALIGNRIGHT', 'ROWSPAN', 'runlength', 'Metricsformatheapused', 'bufappend', 'TD', 'VALIGNTOP', 'ALIGNCENTER', 'ROWSPAN', 'runlength', 'Metricsformat100', 'maxthreadtransactions', 'minthreadtransactions', 'maxthreadtransactions', 'bufappend', 'TD', 'VALIGNTOP', 'ALIGNRIGHT', 'ROWSPAN', 'runlength', 'Metricsformat01', 'elapsed', '1000', 'measint', 'measint', 'for', 'int', 'i1', 'i', 'runlength', 'i', 'return', 'String', 'toFirstRowint', 'StringBuffer', 'bufnew', 'bufappend', 'TD', 'ALIGNRIGHT', 'intwarehouses', 'bufappend', 'TD', 'ALIGNRIGHT', 'Metricsformatscore', 'if', 'whAtPeak', 'intwarehouses', 'intwarehouses', '2', 'whAtPeak', 'bufappend', 'TD', 'ALIGNRIGHT', 'else', 'bufappend', 'TD', 'ALIGNRIGHT', 'nbsp', 'bufappend', 'TD', 'ALIGNRIGHT', 'nbsp', 'bufappend', 'TD', 'ALIGNRIGHT', 'nbsp', 'return', 'String', 'toRowint', 'StringBuffer', 'bufnew', 'bufappend', 'TD', 'ALIGNRIGHT', 'intwarehouses', 'bufappend', 'TD', 'ALIGNRIGHT', 'Metricsformatscore', 'if', 'whAtPeak', 'intwarehouses', 'intwarehouses', '2', 'whAtPeak', 'bufappend', 'TD', 'ALIGNRIGHT', 'else', 'bufappend', 'TD', 'ALIGNRIGHT', 'return', 'String', 'TwoRowResult', 'result2Metrics', 'metrics2int', 'whAtPeakint', 'StringBuffer', 'bufnew', 'bufappend', 'TD', 'ALIGNRIGHT', 'intwarehouses', 'bufappend', 'TD', 'ALIGNRIGHT', 'Metricsformatscore', 'if', 'whAtPeak', 'intwarehouses', 'intwarehouses', '2', 'whAtPeak', 'bufappend', 'TD', 'ALIGNRIGHT', 'else', 'bufappend', 'TD', 'ALIGNRIGHT', 'nbsp', 'bufappend', 'TD', 'ALIGNRIGHT', 'Metricsformatmetrics2scoreatwhintwarehouses', 'if', 'whAtPeak2', 'warehouses', 'warehouses', '2', 'whAtPeak2', 'bufappend', 'TD', 'ALIGNRIGHT', 'else', 'bufappend', 'TD', 'ALIGNRIGHT', 'nbsp', 'return', 'int', 'return'] ****************
# td
# bufappend
# bufnew
# else
# metricsformatscore
# if
# stringbuffer
#
# ************* ['digestExpected', 'byte', 'return'] ****************
# digestexpected
# byte
# return
#
# ************* ['Table', 'String', 'expandNString', 'StringBuffer', 'sbnew', 'char', 'nbnew', 'boolean', 'for', 'int', 'i0', 'i', 'nblength', '1', 'i', 'if', 'nbi', 'nbi', '1', 'n', 'else', 'if', 'sub', 'sbappendnbnblength', 'return', 'String', 'insertBreakAfterColonsString', 'StringBuffer', 'sbnew', 'char', 'cnew', 'for', 'int', 'i0', 'i', 'clength', 'i', 'if', 'i', '1', 'ci', 'ci', 'if', 'ci', '2', 'ci', '2', 'return', 'hBufferedReader', 'inReportProps', 'propsReportProps', 'titlesboolean', 'itemsnew', 'String', 'try', 'while', 'lineinreadLine', 'null', 'if', 'lineequals', 'catch', 'IOException', 'e'] ****************
# if
# nbi
# stringbuffer
# char
# return
# insertbreakaftercolonsstring
# int
#
# ...
# if
# void
# int
# string
# warehouse
# logfinest
# outpropfileprintlnpropprefix
#
# ************* ['DeliveryHandler', 'DeliveryHandlerPrintStream', 'getClass', 'void', 'handleDeliveryDeliveryTransaction'] ****************
# deliveryhandlerprintstream
# getclass
# deliveryhandler
# handledeliverydeliverytransaction
# void
#
# ************* ['SaveOutput', 'static', 'void', 'startString', 'f', 'throws', 'IOException', 'logfilenew', 'PrintStreamnew', 'BufferedOutputStreamnew', 'SystemsetOutnew', 'SystemsetErrnew', 'static', 'void', 'try', 'catch', 'Exception', 'e', 'JBButilgetLoglogLevelWARNINGException', 'void', 'writebyte', 'bufint', 'offint', 'try', 'catch', 'Exception', 'e', 'JBButilgetLoglogLevelWARNINGException', 'void', 'writeint', 'try', 'catch', 'Exception', 'e', 'JBButilgetLoglogLevelWARNINGException'] ****************
# void
# systemsetoutnew
# bufferedoutputstreamnew
# throws
# printstreamnew
# saveoutput
# logfilenew
#
# ************* ['Address', 'synchronized', 'String', 'String', 'return', 'synchronized', 'String', 'String', 'return', 'synchronized', 'String', 'String', 'return', 'synchronized', 'String', 'String', 'return', 'synchronized', 'String', 'String', 'return', 'synchronized', 'void', 'setUsingRandomRandom', 'street1new', 'street1new', 'street2new', 'citynew', 'statenew', 'zipnew'] ****************
# string
# return
# setusingrandomrandom
# street1new
# synchronized
# address
# citynew
#
# ************* ['JBBProperties', 'void', 'boolean', 'SystemoutprintlnnnChecking', 'whether', 'run', 'will', 'be', 'if', 'checkThroughput', 'else', 'compliantcheckCompliancewarehousePopulationBaseCOMPLIANTRATEwarehousePopulationBasewarehousepopulationbase', 'compliantcheckComplianceorderlinesPerOrderCOMPLIANTRATEorderlinesPerOrderorderlinesperorder', 'compliantcheckCompliancedeterministicRandomSeedCOMPLIANTRATEdeterministicRandomSeeddeterministicrandomseed', 'compliantcheckComplianceperjvmwarehouserampupCOMPLIANTRATEperjvmwarehouserampupperjvmwarehouserampup', 'compliantcheckComplianceperjvmwarehouserampdownCOMPLIANTRATEperjvmwarehouserampdownperjvmwarehouserampdown', 'compliantcheckCompliancerampupSecondsCOMPLIANTRATErampupSecondsrampupseconds', 'compliantcheckCompliancemeasurementSecondsCOMPLIANTRATEmeasurementSecondsmeasurementseconds', 'compliantcheckCompliancewaitTimePercentCOMPLIANTRATEwaitTimePercentwaittimepercent', 'compliantcheckCompliancesteadyStateFlagCOMPLIANTRATEsteadyStateFlagsteadystate', 'compliantcheckCompliancescreenWriteFlagCOMPLIANTRATEscreenWriteFlagscreenwrite', 'compliantcheckComplianceuniformRandomItemsCOMPLIANTRATEuniformRandomItemsuniformrandomitems', 'compliantcheckComplianceapplicationLoggingLevelCOMPLIANTRATEapplicationLoggingLevelloglevel', 'if', 'overrideItemTableSize', '0', 'compliantcheckComplianceoverrideItemTableSizeCOMPLIANTRATEoverrideItemTableSizeoverrideitemtablesize', 'if', 'compliant', 'SystemoutprintlnRun', 'will', 'be', 'else', 'SystemoutprintlnINVALID', 'Run', 'will', 'NOT', 'be', 'boolean', 'checkComplianceboolean', 'actualValueboolean', 'compliantValueString', 'if', 'actualValue', 'compliantValue', 'SystemoutprintlnINVALID', 'name', 'actualValue', 'must', 'be', 'return', 'return', 'boolean', 'checkCompliancefloat', 'actualValuefloat', 'compliantValueString', 'if', 'actualValue', 'compliantValue', 'SystemoutprintlnINVALID', 'name', 'actualValue', 'must', 'be', 'return', 'return', 'boolean', 'checkComplianceint', 'actualValueint', 'compliantValueString', 'if', 'actualValue', 'compliantValue', 'SystemoutprintlnINVALID', 'name', 'actualValue', 'must', 'be', 'return', 'return', 'boolean', 'checkComplianceLevel', 'actualValueLevel', 'compliantValueString', 'if', 'actualValueequalscompliantValue', 'false', 'SystemoutprintlnINVALID', 'name', 'actualValue', 'must', 'be', 'return', 'return', 'boolean', 'copyPropsToOutputPrintStream', 'boolean', 'String', 'int', 'for', 'Enumeration', 'ePropertiesForBatchpropertyNames', 'ehasMoreElements', 'String', 'if', 'namestartsWithconfig', 'else', 'if', 'namestartsWithinput', 'boolean', 'for', 'int', 'i0', 'i', 'inputpropslength', 'i', 'if', 'nameequalsinput', 'inputpropsi', 'if', 'found', 'else', 'if', 'nameequalsinputmincapacityratio', 'if', 'checkThroughput', 'else', 'SystemoutprintlnERROR', 'Property', 'file', 'Systemoutprintln', 'inputmincapacityratio', 'invalid', 'for', 'else', 'if', 'nameequalsinputshowwarehousedetail', 'if', 'PropertiesForBatchgetPropertyinputshowwarehousedetailequalsIgnoreCasetrue', 'else', 'SystemoutprintlnERROR', 'Property', 'file', 'Systemoutprintln', 'Unrecognized', 'property', 'else', 'SystemoutprintlnERROR', 'Property', 'file', 'Systemoutprintln', 'Unrecognized', 'property', 'if', 'retval', 'Vector', 'keyvecnew', 'for', 'int', 'i0', 'i', 'keyvecsize', 'i', 'String', 'String', 'outRawFileprintlnpropsKey', 'Integer', 'procsAvailnew', 'outRawFileprintlnconfigswprocsAvailtoJava', 'return', 'Level', 'return', 'String', 'getOptionalPropertyString', 'try', 'return', 'catch', 'NullPointerException', 'e', 'return', 'boolean', 'String', 'String', 'int', 'boolean', 'boolean', 'valgetRequiredPropertyprefix', 'if', 'val', 'null', 'if', 'valequalsSPECjbb', 'else', 'SystemoutprintlnERROR', 'Property', 'file', 'Systemoutprintln', 'suite', 'must', 'be', 'else', 'valgetRequiredPropertyprefix', 'if', 'val', 'null', 'try', 'catch', 'IllegalArgumentException', 'iae', 'else', 'if', 'checkThroughput', 'valgetRequiredPropertyprefix', 'if', 'val',  ...
# if
# systemoutprintlnerror
# valgetrequiredpropertyprefix
# file
# int
# null
# systemoutprintln
#
# ************* ['Infrastructure', 'static', 'JBBSortedStorage', 'return', 'new', 'static', 'JBBDataStorage', 'return', 'new', 'static', 'JBBDataStorage', 'createStorageboolean', 'JBBDataStorage', 'if', 'synch', 'return', 'static', 'JBBDataStorage', 'synchStorageJBBDataStorage', 'return', 'new'] ****************
# static
# return
# new
# if
# infrastructure
# synch
# synchstoragejbbdatastorage
#
# ************* ['Title', 'String', 'return', 'tspecinitialclientFileProperty', 'filen', 'specinitialserverFileServer', 'property', 'filen', 'specinitialmaxRows', 'of', 'fields', 'per', 'edit', 'paneln', 'confighwvendorHardware', 'Vendorn', 'confighwvendorurlVendor', 'URLn', 'confighwmodelModeln', 'confighwprocessorProcessorn', 'confighwMHzMHzn', 'confighwnchips', 'of', 'Chipsn', 'confighwncores', 'of', 'Coresn', 'confighwncoresperchip', 'of', 'CoresChipn', 'confighwhwThreadsHW', 'Threading', 'Enabledn', 'configswprocsAvailtoJavaProcs', 'Avail', 'to', 'Javan', 'confighwmemoryMemory', 'MBn', 'confighwmemorydescriptionMemory', 'Detailsn', 'confighwprimaryCachePrimary', 'cachen', 'confighwsecondaryCacheSecondary', 'cachen', 'confighwotherCacheOther', 'cachen', 'confighwfileSystemFilesystemn', 'confighwdiskDisksn', 'confighwotherOther', 'hardwaren', 'confighwavailableHw', 'availablen', 'configswvendorSoftware', 'Vendorn', 'configswvendorurlVendor', 'URLn', 'configswJVMJVM', 'Versionn', 'configswcommandlineJVM', 'Command', 'Linen', 'configswJVMavailableJVM', 'availablen', 'configswJVMheapInitialJVM', 'Initial', 'Heap', 'Memory', 'MBn', 'configswJVMheapMaxJVM', 'Maximum', 'Heap', 'Memory', 'MB', 'n', 'configswJVMbitnessJVM', 'Address', 'bits', 'n', 'javaclasspathJVM', 'CLASSPATHn', 'sunbootclasspathJVM', 'BOOTCLASSPATHn', 'configswOSOS', 'Versionn', 'configswOSavailableOS', 'availablen', 'configswotherOther', 'softwaren', 'configswotherAvailableOther', 'sw', 'availablen', 'configswnotesOther', 'Notesn', 'configtesttestedByTested', 'byn', 'configtestspecLicenseSPEC', 'license', 'n', 'configtestlocationTest', 'locationn', 'configtestdateTest', 'daten', 'configtestxemailToMail', 'test', 'results', 'ton', 'configtestxemailReturnYour', 'return', 'email', 'addressn', 'configtestxmailHostOutgoing', 'SMTP', 'mail', 'servern', 'configtestxtestedByNameTested', 'by', 'personn', 'configtestxinternalReferenceInternal', 'Referencen', 'specothertestTimeTest', 'timen', 'specotherversionSPEC', 'versionn', 'specotherversionDateSPEC', 'release', 'daten', 'specotherreportDateDate', 'report'] ****************
# of
# daten
# memory
# heap
# urln
# return
# filen
#
# ************* ['Run', 'double', 'double', 'if', 'time', '0', 'return', 'else', 'return', 'ref', 'RunReportProps', 'propsint', 'runNumberdouble', 'timeResult', 'String', 'prefixresult', 'resultname', 'company', 'countpropsgetIntprefix', 'totaltimepropsgetDoubleprefix', 'minimumtimepropsgetDoubleprefix', 'maximumtimepropsgetDoubleprefix', 'averagetimepropsgetDoubleprefix'] ****************
# double
# return
# countpropsgetintprefix
# run
# minimumtimepropsgetdoubleprefix
# runnumberdouble
# runreportprops
#
# ************* ['JBButil', 'static', 'String', 'chooserandomlastnameint', 'maxCustomersshort', 'short', 'String', 'return', 'static', 'char', 'createastringwithoriginalint', 'lengthloint', 'lengthhifloat', 'percenttosetInteger', 'long', 'int', 'actuallength', 'char', 'int', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'if', 'f', 'percenttoset', 'startposrandom0templength', 'return', 'static', 'char', 'createastringwithoriginalint', 'lengthloint', 'lengthhifloat', 'percenttosetInteger', 'hitshort', 'long', 'int', 'actuallength', 'char', 'int', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'if', 'f', 'percenttoset', 'startposrandom0templength', 'return', 'static', 'char', 'createrandomastringint', 'lengthloint', 'int', 'i', 'actuallength', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'if', 'aRandInt', '61', 'return', 'static', 'char', 'createrandomastringint', 'lengthloint', 'lengthhiRandom', 'int', 'i', 'actuallength', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'if', 'aRandInt', '61', 'return', 'static', 'char', 'createrandomastringint', 'lengthloint', 'lengthhishort', 'int', 'i', 'actuallength', 'Random', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'if', 'aRandInt', '61', 'return', 'static', 'short', 'createrandomcustomeridint', 'maxCustomersshort', 'int', 'acidJBButilACID', 'maxCustomers', 'int', 'ccidJBButilCCID', 'maxCustomers', 'short', 'return', 'static', 'float', 'createrandomfloatvalreturnfloat', 'vallofloat', 'valhifloat', 'float', 'f', 'ffloatrnextFloat', 'valhi', 'vallo', 'resultf', 'return', 'static', 'float', 'createrandomfloatvalreturnfloat', 'vallofloat', 'valhifloat', 'precisionRandom', 'float', 'f', 'ffloatrnextFloat', 'valhi', 'vallo', 'resultf', 'return', 'static', 'float', 'createrandomfloatvalreturnfloat', 'vallofloat', 'valhifloat', 'precisionshort', 'float', 'f', 'Random', 'ffloatrnextFloat', 'valhi', 'vallo', 'resultf', 'return', 'static', 'int', 'createrandomitemidint', 'maxItemsshort', 'int', 'aoliidJBButilAOLIID', 'maxItems', 'int', 'coliidJBButilCOLIID', 'maxItems', 'int', 'if', 'JBBmainuniformRandomItems', 'else', 'return', 'static', 'String', 'createrandomlastnameint', 'custnumshort', 'int', 'String', 'if', 'custnum', '0', 'custnum', '1000', 'else', 'randomnumcustnum', 'templastnamepartsrandomnum', 'temptemp', 'lastnamepartsrandomnum', 'temptemp', 'return', 'static', 'char', 'createrandomnstringint', 'lengthloint', 'int', 'i', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'return', 'static', 'char', 'createrandomnstringint', 'lengthloint', 'lengthhiRandom', 'int', 'i', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'return', 'static', 'char', 'createrandomnstringint', 'lengthloint', 'lengthhishort', 'int', 'i', 'Random', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'return', 'static', 'long', 'long', 'return', 'static', 'long', 'long', 'return', 'static', 'long', 'long', 'resultresult', 'return', 'static', 'Random', 'derivedrandominitshort', 'Random', 'r1new', 'r1setSeedlongrnextInt', '0x7fffffff', 'return', 'static', 'Logger', 'return', 'static', 'void', 'milliSecondsToSleeplong', 'try', 'catch', 'InterruptedException', 'e', 'JBButilgetLoglogLevelWARNING', 'Exception', 'SLEEP', 'static', 'double', 'negativeExpDistributiondouble', 'meanshort', 'Random', 'double', 'double', 'double', 'meanX10mean', 'tMathlogrf', 'if', 't', 'meanX10', 'return', 'static', 'int', 'NUrandvalint', 'Aint', 'xint', 'yint', 'CRandom', 'return', 'random0Ar', 'randomxyr', 'C', 'y', 'x', '1', 'static', 'int', 'NUrandvalint', 'Aint', 'xint', 'yint', 'Cshort', 'Random', 'return', 'random0Ar', 'randomxyr', 'C', 'y', 'x', '1', 'static', 'void', 'randominitint', 'rnew', 'warehouserandomstreamnew', 'static', 'int', 'randomint', 'lowint', 'return', 'rnextInt', '0x7fffffff', 'high', 'low', '1', 'static', 'int', 'randomint', 'lowint', 'highRandom', 'return', 'rnextInt', '0x7fffffff', 'high', 'low', '1', 'static', 'int', 'randomint', 'lowint', 'highsho ...
# static
# lengthloint
# tempnew
# float
# for
# i0
# long

# %%
c = []
for i in range(len(class_name)):
      for j in range(len(acsm)):
        if i==j:
            t=[class_name[i],acsm[j]]
            c.append(t)

c = np.array(c)

# %%
from keras import Input,Model
from keras.layers import Dense

# %%
def additem(list):
    if len(list)<3:
        q = len(list)-1
        str = '_1'
        str2 = '_2'
        item = ''.join([list[q], str])
        item_2 = ''.join([list[q], str2])
        # item = list[q]
        list.append(item)
        list.append(item_2)
        # print(list)
    return list

# %%
def word2vec_train(index):
    list = []
    list.append(index[0])
    words = []

    additem(index)
    # for text in index:
    #     #     print(text)
    print(index)
    for word in index:
        if word not in words:
            words.append(word)

    # words = set(words)
    # print(words)

    word2int = {}
    for i,word in enumerate(words):
        word2int[word] = i
    print(word2int)



    WINDOW_SIZE=2
    data = []
    # for sentence in index:
    for idx,word in enumerate(index):
        for neighbor in index[max(idx - WINDOW_SIZE,0) : min(idx + WINDOW_SIZE,len(index))+ 1]:
            if neighbor != word:
                data.append([word, neighbor])
    #                 print(data)
    df = pd.DataFrame(data,columns=['input','label'])

    # print(df)

    ONE_HOT_DIM = len(words)
    #function to convert numbers to one hot vectors
    def to_one_hot_encoding(data_point_index):
        one_hot_encoding = np.zeros(ONE_HOT_DIM)
        one_hot_encoding[data_point_index] = 1
        return one_hot_encoding

    X = []
    Y = []

    for x, y in zip(df['input'],df['label']):
        X.append(to_one_hot_encoding(word2int[x]))
        Y.append(to_one_hot_encoding(word2int[y]))

    x_train = np.array(X)
    y_train = np.array(Y)


    #Defining the size of the embedding
    embed_size = 3
    xx = Input(shape=(x_train.shape[1],))
    yy = Dense(units=embed_size, activation='linear')(xx)
    yy =Dense(units=y_train.shape[1],activation='softmax')(yy)
    model = Model(inputs=xx, outputs=yy)
    model.compile(loss = 'categorical_crossentropy',optimizer = 'adam')
    #optimizing the network weights
    model.fit(x=x_train,y=y_train,
            batch_size=16,
            epochs=10
    )
    weights = model.get_weights()[0]
    # embedding = []
    # embedding.append[index[0]]

    for word in words:
        # list = []
        # list.append(word)
        q = weights[df.get(word)]

        arr_new = np.sum(q, axis=1)
        print('-----------------------')
        print(arr_new.shape)
        print('-----------------------')
        arr_new = arr_new.tolist()

        list.append(arr_new)

        break
        # list.append(q)
        # # print(weights[df.get(word)].shape)
        # print(word)
        # print(q)
        # print('---')
        # embedding.append(list)
    return list

# %%
embedding = []
for item in index[0:200]:
    embedding.append(word2vec_train(item))
print(embedding)
# Out:
# ['OrderStatusTransaction', 'OrderStatusTransactionCompany', 'inCompanyshort', 'int', 'olsupplyingwarehousenew', 'olitemidnew', 'olitemnamenew', 'olquantitynew', 'olstocknew', 'olbgnew', 'olitempricenew', 'olamountnew', 'oldeliverydatenew', 'orderLognew', 'xmlOrderLognew', 'initLognew', 'void', 'orderLogputTextSupplyW', 'ItemId', 'Qty', 'Amount']
# {'OrderStatusTransaction': 0, 'OrderStatusTransactionCompany': 1, 'inCompanyshort': 2, 'int': 3, 'olsupplyingwarehousenew': 4, 'olitemidnew': 5, 'olitemnamenew': 6, 'olquantitynew': 7, 'olstocknew': 8, 'olbgnew': 9, 'olitempricenew': 10, 'olamountnew': 11, 'oldeliverydatenew': 12, 'orderLognew': 13, 'xmlOrderLognew': 14, 'initLognew': 15, 'void': 16, 'orderLogputTextSupplyW': 17, 'ItemId': 18, 'Qty': 19, 'Amount': 20}
# Epoch 1/10
# 5/5 [==============================] - 1s 3ms/step - loss: 3.0532
# Epoch 2/10
# 5/5 [==============================] - 0s 3ms/step - loss: 3.0506
# Epoch 3/10
# 5/5 [==============================] - 0s 3ms/step - loss: 3.0486
# Epoch 4/10
# 5/5 [==============================] - 0s 3ms/step - loss: 3.0468
# Epoch 5/10
# 5/5 [==============================] - 0s 3ms/step - loss: 3.0449
# Epoch 6/10
# 5/5 [==============================] - 0s 3ms/step - loss: 3.0432
# Epoch 7/10
# 5/5 [==============================] - 0s 3ms/step - loss: 3.0415
# Epoch 8/10
# 5/5 [==============================] - 0s 3ms/step - loss: 3.0396
# Epoch 9/10
# 5/5 [==============================] - 0s 3ms/step - loss: 3.0379
# Epoch 10/10
# 5/5 [==============================] - 0s 3ms/step - loss: 3.0360
# -----------------------
# (1, 3)
# -----------------------
# ['MultiVMTxtReport', 'void', 'int', 'int', 'long', 'long', 'long', 'long', 'long', 'long', 'long', 'long', 'for', 'int', 'n1', 'n', 'instances', 'n', 'if', 'count', 'metricsngetWarehousesTested', 'if', 'instancesChecked', 'instances', 'SystemoutprintlnINVALID', 'Instances', 'do', 'not', 'have', 'identical', 'test', 'else', 'for', 'int', 'i1', 'i', 'count', 'instanceChecksPassed', 'i', 'for', 'int', 'j0', 'j', 'instances', 'j', 'if', 'tmpStart', 'firststartmillis', 'if', 'tmpRampup', 'lastrampupmillis', 'if', 'tmpRampdown', 'firstrampdownmillis', 'if', 'tmpEnd', 'lastendmillis', 'if', 'firstrampdownmillis', 'lastendmillis', 'firststartmillis', 'lastrampupmillis', 'else', 'MultiVMTxtReportString', 'newsletterString', 'outputdirectoryboolean', 'MultiVMTxtReportString', 'newsletterString', 'outputdirectoryboolean', 'SPECInternalUseString', 'String', 'File', 'dirnew', 'if', 'direxists', 'SystemoutprintlnError', 'file', 'outputdirectory', 'doesnt', 'if', 'dirisDirectory', 'SystemoutprintlnError', 'file', 'outputdirectory', 'is', 'not', 'a', 'FilenameFilter', 'filternew', 'File', 'resultsnew', 'metricsnew', 'metricnew', 'double', 'boolean', 'for', 'int', 'i0', 'i', 'resultFileslength', 'i', 'resultsinew', 'try', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'reading', 'results', 'file', 'resultFilesi', 'metricsinew', 'try', 'catch', 'NumberFormatException', 'e', 'if', 'isMetricsDouble', 'metric2Metricsformatsum', 'thishardwaregetconfighwvendor', 'for', 'int', 'i0', 'i', 'metricslength', 'i', 'if', 'metricsivalid', 'thissoftwaregetconfigswvendor']
# {'MultiVMTxtReport': 0, 'void': 1, 'int': 2, 'long': 3, 'for': 4, 'n1': 5, 'n': 6, 'instances': 7, 'if': 8, 'count': 9, 'metricsngetWarehousesTested': 10, 'instancesChecked': 11, 'SystemoutprintlnINVALID': 12, 'Instances': 13, 'do': 14, 'not': 15, 'have': 16, 'identical': 17, 'test': 18, 'else': 19, 'i1': 20, 'i': 21, 'instanceChecksPassed': 22, 'j0': 23, 'j': 24, 'tmpStart': 25, 'firststartmillis': 26, 'tmpRampup': 27, 'lastrampupmillis': 28, 'tmpRampdown': 29, 'firstrampdownmillis': 30, 'tmpEnd': 31, 'lastendmillis': 32, 'MultiVMTxtReportString': 33, 'newsletterString': 34, 'outputdirectoryboolean': 35, 'SPECInternalUseString': 36, 'String': 37, 'File': 38, 'dirnew': 39, 'direxists': 40, 'SystemoutprintlnError': 41, 'file': 42, 'outputdirectory': 43, 'doesnt': 44, 'dirisDirectory': 45, 'is': 46, 'a': 47, 'FilenameFilter': 48, 'filternew': 49, 'resultsnew': 50, 'metricsnew': 51, 'metricnew': 52, 'double': 53, 'boolean': 54, 'i0': 55, 'resultFileslength': 56, 'resultsinew': 57, 'try': 58, 'catch': 59, 'IOException': 60, 'e': 61, 'JBButilgetLoglogLevelWARNINGError': 62, 'reading': 63, 'results': 64, 'resultFilesi': 65, 'metricsinew': 66, 'NumberFormatException': 67, 'isMetricsDouble': 68, 'metric2Metricsformatsum': 69, 'thishardwaregetconfighwvendor': 70, 'metricslength': 71, 'metricsivalid': 72, 'thissoftwaregetconfigswvendor': 73}
# Epoch 1/10
# 30/30 [==============================] - 0s 2ms/step - loss: 4.3023
# Epoch 2/10
# 30/30 [==============================] - 0s 2ms/step - loss: 4.2926
# Epoch 3/10
# 30/30 [==============================] - 0s 2ms/step - loss: 4.2838
# Epoch 4/10
# 30/30 [==============================] - 0s 2ms/step - loss: 4.2750
# Epoch 5/10
# 30/30 [==============================] - 0s 2ms/step - loss: 4.2657
# Epoch 6/10
# 30/30 [==============================] - 0s 2ms/step - loss: 4.2560
# Epoch 7/10
# 30/30 [==============================] - 0s 3ms/step - loss: 4.2457
# Epoch 8/10
# 30/30 [==============================] - 0s 2ms/step - loss: 4.2343
# Epoch 9/10
# 30/30 [==============================] - 0s 2ms/step - loss: 4.2225
# Epoch 10/10
# 30/30 [==============================] - 0s 2ms/step - loss: 4.2091
# -----------------------
# (1, 3)
# -----------------------
# ['Sub', 'String', 'return', 'int', 'return', 'priv', 'int', 'return', 'prot', 'Subint', 'superblack', 'pubblack']
# {'Sub': 0, 'String': 1, 'return': 2, 'int': 3, 'priv': 4, 'prot': 5, 'Subint': 6, 'superblack': 7, 'pubblack': 8}
# Epoch 1/10
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2751
# Epoch 2/10
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2714
# Epoch 3/10
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2679
# Epoch 4/10
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2647
# Epoch 5/10
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2612
# Epoch 6/10
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2583
# Epoch 7/10
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2551
# Epoch 8/10
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2521
# Epoch 9/10
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2488
# Epoch 10/10
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2458
# -----------------------
# (1, 3)
# -----------------------
# ['Item', 'String', 'return', 'BigDecimal', 'return', 'synchronized', 'void', 'setUsingRandomint', 'namenew', 'float', 'pricenew', 'brandInformationnew']
# {'Item': 0, 'String': 1, 'return': 2, 'BigDecimal': 3, 'synchronized': 4, 'void': 5, 'setUsingRandomint': 6, 'namenew': 7, 'float': 8, 'pricenew': 9, 'brandInformationnew': 10}
# Epoch 1/10
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4594
# Epoch 2/10
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4569
# Epoch 3/10
# 3/3 [==============================] - 0s 5ms/step - loss: 2.4544
# Epoch 4/10
# 3/3 [==============================] - 0s 5ms/step - loss: 2.4525
# Epoch 5/10
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4503
# Epoch 6/10
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4485
# Epoch 7/10
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4466
# Epoch 8/10
# 3/3 [==============================] - 0s 5ms/step - loss: 2.4445
# Epoch 9/10
# 3/3 [==============================] - 0s 5ms/step - loss: 2.4428
# Epoch 10/10
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4407
# -----------------------
# (1, 3)
# -----------------------
# ['TemplateCompare', 'tTitle', 'Faken', 'Table', '0', '0', '0n', 'n', 'Title', 'Hardwaren', 'Table', '0', '0', '0n', 'confighwvendorn', 'confighwvendorurln', 'confighwmodeln', 'confighwprocessorn', 'confighwMHzn', 'confighwnchipsn', 'confighwncoresn', 'confighwncoresperchipn', 'confighwhwThreadsn', 'configswprocsAvailtoJavan', 'confighwmemoryn', 'confighwmemorydescriptionn', 'confighwprimaryCachen', 'confighwsecondaryCachen', 'confighwotherCachen', 'confighwfileSystemn', 'confighwdiskn', 'confighwothern', 'n', 'Title', 'Softwaren', 'Table', '0', '1', '0n', 'configswvendorn', 'configswvendorurln', 'configswJVMn', 'configswcommandlinen', 'configswJVMheapInitialn', 'configswJVMheapMaxn', 'configswOSn', 'configswothern', 'n', 'Title', 'AOT', 'Compilationn', 'Table', '1', '1', '1n', 'configswaotn', 'n', 'Title', 'Tuningn', 'Table', '1', '1', '1n', 'configswtuningn', 'n', 'Title', 'Test', 'Informationn', 'Table', '1', '0', '0n', 'configtesttestedByn', 'configtestspecLicensen', 'configtestlocationn', 'configtestdaten', 'confighwavailablen', 'configswJVMavailablen', 'configswOSavailablen', 'configswotherAvailablen', 'n', 'Title', 'Notesn', 'Table', '1', '1', '1n', 'configswnotesn']
# {'TemplateCompare': 0, 'tTitle': 1, 'Faken': 2, 'Table': 3, '0': 4, '0n': 5, 'n': 6, 'Title': 7, 'Hardwaren': 8, 'confighwvendorn': 9, 'confighwvendorurln': 10, 'confighwmodeln': 11, 'confighwprocessorn': 12, 'confighwMHzn': 13, 'confighwnchipsn': 14, 'confighwncoresn': 15, 'confighwncoresperchipn': 16, 'confighwhwThreadsn': 17, 'configswprocsAvailtoJavan': 18, 'confighwmemoryn': 19, 'confighwmemorydescriptionn': 20, 'confighwprimaryCachen': 21, 'confighwsecondaryCachen': 22, 'confighwotherCachen': 23, 'confighwfileSystemn': 24, 'confighwdiskn': 25, 'confighwothern': 26, 'Softwaren': 27, '1': 28, 'configswvendorn': 29, 'configswvendorurln': 30, 'configswJVMn': 31, 'configswcommandlinen': 32, 'configswJVMheapInitialn': 33, 'configswJVMheapMaxn': 34, 'configswOSn': 35, 'configswothern': 36, 'AOT': 37, 'Compilationn': 38, '1n': 39, 'configswaotn': 40, 'Tuningn': 41, 'configswtuningn': 42, 'Test': 43, 'Informationn': 44, 'configtesttestedByn': 45, 'configtestspecLicensen': 46, 'configtestlocationn': 47, 'configtestdaten': 48, 'confighwavailablen': 49, 'configswJVMavailablen': 50, 'configswOSavailablen': 51, 'configswotherAvailablen': 52, 'Notesn': 53, 'configswnotesn': 54}
# Epoch 1/10
# 21/21 [==============================] - 0s 2ms/step - loss: 4.0077
# Epoch 2/10
# 21/21 [==============================] - 0s 2ms/step - loss: 3.9981
# Epoch 3/10
# 21/21 [==============================] - 0s 2ms/step - loss: 3.9890
# Epoch 4/10
# 21/21 [==============================] - 0s 2ms/step - loss: 3.9801
# Epoch 5/10
# 21/21 [==============================] - 0s 2ms/step - loss: 3.9713
# Epoch 6/10
# 21/21 [==============================] - 0s 2ms/step - loss: 3.9620
# Epoch 7/10
# 21/21 [==============================] - 0s 3ms/step - loss: 3.9528
# Epoch 8/10
# 21/21 [==============================] - 0s 2ms/step - loss: 3.9433
# Epoch 9/10
# 21/21 [==============================] - 0s 2ms/step - loss: 3.9332
# Epoch 10/10
# 21/21 [==============================] - 0s 2ms/step - loss: 3.9232
# -----------------------
# (1, 3)
# -----------------------
# ['MapDataStorage', 'boolean', 'containsKeyObject', 'return', 'Iterator', 'return', 'Object', 'getObject', 'return', 'thisnew', 'MapDataStorageMap', 'Object', 'putObject', 'keyObject', 'return', 'Object', 'removeObject', 'return']
# {'MapDataStorage': 0, 'boolean': 1, 'containsKeyObject': 2, 'return': 3, 'Iterator': 4, 'Object': 5, 'getObject': 6, 'thisnew': 7, 'MapDataStorageMap': 8, 'putObject': 9, 'keyObject': 10, 'removeObject': 11}
# Epoch 1/10
# 4/4 [==============================] - 0s 4ms/step - loss: 2.5393
# Epoch 2/10
# 4/4 [==============================] - 0s 5ms/step - loss: 2.5351
# Epoch 3/10
# 4/4 [==============================] - 0s 4ms/step - loss: 2.5312
# Epoch 4/10
# 4/4 [==============================] - 0s 4ms/step - loss: 2.5279
# Epoch 5/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5242
# Epoch 6/10
# 4/4 [==============================] - 0s 5ms/step - loss: 2.5205
# Epoch 7/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5172
# Epoch 8/10
# 4/4 [==============================] - 0s 4ms/step - loss: 2.5138
# Epoch 9/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5107
# Epoch 10/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5073
# -----------------------
# (1, 3)
# -----------------------
# ['GraphImage', 'void', 'drawLegendString', 'legenddouble', 'XOffsetdouble', 'YOffsetColor', 'symbolColorColor', 'legendColorString', 'FontMetrics', 'int', 'txgetLinearMapXscaleMINX', 'int', 'tygetLinearMapY0', 'intYOffset', 'AXISTICKRADIUS', 'int', 'int', 'rintMathroundp', 'if', 'legendTypeequalsLine', 'graphicsdrawLinetxty', 'fmgetAscent', '2tx', '20ty', 'fmgetAscent', 'graphicsdrawString', 'legendtx', 'else', 'if', 'legendTypeequalsDot', 'graphicsfillArctx', 'rty', 'r', 'fmgetAscent', 'graphicsdrawString', 'int', 'getLinearMapXdouble', 'return', 'intMathroundx', 'scaleMINX', 'int', 'getLinearMapYdouble', 'return', 'intMathroundscaleMAXY', 'y', 'synchronized', 'double', 'getSuggestedMinXScaledouble', 'maxxdouble', 'double', 'scalenew', 'setScalenew', 'FontMetrics', 'int', 'wfmstringWidthdfyformatmaxy', 'AXISTICKRADIUS', 'double', 'minxthisscaleMINX', 'w', 'return', 'synchronized', 'double', 'getSuggestedMinYScaledouble', 'maxxdouble', 'double', 'scalenew', 'setScalenew', 'FontMetrics', 'int', 'hAXISTICKRADIUS', 'fmgetHeight', 'double', 'minythisscaleMAXY', 'h', 'alphay', 'return', 'int', 'getSuggestedYAxisTickIntervalint', 'suggestedNumTicksdouble', 'double', 'tmaxy', 'int', 'llintMathlogt', 'int', 'lull', 'int', 'tinew', 'for', 'int', 'i0', 'i', 'tilength', '1', 'i', 'tii', '1tii', 'int', 'int', 'for', 'int', 'itilength', '1', 'i', '0', 'i', 'double', 'ddifftii', 'if', 'ddiff', '00', 'int', 'if', 'diff', 'delta', 'delta', '0', 'return', 'GraphImageint', 'widthint', 'void', 'void', 'void', 'makeString', 'if', 'filename', 'null', 'try', 'File', 'outfilenew', 'catch', 'Exception', 'e', 'JBButilgetLoglogLevelWARNINGException', 'void', 'plotFlatLinedouble', 'yColor', 'int', 'int', 'int', 'for', 'int', 'xpx', 'x', 'w', 'x2', 'DASHLENGTH', 'graphicsdrawLinexpyx', 'void', 'plotFlatLinedouble', 'x1double', 'x2double', 'yColor', 'int', 'int', 'int', 'for', 'int', 'xpx', 'x', 'ex', 'x2', 'DASHLENGTH', 'graphicsdrawLinexpyx', 'void', 'plotLinedouble', 'x1double', 'y1double', 'x2double', 'void', 'plotXAxisTicksdouble', 'stepColor', 'cString', 'int', 'FontMetrics', 'for', 'double', 'x00', 'x', 'scaleMAXX', 'xstep', 'int', 'graphicsdrawLinepxpy', 'AXISTICKRADIUS', 'x', '00', '2', '1pxpy', 'AXISTICKRADIUS', 'x', '00', '2', 'if', 'x', '00', 'String', 'int', 'swfmstringWidthsx', 'graphicsdrawStringsxpx', 'swpy', 'AXISTICKRADIUS', 'for', 'double', 'x00', 'x', 'scaleMINX', 'xstep', 'int', 'graphicsdrawLinepxpy', 'AXISTICKRADIUSpxpy', 'graphicsdrawStringlabelgetLinearMapXscaleMAXX', '2py', '3', 'AXISTICKRADIUS', 'void', 'plotXYAxesColor', 'int', 'int', 'void', 'plotYAxisTicksdouble', 'stepColor', 'cString', 'int', 'FontMetrics', 'for', 'double', 'y00', 'y', 'scaleMAXY', 'step', 'ystep', 'int', 'graphicsdrawLinepx', 'AXISTICKRADIUS', 'y', '00', '2', '1pypx', 'AXISTICKRADIUS', 'y', '00', '2', 'if', 'y', '00', 'String', 'graphicsdrawStringsypx', 'AXISTICKRADIUS', 'fmstringWidthsy', '2py', 'for', 'double', 'y00', 'y', 'scaleMINY', 'ystep', 'int', 'graphicsdrawLinepx', 'AXISTICKRADIUSpypx', 'graphicsdrawStringlabelpx', 'AXISTICKRADIUS', 'fmstringWidthlabelgetLinearMapYscaleMAXY', '4', 'void', 'plotdouble', 'xdouble', 'void', 'plotdouble', 'xdouble', 'yColor', 'void', 'plotdouble', 'xdouble', 'yint', 'pColor', 'if', 'connectPointsEnabled', 'if', 'prevSet', 'else', 'int', 'int', 'int', 'rintMathroundp', 'pixeltype', 'graphicsfillArcpx', 'rpy', 'rpy', 'void', 'void', 'setAxisLabelsPrecisionDecimalFormat', 'dfint', 'iint', 'void', 'setBackgroundColor', 'void', 'setConnectPointsEnabledboolean', 'void', 'setForegroundColor', 'void', 'setImageQualityfloat', 'if', 'quality', '00f', 'quality', '10f', 'void', 'setPixelSizeint', 'void', 'setPixelTypeint', 'void', 'setScaledouble', 'if', 'scale', 'null', 'scalelength', 'thisscalelength', 'alphaxthisscaleMAXX', 'thisscaleMINX', 'alphaythisscaleMAXY', 'thisscaleMINY', 'void', 'setXAxisLabelsPrecisionint', 'iint', 'void', 'setXYAxesLabelsPrecisionint', 'xint', 'void', 'setYAxisLabelsPrecisionint', 'iint']
# {'GraphImage': 0, 'void': 1, 'drawLegendString': 2, 'legenddouble': 3, 'XOffsetdouble': 4, 'YOffsetColor': 5, 'symbolColorColor': 6, 'legendColorString': 7, 'FontMetrics': 8, 'int': 9, 'txgetLinearMapXscaleMINX': 10, 'tygetLinearMapY0': 11, 'intYOffset': 12, 'AXISTICKRADIUS': 13, 'rintMathroundp': 14, 'if': 15, 'legendTypeequalsLine': 16, 'graphicsdrawLinetxty': 17, 'fmgetAscent': 18, '2tx': 19, '20ty': 20, 'graphicsdrawString': 21, 'legendtx': 22, 'else': 23, 'legendTypeequalsDot': 24, 'graphicsfillArctx': 25, 'rty': 26, 'r': 27, 'getLinearMapXdouble': 28, 'return': 29, 'intMathroundx': 30, 'scaleMINX': 31, 'getLinearMapYdouble': 32, 'intMathroundscaleMAXY': 33, 'y': 34, 'synchronized': 35, 'double': 36, 'getSuggestedMinXScaledouble': 37, 'maxxdouble': 38, 'scalenew': 39, 'setScalenew': 40, 'wfmstringWidthdfyformatmaxy': 41, 'minxthisscaleMINX': 42, 'w': 43, 'getSuggestedMinYScaledouble': 44, 'hAXISTICKRADIUS': 45, 'fmgetHeight': 46, 'minythisscaleMAXY': 47, 'h': 48, 'alphay': 49, 'getSuggestedYAxisTickIntervalint': 50, 'suggestedNumTicksdouble': 51, 'tmaxy': 52, 'llintMathlogt': 53, 'lull': 54, 'tinew': 55, 'for': 56, 'i0': 57, 'i': 58, 'tilength': 59, '1': 60, 'tii': 61, '1tii': 62, 'itilength': 63, '0': 64, 'ddifftii': 65, 'ddiff': 66, '00': 67, 'diff': 68, 'delta': 69, 'GraphImageint': 70, 'widthint': 71, 'makeString': 72, 'filename': 73, 'null': 74, 'try': 75, 'File': 76, 'outfilenew': 77, 'catch': 78, 'Exception': 79, 'e': 80, 'JBButilgetLoglogLevelWARNINGException': 81, 'plotFlatLinedouble': 82, 'yColor': 83, 'xpx': 84, 'x': 85, 'x2': 86, 'DASHLENGTH': 87, 'graphicsdrawLinexpyx': 88, 'x1double': 89, 'x2double': 90, 'ex': 91, 'plotLinedouble': 92, 'y1double': 93, 'plotXAxisTicksdouble': 94, 'stepColor': 95, 'cString': 96, 'x00': 97, 'scaleMAXX': 98, 'xstep': 99, 'graphicsdrawLinepxpy': 100, '2': 101, '1pxpy': 102, 'String': 103, 'swfmstringWidthsx': 104, 'graphicsdrawStringsxpx': 105, 'swpy': 106, 'AXISTICKRADIUSpxpy': 107, 'graphicsdrawStringlabelgetLinearMapXscaleMAXX': 108, '2py': 109, '3': 110, 'plotXYAxesColor': 111, 'plotYAxisTicksdouble': 112, 'y00': 113, 'scaleMAXY': 114, 'step': 115, 'ystep': 116, 'graphicsdrawLinepx': 117, '1pypx': 118, 'graphicsdrawStringsypx': 119, 'fmstringWidthsy': 120, 'scaleMINY': 121, 'AXISTICKRADIUSpypx': 122, 'graphicsdrawStringlabelpx': 123, 'fmstringWidthlabelgetLinearMapYscaleMAXY': 124, '4': 125, 'plotdouble': 126, 'xdouble': 127, 'yint': 128, 'pColor': 129, 'connectPointsEnabled': 130, 'prevSet': 131, 'pixeltype': 132, 'graphicsfillArcpx': 133, 'rpy': 134, 'setAxisLabelsPrecisionDecimalFormat': 135, 'dfint': 136, 'iint': 137, 'setBackgroundColor': 138, 'setConnectPointsEnabledboolean': 139, 'setForegroundColor': 140, 'setImageQualityfloat': 141, 'quality': 142, '00f': 143, '10f': 144, 'setPixelSizeint': 145, 'setPixelTypeint': 146, 'setScaledouble': 147, 'scale': 148, 'scalelength': 149, 'thisscalelength': 150, 'alphaxthisscaleMAXX': 151, 'thisscaleMINX': 152, 'alphaythisscaleMAXY': 153, 'thisscaleMINY': 154, 'setXAxisLabelsPrecisionint': 155, 'setXYAxesLabelsPrecisionint': 156, 'xint': 157, 'setYAxisLabelsPrecisionint': 158}
# Epoch 1/10
# 78/78 [==============================] - 0s 2ms/step - loss: 5.0574
# Epoch 2/10
# 78/78 [==============================] - 0s 2ms/step - loss: 5.0283
# Epoch 3/10
# 78/78 [==============================] - 0s 2ms/step - loss: 4.9936
# Epoch 4/10
# 78/78 [==============================] - 0s 2ms/step - loss: 4.9434
# Epoch 5/10
# 78/78 [==============================] - 0s 2ms/step - loss: 4.8739
# Epoch 6/10
# 78/78 [==============================] - 0s 2ms/step - loss: 4.7894
# Epoch 7/10
# 78/78 [==============================] - 0s 2ms/step - loss: 4.7031
# Epoch 8/10
# 78/78 [==============================] - 0s 2ms/step - loss: 4.6298
# Epoch 9/10
# 78/78 [==============================] - 0s 2ms/step - loss: 4.5779
# Epoch 10/10
# 78/78 [==============================] - 0s 2ms/step - loss: 4.5463
# -----------------------
# (1, 3)
# -----------------------
# ['Check', 'static', 'boolean', 'boolean', 'Super', 'supnew', 'Sub', 'subnew', 'SystemoutprintlnsupgetName', 'SystemoutprintlnsubgetName', 'if', 'suptoStringequalsClass', 'Super', 'public34', 'protected33', 'private32', 'if', 'subtoStringequalsClass', 'Super', 'public804', 'protected803', 'private802', 'SystemoutprintlnSuper', 'prot', 'supgetProtected', 'priv', 'SystemoutprintlnSub', 'prot', 'subgetProtected', 'priv', 'if', 'supgetProtected', '33', 'supgetPrivate', '32', 'if', 'subgetProtected', '111', 'subgetPrivate', '105', 'SystemoutprintlnSubclass', 'test', 'error', 'error', 'return', 'static', 'boolean', 'boolean', 'Document', 'DocumentBuilder', 'DocumentBuilderFactory', 'try', 'boolean', 'if', 'result', 'else', 'SystemoutprintlnXML', 'StrictErrorChecking', 'test', 'error', 'error', 'catch', 'ParserConfigurationException', 'pce', 'return', 'static', 'boolean', 'SystemoutprintlnnChecking', 'boolean', 'boolean', 'boolean', 'try', 'int', 'anew', 'for', 'int', 'i0', 'i', '10', 'i', 'SystemoutprintlnError', 'array', 'bounds', 'not', 'catch', 'ArrayIndexOutOfBoundsException', 'e', 'finally', 'if', 'caughtIndex', 'Systemoutprintln1st', 'bounds', 'test', 'errortindex', 'exception', 'not', 'if', 'gotToFinally', 'Systemoutprintln1st', 'bounds', 'test', 'errortfinally', 'clause', 'not', 'if', 'caughtIndex', 'gotToFinally', 'Systemoutprintln1st', 'bounds', 'if', 'checkSubclassing', 'if', 'checkXMLErrorChecking', 'LoopBounds', 'mulenew', 'if', 'LoopBoundsgotError', 'Systemoutprintln2nd', 'bounds', 'else', 'Systemoutprintln2nd', 'bounds', 'PepTest', 'horsenew', 'if', 'horsegotError', 'if', 'error', 'SystemoutprintlnnINVALID', 'JVM', 'Check', 'detected', 'else', 'SystemoutprintlnnJVM', 'Check', 'return']
# {'Check': 0, 'static': 1, 'boolean': 2, 'Super': 3, 'supnew': 4, 'Sub': 5, 'subnew': 6, 'SystemoutprintlnsupgetName': 7, 'SystemoutprintlnsubgetName': 8, 'if': 9, 'suptoStringequalsClass': 10, 'public34': 11, 'protected33': 12, 'private32': 13, 'subtoStringequalsClass': 14, 'public804': 15, 'protected803': 16, 'private802': 17, 'SystemoutprintlnSuper': 18, 'prot': 19, 'supgetProtected': 20, 'priv': 21, 'SystemoutprintlnSub': 22, 'subgetProtected': 23, '33': 24, 'supgetPrivate': 25, '32': 26, '111': 27, 'subgetPrivate': 28, '105': 29, 'SystemoutprintlnSubclass': 30, 'test': 31, 'error': 32, 'return': 33, 'Document': 34, 'DocumentBuilder': 35, 'DocumentBuilderFactory': 36, 'try': 37, 'result': 38, 'else': 39, 'SystemoutprintlnXML': 40, 'StrictErrorChecking': 41, 'catch': 42, 'ParserConfigurationException': 43, 'pce': 44, 'SystemoutprintlnnChecking': 45, 'int': 46, 'anew': 47, 'for': 48, 'i0': 49, 'i': 50, '10': 51, 'SystemoutprintlnError': 52, 'array': 53, 'bounds': 54, 'not': 55, 'ArrayIndexOutOfBoundsException': 56, 'e': 57, 'finally': 58, 'caughtIndex': 59, 'Systemoutprintln1st': 60, 'errortindex': 61, 'exception': 62, 'gotToFinally': 63, 'errortfinally': 64, 'clause': 65, 'checkSubclassing': 66, 'checkXMLErrorChecking': 67, 'LoopBounds': 68, 'mulenew': 69, 'LoopBoundsgotError': 70, 'Systemoutprintln2nd': 71, 'PepTest': 72, 'horsenew': 73, 'horsegotError': 74, 'SystemoutprintlnnINVALID': 75, 'JVM': 76, 'detected': 77, 'SystemoutprintlnnJVM': 78}
# Epoch 1/10
# 33/33 [==============================] - 0s 2ms/step - loss: 4.3678
# Epoch 2/10
# 33/33 [==============================] - 0s 2ms/step - loss: 4.3583
# Epoch 3/10
# 33/33 [==============================] - 0s 2ms/step - loss: 4.3496
# Epoch 4/10
# 33/33 [==============================] - 0s 2ms/step - loss: 4.3408
# Epoch 5/10
# 33/33 [==============================] - 0s 2ms/step - loss: 4.3321
# Epoch 6/10
# 33/33 [==============================] - 0s 2ms/step - loss: 4.3228
# Epoch 7/10
# 33/33 [==============================] - 0s 2ms/step - loss: 4.3134
# Epoch 8/10
# 33/33 [==============================] - 0s 2ms/step - loss: 4.3026
# Epoch 9/10
# 33/33 [==============================] - 0s 3ms/step - loss: 4.2915
# Epoch 10/10
# 33/33 [==============================] - 0s 3ms/step - loss: 4.2796
# -----------------------
# (1, 3)
# -----------------------
# ['Report', 'String', 'return', 'void', 'printOtherPropertiesPrintStream', 'outprintlnH4Optional', 'InformationH4n', 'IThis', 'information', 'is', 'for', 'internal', 'documentation', 'purposesn', 'and', 'is', 'not', 'required', 'for', 'SPEC', 'reportingn', 'for', 'Enumeration', 'eresultspropertyNames', 'ehasMoreElements', 'String', 'if', 'keystartsWithconfigtestx', 'keystartsWithconfiginitial', 'String', 'if', 'keyequalsconfigtestxinternalReference', 'valuestartsWithhttp', 'valuestartsWithfile', 'valueA', 'HREF', 'value', 'value', 'outprintlnBR', 'key', 'void', 'printPrintStream', 'try', 'outprintlnHTMLHEADn', 'META', 'NAMEGENERATOR', 'CONTENT', 'SPEC', 'Java', 'Reportern', 'TITLE', 'name', 'TITLEn', 'outprintBODY', 'if', 'metricsvalid', 'else', 'outprintTABLE', 'WIDTH100n', 'TRTD', 'if', 'issue', 'null', 'issueequals', 'else', 'outprintFONT', 'if', 'metricsvalid', 'outprintFONT', 'SIZE2', 'outprintFONT', 'SIZE2', 'name', '2005FONTTDn', 'TD', 'COLSPAN2', 'ALIGNRIGHT', 'bgcolorFFFF00', 'FONT', 'SIZE2', 'COLOR000000BSPECjbb2005', 'bops', 'metric', 'SPECjbb2005', 'bopsJVM', 'metric', 'BFONTTDTRn', 'TRTD', 'COLSPAN3FONT', 'SIZE1', 'hardware', 'if', 'software', 'null', 'outprintTRTD', 'COLSPAN3FONT', 'SIZE1', 'software', 'BufferedReader', 'BufferedReader', 'TableGroupCompare', 'if', 'metrics2', 'null', 'innew', 'BufferedReadernew', 'StringReadernew', 'in2new', 'BufferedReadernew', 'StringReadernew', 'mnew', 'else', 'innew', 'BufferedReadernew', 'StringReadernew', 'in2new', 'BufferedReadernew', 'StringReadernew', 'mnew', 'if', 'metrics2', 'null', 'if', 'verbose', 'outprintlnHRFONT', 'outprintlnSPECjbb2005', 'Version', 'resultsgetconfigbenchmarkversionNA', 'resultsgetconfigbenchmarkversionDate', 'if', 'issue', 'null', 'issueequals', 'metricsvalid', 'outprintlnPublished', 'by', 'SPEC', 'issue', 'outprintlnReporting', 'page', 'Copyright', 'copy', '2005', 'SPEC', 'All', 'rights', 'reservedn', 'outprintln', 'outprintlnReporting', 'Page', 'Generator', 'if', 'echoRaw', 'resultsstoreoutRaw', 'outprintln', 'catch', 'Exception', 'e', 'JBButilgetLoglogLevelWARNINGError', 'void', 'printString', 'try', 'printnew', 'PrintStreamnew', 'BufferedOutputStreamnew', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'creating', 'output', 'Reportboolean', 'echoRawboolean', 'SPECInternalUseString', 'newsletterString', 'resultFileboolean', 'verboseString', 'resultFile2String', 'labelboolean', 'useHtmlString', 'try', 'StringReader', 'tisnew', 'StringReadernew', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'loading', 'titles', 'for', 'try', 'if', 'resultFile', 'null', 'resultsloadnew', 'else', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'reading', 'results', 'file', 'resultFile', 'metricsnew', 'try', 'if', 'resultFile2', 'null', 'metrics2new', 'else', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'reading', 'comparison', 'results', 'file', 'resultFile2', 'if', 'metrics2', 'null', 'else', 'thishardwareresultsgetconfighwvendor', 'if', 'metric', 'null', 'metric', 'if', 'metricsvalid', 'if', 'SPECInternalUse', 'metricsresultsbufappendnValid', 'run', 'Score', 'is', 'metric', 'else', 'if', 'metricsprintscore', 'metricsresultsbufappendINVALID', 'run', 'Score', 'is', 'metric', 'else', 'metricsresultsbufappendINVALID', 'run', 'preventing', 'score', 'thissoftwareresultsgetconfigswvendor', 'void', 'testBarPrintStream', 'out', 'throws', 'IOException', 'String', 'String', 'String', 'outprintlnTABLE', 'WIDTH100', 'BORDER1', 'CELLSPACING2', 'CELLPADDING0trn', 'td', 'width33bSPEC', 'license', 'b', 'license', 'tdn', 'td', 'width33bTested', 'by', 'b', 'testedBy', 'tdn', 'tdbTest', 'date', 'b', 'testDate', 'tdn']
# {'Report': 0, 'String': 1, 'return': 2, 'void': 3, 'printOtherPropertiesPrintStream': 4, 'outprintlnH4Optional': 5, 'InformationH4n': 6, 'IThis': 7, 'information': 8, 'is': 9, 'for': 10, 'internal': 11, 'documentation': 12, 'purposesn': 13, 'and': 14, 'not': 15, 'required': 16, 'SPEC': 17, 'reportingn': 18, 'Enumeration': 19, 'eresultspropertyNames': 20, 'ehasMoreElements': 21, 'if': 22, 'keystartsWithconfigtestx': 23, 'keystartsWithconfiginitial': 24, 'keyequalsconfigtestxinternalReference': 25, 'valuestartsWithhttp': 26, 'valuestartsWithfile': 27, 'valueA': 28, 'HREF': 29, 'value': 30, 'outprintlnBR': 31, 'key': 32, 'printPrintStream': 33, 'try': 34, 'outprintlnHTMLHEADn': 35, 'META': 36, 'NAMEGENERATOR': 37, 'CONTENT': 38, 'Java': 39, 'Reportern': 40, 'TITLE': 41, 'name': 42, 'TITLEn': 43, 'outprintBODY': 44, 'metricsvalid': 45, 'else': 46, 'outprintTABLE': 47, 'WIDTH100n': 48, 'TRTD': 49, 'issue': 50, 'null': 51, 'issueequals': 52, 'outprintFONT': 53, 'SIZE2': 54, '2005FONTTDn': 55, 'TD': 56, 'COLSPAN2': 57, 'ALIGNRIGHT': 58, 'bgcolorFFFF00': 59, 'FONT': 60, 'COLOR000000BSPECjbb2005': 61, 'bops': 62, 'metric': 63, 'SPECjbb2005': 64, 'bopsJVM': 65, 'BFONTTDTRn': 66, 'COLSPAN3FONT': 67, 'SIZE1': 68, 'hardware': 69, 'software': 70, 'outprintTRTD': 71, 'BufferedReader': 72, 'TableGroupCompare': 73, 'metrics2': 74, 'innew': 75, 'BufferedReadernew': 76, 'StringReadernew': 77, 'in2new': 78, 'mnew': 79, 'verbose': 80, 'outprintlnHRFONT': 81, 'outprintlnSPECjbb2005': 82, 'Version': 83, 'resultsgetconfigbenchmarkversionNA': 84, 'resultsgetconfigbenchmarkversionDate': 85, 'outprintlnPublished': 86, 'by': 87, 'outprintlnReporting': 88, 'page': 89, 'Copyright': 90, 'copy': 91, '2005': 92, 'All': 93, 'rights': 94, 'reservedn': 95, 'outprintln': 96, 'Page': 97, 'Generator': 98, 'echoRaw': 99, 'resultsstoreoutRaw': 100, 'catch': 101, 'Exception': 102, 'e': 103, 'JBButilgetLoglogLevelWARNINGError': 104, 'printString': 105, 'printnew': 106, 'PrintStreamnew': 107, 'BufferedOutputStreamnew': 108, 'IOException': 109, 'creating': 110, 'output': 111, 'Reportboolean': 112, 'echoRawboolean': 113, 'SPECInternalUseString': 114, 'newsletterString': 115, 'resultFileboolean': 116, 'verboseString': 117, 'resultFile2String': 118, 'labelboolean': 119, 'useHtmlString': 120, 'StringReader': 121, 'tisnew': 122, 'loading': 123, 'titles': 124, 'resultFile': 125, 'resultsloadnew': 126, 'reading': 127, 'results': 128, 'file': 129, 'metricsnew': 130, 'resultFile2': 131, 'metrics2new': 132, 'comparison': 133, 'thishardwareresultsgetconfighwvendor': 134, 'SPECInternalUse': 135, 'metricsresultsbufappendnValid': 136, 'run': 137, 'Score': 138, 'metricsprintscore': 139, 'metricsresultsbufappendINVALID': 140, 'preventing': 141, 'score': 142, 'thissoftwareresultsgetconfigswvendor': 143, 'testBarPrintStream': 144, 'out': 145, 'throws': 146, 'outprintlnTABLE': 147, 'WIDTH100': 148, 'BORDER1': 149, 'CELLSPACING2': 150, 'CELLPADDING0trn': 151, 'td': 152, 'width33bSPEC': 153, 'license': 154, 'b': 155, 'tdn': 156, 'width33bTested': 157, 'testedBy': 158, 'tdbTest': 159, 'date': 160, 'testDate': 161}
# Epoch 1/10
# 70/70 [==============================] - 1s 6ms/step - loss: 5.0840
# Epoch 2/10
# 70/70 [==============================] - 0s 7ms/step - loss: 5.0688
# Epoch 3/10
# 70/70 [==============================] - 1s 8ms/step - loss: 5.0552
# Epoch 4/10
# 70/70 [==============================] - 0s 4ms/step - loss: 5.0417
# Epoch 5/10
# 70/70 [==============================] - 0s 4ms/step - loss: 5.0274
# Epoch 6/10
# 70/70 [==============================] - 0s 6ms/step - loss: 5.0113
# Epoch 7/10
# 70/70 [==============================] - 0s 7ms/step - loss: 4.9922
# Epoch 8/10
# 70/70 [==============================] - 0s 7ms/step - loss: 4.9683
# Epoch 9/10
# 70/70 [==============================] - 0s 6ms/step - loss: 4.9402
# Epoch 10/10
# 70/70 [==============================] - 0s 5ms/step - loss: 4.9082
# -----------------------
# (1, 3)
# -----------------------
# ['Warehouse', 'int', 'return', 'District', 'getDistrictPtrbyte', 'inDistrictIdboolean', 'District', 'if', 'inDistrictId', '0', 'if', 'inDistrictId', 'distCount', 'return', 'District', 'getDistrictint', 'District', 'if', 'distId', '0', 'if', 'distId', 'distCount', 'return', 'synchronized', 'JBBDataStorage', 'return', 'void', 'initWarehouseCompany', 'inCompanyJBBDataStorage', 'inItemTableshort', 'districtsnew', 'addressnew', 'synchronized', 'void', 'String', 'for', 'byte', 'districtId1', 'districtId', 'companygetMaxDistrictsPerWarehouse', 'districtId', 'for', 'short', 'customerId1', 'customerId', 'companygetMaxCustomersPerDistrict', 'customerId', 'long', 'Customer', 'BigDecimal', 'historyDatanew', 'Date', 'creationtimenew', 'History', 'newHistorynew', 'void', 'int', 'Item', 'Stock', 'for', 'int', 'i1', 'i', 'numItems', 'i', 'newStocknew', 'void', 'removeOldestHistorySynch', 'Item', 'retrieveItemint', 'return', 'Stock', 'retrieveStockint', 'return', 'synchronized', 'void', 'setUsingRandomshort', 'int', 'namenew', 'float', 'taxRatenew', 'for', 'i0', 'i', 'distCount', 'i', 'byte', 'newDistrictIdbytei', 'District', 'newDistrictnew', 'synchronized', 'void', 'int', 'int', 'synchronized', 'void', 'trimOrdersForSteadyStateint', 'initialOrdersint', 'int', 'int', 'District', 'for', 'distId1', 'distId', 'distCount', 'distId', 'if', 'TransactionsteadyStateMem', 'currentDistrictremoveOldNewOrdersinitialOrders', 'void', 'updateHistoryHistory', 'updateHistorySynch', 'boolean', 'validDistrictbyte', 'District', 'int', 'for', 'i0', 'i', 'distCount', 'i', 'if', 'currentDistrictgetId', 'inDistrictId', 'return', 'return', 'WarehouseCompany', 'inCompanyJBBDataStorage', 'districtsnew', 'addressnew']
# {'Warehouse': 0, 'int': 1, 'return': 2, 'District': 3, 'getDistrictPtrbyte': 4, 'inDistrictIdboolean': 5, 'if': 6, 'inDistrictId': 7, '0': 8, 'distCount': 9, 'getDistrictint': 10, 'distId': 11, 'synchronized': 12, 'JBBDataStorage': 13, 'void': 14, 'initWarehouseCompany': 15, 'inCompanyJBBDataStorage': 16, 'inItemTableshort': 17, 'districtsnew': 18, 'addressnew': 19, 'String': 20, 'for': 21, 'byte': 22, 'districtId1': 23, 'districtId': 24, 'companygetMaxDistrictsPerWarehouse': 25, 'short': 26, 'customerId1': 27, 'customerId': 28, 'companygetMaxCustomersPerDistrict': 29, 'long': 30, 'Customer': 31, 'BigDecimal': 32, 'historyDatanew': 33, 'Date': 34, 'creationtimenew': 35, 'History': 36, 'newHistorynew': 37, 'Item': 38, 'Stock': 39, 'i1': 40, 'i': 41, 'numItems': 42, 'newStocknew': 43, 'removeOldestHistorySynch': 44, 'retrieveItemint': 45, 'retrieveStockint': 46, 'setUsingRandomshort': 47, 'namenew': 48, 'float': 49, 'taxRatenew': 50, 'i0': 51, 'newDistrictIdbytei': 52, 'newDistrictnew': 53, 'trimOrdersForSteadyStateint': 54, 'initialOrdersint': 55, 'distId1': 56, 'TransactionsteadyStateMem': 57, 'currentDistrictremoveOldNewOrdersinitialOrders': 58, 'updateHistoryHistory': 59, 'updateHistorySynch': 60, 'boolean': 61, 'validDistrictbyte': 62, 'currentDistrictgetId': 63, 'WarehouseCompany': 64}
# Epoch 1/10
# 32/32 [==============================] - 1s 5ms/step - loss: 4.1721
# Epoch 2/10
# 32/32 [==============================] - 0s 4ms/step - loss: 4.1599
# Epoch 3/10
# 32/32 [==============================] - 0s 8ms/step - loss: 4.1485
# Epoch 4/10
# 32/32 [==============================] - 0s 7ms/step - loss: 4.1375
# Epoch 5/10
# 32/32 [==============================] - 0s 4ms/step - loss: 4.1267
# Epoch 6/10
# 32/32 [==============================] - 0s 6ms/step - loss: 4.1161
# Epoch 7/10
# 32/32 [==============================] - 0s 6ms/step - loss: 4.1050
# Epoch 8/10
# 32/32 [==============================] - 0s 5ms/step - loss: 4.0937
# Epoch 9/10
# 32/32 [==============================] - 0s 2ms/step - loss: 4.0819
# Epoch 10/10
# 32/32 [==============================] - 0s 2ms/step - loss: 4.0694
# -----------------------
# (1, 3)
# -----------------------
# ['TableGroup', 'inReportProps', 'propsReportProps', 'titles', 'throws', 'IllegalArgumentException', 'String', 'String', 'try', 'while', 'lineinreadLine', 'null', 'if', 'linestartsWithTitle', 'else', 'if', 'linestartsWithTable', 'StringTokenizer', 'tokennew', 'int', 'int', 'boolean', 'freeFormIntegerparseInttokennextToken', 'if', 'group', '0', 'group', 'MAXGROUPS', 'column', '0', 'column', 'MAXCOLUMNS', 'throw', 'new', 'int', 'if', 'row', '0', 'row', 'MAXROWS', 'throw', 'new', 'tablesgroupcolumnrownew', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError']
# {'TableGroup': 0, 'inReportProps': 1, 'propsReportProps': 2, 'titles': 3, 'throws': 4, 'IllegalArgumentException': 5, 'String': 6, 'try': 7, 'while': 8, 'lineinreadLine': 9, 'null': 10, 'if': 11, 'linestartsWithTitle': 12, 'else': 13, 'linestartsWithTable': 14, 'StringTokenizer': 15, 'tokennew': 16, 'int': 17, 'boolean': 18, 'freeFormIntegerparseInttokennextToken': 19, 'group': 20, '0': 21, 'MAXGROUPS': 22, 'column': 23, 'MAXCOLUMNS': 24, 'throw': 25, 'new': 26, 'row': 27, 'MAXROWS': 28, 'tablesgroupcolumnrownew': 29, 'catch': 30, 'IOException': 31, 'e': 32, 'JBButilgetLoglogLevelWARNINGError': 33}
# Epoch 1/10
# 11/11 [==============================] - 1s 2ms/step - loss: 3.5236
# Epoch 2/10
# 11/11 [==============================] - 0s 4ms/step - loss: 3.5190
# Epoch 3/10
# 11/11 [==============================] - 0s 3ms/step - loss: 3.5146
# Epoch 4/10
# 11/11 [==============================] - 0s 6ms/step - loss: 3.5107
# Epoch 5/10
# 11/11 [==============================] - 0s 6ms/step - loss: 3.5067
# Epoch 6/10
# 11/11 [==============================] - 0s 6ms/step - loss: 3.5028
# Epoch 7/10
# 11/11 [==============================] - 0s 5ms/step - loss: 3.4987
# Epoch 8/10
# 11/11 [==============================] - 0s 4ms/step - loss: 3.4948
# Epoch 9/10
# 11/11 [==============================] - 0s 4ms/step - loss: 3.4911
# Epoch 10/10
# 11/11 [==============================] - 0s 4ms/step - loss: 3.4871
# -----------------------
# (1, 3)
# -----------------------
# ['NewOrder', 'void', 'synchronized', 'Order', 'Order', 'return', 'void', 'initNewOrderOrder', 'inOrderPtrint', 'inOrderIdbyte', 'inDistrictIdshort', 'if', 'JBButilgetLogisLoggableLevelFINEST', 'JBButilgetLogfinestNewOrderinitNewOrder', 'orderId', 'orderId', 'districtId', 'districtId', 'warehouseId', 'NewOrderOrder', 'inOrderPtrint', 'inOrderIdbyte', 'inDistrictIdshort']
# {'NewOrder': 0, 'void': 1, 'synchronized': 2, 'Order': 3, 'return': 4, 'initNewOrderOrder': 5, 'inOrderPtrint': 6, 'inOrderIdbyte': 7, 'inDistrictIdshort': 8, 'if': 9, 'JBButilgetLogisLoggableLevelFINEST': 10, 'JBButilgetLogfinestNewOrderinitNewOrder': 11, 'orderId': 12, 'districtId': 13, 'warehouseId': 14, 'NewOrderOrder': 15}
# Epoch 1/10
# 5/5 [==============================] - 1s 4ms/step - loss: 2.7983
# Epoch 2/10
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7953
# Epoch 3/10
# 5/5 [==============================] - 0s 4ms/step - loss: 2.7924
# Epoch 4/10
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7900
# Epoch 5/10
# 5/5 [==============================] - 0s 8ms/step - loss: 2.7874
# Epoch 6/10
# 5/5 [==============================] - 0s 4ms/step - loss: 2.7850
# Epoch 7/10
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7826
# Epoch 8/10
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7800
# Epoch 9/10
# 5/5 [==============================] - 0s 4ms/step - loss: 2.7776
# Epoch 10/10
# 5/5 [==============================] - 0s 3ms/step - loss: 2.7750
# -----------------------
# (1, 3)
# -----------------------
# ['JBBmain', 'void', 'callReporterString', 'outputdirectoryString', 'outRawFilenameString', 'outRawPrefixString', 'String', 'msgCalling', 'boolean', 'boolean', 'String', 'String', 'boolean', 'String', 'String', 'optooutputdirectory', 'Fileseparator', 'outRawPrefix', 'sequenceNumber', 'String', 'fileAsciioutputdirectory', 'Fileseparator', 'outRawPrefix', 'sequenceNumber', 'String', 'String', 'boolean', 'specreporterReport', 'try', 'TextiReport', 'arnew', 'catch', 'Exception', 'e', 'try', 'rnew', 'catch', 'Exception', 'e', 'JBButilgetLogwarningProducing', 'html', 'chart', 'in', 'report', 'instead', 'of', 'JPEG', 'see', 'Users', 'rnew', 'javalangInternalError', 'e', 'JBButilgetLogwarningProducing', 'html', 'chart', 'in', 'report', 'instead', 'of', 'JPEG', 'see', 'Users', 'rnew', 'javalangUnsatisfiedLinkError', 'e', 'JBButilgetLogwarningProducing', 'html', 'chart', 'in', 'report', 'instead', 'of', 'JPEG', 'see', 'Users', 'rnew', 'javalangError', 'e', 'JBButilgetLogwarningProducing', 'html', 'chart', 'in', 'report', 'instead', 'of', 'JPEG', 'see', 'Users', 'rnew', 'try', 'BufferedReader', 'AscBrnew', 'BufferedReadernew', 'String', 'while', 'sAscBrreadLine', 'null', 'catch', 'IOException', 'e', 'JBButilgetLoglogLevelWARNINGError', 'opening', 'ASCII', 'output', 'SystemoutprintlnOutput', 'files', 'fileAscii', 'outRawFilename', 'SystemoutprintlnReporter', 'String', 'commandLineParserString', 'String', 'if', 'argslength', '0', 'else', 'if', 'args0equalsid', 'else', 'if', 'args0equalspropfile', 'if', 'argslength', '2', 'else', 'if', 'argslength', '1', 'SystemoutprintlnMissing', 'properties', 'file', 'Systemoutprintln', 'Parameters', 'propfile', 'propertiesfilename', 'id', 'else', 'if', 'argslength', '4', 'args2equalsid', 'else', 'SystemoutprintlnToo', 'many', 'Systemoutprintln', 'Parameters', 'propfile', 'propertiesfilename', 'id', 'else', 'SystemoutprintlnUnrecognized', 'command', 'line', 'parameter', 'Systemoutprintln', 'Parameters', 'propfile', 'return', 'void', 'DoARunCompany', 'myCompanyshort', 'numberofwarehousesint', 'rampuptimeint', 'short', 'myCompanysetPropOutputPrefixresulttest', 'testnum', 'SystemoutprintlnStart', 'User', 'JBButilgetLoginfoStart', 'User', 'try', 'for', 'whID1', 'whID', 'numberofwarehouses', 'whID', 'String', 'msg', 'started', 'user', 'thread', 'for', 'Warehouse', 'catch', 'javalangThreadDeath', 'e', 'try', 'JBButilgetLoglogLevelWARNINGERROR', 'A', 'thread', 'died', 'probably', 'out', 'of', 'memory', 'Increase', 'the', 'heap', 'size', 'and', 'run', 'catch', 'OutOfMemoryError', 'oome', 'SystemoutprintlnERROR', 'A', 'thread', 'died', 'probably', 'out', 'of', 'memory', 'Increase', 'the', 'heap', 'size', 'and', 'run', 'javalangOutOfMemoryError', 'e', 'try', 'JBButilgetLoglogLevelWARNINGERROR', 'Out', 'of', 'memory', 'error', 'caught', 'Increase', 'the', 'heap', 'size', 'and', 'run', 'catch', 'OutOfMemoryError', 'oome', 'SystemoutprintlnERROR', 'Out', 'of', 'memory', 'error', 'caught', 'Increase', 'the', 'heap', 'size', 'and', 'run', 'boolean', 'DoAValidationRunCompany', 'short', 'TransactionManager', 'transMgrnew', 'return', 'void', 'float', 'minbtpsfloatpropminBTPSRatio', '1000', 'propwaitTimePercent', '23', 'myCompanynew', 'if', 'propdeterministicRandomSeed', 'true', 'int', 'int', 'if', 'propsequenceOfWarehouses', 'null', 'for', 'numwhpropstartingNumberWarehouses', 'numwh', 'propendingNumberWarehouses', 'numwhpropincrementNumberWarehouses', 'if', 'runWarehousecurwarehousesnumwhminbtps', 'else', 'for', 'int', 'seqndx0', 'seqndx', 'propsequenceOfWarehouseslength', 'seqndx', 'if', 'runWarehousecurwarehousesnumwhminbtps', 'boolean', 'myCompanynew', 'long', 'boolean', 'return', 'void', 'Handler', 'for', 'Handler', 'logHandler', 'handlers', 'void', 'increaseNumWarehousesint', 'currentint', 'nextint', 'for', 'int', 'icurrent', '1', 'i', 'next', 'i', 'boolean', 'initApplicationLoggingString', 'StreamHandler', 'try', 'handlernew', 'StreamHandlernew', 'FileOutputStreamlogFileNamenew', 'catch', 'FileNotFoundException', 'fnf ...
# {'JBBmain': 0, 'void': 1, 'callReporterString': 2, 'outputdirectoryString': 3, 'outRawFilenameString': 4, 'outRawPrefixString': 5, 'String': 6, 'msgCalling': 7, 'boolean': 8, 'optooutputdirectory': 9, 'Fileseparator': 10, 'outRawPrefix': 11, 'sequenceNumber': 12, 'fileAsciioutputdirectory': 13, 'specreporterReport': 14, 'try': 15, 'TextiReport': 16, 'arnew': 17, 'catch': 18, 'Exception': 19, 'e': 20, 'rnew': 21, 'JBButilgetLogwarningProducing': 22, 'html': 23, 'chart': 24, 'in': 25, 'report': 26, 'instead': 27, 'of': 28, 'JPEG': 29, 'see': 30, 'Users': 31, 'javalangInternalError': 32, 'javalangUnsatisfiedLinkError': 33, 'javalangError': 34, 'BufferedReader': 35, 'AscBrnew': 36, 'BufferedReadernew': 37, 'while': 38, 'sAscBrreadLine': 39, 'null': 40, 'IOException': 41, 'JBButilgetLoglogLevelWARNINGError': 42, 'opening': 43, 'ASCII': 44, 'output': 45, 'SystemoutprintlnOutput': 46, 'files': 47, 'fileAscii': 48, 'outRawFilename': 49, 'SystemoutprintlnReporter': 50, 'commandLineParserString': 51, 'if': 52, 'argslength': 53, '0': 54, 'else': 55, 'args0equalsid': 56, 'args0equalspropfile': 57, '2': 58, '1': 59, 'SystemoutprintlnMissing': 60, 'properties': 61, 'file': 62, 'Systemoutprintln': 63, 'Parameters': 64, 'propfile': 65, 'propertiesfilename': 66, 'id': 67, '4': 68, 'args2equalsid': 69, 'SystemoutprintlnToo': 70, 'many': 71, 'SystemoutprintlnUnrecognized': 72, 'command': 73, 'line': 74, 'parameter': 75, 'return': 76, 'DoARunCompany': 77, 'myCompanyshort': 78, 'numberofwarehousesint': 79, 'rampuptimeint': 80, 'short': 81, 'myCompanysetPropOutputPrefixresulttest': 82, 'testnum': 83, 'SystemoutprintlnStart': 84, 'User': 85, 'JBButilgetLoginfoStart': 86, 'for': 87, 'whID1': 88, 'whID': 89, 'numberofwarehouses': 90, 'msg': 91, 'started': 92, 'user': 93, 'thread': 94, 'Warehouse': 95, 'javalangThreadDeath': 96, 'JBButilgetLoglogLevelWARNINGERROR': 97, 'A': 98, 'died': 99, 'probably': 100, 'out': 101, 'memory': 102, 'Increase': 103, 'the': 104, 'heap': 105, 'size': 106, 'and': 107, 'run': 108, 'OutOfMemoryError': 109, 'oome': 110, 'SystemoutprintlnERROR': 111, 'javalangOutOfMemoryError': 112, 'Out': 113, 'error': 114, 'caught': 115, 'DoAValidationRunCompany': 116, 'TransactionManager': 117, 'transMgrnew': 118, 'float': 119, 'minbtpsfloatpropminBTPSRatio': 120, '1000': 121, 'propwaitTimePercent': 122, '23': 123, 'myCompanynew': 124, 'propdeterministicRandomSeed': 125, 'true': 126, 'int': 127, 'propsequenceOfWarehouses': 128, 'numwhpropstartingNumberWarehouses': 129, 'numwh': 130, 'propendingNumberWarehouses': 131, 'numwhpropincrementNumberWarehouses': 132, 'runWarehousecurwarehousesnumwhminbtps': 133, 'seqndx0': 134, 'seqndx': 135, 'propsequenceOfWarehouseslength': 136, 'long': 137, 'Handler': 138, 'logHandler': 139, 'handlers': 140, 'increaseNumWarehousesint': 141, 'currentint': 142, 'nextint': 143, 'icurrent': 144, 'i': 145, 'next': 146, 'initApplicationLoggingString': 147, 'StreamHandler': 148, 'handlernew': 149, 'StreamHandlernew': 150, 'FileOutputStreamlogFileNamenew': 151, 'FileNotFoundException': 152, 'fnfe': 153, 'Unable': 154, 'to': 155, 'open': 156, 'logging': 157, 'ConsoleHandler': 158, 'errHandlernew': 159, 'Logger': 160, 'runWarehouseint': 161, 'curwarehousesint': 162, 'numwhfloat': 163, 'propexpectedPeakWarehouse': 164, 'propcheckThroughput': 165, 'TimerData': 166, 'double': 167, 'result': 168, 'minbtps': 169, 'Systemoutprintlnresult': 170, 'below': 171, 'min': 172, 'synchronized': 173, 'startJBBthreadshort': 174, 'threadList': 175, 'threadListnew': 176, 'whIdStack': 177, 'whIdStacknew': 178, 'Thread': 179, 'whThreadnew': 180, 'threadListisEmpty': 181, 'ThreadthreadListfirstElementisAlive': 182, 'NoSuchElementException': 183, 'SystemoutprintlnNo': 184, 'first': 185, 'element': 186, 'list': 187}
# Epoch 1/10
# 94/94 [==============================] - 1s 4ms/step - loss: 5.2281
# Epoch 2/10
# 94/94 [==============================] - 1s 5ms/step - loss: 5.2062
# Epoch 3/10
# 94/94 [==============================] - 0s 3ms/step - loss: 5.1828
# Epoch 4/10
# 94/94 [==============================] - 0s 3ms/step - loss: 5.1508
# Epoch 5/10
# 94/94 [==============================] - 0s 4ms/step - loss: 5.1050
# Epoch 6/10
# 94/94 [==============================] - 0s 3ms/step - loss: 5.0475
# Epoch 7/10
# 94/94 [==============================] - 0s 3ms/step - loss: 4.9883
# Epoch 8/10
# 94/94 [==============================] - 0s 4ms/step - loss: 4.9399
# Epoch 9/10
# 94/94 [==============================] - 0s 3ms/step - loss: 4.9026
# Epoch 10/10
# 94/94 [==============================] - 0s 4ms/step - loss: 4.8775
# -----------------------
# (1, 3)
# -----------------------
# ...
# {'Title': 0, 'String': 1, 'return': 2, 'tspecinitialclientFileProperty': 3, 'filen': 4, 'specinitialserverFileServer': 5, 'property': 6, 'specinitialmaxRows': 7, 'of': 8, 'fields': 9, 'per': 10, 'edit': 11, 'paneln': 12, 'confighwvendorHardware': 13, 'Vendorn': 14, 'confighwvendorurlVendor': 15, 'URLn': 16, 'confighwmodelModeln': 17, 'confighwprocessorProcessorn': 18, 'confighwMHzMHzn': 19, 'confighwnchips': 20, 'Chipsn': 21, 'confighwncores': 22, 'Coresn': 23, 'confighwncoresperchip': 24, 'CoresChipn': 25, 'confighwhwThreadsHW': 26, 'Threading': 27, 'Enabledn': 28, 'configswprocsAvailtoJavaProcs': 29, 'Avail': 30, 'to': 31, 'Javan': 32, 'confighwmemoryMemory': 33, 'MBn': 34, 'confighwmemorydescriptionMemory': 35, 'Detailsn': 36, 'confighwprimaryCachePrimary': 37, 'cachen': 38, 'confighwsecondaryCacheSecondary': 39, 'confighwotherCacheOther': 40, 'confighwfileSystemFilesystemn': 41, 'confighwdiskDisksn': 42, 'confighwotherOther': 43, 'hardwaren': 44, 'confighwavailableHw': 45, 'availablen': 46, 'configswvendorSoftware': 47, 'configswvendorurlVendor': 48, 'configswJVMJVM': 49, 'Versionn': 50, 'configswcommandlineJVM': 51, 'Command': 52, 'Linen': 53, 'configswJVMavailableJVM': 54, 'configswJVMheapInitialJVM': 55, 'Initial': 56, 'Heap': 57, 'Memory': 58, 'configswJVMheapMaxJVM': 59, 'Maximum': 60, 'MB': 61, 'n': 62, 'configswJVMbitnessJVM': 63, 'Address': 64, 'bits': 65, 'javaclasspathJVM': 66, 'CLASSPATHn': 67, 'sunbootclasspathJVM': 68, 'BOOTCLASSPATHn': 69, 'configswOSOS': 70, 'configswOSavailableOS': 71, 'configswotherOther': 72, 'softwaren': 73, 'configswotherAvailableOther': 74, 'sw': 75, 'configswnotesOther': 76, 'Notesn': 77, 'configtesttestedByTested': 78, 'byn': 79, 'configtestspecLicenseSPEC': 80, 'license': 81, 'configtestlocationTest': 82, 'locationn': 83, 'configtestdateTest': 84, 'daten': 85, 'configtestxemailToMail': 86, 'test': 87, 'results': 88, 'ton': 89, 'configtestxemailReturnYour': 90, 'email': 91, 'addressn': 92, 'configtestxmailHostOutgoing': 93, 'SMTP': 94, 'mail': 95, 'servern': 96, 'configtestxtestedByNameTested': 97, 'by': 98, 'personn': 99, 'configtestxinternalReferenceInternal': 100, 'Referencen': 101, 'specothertestTimeTest': 102, 'timen': 103, 'specotherversionSPEC': 104, 'versionn': 105, 'specotherversionDateSPEC': 106, 'release': 107, 'specotherreportDateDate': 108, 'report': 109}
# Epoch 1/10
# 32/32 [==============================] - 1s 4ms/step - loss: 4.7002
# Epoch 2/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.6953
# Epoch 3/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.6914
# Epoch 4/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.6877
# Epoch 5/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.6836
# Epoch 6/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.6797
# Epoch 7/10
# 32/32 [==============================] - 0s 4ms/step - loss: 4.6755
# Epoch 8/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.6711
# Epoch 9/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.6667
# Epoch 10/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.6618
# -----------------------
# (1, 3)
# -----------------------
# ['Run', 'double', 'double', 'if', 'time', '0', 'return', 'else', 'return', 'ref', 'RunReportProps', 'propsint', 'runNumberdouble', 'timeResult', 'String', 'prefixresult', 'resultname', 'company', 'countpropsgetIntprefix', 'totaltimepropsgetDoubleprefix', 'minimumtimepropsgetDoubleprefix', 'maximumtimepropsgetDoubleprefix', 'averagetimepropsgetDoubleprefix']
# {'Run': 0, 'double': 1, 'if': 2, 'time': 3, '0': 4, 'return': 5, 'else': 6, 'ref': 7, 'RunReportProps': 8, 'propsint': 9, 'runNumberdouble': 10, 'timeResult': 11, 'String': 12, 'prefixresult': 13, 'resultname': 14, 'company': 15, 'countpropsgetIntprefix': 16, 'totaltimepropsgetDoubleprefix': 17, 'minimumtimepropsgetDoubleprefix': 18, 'maximumtimepropsgetDoubleprefix': 19, 'averagetimepropsgetDoubleprefix': 20}
# Epoch 1/10
# 6/6 [==============================] - 1s 4ms/step - loss: 3.0492
# Epoch 2/10
# 6/6 [==============================] - 0s 3ms/step - loss: 3.0465
# Epoch 3/10
# 6/6 [==============================] - 0s 3ms/step - loss: 3.0443
# Epoch 4/10
# 6/6 [==============================] - 0s 3ms/step - loss: 3.0421
# Epoch 5/10
# 6/6 [==============================] - 0s 3ms/step - loss: 3.0402
# Epoch 6/10
# 6/6 [==============================] - 0s 3ms/step - loss: 3.0384
# Epoch 7/10
# 6/6 [==============================] - 0s 3ms/step - loss: 3.0365
# Epoch 8/10
# 6/6 [==============================] - 0s 3ms/step - loss: 3.0348
# Epoch 9/10
# 6/6 [==============================] - 0s 3ms/step - loss: 3.0328
# Epoch 10/10
# 6/6 [==============================] - 0s 4ms/step - loss: 3.0311
# -----------------------
# (1, 3)
# -----------------------
# ['JBButil', 'static', 'String', 'chooserandomlastnameint', 'maxCustomersshort', 'short', 'String', 'return', 'static', 'char', 'createastringwithoriginalint', 'lengthloint', 'lengthhifloat', 'percenttosetInteger', 'long', 'int', 'actuallength', 'char', 'int', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'if', 'f', 'percenttoset', 'startposrandom0templength', 'return', 'static', 'char', 'createastringwithoriginalint', 'lengthloint', 'lengthhifloat', 'percenttosetInteger', 'hitshort', 'long', 'int', 'actuallength', 'char', 'int', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'if', 'f', 'percenttoset', 'startposrandom0templength', 'return', 'static', 'char', 'createrandomastringint', 'lengthloint', 'int', 'i', 'actuallength', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'if', 'aRandInt', '61', 'return', 'static', 'char', 'createrandomastringint', 'lengthloint', 'lengthhiRandom', 'int', 'i', 'actuallength', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'if', 'aRandInt', '61', 'return', 'static', 'char', 'createrandomastringint', 'lengthloint', 'lengthhishort', 'int', 'i', 'actuallength', 'Random', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'if', 'aRandInt', '61', 'return', 'static', 'short', 'createrandomcustomeridint', 'maxCustomersshort', 'int', 'acidJBButilACID', 'maxCustomers', 'int', 'ccidJBButilCCID', 'maxCustomers', 'short', 'return', 'static', 'float', 'createrandomfloatvalreturnfloat', 'vallofloat', 'valhifloat', 'float', 'f', 'ffloatrnextFloat', 'valhi', 'vallo', 'resultf', 'return', 'static', 'float', 'createrandomfloatvalreturnfloat', 'vallofloat', 'valhifloat', 'precisionRandom', 'float', 'f', 'ffloatrnextFloat', 'valhi', 'vallo', 'resultf', 'return', 'static', 'float', 'createrandomfloatvalreturnfloat', 'vallofloat', 'valhifloat', 'precisionshort', 'float', 'f', 'Random', 'ffloatrnextFloat', 'valhi', 'vallo', 'resultf', 'return', 'static', 'int', 'createrandomitemidint', 'maxItemsshort', 'int', 'aoliidJBButilAOLIID', 'maxItems', 'int', 'coliidJBButilCOLIID', 'maxItems', 'int', 'if', 'JBBmainuniformRandomItems', 'else', 'return', 'static', 'String', 'createrandomlastnameint', 'custnumshort', 'int', 'String', 'if', 'custnum', '0', 'custnum', '1000', 'else', 'randomnumcustnum', 'templastnamepartsrandomnum', 'temptemp', 'lastnamepartsrandomnum', 'temptemp', 'return', 'static', 'char', 'createrandomnstringint', 'lengthloint', 'int', 'i', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'return', 'static', 'char', 'createrandomnstringint', 'lengthloint', 'lengthhiRandom', 'int', 'i', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'return', 'static', 'char', 'createrandomnstringint', 'lengthloint', 'lengthhishort', 'int', 'i', 'Random', 'char', 'tempnew', 'for', 'i0', 'i', 'actuallength', 'i', 'return', 'static', 'long', 'long', 'return', 'static', 'long', 'long', 'return', 'static', 'long', 'long', 'resultresult', 'return', 'static', 'Random', 'derivedrandominitshort', 'Random', 'r1new', 'r1setSeedlongrnextInt', '0x7fffffff', 'return', 'static', 'Logger', 'return', 'static', 'void', 'milliSecondsToSleeplong', 'try', 'catch', 'InterruptedException', 'e', 'JBButilgetLoglogLevelWARNING', 'Exception', 'SLEEP', 'static', 'double', 'negativeExpDistributiondouble', 'meanshort', 'Random', 'double', 'double', 'double', 'meanX10mean', 'tMathlogrf', 'if', 't', 'meanX10', 'return', 'static', 'int', 'NUrandvalint', 'Aint', 'xint', 'yint', 'CRandom', 'return', 'random0Ar', 'randomxyr', 'C', 'y', 'x', '1', 'static', 'int', 'NUrandvalint', 'Aint', 'xint', 'yint', 'Cshort', 'Random', 'return', 'random0Ar', 'randomxyr', 'C', 'y', 'x', '1', 'static', 'void', 'randominitint', 'rnew', 'warehouserandomstreamnew', 'static', 'int', 'randomint', 'lowint', 'return', 'rnextInt', '0x7fffffff', 'high', 'low', '1', 'static', 'int', 'randomint', 'lowint', 'highRandom', 'return', 'rnextInt', '0x7fffffff', 'high', 'low', '1', 'static', 'int', 'randomint', 'lowint', 'highshort', 'Random', ...
# {'JBButil': 0, 'static': 1, 'String': 2, 'chooserandomlastnameint': 3, 'maxCustomersshort': 4, 'short': 5, 'return': 6, 'char': 7, 'createastringwithoriginalint': 8, 'lengthloint': 9, 'lengthhifloat': 10, 'percenttosetInteger': 11, 'long': 12, 'int': 13, 'actuallength': 14, 'tempnew': 15, 'for': 16, 'i0': 17, 'i': 18, 'if': 19, 'f': 20, 'percenttoset': 21, 'startposrandom0templength': 22, 'hitshort': 23, 'createrandomastringint': 24, 'aRandInt': 25, '61': 26, 'lengthhiRandom': 27, 'lengthhishort': 28, 'Random': 29, 'createrandomcustomeridint': 30, 'acidJBButilACID': 31, 'maxCustomers': 32, 'ccidJBButilCCID': 33, 'float': 34, 'createrandomfloatvalreturnfloat': 35, 'vallofloat': 36, 'valhifloat': 37, 'ffloatrnextFloat': 38, 'valhi': 39, 'vallo': 40, 'resultf': 41, 'precisionRandom': 42, 'precisionshort': 43, 'createrandomitemidint': 44, 'maxItemsshort': 45, 'aoliidJBButilAOLIID': 46, 'maxItems': 47, 'coliidJBButilCOLIID': 48, 'JBBmainuniformRandomItems': 49, 'else': 50, 'createrandomlastnameint': 51, 'custnumshort': 52, 'custnum': 53, '0': 54, '1000': 55, 'randomnumcustnum': 56, 'templastnamepartsrandomnum': 57, 'temptemp': 58, 'lastnamepartsrandomnum': 59, 'createrandomnstringint': 60, 'resultresult': 61, 'derivedrandominitshort': 62, 'r1new': 63, 'r1setSeedlongrnextInt': 64, '0x7fffffff': 65, 'Logger': 66, 'void': 67, 'milliSecondsToSleeplong': 68, 'try': 69, 'catch': 70, 'InterruptedException': 71, 'e': 72, 'JBButilgetLoglogLevelWARNING': 73, 'Exception': 74, 'SLEEP': 75, 'double': 76, 'negativeExpDistributiondouble': 77, 'meanshort': 78, 'meanX10mean': 79, 'tMathlogrf': 80, 't': 81, 'meanX10': 82, 'NUrandvalint': 83, 'Aint': 84, 'xint': 85, 'yint': 86, 'CRandom': 87, 'random0Ar': 88, 'randomxyr': 89, 'C': 90, 'y': 91, 'x': 92, '1': 93, 'Cshort': 94, 'randominitint': 95, 'rnew': 96, 'warehouserandomstreamnew': 97, 'randomint': 98, 'lowint': 99, 'rnextInt': 100, 'high': 101, 'low': 102, 'highRandom': 103, 'highshort': 104, 'registerwarehouseRandomstreamshort': 105, 'warehouseIdRandom': 106, 'warehouserandomstreamwarehouseId': 107, 'null': 108, 'SystemoutprintlnWarning': 109, 'reregistering': 110, 'stream': 111, 'warehouse': 112, 'SecondsToSleepdouble': 113, 'millslongseconds': 114, 'SecondsToSleeplong': 115, 'millsseconds': 116, 'synchronized': 117, 'setLogLogger': 118, 'setrandomseedlong': 119}
# Epoch 1/10
# 97/97 [==============================] - 1s 3ms/step - loss: 4.7672
# Epoch 2/10
# 97/97 [==============================] - 0s 3ms/step - loss: 4.7184
# Epoch 3/10
# 97/97 [==============================] - 0s 2ms/step - loss: 4.6480
# Epoch 4/10
# 97/97 [==============================] - 0s 3ms/step - loss: 4.5393
# Epoch 5/10
# 97/97 [==============================] - 0s 3ms/step - loss: 4.4075
# Epoch 6/10
# 97/97 [==============================] - 0s 3ms/step - loss: 4.2914
# Epoch 7/10
# 97/97 [==============================] - 0s 2ms/step - loss: 4.2154
# Epoch 8/10
# 97/97 [==============================] - 0s 2ms/step - loss: 4.1755
# Epoch 9/10
# 97/97 [==============================] - 0s 2ms/step - loss: 4.1537
# Epoch 10/10
# 97/97 [==============================] - 0s 3ms/step - loss: 4.1397
# -----------------------
# (1, 3)
# -----------------------
# [['OrderStatusTransaction', [[-0.8796776533126831, -0.6002922654151917, 1.3763515949249268]]], ['MultiVMTxtReport', [[3.566541910171509, 0.9438815712928772, -3.565392255783081]]], ['Sub', [[2.411482572555542, 0.3921023905277252, 1.3149999380111694]]], ['Item', [[-0.2720460891723633, 1.343341588973999, -1.0988913774490356]]], ['TemplateCompare', [[-2.0173935890197754, -0.7085472941398621, 1.7567633390426636]]], ['MapDataStorage', [[-0.6246585249900818, -0.4867159426212311, -1.3251761198043823]]], ['GraphImage', [[-8.986227989196777, -12.786615371704102, -12.676591873168945]]], ['Check', [[-1.297882318496704, 2.9827427864074707, 0.05721282958984375]]], ['Report', [[-0.9093233942985535, -4.007366180419922, 2.5848233699798584]]], ['Warehouse', [[0.34306666254997253, 0.9404402375221252, -0.6887709498405457]]], ['TableGroup', [[-0.3058072328567505, 0.14502307772636414, -0.2877187430858612]]], ['NewOrder', [[0.07623985409736633, -1.492913842201233, 0.49799513816833496]]], ['JBBmain', [[-9.65148639678955, -9.301032066345215, -9.004155158996582]]], ['MultiVMReporter', [[0.18611875176429749, -1.4985557794570923, -2.647965431213379]]], ['History', [[0.06865258514881134, 0.5102238655090332, 0.6963672637939453]]], ['Order', [[-0.007982313632965088, 0.7602161765098572, 1.6049116849899292]]], ['TextColumn', [[0.24396951496601105, -4.084830284118652, -2.0020408630371094]]], ['LoopBounds', [[1.548418641090393, 1.8447448015213013, 0.2968427538871765]]], ['NewOrderTransaction', [[-0.5212345123291016, 0.09185011684894562, 2.978017568588257]]], ['TransactionLogBuffer', [[-9.346436500549316, 10.668756484985352, -13.709293365478516]]], ['MultiVMReport', [[-0.800668478012085, -0.12261050194501877, 1.9272210597991943]]], ['HTMLTableGraphGenerator3', [[8.476232528686523, -0.3328438997268677, -1.0226496458053589]]], ['TextBlock', [[3.8552768230438232, -1.3884865045547485, 1.2295753955841064]]], ['CustomerReportTransaction', [[-0.9735146164894104, 1.5629897117614746, 0.2191290259361267]]], ['TimerData', [[16.796354293823242, -10.912470817565918, -16.70534324645996]]], ['Result', [[-2.6371827125549316, 1.736781120300293, -2.640503406524658]]], ['digestExpected', [[-0.37368881702423096, 0.35251396894454956, -0.08442626148462296]]], ['Table', [[-2.7662785053253174, 0.03725436329841614, -0.08655916154384613]]], ['TextMetrics', [[-0.20230768620967865, -1.5532417297363281, -1.308170199394226]]], ['Customer', [[-0.804513692855835, -0.45923298597335815, 1.2969446182250977]]], ['PaymentTransaction', [[2.42401123046875, 1.022026538848877, -0.4958757758140564]]], ['Controller', [[1.6616580486297607, 1.166192889213562, -0.9483296871185303]]], ['ReportProps', [[0.6549903154373169, -0.45768046379089355, 0.17869946360588074]]], ['PepTest', [[32.653770446777344, -29.420379638671875, 33.35258865356445]]], ['digest', [[-1.6955337524414062, 0.4782504141330719, -0.03585765138268471]]], ['TextiReport', [[1.9303191900253296, 2.7102363109588623, 1.9285774230957031]]], ['StockLevelTransaction', [[1.950617790222168, -1.402076005935669, -0.025393158197402954]]], ['Template', [[-0.8036419153213501, 1.3786342144012451, 0.32788944244384766]]], ['RunSequencer', [[0.06425333023071289, -0.2967725098133087, -0.6017335653305054]]], ['TreeMapDataStorage', [[-0.1658712476491928, -2.357036828994751, 1.0368174314498901]]], ['Transaction', [[-0.4861874580383301, 1.5244736671447754, 0.07692959904670715]]], ['Metrics', [[12.94448471069336, -23.81734275817871, 16.907344818115234]]], ['Orderline', [[0.832336962223053, -1.634315013885498, 1.5893174409866333]]], ['Super', [[-1.2691550254821777, -1.254319429397583, -0.4585966169834137]]], ['XMLTransactionLog', [[-1.4753835201263428, 0.4725504219532013, -0.3898868262767792]]], ['Stock', [[-1.2847771644592285, -3.253124475479126, -1.5300499200820923]]], ['District', [[0.9703847169876099, 0.6082085371017456, 2.749824285507202]]], ['JBBLogFormatter', [[1.4037190675735474, -1.9128668308258057, 1.2004114389419556]]], ['TableGroupCompare', [[2.154261350631 ...

# %%
df =pd.read_csv("/content/drive/MyDrive/delesmell/dataset_class/SPECjbb/SPECjbb2.csv")

# %%
x= df.iloc[:, 0]

# %%
ngList = []

# %%
for index in x:
#     print(index)
    q = 1
    for i in range(0,len(embedding)):
        st = str(embedding[i][0])
        st = st[1:]
#         print(st)
        if index == st:
            # embedding[i][1].reshape((1,3))
            # l = embedding[i][1].tolist()
            ngList.append(embedding[i][1])
            q = 0
            # break
#             print('*')
    if q==1 :
        ngList.append([[1, 1, 1]])



word2vec = []
list1 = []
list2 = []
list3 = []
for i in range(0,len(ngList)):
    word2vec.append(ngList[i][0])

for i in range(0,len(word2vec)):
    list1.append(word2vec[i][0])
for i in range(0,len(word2vec)):
    list2.append(word2vec[i][1])
for i in range(0,len(word2vec)):
    list3.append(word2vec[i][2])

# %%
for i in range(0,len(Brain_Class)):
    if 'False' == Brain_Class[i][1]:
        q = 1
    else :
        print('*')
# Out:
# *
# *

# %%
#add new column
ngList=[] #Prepare a list and store the data of the new column in it

for index in x:
#     print(index)
    q = 1
    for i in range(0,len(c)):
        st = str(c[i][0])
        st = st[1:]
#         print(st)
        if index == st:
            ngList.append(c[i][1])
            q = 0
#             print('*')
    if q==1 :
        ngList.append(1)

# %%
brainList=[] #Prepare a list and store the data of the new column in it

for index in x:
#     print(index)
    q = 1
    for i in range(0,len(c)):
        st = str(Brain_Class[i][0])
        st = st[1:]
        if index == st:
            brainList.append(Brain_Class[i][1])
            q = 0
    if q==1 :
        brainList.append('0')
        
        
print(len(brainList))
print(len(x))
# Out:
# 82
# 82

# %%
column=df.columns.tolist()

# %%
df['acsm'] = ngList 
df['is_brain'] = brainList 
df.to_csv(save_file_csv,mode = 'a',index =False)

# %%
df
# Out:
#                             NAME   AMW  ATDF  BOVM  BUR  CBO  CC  CM  CRIX  \
# 0   SynchronizedJBBSortedStorage  1.00     0     0  1.0    0   0   0   0.0
# 1                    ReportProps  1.50     0     0  1.0    0   8  25   0.0
# 2                      TextBlock  2.40     0     0  1.0    0   4   7   0.0
# 3                     TextColumn  1.67     0     0  1.0    1   2   4   0.0
# 4                 JBBDataStorage  0.00     0     0  1.0    0   5  20   0.0
# ..                           ...   ...   ...   ...  ...  ...  ..  ..   ...
# 77                            C1  0.00     0     0  1.0    0   0   0   0.0
# 78                            C2  0.00     0     0  1.0    0   0   0   0.0
# 79                            C3  0.00     0     0  1.0    0   0   0   0.0
# 80               ScreenException  1.00     0     0  1.0    0   0   0   0.0
# 81      XMLLineDocumentException  1.00     0     0  1.0    0   0   0   0.0
#
#     DAC  ...  NOA  NOAM  NOD  NOM  NOPA   TCC  WMC   WOC  acsm  is_brain
# 0     0  ...    0     0    0    5     0  1.00    5  1.00     1         0
# 1     0  ...    2     0    0   12     0  0.00   18  0.92     1         0
# 2     0  ...    6     0    0   15     0  0.31   36  0.91     1         0
# 3     0  ...    5     0    0    9     0  0.29   15  0.88     1         0
# 4     0  ...    1     0    5    6     0  0.00    0  0.86     1         0
# ..  ...  ...  ...   ...  ...  ...   ...   ...  ...   ...   ...       ...
# 77    0  ...    1     0    2    1     1  0.00    0  0.00     1         0
# 78    0  ...    1     0    1    1     1  0.00    0  0.00     1         0
# 79    0  ...    1     0    0    1     1  0.00    0  0.00     1         0
# 80    0  ...    2     0    0    2     0  0.00    2  0.00     1         0
# 81    0  ...    2     0    0    2     0  0.00    2  0.00     1         0
#
# [82 rows x 27 columns]
