# %% [markdown]
# <a href="https://colab.research.google.com/github/tarvt/DeleSmell_SA_G5/blob/main/dataset_class%5Ccassandra-trunk%5Ccassandra_semantic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
import numpy as np
import re
from string import punctuation
import pandas as pd
import csv
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
save_file_csv = 'cassandra2.csv'
file_csv =  'cassandra.csv'
file_dir = '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk' #Newly stored class address

# %%
fileList = [] # list of all the cassandra file classes 
def file_name(file_dir):
    for root, dirs, files in os.walk(file_dir):
         for file in files:
            if file[-4:] == '.txt':
                fileList.append(os.path.join(root, file))

# %%
file_name(file_dir)
fileList
# Out:
# ['/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Ec2MultiRegionSnitch.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BootStrapper.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ImmediateExecutor.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/InvalidRequestException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SnapshotDetailsTabularData.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CompactionStrategyHolder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CollectionKeyIndex.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractConditions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BufferDecoratedKey.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AggregateFunctionSelector.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraValidationIterator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RingPosition.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ArrayClusteringBoundary.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CreateFunctionStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LastEventIdBroadcasterMBean.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DropKeyspaceStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MorePartitions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/JMXEnabledThreadPoolExecutorMBean.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AuthenticationStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AuthKeyspace.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DoubleType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DropTableStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DateType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FSError.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ArrayClusteringBoundOrBoundary.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Batch.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TableAttributes.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CorruptSSTableException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IndexNotAvailableException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/GossiperEvent.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CqlOutputFormat.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IndexSummary.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SchemaElement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CreateViewStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintsServiceDiagnostics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractCompactionController.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CASClientWriteRequestMetrics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CachesTable.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractGettableByIndexData.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractArrayClusteringPrefix.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RangeIntersectionIterator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/KeyspaceAttributes.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/VersionGenerator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintEvent.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraCompressedStreamWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AlibabaCloudSnitch.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BufferClusteringBound.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/InternodeOutboundMetrics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AlreadyExistsException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/NonTokenizingAnalyzer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ByteTerm.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DataOutputBufferFixed.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraStreamHeader.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AuditEvent.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IFailureDetectionEventListener.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ByteType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CBuilder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ActiveCompactionsTracker.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DroppedMessageMetrics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractMarker.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractVirtualTable.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DecimalType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintMessage.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AlterViewStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractReaderFileProxy.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IncompatibleSchemaException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IndexedTerm.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FSDiskFullWriteError.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraCompressedStreamReader.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ClientsTable.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ArrayCell.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IntegralSA.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/InstrumentingCache.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ClusteringBound.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FromJsonFct.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SSTableMultiWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SnappyCompressor.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DropRoleStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DriverInternalError.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FieldIdentifier.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DiagnosticEventAuditLogger.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CellPath.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/InvalidSerializedSizeException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BatchlogManagerMBean.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/EncryptedFileSegmentInputStream.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ImmutableBTreePartition.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FunctionResource.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CachedBTreePartition.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DateTieredCompactionStrategyOptions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DuplicateRowChecker.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FilterPipelineExecutor.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CreateRoleStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraKeyspaceWriteHandler.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RoleName.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BigFormat.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ClusteringBoundary.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraWriteContext.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintsServiceEvent.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LocalAwareExecutorService.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IsBootstrappingException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TermTree.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ISSTableScanner.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BufferClustering.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FunctionExecutionException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/EndpointsForRange.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CASClientRequestMetrics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CachedHashDecoratedKey.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CasWriteTimeoutException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SingleRestriction.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ColumnData.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/StreamStateStore.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/EndpointsByRange.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FileAuditLogger.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ReservedKeywords.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CDCWriteException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DropIndexStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/EndpointSnitchInfo.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AuthenticationException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractClusteringIndexFilter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DelimiterTokenizingOptions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CompactionTasks.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/GoogleCloudSnitch.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DynamicTokenTreeBuilder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CasWriteUnknownResultException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/OfflineTokenAllocator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ReadQuery.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CaffeineCache.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CollectionKeyIndexBase.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/GossipDigestAck.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MetricNameFactory.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CodecNotFoundException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DynamicCompositeType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CounterColumnType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Downsampling.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IndexTarget.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IVerbHandler.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HandshakeProtocol.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IMutation.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractTrie.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CombinedTerm.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TokenTreeBuilder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ReplicationStrategy.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FSReadError.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CollatedViewIndexBuilder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CloudstackSnitch.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/InvalidTypeException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CompressedSegment.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ArrayClusteringBound.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ChecksumMismatchException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DefaultCompactionWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FilterPipelineBuilder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AlterTableStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IndexEntry.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AuthenticationProxy.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LatencyConsumer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AsciiType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/GroupingState.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AuthConfig.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/GrantPermissionsStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TableMetricTables.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CorruptBlockException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CheckedFunction.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DropFunctionStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ClientRequestMetrics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ByteOrderedPartitioner.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FileDirectSegment.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FilteredRows.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CollectionEntryIndex.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/EndpointSnitchInfoMBean.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AcceptVersions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AuthenticatedUser.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BootstrapEvent.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractUnfilteredRowIterator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CounterCells.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DiskBoundaries.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BytesType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DeleteStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ChecksummedRebufferer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BufferManagingRebufferer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CompactionHistoryTabularData.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FrameDecoderLegacy.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FilteredPartitions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CqlClientHelper.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractAddressableByIndexData.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Selector.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IndexMemtable.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IndexAttributes.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RandomPartitioner.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/InboundConnectionInitiator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ColumnMetadataVersionComparator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DataIntegrityMetadata.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FutureCombiner.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/GossipDigestSynVerbHandler.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/StopWordFactory.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BufferClusteringBoundary.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MetadataComponent.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RepairMetrics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ClockAndCount.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ColumnConditions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/EncryptedHintsWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FrameDecoderLegacyLZ4.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractGettableData.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TokenAllocatorFactory.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CQLMetrics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AuditLogContext.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FSWriteError.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/GettableByIndexData.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AsyncMessageOutputPlus.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CompactionInterruptedException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FrameDecoderUnprotected.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ByteArrayObjectFactory.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DurationType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AuthCache.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MaxSampler.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DropViewStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/VariableSpecifications.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RequestValidationException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/WritetimeOrTTLSelector.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TypeUtil.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CQLFragmentParser.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/UUIDType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/StatsMetadata.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractLocalAwareExecutorService.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/EndpointState.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TupleSelector.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SelectorFactories.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraTableWriteHandler.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/GossipDigestAck2.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CacheKey.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Cells.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SinglePartitionReadCommand.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/WriteTimeoutException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/JMXResource.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintsDispatcher.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DisallowedDirectories.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CollectionFactory.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SimpleChunkReader.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SSTableTxnWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CqlBuilder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CombinedValue.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/StandardAnalyzer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintsBuffer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/EndpointsForToken.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Bounds.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/OutboundDebugCallbacks.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ReadExecutionController.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SizeTieredCompactionStrategy.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MemoryMappedSegment.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ErrorListener.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DataLimits.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractBounds.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/JavaBasedUDFunction.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SSTableSplitter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/UserTypes.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MutableDeletionInfo.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ManyToOneConcurrentLinkedQueue.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SequentialWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TokenRelation.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/WhereClause.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CqlBulkRecordWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/INetworkAuthorizer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TermSlice.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LeveledManifest.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ParameterizedClass.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BytesConversionFcts.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PrefixTermTree.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DatabaseDescriptor.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TypeSizes.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Splitter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SafeMemoryWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PerSSTableIndexWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/InetAddressType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/NumberType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ListSelector.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ListType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintsCatalog.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PermissionDetails.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IndexTransaction.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ListRolesStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MaxSSTableSizeWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/NativeCell.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IncludingExcludingBounds.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/KeyspaceNotDefinedException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PendingRangeMaps.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IVersionedAsymmetricSerializer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MemoryOutputStream.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HadoopCompat.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LogRecord.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ChannelProxy.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Ec2Snitch.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TimeWindowCompactionStrategyOptions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/NoSizeEstimator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CommitLog.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BatchlogManager.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ViewBuilderTask.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RevokePermissionsStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Replicas.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LimitedLocalNodeFirstLocalBalancingPolicy.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TruncateException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BatchUpdatesCollector.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/UnauthorizedException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraStreamManager.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/KeyRangeIterator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CompressionInfo.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/NativeDecoratedKey.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CreateAggregateStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LogAwareFileLister.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PropertyDefinitions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Operation.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Digest.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AggregateFcts.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FailureDetectorMBean.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AsyncChannelOutputPlus.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Helpers.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/InternodeOutboundTable.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Terms.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/NamedThreadFactory.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PermissionsManagementStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CQLSSTableWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LogReplica.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Stage.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TokenFct.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/GlobalBufferPoolAllocator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SystemPropertiesTable.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TrieMemIndex.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AliasedSelectable.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraMetricsRegistry.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PreparedQueryNotFoundException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/InternodeInboundMetrics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/NativeAggregateFunction.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RowCacheSentinel.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LZ4Compressor.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Sampler.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SA.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CQL3Type.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RequestFailureReason.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ISerializer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CompactionInfo.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LeveledCompactionStrategy.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/VirtualTablePartitionRangeReadQuery.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ChunkCacheMetrics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ResultSetBuilder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SnapshotDeletingTask.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RebufferingInputStream.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LocalDate.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ValueAccessor.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ReplicaLayout.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/OutboundSink.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/UDFContextImpl.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AutoSavingCache.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractReadCommandBuilder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintsBufferPool.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TableViews.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RowIndexEntry.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CqlRecordWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ColumnFamilyStoreMBean.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Cell.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IAuthenticator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LogFile.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ColumnFamilySplit.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BatchStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TableMetrics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LengthAvailableInputStream.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SSTableReader.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AuditLogManager.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DataOutputPlus.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MoreContents.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ReadCommandVerbHandler.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/EndpointMessagingVersions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DelimiterAnalyzer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TimestampType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DebuggableThreadPoolExecutor.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PendingRepairManager.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/NonTokenizingOptions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/GossipDigestSyn.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CompactionManager.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/KeyAnalyzer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Crc.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FrameDecoderCrc.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/GossipDigest.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LexicalUUIDType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BufferPoolMetrics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FunctionResolver.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/VirtualMutation.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RangeStreamer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Maps.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/UseStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/InboundMessageCallbacks.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DCPermissions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/UnfilteredSerializer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CastFcts.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintsWriteExecutor.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/OverloadedException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ChecksumWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/InOurDcTester.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraKeyspaceRepairManager.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BigTableWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IndexSummaryRedistribution.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SsdDiskOptimizationStrategy.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RequestTimeoutException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BatchQueryOptions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TemporalType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/UnfilteredRowIteratorWithLowerBound.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FilterPipelineTask.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RequestExecutionException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/StaticTokenTreeBuilder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/UpdateParameters.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Config.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IEndpointSnitch.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Murmur3Partitioner.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MmapRebufferer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ComponentManifest.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BufferedDataOutputStreamPlus.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ClusteringPrefix.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/OnDiskIndex.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MutationExceededMaxSizeException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FieldSelector.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractTokenTreeBuilder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Version.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SchemaCQLHelper.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/UDAggregate.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractCell.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/NIODataInputStream.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TimeWindowCompactionTask.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FullQueryLoggerOptionsCompositeData.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HeartBeatState.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SecondaryIndexManager.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ParseUtils.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ReplicaPlans.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Tuples.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SSTableReversedIterator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ReporterWrapper.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MultiCBuilder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/NoPayload.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DebuggableScheduledThreadPoolExecutor.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintsDispatchTrigger.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SystemKeyspace.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LifecycleTransaction.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DiagnosticEventServiceMBean.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/EncodingStats.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/InputPosition.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/View.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/VirtualKeyspaceRegistry.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ReadCommand.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PartitionKeySingleRestrictionSet.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TokenTree.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BTreeRow.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ListPermissionsStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Attributes.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ColumnSpecification.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Lists.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TokenAllocatorBase.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LatencyMetrics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/VirtualSchemaKeyspace.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DiagnosticEventPersistence.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ClusteringIndexNamesFilter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/UnbufferedDataOutputStreamPlus.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DynamicEndpointSnitchMBean.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ChecksummedSequentialWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RangeUnionIterator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/UpdatesCollector.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RTBoundCloser.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintVerbHandler.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CustomIndexExpression.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Clustering.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SSTableIndex.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SelectionColumnMapping.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SimpleDateType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SplittingSizeTieredCompactionWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintsService.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MappedBuffer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FrameEncoderLegacyLZ4.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Relation.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CompressedChecksummedDataInput.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MemoryInputStream.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IndexInfo.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Trie.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TrackedInputStream.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ReconnectableSnitchHelper.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ValidationMetadata.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LongType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ReplicaPlan.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MultiColumnRelation.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/QueryEvents.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/UnfilteredRows.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RegularAndStaticColumns.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/VersionedValue.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SASIIndexBuilder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IndexSummaryBuilder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/QueryProcessor.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/OperationExecutionException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SimpleSSTableMultiWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SimpleSeedProvider.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DataOutputBuffer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractEndpointSnitch.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/EncryptedChecksummedDataInput.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DisallowedDirectoriesMBean.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DiskOptimizationStrategy.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ThreadLocalByteBufferHolder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SafeMemory.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PasswordAuthenticator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SingletonUnfilteredPartitionIterator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TruncateStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ChunkReader.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/WindowsFailedSnapshotTracker.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraStreamWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RangesAtEndpoint.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Term.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SSTableIterator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraOutgoingFile.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LogReplicaSet.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TokenAllocatorEvent.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IntervalSet.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/OutboundConnections.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CqlRecordReader.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SinglePartitionReadQuery.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/JavaUDF.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SetSelector.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractAnalyzer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LivenessInfo.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ByteArrayAccessor.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Json.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintsWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ClientMetrics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/NoOpAuditLogger.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SimpleCachedBufferPool.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ComponentContext.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ChecksummedRandomAccessReader.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MapType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DeflateCompressor.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DataInputBuffer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CommitLogSegmentManagerCDC.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PropertyFileSnitch.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TimeFcts.txt',
# ...
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TruncateResponse.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Sets.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SimpleDataSet.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TokenFilter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DiagnosticEventMemoryStore.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/QueryController.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CollectionValueIndex.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/VirtualKeyspace.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractRow.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CreateTypeStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RawSelector.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SASIIndex.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RestrictionSet.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FailureDetector.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ThreadPoolMetrics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/OutboundConnection.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/UTName.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RefCountedMemory.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SEPExecutor.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MmappedRegions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Roles.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ExpirationDateOverflowHandling.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TokenSerializer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AuthorizationProxy.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/WrappedDataOutputStreamPlus.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractPatriciaTrie.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/StandardTokenizerOptions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SystemViewsKeyspace.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ChecksummedDataInput.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SSTableFlushObserver.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SuffixSA.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MemIndex.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TokenRestriction.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ThrottledUnfilteredIterator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintsDispatchExecutor.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ClusteringIndexFilter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TombstoneOverwhelmingException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Gossiper.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FrameEncoderLZ4.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/OnDiskIndexIterator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/KeysIndex.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TargetParser.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CombinedTermIterator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TypeParser.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraRoleManager.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PartitionKeyIndex.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintsServiceMetrics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MonitorableImpl.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Endpoints.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RequestCallbacks.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LimitingRebufferer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RangeTombstone.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/StreamingMetrics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/InboundSockets.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RequestValidations.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CleanupTransaction.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ThreadPoolsTable.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SingleSSTableLCSTask.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Columns.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TokenMetadataEvent.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/UDTValue.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/NoReplicationTokenAllocator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ResizableThreadPool.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BigTableReader.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MajorLeveledCompactionWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RewindableDataInputStreamPlus.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RestorableMeter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/StorageHook.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DiagnosticEventService.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintDiagnostics.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CounterContext.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Upgrader.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ClusteringComparator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AuthSchemaChangeListener.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintsDescriptor.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraIndex.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PingRequest.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LazilyInitializedUnfilteredRowIterator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Duration.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Verifier.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CodecUtils.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PartitionSerializationException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/VirtualTableReadQuery.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BinAuditLogger.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AsyncPromise.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DataTracker.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LocalBufferPoolAllocator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TokenMetadata.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/StandardTokenizerInterface.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CreateTableStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BatchCommitLogService.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AsyncStreamingInputPlus.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/UserType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ColumnFilter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ScalarFunctionSelector.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SSTableSimpleWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraEntireSSTableStreamReader.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FunctionCall.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FileDataInput.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractStrategyHolder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AlterTypeStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SSTableRewriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CreateIndexStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RowDiffListener.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FunctionName.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractSSTableIterator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Role.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraEntireSSTableStreamWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CompactionStrategyManager.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/InboundMessageHandler.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SelectStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MessagingService.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SSTableReadsListener.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraStreamReceiver.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IFailureDetector.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CounterMutation.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MetadataCollector.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CassandraIndexFunctions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ComparableObjectToken.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DataType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/StatementRestrictions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CompactionTransaction.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/InetAddressAndPort.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CompositeType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FrameDecoderLZ4.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/StartupException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/IndexSummaryManager.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/MetadataSerializer.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FloatType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CommitLogSegment.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Mutation.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractFunctionSelector.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LegacyFlag.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CommitLogSegmentReader.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PreHashedDecoratedKey.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PurgeFunction.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ReversedType.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/VirtualTableSinglePartitionReadQuery.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TokenAllocation.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/JMXEnabledSingleThreadExecutor.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/WriteFailureException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SSTableLoader.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Replica.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BasePartitions.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CqlConfigHelper.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ReadResponse.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SSTableReaderBuilder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SnapshotCommand.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RangeTombstoneBoundMarker.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/TupleValue.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ColumnIndex.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PartitionRangeReadCommand.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/DropAggregateStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FrameDecoder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SSTableIdentityIterator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/QualifiedStatement.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/HintsStore.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/PartitionerDefinedOrder.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractData.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CodecRegistry.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LeveledCompactionTask.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Memtable.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/RowAndDeletionMergeIterator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BaseIterator.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Resources.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ConfigHelper.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CompressedChunkReader.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/LastEventIdBroadcaster.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CompactionController.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/Directories.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/SSTable.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CounterCacheKey.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractBTreePartition.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/AbstractCommitLogSegmentManager.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/UnknownColumnException.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/BufferClusteringBoundOrBoundary.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/CompressedHintsWriter.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/ClusteringColumnIndex.txt',
#  '/content/drive/MyDrive/delesmell/dataset_class/cassandra-trunk/FutureResult.txt',
#  ...]

# %%
# stopwords
stopwords = ['abstract', 'java','assert', 'boolean', 'break', 'byte', 'case', 'catch', 'class','char', 'continue', 'default', 'do', 'double', 'else', 'enum', 'extends', 'final', 'finally', 'float', 'for', 'if', 'implements', 'import', 'int', 'interface', 'long', 'native', 'new', 'package','private','public', 'protected',  'return', 'short', 'static', 'strictfp', 'super', 'switch', 'synchronized', 'this', 'throw', 'transient', 'try', 'void', 'volatile', 'while']
dicts = {'\n': '','!': '', '"': '','：':'', '#': '', '$': '', '%': '', '&': '', "'": '', '(': '', ')': '', '*': '', '+': '', ',': '', '-': '', '.': '', '/': '', ':': '', ';': '', '<': '', '=': '', '>': '', '?': '', '@': '', '[': '', '\\': '', ']': '', '^': '', '_': '', '`': '', '{': '', '|': '', '}': '', '~': ''}

# %%
def lm_find_unchinese(line):
    pattern = re.compile(r'[\u4e00-\u9fa5]')
    unchinese = re.sub(pattern,"",line) #Exclude Chinese characters
    unchinese = re.sub('[{}]'.format(punctuation),"",unchinese) #Exclude Chinese characters
    return unchinese

# %%
def del_stopwords(line):
    punc_table = str.maketrans(dicts)
    new_line = line.translate(punc_table)

    return new_line

# %%
index = []
index_all = []
class_name = []
Brain_Class = []
for i, f in enumerate(fileList):
    with open(f,encoding='gb18030',errors='ignore') as file:
        list = []
        list2 = []
        is_brain = 0
        filename = os.path.basename(file.name)
        name = filename[:-4]
        class_name.append(name)
        list.append(name)
        list2.append(name)
        
        for line in file.readlines():
            line = lm_find_unchinese(line)
            line = del_stopwords(line)
            values = line.split(' ')
            coefs = values[1:-1]
            coefs = [i for i in coefs if i != '']
            keyword_brain = 'hongshuai'  # if the code contains hongshuai function it is made by refactoring tool  

            if  keyword_brain in line:
                is_brain = 1

            for i in coefs:
                list.append(i)

        index.append(list)
        
        if is_brain == 0:
            list2.append(False)
        else :
            list2.append(True)
            print('T')

        
        Brain_Class.append(list2)
# Out:
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T

# %%
for k in range(0,len(Brain_Class)):
    a = Brain_Class[k][0]
    if '_' in a:
        n = a.find('_')
        new_str = ''
        for i in range(0, n):
            new_str = new_str + a[i]
        Brain_Class[k][0] = new_str
    print(Brain_Class[k][0])
# Out:
# Ec2MultiRegionSnitch
# BootStrapper
# ImmediateExecutor
# InvalidRequestException
# SnapshotDetailsTabularData
# CompactionStrategyHolder
# CollectionKeyIndex
# AbstractConditions
# BufferDecoratedKey
# AggregateFunctionSelector
# CassandraValidationIterator
# RingPosition
# ArrayClusteringBoundary
# CreateFunctionStatement
# CassandraException
# LastEventIdBroadcasterMBean
# DropKeyspaceStatement
# MorePartitions
# JMXEnabledThreadPoolExecutorMBean
# AuthenticationStatement
# AuthKeyspace
# DoubleType
# DropTableStatement
# DateType
# FSError
# ArrayClusteringBoundOrBoundary
# Batch
# TableAttributes
# CorruptSSTableException
# IndexNotAvailableException
# GossiperEvent
# CqlOutputFormat
# IndexSummary
# SchemaElement
# CreateViewStatement
# HintsServiceDiagnostics
# AbstractCompactionController
# CASClientWriteRequestMetrics
# CachesTable
# AbstractGettableByIndexData
# AbstractArrayClusteringPrefix
# RangeIntersectionIterator
# KeyspaceAttributes
# VersionGenerator
# HintEvent
# CassandraCompressedStreamWriter
# AlibabaCloudSnitch
# BufferClusteringBound
# InternodeOutboundMetrics
# AlreadyExistsException
# NonTokenizingAnalyzer
# ByteTerm
# DataOutputBufferFixed
# CassandraStreamHeader
# AuditEvent
# IFailureDetectionEventListener
# ByteType
# CBuilder
# ActiveCompactionsTracker
# DroppedMessageMetrics
# AbstractMarker
# AbstractVirtualTable
# DecimalType
# HintMessage
# AlterViewStatement
# AbstractReaderFileProxy
# IncompatibleSchemaException
# IndexedTerm
# FSDiskFullWriteError
# CassandraCompressedStreamReader
# ClientsTable
# ArrayCell
# IntegralSA
# InstrumentingCache
# ClusteringBound
# FromJsonFct
# SSTableMultiWriter
# SnappyCompressor
# DropRoleStatement
# DriverInternalError
# FieldIdentifier
# DiagnosticEventAuditLogger
# CellPath
# InvalidSerializedSizeException
# BatchlogManagerMBean
# EncryptedFileSegmentInputStream
# ImmutableBTreePartition
# FunctionResource
# CachedBTreePartition
# DateTieredCompactionStrategyOptions
# DuplicateRowChecker
# FilterPipelineExecutor
# CreateRoleStatement
# CassandraKeyspaceWriteHandler
# RoleName
# BigFormat
# ClusteringBoundary
# CassandraWriteContext
# HintsServiceEvent
# LocalAwareExecutorService
# IsBootstrappingException
# TermTree
# ISSTableScanner
# BufferClustering
# FunctionExecutionException
# EndpointsForRange
# CASClientRequestMetrics
# CachedHashDecoratedKey
# CasWriteTimeoutException
# SingleRestriction
# ColumnData
# StreamStateStore
# EndpointsByRange
# FileAuditLogger
# ReservedKeywords
# CDCWriteException
# DropIndexStatement
# EndpointSnitchInfo
# AuthenticationException
# AbstractClusteringIndexFilter
# DelimiterTokenizingOptions
# CompactionTasks
# GoogleCloudSnitch
# DynamicTokenTreeBuilder
# CasWriteUnknownResultException
# OfflineTokenAllocator
# ReadQuery
# CaffeineCache
# CollectionKeyIndexBase
# GossipDigestAck
# MetricNameFactory
# CodecNotFoundException
# DynamicCompositeType
# CounterColumnType
# Downsampling
# IndexTarget
# IVerbHandler
# HandshakeProtocol
# IMutation
# AbstractTrie
# CombinedTerm
# TokenTreeBuilder
# ReplicationStrategy
# FSReadError
# CollatedViewIndexBuilder
# CloudstackSnitch
# InvalidTypeException
# CompressedSegment
# ArrayClusteringBound
# ChecksumMismatchException
# DefaultCompactionWriter
# FilterPipelineBuilder
# AlterTableStatement
# IndexEntry
# AuthenticationProxy
# LatencyConsumer
# AsciiType
# GroupingState
# AuthConfig
# GrantPermissionsStatement
# TableMetricTables
# CorruptBlockException
# CheckedFunction
# DropFunctionStatement
# ClientRequestMetrics
# ByteOrderedPartitioner
# FileDirectSegment
# FilteredRows
# CollectionEntryIndex
# EndpointSnitchInfoMBean
# AcceptVersions
# AuthenticatedUser
# BootstrapEvent
# AbstractUnfilteredRowIterator
# CounterCells
# DiskBoundaries
# BytesType
# DeleteStatement
# ChecksummedRebufferer
# BufferManagingRebufferer
# CompactionHistoryTabularData
# FrameDecoderLegacy
# FilteredPartitions
# CqlClientHelper
# AbstractAddressableByIndexData
# Selector
# IndexMemtable
# IndexAttributes
# RandomPartitioner
# InboundConnectionInitiator
# ColumnMetadataVersionComparator
# DataIntegrityMetadata
# FutureCombiner
# GossipDigestSynVerbHandler
# StopWordFactory
# BufferClusteringBoundary
# MetadataComponent
# RepairMetrics
# ClockAndCount
# ColumnConditions
# EncryptedHintsWriter
# FrameDecoderLegacyLZ4
# AbstractGettableData
# TokenAllocatorFactory
# CQLMetrics
# AuditLogContext
# FSWriteError
# GettableByIndexData
# AsyncMessageOutputPlus
# CompactionInterruptedException
# FrameDecoderUnprotected
# ByteArrayObjectFactory
# DurationType
# AuthCache
# MaxSampler
# DropViewStatement
# VariableSpecifications
# RequestValidationException
# WritetimeOrTTLSelector
# TypeUtil
# CQLFragmentParser
# UUIDType
# StatsMetadata
# AbstractLocalAwareExecutorService
# EndpointState
# TupleSelector
# SelectorFactories
# CassandraTableWriteHandler
# GossipDigestAck2
# CacheKey
# Cells
# SinglePartitionReadCommand
# WriteTimeoutException
# JMXResource
# HintsDispatcher
# DisallowedDirectories
# CollectionFactory
# SimpleChunkReader
# SSTableTxnWriter
# CqlBuilder
# CombinedValue
# StandardAnalyzer
# HintsBuffer
# EndpointsForToken
# Bounds
# OutboundDebugCallbacks
# ReadExecutionController
# SizeTieredCompactionStrategy
# MemoryMappedSegment
# ErrorListener
# DataLimits
# AbstractBounds
# JavaBasedUDFunction
# SSTableSplitter
# UserTypes
# MutableDeletionInfo
# ManyToOneConcurrentLinkedQueue
# SequentialWriter
# TokenRelation
# WhereClause
# CqlBulkRecordWriter
# INetworkAuthorizer
# TermSlice
# LeveledManifest
# ParameterizedClass
# BytesConversionFcts
# PrefixTermTree
# DatabaseDescriptor
# TypeSizes
# Splitter
# SafeMemoryWriter
# PerSSTableIndexWriter
# InetAddressType
# NumberType
# ListSelector
# ListType
# HintsCatalog
# PermissionDetails
# IndexTransaction
# ListRolesStatement
# MaxSSTableSizeWriter
# NativeCell
# IncludingExcludingBounds
# KeyspaceNotDefinedException
# PendingRangeMaps
# IVersionedAsymmetricSerializer
# MemoryOutputStream
# HadoopCompat
# LogRecord
# ChannelProxy
# Ec2Snitch
# TimeWindowCompactionStrategyOptions
# NoSizeEstimator
# CommitLog
# BatchlogManager
# ViewBuilderTask
# RevokePermissionsStatement
# Replicas
# LimitedLocalNodeFirstLocalBalancingPolicy
# TruncateException
# BatchUpdatesCollector
# UnauthorizedException
# CassandraStreamManager
# KeyRangeIterator
# CompressionInfo
# NativeDecoratedKey
# CreateAggregateStatement
# LogAwareFileLister
# PropertyDefinitions
# Operation
# Digest
# AggregateFcts
# FailureDetectorMBean
# AsyncChannelOutputPlus
# Helpers
# InternodeOutboundTable
# Terms
# NamedThreadFactory
# PermissionsManagementStatement
# CQLSSTableWriter
# LogReplica
# Stage
# TokenFct
# GlobalBufferPoolAllocator
# SystemPropertiesTable
# TrieMemIndex
# AliasedSelectable
# CassandraMetricsRegistry
# PreparedQueryNotFoundException
# InternodeInboundMetrics
# NativeAggregateFunction
# RowCacheSentinel
# LZ4Compressor
# Sampler
# SA
# CQL3Type
# RequestFailureReason
# ISerializer
# CompactionInfo
# LeveledCompactionStrategy
# VirtualTablePartitionRangeReadQuery
# ChunkCacheMetrics
# ResultSetBuilder
# SnapshotDeletingTask
# RebufferingInputStream
# LocalDate
# ValueAccessor
# ReplicaLayout
# OutboundSink
# UDFContextImpl
# AutoSavingCache
# AbstractReadCommandBuilder
# HintsBufferPool
# TableViews
# RowIndexEntry
# CqlRecordWriter
# ColumnFamilyStoreMBean
# Cell
# IAuthenticator
# LogFile
# ColumnFamilySplit
# BatchStatement
# TableMetrics
# LengthAvailableInputStream
# SSTableReader
# AuditLogManager
# DataOutputPlus
# MoreContents
# ReadCommandVerbHandler
# EndpointMessagingVersions
# DelimiterAnalyzer
# TimestampType
# DebuggableThreadPoolExecutor
# PendingRepairManager
# NonTokenizingOptions
# GossipDigestSyn
# AbstractType
# CompactionManager
# KeyAnalyzer
# Crc
# FrameDecoderCrc
# GossipDigest
# LexicalUUIDType
# BufferPoolMetrics
# FunctionResolver
# VirtualMutation
# RangeStreamer
# Maps
# UseStatement
# InboundMessageCallbacks
# DCPermissions
# UnfilteredSerializer
# CastFcts
# HintsWriteExecutor
# OverloadedException
# ChecksumWriter
# InOurDcTester
# CassandraKeyspaceRepairManager
# BigTableWriter
# IndexSummaryRedistribution
# SsdDiskOptimizationStrategy
# RequestTimeoutException
# BatchQueryOptions
# TemporalType
# UnfilteredRowIteratorWithLowerBound
# FilterPipelineTask
# RequestExecutionException
# StaticTokenTreeBuilder
# UpdateParameters
# Config
# IEndpointSnitch
# Murmur3Partitioner
# MmapRebufferer
# ComponentManifest
# BufferedDataOutputStreamPlus
# ClusteringPrefix
# OnDiskIndex
# MutationExceededMaxSizeException
# FieldSelector
# AbstractTokenTreeBuilder
# Version
# SchemaCQLHelper
# UDAggregate
# AbstractCell
# NIODataInputStream
# TimeWindowCompactionTask
# FullQueryLoggerOptionsCompositeData
# HeartBeatState
# SecondaryIndexManager
# ParseUtils
# ReplicaPlans
# Tuples
# SSTableReversedIterator
# ReporterWrapper
# MultiCBuilder
# NoPayload
# DebuggableScheduledThreadPoolExecutor
# HintsDispatchTrigger
# SystemKeyspace
# LifecycleTransaction
# DiagnosticEventServiceMBean
# EncodingStats
# InputPosition
# View
# VirtualKeyspaceRegistry
# ReadCommand
# PartitionKeySingleRestrictionSet
# TokenTree
# BTreeRow
# ListPermissionsStatement
# Attributes
# ColumnSpecification
# Lists
# TokenAllocatorBase
# LatencyMetrics
# VirtualSchemaKeyspace
# DiagnosticEventPersistence
# ClusteringIndexNamesFilter
# UnbufferedDataOutputStreamPlus
# DynamicEndpointSnitchMBean
# ChecksummedSequentialWriter
# RangeUnionIterator
# UpdatesCollector
# RTBoundCloser
# HintVerbHandler
# CustomIndexExpression
# Clustering
# SSTableIndex
# SelectionColumnMapping
# SimpleDateType
# SplittingSizeTieredCompactionWriter
# HintsService
# MappedBuffer
# FrameEncoderLegacyLZ4
# Relation
# CompressedChecksummedDataInput
# MemoryInputStream
# IndexInfo
# Trie
# TrackedInputStream
# ReconnectableSnitchHelper
# ValidationMetadata
# LongType
# ReplicaPlan
# MultiColumnRelation
# QueryEvents
# UnfilteredRows
# RegularAndStaticColumns
# VersionedValue
# SASIIndexBuilder
# IndexSummaryBuilder
# QueryProcessor
# OperationExecutionException
# SimpleSSTableMultiWriter
# SimpleSeedProvider
# DataOutputBuffer
# AbstractEndpointSnitch
# EncryptedChecksummedDataInput
# DisallowedDirectoriesMBean
# DiskOptimizationStrategy
# ThreadLocalByteBufferHolder
# SafeMemory
# PasswordAuthenticator
# SingletonUnfilteredPartitionIterator
# TruncateStatement
# ChunkReader
# WindowsFailedSnapshotTracker
# CassandraStreamWriter
# RangesAtEndpoint
# Term
# SSTableIterator
# CassandraOutgoingFile
# LogReplicaSet
# TokenAllocatorEvent
# IntervalSet
# OutboundConnections
# CqlRecordReader
# SinglePartitionReadQuery
# JavaUDF
# SetSelector
# AbstractAnalyzer
# LivenessInfo
# ByteArrayAccessor
# Json
# HintsWriter
# ClientMetrics
# NoOpAuditLogger
# SimpleCachedBufferPool
# ComponentContext
# ChecksummedRandomAccessReader
# MapType
# DeflateCompressor
# DataInputBuffer
# CommitLogSegmentManagerCDC
# PropertyFileSnitch
# TimeFcts
# Function
# Slices
# TypeCodec
# DeletionPurger
# RoleResource
# ViewUtils
# UDFunction
# SyntaxException
# IntegerType
# Cursor
# TupleType
# NativeScalarFunction
# TimeWindowCompactionStrategy
# TermSelector
# ReplicationAwareTokenAllocator
# MutationVerbHandler
# Descriptor
# RangeFetchMapCalculator
# JMXEnabledThreadPoolExecutor
# UnavailableException
# PermissionsCache
# ReadFailureException
# PeriodicCommitLogService
# SimpleSelector
# VirtualTable
# HintsReader
# UDHelper
# SerializationHeader
# SSTableWriter
# FileHandle
# Operations
# TypeTokens
# OperationFcts
# NetworkTopologyStrategy
# GroupMaker
# InboundCounters
# ColumnSubselection
# TimeUUIDType
# RepairException
# CommitLogReplayer
# BootstrapDiagnostics
# PatriciaTrie
# ExecutorLocals
# RandomAccessReader
# Component
# UTF8Type
# ZstdCompressor
# InfiniteLoopExecutor
# Keyspace
# IndexMode
# YamlConfigurationLoader
# AbstractCompactionStrategy
# DataInputPlus
# AbstractBufferClusteringPrefix
# MessagingMetrics
# SingleColumnRestriction
# AtomicBTreePartition
# ElementsSelector
# DeserializationHelper
# Bytes
# CassandraLoginModule
# ViewWriteMetrics
# UnknownIndexException
# WrappingUnfilteredRowIterator
# RoleOptions
# DescribeStatement
# QualifiedName
# Hint
# Selectable
# StoppingTransformation
# AbstractSSTableSimpleWriter
# GossiperDiagnostics
# FullQueryLogger
# Range
# EncryptionOptions
# CompactionIterator
# SSTableSimpleIterator
# RegularColumnIndex
# AbstractReplicaCollection
# ViewUpdateGenerator
# ReadTimeoutException
# SetType
# PrunableArrayQueue
# TypeCast
# AsyncStreamingOutputPlus
# AuthorizationStatement
# RoleManagementStatement
# EncryptedSegment
# TokenMetadataDiagnostics
# CacheMetrics
# CommitLogArchiver
# CassandraNetworkAuthorizer
# SimpleBuilders
# UpdateStatement
# RepairedDataInfo
# AbstractRangeTombstoneMarker
# TrackedDataInputPlus
# ScriptBasedUDFunction
# CassandraIndexSearcher
# SSTableHeaderFix
# ChunkedInputPlus
# KeyCacheKey
# UntypedResultSet
# CqlBulkOutputFormat
# ToJsonFct
# Tracker
# SingleColumnRelation
# SSTableImporter
# UpdateTransaction
# DataResource
# Expression
# Validation
# Metadata
# Monitorable
# SharedExecutorPool
# NativeClustering
# CassandraAuthorizer
# UnknownTableException
# SimpleStrategy
# DataOutputStreamPlus
# CachedPartition
# OnDiskIndexBuilder
# SizeEstimatesRecorder
# AbstractFunction
# DataRange
# RowFilter
# RTBoundValidator
# UDFByteCodeVerifier
# AbstractCommitLogService
# Transformation
# PartitionIterators
# AlterKeyspaceStatement
# RequestCallback
# IndexRestrictions
# SnitchProperties
# AbstractCompositeType
# RangeTermTree
# TransparentDataEncryptionOptions
# OutboundConnectionInitiator
# SerializationHelper
# LocalStrategy
# CQL3CasRequest
# UnfilteredPartitionIterators
# ColumnFilterFactory
# CqlInputFormat
# DeletionTime
# TruncateRequest
# KeysSearcher
# MonitoringTask
# KeyIterator
# CommitLogDescriptor
# ExecutorLocal
# PartitionUpdate
# Slice
# OutboundConnectionSettings
# CompressedSequentialWriter
# SSTableIntervalTree
# OnDiskBlock
# BufferPoolAllocator
# IAuthorizer
# ErrorCollector
# NativeFunction
# SettingsTable
# SharedDefaultFileRegion
# RequestFailureException
# RolesCache
# AuthCacheMBean
# ModificationStatement
# RangeTombstoneBoundaryMarker
# TermIterator
# RevokeRoleStatement
# CompressedInputStream
# AbstractMessageHandler
# OrderPreservingPartitioner
# CollectionType
# OutboundMessageQueue
# Scrubber
# ShortType
# SimpleSnitch
# SSTableTasksTable
# ForwardingFactory
# QueryOptions
# RangeTombstoneList
# PendingRepairHolder
# UnfilteredRowIterators
# CompactionLogger
# ViewBuilder
# BufferCell
# LocalPartitioner
# CassandraTableRepairManager
# DataTypeClassNameParser
# ByteBufferAccessor
# IMetadataComponentSerializer
# UnfilteredDeserializer
# PendingAntiCompaction
# RangeAwareSSTableWriter
# RangesByEndpoint
# NetworkAuthCache
# Message
# UnfilteredValidation
# SerializingCache
# AuditLogFilter
# ReducingKeyIterator
# ResultSet
# AbstractReplicationStrategy
# RangeIterator
# KeyspaceMetrics
# SizeTieredCompactionStrategyOptions
# Memory
# HintedHandoffMetrics
# Tries
# ClusteringColumnRestrictions
# TimeType
# AuthEvents
# EmptyIterators
# TimeQuotaExceededException
# SingleTableUpdatesCollector
# QueryPlan
# CassandraIncomingFile
# CompressionMetadata
# DateTieredCompactionStrategy
# ShareableBytes
# ForwardingInfo
# BigTableScanner
# FilteredPartition
# Selection
# LogTransaction
# UDFExecutorService
# IPartitionerDependentSerializer
# TokenAllocatorDiagnostics
# BigTableZeroCopyWriter
# Datacenters
# ValueComparators
# UnfilteredPartitions
# ColumnIdentifier
# LeveledGenerations
# SystemKeyspaceMigrator40
# AbstractCompactionTask
# IndexRegistry
# AbstractReadQuery
# UserTypeSelector
# RowIterators
# UnfilteredRowIteratorSerializer
# SkipListMemIndex
# SEPWorker
# CompactionAwareWriter
# RowCacheKey
# InboundMessageHandlers
# AlterSchemaStatement
# MapSelector
# GossipingPropertyFileSnitch
# AsyncChannelPromise
# ArrayClustering
# WrappedLifecycleTransaction
# CompactionTask
# ColumnFamilyStore
# CommitLogReader
# Stack
# SSTableSimpleUnsortedWriter
# ViewManager
# CassandraStreamReader
# ChunkCache
# InboundSink
# MessagingServiceMBeanImpl
# SequentialWriterOption
# IPartitioner
# SocketFactory
# Rows
# FutureDelegate
# FrameEncoder
# DecayingEstimatedHistogramReservoir
# ReplicationFactor
# DiagnosticEventStore
# DynamicEndpointSnitch
# TimeWindowCompactionController
# ClusteringIndexSliceFilter
# MultiColumnRestriction
# ComplexColumnData
# GossiperMBean
# FileUtils
# EmptyType
# AggregationSpecification
# RestrictionSetWrapper
# Token
# ReplicaMultimap
# TruncateResponse
# Sets
# SimpleDataSet
# TokenFilter
# DiagnosticEventMemoryStore
# QueryController
# CollectionValueIndex
# VirtualKeyspace
# AbstractRow
# CreateTypeStatement
# RawSelector
# SASIIndex
# RestrictionSet
# FailureDetector
# ThreadPoolMetrics
# OutboundConnection
# UTName
# RefCountedMemory
# SEPExecutor
# MmappedRegions
# Roles
# ExpirationDateOverflowHandling
# TokenSerializer
# AuthorizationProxy
# WrappedDataOutputStreamPlus
# AbstractPatriciaTrie
# StandardTokenizerOptions
# SystemViewsKeyspace
# ChecksummedDataInput
# SSTableFlushObserver
# SuffixSA
# MemIndex
# TokenRestriction
# ThrottledUnfilteredIterator
# HintsDispatchExecutor
# ClusteringIndexFilter
# TombstoneOverwhelmingException
# Gossiper
# FrameEncoderLZ4
# OnDiskIndexIterator
# KeysIndex
# TargetParser
# CombinedTermIterator
# TypeParser
# CassandraRoleManager
# PartitionKeyIndex
# HintsServiceMetrics
# MonitorableImpl
# Endpoints
# RequestCallbacks
# LimitingRebufferer
# RangeTombstone
# StreamingMetrics
# InboundSockets
# RequestValidations
# CleanupTransaction
# ThreadPoolsTable
# SingleSSTableLCSTask
# Columns
# TokenMetadataEvent
# UDTValue
# NoReplicationTokenAllocator
# ResizableThreadPool
# BigTableReader
# MajorLeveledCompactionWriter
# RewindableDataInputStreamPlus
# RestorableMeter
# StorageHook
# DiagnosticEventService
# HintDiagnostics
# CounterContext
# Upgrader
# ClusteringComparator
# AuthSchemaChangeListener
# HintsDescriptor
# CassandraIndex
# PingRequest
# LazilyInitializedUnfilteredRowIterator
# Duration
# Verifier
# CodecUtils
# PartitionSerializationException
# VirtualTableReadQuery
# BinAuditLogger
# AsyncPromise
# DataTracker
# LocalBufferPoolAllocator
# TokenMetadata
# StandardTokenizerInterface
# CreateTableStatement
# BatchCommitLogService
# AsyncStreamingInputPlus
# UserType
# ColumnFilter
# ScalarFunctionSelector
# SSTableSimpleWriter
# CassandraEntireSSTableStreamReader
# FunctionCall
# FileDataInput
# AbstractStrategyHolder
# AlterTypeStatement
# SSTableRewriter
# CreateIndexStatement
# RowDiffListener
# FunctionName
# AbstractSSTableIterator
# Role
# CassandraEntireSSTableStreamWriter
# CompactionStrategyManager
# InboundMessageHandler
# SelectStatement
# MessagingService
# SSTableReadsListener
# CassandraStreamReceiver
# IFailureDetector
# CounterMutation
# MetadataCollector
# CassandraIndexFunctions
# ComparableObjectToken
# DataType
# StatementRestrictions
# CompactionTransaction
# InetAddressAndPort
# CompositeType
# FrameDecoderLZ4
# StartupException
# IndexSummaryManager
# MetadataSerializer
# FloatType
# CommitLogSegment
# Mutation
# AbstractFunctionSelector
# LegacyFlag
# CommitLogSegmentReader
# PreHashedDecoratedKey
# PurgeFunction
# ReversedType
# VirtualTableSinglePartitionReadQuery
# TokenAllocation
# JMXEnabledSingleThreadExecutor
# WriteFailureException
# SSTableLoader
# Replica
# BasePartitions
# CqlConfigHelper
# ReadResponse
# SSTableReaderBuilder
# SnapshotCommand
# RangeTombstoneBoundMarker
# TupleValue
# ColumnIndex
# PartitionRangeReadCommand
# DropAggregateStatement
# FrameDecoder
# SSTableIdentityIterator
# QualifiedStatement
# HintsStore
# PartitionerDefinedOrder
# AbstractData
# CodecRegistry
# LeveledCompactionTask
# Memtable
# RowAndDeletionMergeIterator
# BaseIterator
# Resources
# ConfigHelper
# CompressedChunkReader
# LastEventIdBroadcaster
# CompactionController
# Directories
# SSTable
# CounterCacheKey
# AbstractBTreePartition
# AbstractCommitLogSegmentManager
# UnknownColumnException
# BufferClusteringBoundOrBoundary
# CompressedHintsWriter
# ClusteringColumnIndex
# FutureResult
# ByteBufferObjectFactory
# DiskBoundaryManager
# CommitLogPosition
# ColumnCondition
# DecoratedKey
# BatchMetrics
# CompositesSearcher
# GroupCommitLogService
# ClearableHistogram
# CommitLogSegmentManagerStandard
# CompactionMetrics
# BooleanType
# Index
# GrantRoleStatement
# CompactionMetadata
# InternodeInboundTable
# Int32Type
# DropTriggerStatement
# SystemReplicas
# FileSegmentInputStream
# StemmerFactory
# ClientWriteRequestMetrics
# Unfiltered
# BaseRows
# AuditLogEntry
# ConfigurationException
# DriverException
# CommitLogMetrics
# BloomFilterTracker
# MoreRows
# CorruptFileException
# CharTerm
# CreateTriggerStatement
# AllowAllInternodeAuthenticator
# Filter
# CassandraPrincipal
# AbstractIterator
# TransportException
# AbstractOnHeapClusteringPrefix
# ExcludingBounds
# FrozenType
# DefaultNameFactory
# ActiveCompactions
# CreateKeyspaceStatement
# DropTypeStatement
# AlterRoleStatement
# EndpointsByReplica

# %%
Brain_Class = np.array(Brain_Class)
Brain_Class
# Out:
# array([['Ec2MultiRegionSnitch', 'False'],
#        ['BootStrapper', 'False'],
#        ['ImmediateExecutor', 'False'],
#        ...,
#        ['DropTypeStatement', 'False'],
#        ['AlterRoleStatement', 'False'],
#        ['EndpointsByReplica', 'False']], dtype='<U41')

# %%
len(index)
# Out:
# 1047

# %%
def additem(list):
    if len(list)<3:
        q = len(list)-1
        str = '_1'
        str2 = '_2'
        item = ''.join([list[q], str])
        item_2 = ''.join([list[q], str2])
        # item = list[q]
        list.append(item)
        list.append(item_2)
        # print(list)
    return list

# %%
for item in index_all:
    item = additem(item)

# %%
news_df = np.array(index,dtype=object)
print(news_df)
# Out:
# [list(['Ec2MultiRegionSnitch', 'Ec2MultiRegionSnitch', 'throws', 'IOException', 'ConfigurationException', 'InetAddress', 'loggerinfoEC2Snitch', 'using', 'publicIP', 'as', 'identifier', 'if', 'DatabaseDescriptorgetBroadcastRpcAddress', 'null', 'loggerinfobroadcastrpcaddress', 'unset', 'broadcasting', 'public', 'IP', 'as', 'rpcaddress'])
#  list(['BootStrapper', 'CollectionToken', 'allocateTokensfinal', 'TokenMetadata', 'metadataInetAddressAndPort', 'addressint', 'rfint', 'numTokenslong', 'if', 'FBUtilitiesgetBroadcastAddressAndPortequalsInetAddressAndPortgetLoopbackAddress', 'CollectionToken', 'return', 'CollectionToken', 'allocateTokensfinal', 'TokenMetadata', 'metadataInetAddressAndPort', 'addressString', 'allocationKeyspaceint', 'numTokenslong', 'if', 'FBUtilitiesgetBroadcastAddressAndPortequalsInetAddressAndPortgetLoopbackAddress', 'Keyspace', 'if', 'ks', 'null', 'throw', 'new', 'ConfigurationExceptionProblem', 'opening', 'token', 'allocation', 'keyspace', 'AbstractReplicationStrategy', 'CollectionToken', 'return', 'BootStrapperInetAddressAndPort', 'addressCollectionToken', 'tokensTokenMetadata', 'assert', 'address', 'assert', 'tokens', 'null', 'ListenableFutureStreamState', 'bootstrapStreamStateStore', 'stateStoreboolean', 'loggertraceBeginning', 'bootstrap', 'RangeStreamer', 'streamernew', 'for', 'String', 'keyspaceName', 'SchemainstancegetNonLocalStrategyKeyspaces', 'AbstractReplicationStrategy', 'StreamResultFuture', 'bootstrapStreamResultaddEventListenernew', 'private', 'final', 'AtomicInteger', 'receivedFilesnew', 'private', 'final', 'AtomicInteger', 'totalFilesToReceivenew', 'Override', 'public', 'void', 'handleStreamEvent', 'StreamEvent', 'eventeventType', 'StreamEventSessionPreparedEvent', 'int', 'ProgressEvent', 'prepareProgressnew', 'ProgressEventProgressEventTypePROGRESSreceivedFilesgetcurrentTotalprepare', 'with', 'preparedsessionpeer', 'progressprogressisCompleted', 'currentProgressnew', 'ProgressEventProgressEventTypePROGRESSreceivedtotalFilesToReceivegetreceived', 'file', 'completeProgressnew', 'ProgressEventProgressEventTypePROGRESSreceivedFilesgettotalFilesToReceivegetsession', 'with', 'completeEventpeer', 'public', 'void', 'onSuccessStreamState', 'streamStatehasFailedSession', 'bootstrap', 'stream', 'else', 'streaming', 'currentProgressnew', 'public', 'void', 'onFailureThrowable', 'currentProgressnew', 'if', 'initialtoken', 'was', 'specified', 'use', 'that', 'split', 'on', 'comma', 'otherwise', 'if', 'allocationKeyspace', 'is', 'specified', 'use', 'the', 'token', 'allocation', 'algorithm', 'to', 'generate', 'suitable', 'tokens', 'else', 'choose', 'numtokens', 'tokens', 'at', 'static', 'CollectionToken', 'getBootstrapTokensfinal', 'TokenMetadata', 'metadataInetAddressAndPort', 'addresslong', 'schemaWaitDelay', 'throws', 'ConfigurationException', 'String', 'Integer', 'CollectionString', 'if', 'initialTokenssize', '0', 'allocationKeyspace', 'null', 'loggerwarnmanually', 'specified', 'tokens', 'override', 'automatic', 'if', 'initialTokenssize', '0', 'CollectionToken', 'return', 'int', 'if', 'numTokens', '1', 'throw', 'new', 'ConfigurationExceptionnumtokens', 'must', 'be', 'if', 'allocationKeyspace', 'null', 'return', 'if', 'allocationLocalRf', 'null', 'return', 'if', 'numTokens', '1', 'loggerwarnPicking', 'random', 'token', 'for', 'a', 'single', 'vnode', 'You', 'should', 'probably', 'add', 'more', 'vnodes', 'andor', 'use', 'the', 'automatic', 'token', 'allocation', 'CollectionToken', 'return', 'static', 'CollectionToken', 'getRandomTokensTokenMetadata', 'metadataint', 'SetToken', 'tokensnew', 'while', 'tokenssize', 'numTokens', 'Token', 'if', 'metadatagetEndpointtoken', 'null', 'loggerinfoGenerated', 'random', 'tokens', 'tokens', 'are', 'return', 'static', 'CollectionToken', 'getSpecifiedTokensfinal', 'TokenMetadata', 'metadataCollectionString', 'loggerinfotokens', 'manually', 'specified', 'as', 'ListToken', 'tokensnew', 'for', 'String', 'tokenString', 'initialTokens', 'Token', 'if', 'metadatagetEndpointtoken', 'null', 'throw', 'new', 'ConfigurationExceptionBootstrapping', 'to', 'existing', 'token', 'tokenString', 'is', 'not', 'allowed', 'decommissionremovenode', 'the', 'old', 'node', 'return'])
#  list(['ImmediateExecutor']) ...
#  list(['DropTypeStatement', 'DropTypeStatementString', 'keyspaceNameString', 'typeNameboolean'])
#  list(['AlterRoleStatement', 'AlterRoleStatementRoleName', 'nameRoleOptions', 'AlterRoleStatementRoleName', 'nameRoleOptions', 'optsDCPermissions'])
#  list(['EndpointsByReplica', 'EndpointsByReplicaMapReplicaEndpointsForRange', 'EndpointsForRange', 'getReplica', 'return'])]

# %%
#training phase
def f_lsa(news_df, n):
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(news_df)
    #Get the vocabulary found by the model directly analyzing the data（collection of words above）
    # Printing X directly outputs the position of each word


    n_cap = 1
    svd_model = TruncatedSVD(n_components=n_cap)  # Latent semantic analysis, set 4 topics
    X2 = svd_model.fit_transform(X) # train and convert

    #print("--------Representation of text in topic vector space Left singular matrix---------")
    #print(X2)

    terms = vectorizer.get_feature_names()
    # print("--------Topics and keywords---------")
    for i, comp in enumerate(svd_model.components_):
        terms_comp = zip(terms, comp)
        sorted_terms = sorted(terms_comp, key=lambda x: x[1], reverse=True)[:7]
        # print("Topic " + str(i) + ": ")
        for t in sorted_terms:
            print(t[0])
    print(" ")

    D = svd_model.components_
    T = X2
    S = np.diagflat(svd_model.singular_values_)

    X = np.dot(T, S)
    X = np.dot(X, D)
    c = np.dot(X, X.T)

    acsm = None
    sum = 0
    for i in c:
        for j in i:
            if j < 0:
                j = 0
            sum += j
        acsm = sum / n / n
    # print("-------------acsm----------------------")
    # print(acsm)

    return acsm

# %%
q = 0
acsm= []
for i in index:
    lists = []
    print("*************",i,"****************")
    # print("------------------------------------------------------------------")
    for j in i:
        lists.append(j)
    # lists = deleteDuplicatedElementFromList(lists)
    if len(lists) > 1:
        acsm.append(f_lsa(lists,len(i)))
    else :
        acsm.append(1)
#

# print(type(class_name))
# print(type(acsm))
# Out:
# Streaming output truncated to the last 5000 lines.
# group
# metric
# nameprefix
#
# ************* ['VirtualSchemaKeyspace', 'superVIRTUALSCHEMAImmutableListofnew', 'VirtualKeyspacesVIRTUALSCHEMAnew', 'VirtualTablesVIRTUALSCHEMAnew'] ****************
# virtualschemakeyspace
# supervirtualschemaimmutablelistofnew
# virtualtablesvirtualschemanew
# virtualkeyspacesvirtualschemanew
#
# ************* ['DiagnosticEventPersistence', 'void', 'disableEventPersistenceString', 'try', 'loggerdebugDisabling', 'events', 'catch', 'ClassNotFoundExceptionInvalidClassException', 'e', 'throw', 'new', 'void', 'enableEventPersistenceString', 'try', 'loggerdebugEnabling', 'events', 'catch', 'ClassNotFoundExceptionInvalidClassException', 'e', 'throw', 'new', 'ClassDiagnosticEvent', 'getEventClassString', 'eventClazz', 'throws', 'ClassNotFoundException', 'InvalidClassException', 'if', 'eventClazzstartsWithorgapachecassandra', 'throw', 'new', 'RuntimeExceptionNot', 'a', 'Cassandra', 'event', 'class', 'ClassDiagnosticEvent', 'if', 'DiagnosticEventclassisAssignableFromclazz', 'throw', 'new', 'InvalidClassExceptionEvent', 'class', 'must', 'be', 'of', 'type', 'return', 'SortedMapLongMapStringSerializable', 'getEventsString', 'eventClazzLong', 'keyint', 'limitboolean', 'assert', 'eventClazz', 'assert', 'key', 'assert', 'limit', 'Class', 'try', 'catch', 'ClassNotFoundExceptionInvalidClassException', 'e', 'throw', 'new', 'DiagnosticEventStoreLong', 'NavigableMapLongDiagnosticEvent', 'eventsstorescankeyincludeKey', 'limit', 'limit', 'if', 'includeKey', 'eventsisEmpty', 'TreeMapLongMapStringSerializable', 'retnew', 'for', 'MapEntryLongDiagnosticEvent', 'entry', 'eventsentrySet', 'DiagnosticEvent', 'HashMapStringSerializable', 'valnew', 'loggerdebugReturning', 'events', 'for', 'key', 'limit', 'includeKey', 'return', 'DiagnosticEventStoreLong', 'getStoreClass', 'return', 'storescomputeIfAbsentclsstoreKey', 'new', 'void', 'onEventDiagnosticEvent', 'Class', 'extends', 'DiagnosticEvent', 'if', 'loggerisTraceEnabled', 'loggertracePersisting', 'received', 'DiagnosticEventStoreLong'] ****************
# new
# try
# eventclazz
# class
# includekey
# catch
# if
#
# ************* ['ClusteringIndexNamesFilter', 'ClusteringIndexNamesFilterNavigableSetClustering', 'clusteringsboolean', 'assert', 'thisclusteringsInQueryOrderreversed', 'clusteringsdescendingSet', 'The', 'set', 'of', 'requested', 'rows', 'Please', 'note', 'that', 'this', 'can', 'be', 'empty', 'if', 'only', 'the', 'static', 'row', 'is', 'return', 'the', 'set', 'of', 'requested', 'clustering', 'in', 'clustering', 'order', 'note', 'thatthis', 'is', 'always', 'in', 'clustering', 'order', 'even', 'if', 'the', 'query', 'is', 'NavigableSetClustering', 'return'] ****************
# the
# this
# clusteringsdescendingset
# requested
# only
# clusteringsboolean
# rows
#
# ************* ['UnbufferedDataOutputStreamPlus', 'UnbufferedDataOutputStreamPlusWritableByteChannel', 'Writes', 'a', 'boolean', 'to', 'this', 'output', 'param', 'val', 'the', 'boolean', 'value', 'to', 'write', 'to', 'the', 'throws', 'IOException', 'If', 'an', 'error', 'occurs', 'attempting', 'to', 'write', 'to', 'final', 'void', 'writeBooleanboolean', 'val', 'throws', 'IOException', 'writeval', '1', 'Writes', 'the', 'low', 'order', '8bit', 'bytes', 'from', 'a', 'String', 'to', 'this', 'output', 'param', 'str', 'the', 'String', 'containing', 'the', 'bytes', 'to', 'write', 'to', 'the', 'throws', 'IOException', 'If', 'an', 'error', 'occurs', 'attempting', 'to', 'write', 'to', 'final', 'void', 'writeBytesString', 'str', 'throws', 'IOException', 'byte', 'bytesnew', 'for', 'int', 'index0', 'index', 'strlength', 'index', 'bytesindexbytestrcharAtindex', 'Writes', 'a', '8bit', 'byte', 'to', 'this', 'output', 'param', 'val', 'the', 'byte', 'value', 'to', 'write', 'to', 'the', 'throws', 'javaioIOException', 'If', 'an', 'error', 'occurs', 'attempting', 'to', 'write', 'to', 'final', 'void', 'writeByteint', 'val', 'throws', 'IOException', 'writeval', 'Writes', 'the', 'specified', '16bit', 'characters', 'contained', 'in', 'str', 'to', 'the', 'OutputStream', 'Only', 'the', 'lower', '2', 'bytes', 'of', 'each', 'character', 'are', 'written', 'with', 'the', 'higher', 'of', 'the', '2', 'bytes', 'written', 'first', 'This', 'represents', 'the', 'Unicode', 'value', 'of', 'each', 'character', 'in', 'param', 'str', 'the', 'String', 'whose', 'characters', 'are', 'to', 'be', 'throws', 'IOException', 'If', 'an', 'error', 'occurs', 'attempting', 'to', 'write', 'to', 'final', 'void', 'writeCharsString', 'str', 'throws', 'IOException', 'byte', 'newBytesnew', 'bytestrlength', 'for', 'int', 'index0', 'index', 'strlength', 'index', 'int', 'newIndexindex', '0', 'index', 'index', 'newBytesnewIndexbytestrcharAtindex', '8', 'newBytesnewIndex', '1bytestrcharAtindex', 'Writes', 'the', 'specified', '16bit', 'character', 'to', 'the', 'OutputStream', 'Only', 'the', 'lower', '2', 'bytes', 'are', 'written', 'with', 'the', 'higher', 'of', 'the', '2', 'bytes', 'written', 'first', 'This', 'represents', 'the', 'Unicode', 'value', 'of', 'param', 'val', 'the', 'character', 'to', 'be', 'throws', 'IOException', 'If', 'an', 'error', 'occurs', 'attempting', 'to', 'write', 'to', 'final', 'void', 'writeCharint', 'val', 'throws', 'IOException', 'writeval', '8', 'writeval', '0', 'Writes', 'a', '64bit', 'double', 'to', 'this', 'output', 'stream', 'The', 'resulting', 'output', 'is', 'the', '8', 'bytes', 'resulting', 'from', 'calling', 'param', 'val', 'the', 'double', 'to', 'be', 'throws', 'IOException', 'If', 'an', 'error', 'occurs', 'attempting', 'to', 'write', 'to', 'final', 'void', 'writeDoubledouble', 'val', 'throws', 'IOException', 'Writes', 'a', '32bit', 'float', 'to', 'this', 'output', 'stream', 'The', 'resulting', 'output', 'is', 'the', '4', 'bytes', 'resulting', 'from', 'calling', 'param', 'val', 'the', 'float', 'to', 'be', 'throws', 'IOException', 'If', 'an', 'error', 'occurs', 'attempting', 'to', 'write', 'to', 'final', 'void', 'writeFloatfloat', 'val', 'throws', 'IOException', 'Writes', 'a', '32bit', 'int', 'to', 'this', 'output', 'stream', 'The', 'resulting', 'output', 'is', 'the', '4', 'bytes', 'highest', 'order', 'first', 'of', 'param', 'val', 'the', 'int', 'to', 'be', 'throws', 'IOException', 'If', 'an', 'error', 'occurs', 'attempting', 'to', 'write', 'to', 'void', 'writeIntint', 'val', 'throws', 'IOException', 'writeval', '24', 'writeval', '16', 'writeval', '8', 'writeval', '0', 'Writes', 'a', '64bit', 'long', 'to', 'this', 'output', 'stream', 'The', 'resulting', 'output', 'is', 'the', '8', 'bytes', 'highest', 'order', 'first', 'of', 'param', 'val', 'the', 'long', 'to', 'be', 'throws', 'IOException', 'If', 'an', 'error', 'occurs', 'attempting', 'to', 'write', 'to', 'void', 'writeLonglong', 'val', 'throws', 'IOException', 'writeintval', '56', 'writeintval', '48', 'writei ...
# to
# occurs
# void
# an
# of
# this
# written
#
# ************* ['DynamicEndpointSnitchMBean', 'ListDouble', 'dumpTimingsString', 'hostname', 'throws', 'UnknownHostException', 'double', 'int', 'public', 'MapInetAddressDouble', 'MapStringDouble', 'return', 'the', 'current', 'manually', 'injected', 'double', 'String', 'int', 'Setting', 'a', 'Severity', 'allows', 'operators', 'to', 'inject', 'preference', 'information', 'into', 'the', 'Dynamic', 'Snitch', 'replica', 'selection', 'When', 'choosing', 'which', 'replicas', 'to', 'participate', 'in', 'a', 'read', 'request', 'the', 'DSnitch', 'sorts', 'replicas', 'by', 'response', 'latency', 'and', 'selects', 'the', 'fastest', 'replicas', 'Latencies', 'are', 'normalized', 'to', 'a', 'score', 'from', '0', 'to', '1', 'with', 'lower', 'scores', 'being', 'faster', 'The', 'Severity', 'injected', 'here', 'will', 'be', 'added', 'to', 'the', 'normalized', 'score', 'Thus', 'adding', 'a', 'Severity', 'greater', 'than', '1', 'will', 'mean', 'the', 'replica', 'will', 'never', 'be', 'contacted', 'unless', 'needed', 'for', 'ALL', 'or', 'if', 'it', 'is', 'added', 'later', 'for', 'rapid', 'read', 'protection', 'Conversely', 'adding', 'a', 'negative', 'Severity', 'means', 'the', 'replica', 'will', 'always', 'be', 'contacted', 'The', 'Severity', 'term', 'is', 'historical', 'and', 'dates', 'to', 'when', 'this', 'was', 'used', 'to', 'represent', 'how', 'badly', 'background', 'tasks', 'like', 'compaction', 'were', 'affecting', 'a', 'replicas', 'performance', 'See', 'CASSANDRA3722', 'for', 'when', 'this', 'was', 'introduced', 'and', 'CASSANDRA11738', 'for', 'why', 'it', 'was', 'void', 'setSeveritydouble'] ****************
# the
# it
# contacted
# replica
# adding
# injected
# this
#
# ************* ['ChecksummedSequentialWriter', 'ChecksummedSequentialWriterFile', 'fileFile', 'crcPathFile', 'digestFileSequentialWriterOption', 'crcWriternew', 'crcMetadatanew', 'protected', 'void', 'ByteBuffer', 'protected', 'SequentialWriterTransactionalProxy', 'return', 'new'] ****************
# protected
# crcwriternew
# digestfilesequentialwriteroption
# new
# crcpathfile
# filefile
# return
#
# ************* ['RangeUnionIterator', 'static', 'K', 'extends', 'ComparableKD', 'extends', 'CombinedValueKRangeIteratorKD', 'buildListRangeIteratorKD', 'return', 'new', 'RangeUnionIteratorBuilderStatisticsKD', 'statisticsPriorityQueueRangeIteratorKD'] ****************
# extends
# combinedvaluekrangeiteratorkd
# return
# rangeunioniteratorbuilderstatisticskd
# buildlistrangeiteratorkd
# new
# comparablekd
#
# ************* ['UpdatesCollector', 'getPartitionUpdateBuilderTableMetadata', 'metadataDecoratedKey', 'dkConsistencyLevel'] ****************
# updatescollector
# metadatadecoratedkey
# dkconsistencylevel
# getpartitionupdatebuildertablemetadata
#
# ************* ['RTBoundCloser', 'static', 'UnfilteredPartitionIterator', 'closeUnfilteredPartitionIterator', 'return', 'Transformationapplypartitionsnew', 'static', 'UnfilteredRowIterator', 'closeUnfilteredRowIterator', 'RowsTransformation', 'transformationnew', 'return'] ****************
# static
# return
# transformationnew
# rtboundcloser
# unfilteredpartitioniterator
# closeunfilteredpartitioniterator
# unfilteredrowiterator
#
# ************* ['HintVerbHandler', 'static', 'void', 'respondMessageHintMessage'] ****************
# respondmessagehintmessage
# hintverbhandler
# void
# static
#
# ************* ['CustomIndexExpression', 'void', 'addToRowFilterRowFilter', 'filterTableMetadata', 'tableQueryOptions', 'filteraddCustomIndexExpressiontabletableindexesgettargetIndexgetNameorElseThrow', 'CustomIndexExpressionQualifiedName', 'targetIndexTermRaw', 'void', 'prepareValueTableMetadata', 'tableAbstractType', 'expressionTypeVariableSpecifications', 'ColumnSpecification', 'specnew'] ****************
# void
# customindexexpressionqualifiedname
# tablequeryoptions
# tableabstracttype
# filteraddcustomindexexpressiontabletableindexesgettargetindexgetnameorelsethrow
# columnspecification
# targetindextermraw
#
# ************* ['Clustering', 'static', 'ClusteringByteBuffer', 'makeByteBuffer', 'return', 'valueslength', '0', 'EMPTY', 'new'] ****************
# empty
# new
# static
# valueslength
# clusteringbytebuffer
# clustering
# return
#
# ************* ['SSTableIndex', 'SSTableReader', 'return', 'boolean', 'return', 'void', 'boolean', 'while', 'true', 'int', 'if', 'n', '0', 'return', 'if', 'referencescompareAndSetnn', '1', 'return', 'SSTableIndexColumnIndex', 'indexFile', 'indexFileSSTableReader', 'if', 'sstable', 'null', 'throw', 'new', 'IllegalStateExceptionCouldnt', 'acquire', 'reference', 'to', 'the', 'sstable', 'AbstractType', 'assert', 'validator', 'assert', 'indexFileexists', 'StringformatSSTable', 's', 'should', 'have', 'index', 'thisindexnew', 'OnDiskIndexindexFilevalidatornew'] ****************
# return
# ondiskindexindexfilevalidatornew
# have
# throw
# void
# sstableindex
# indexfilesstablereader
#
# ************* ['SelectionColumnMapping', 'SelectionColumnMapping', 'addMappingColumnSpecification', 'colSpecColumnMetadata', 'if', 'column', 'null', 'return', 'SelectionColumnMapping', 'addMappingColumnSpecification', 'colSpecIterableColumnMetadata', 'return', 'ListColumnSpecification', 'return', 'MultimapColumnSpecificationColumnMetadata', 'return', 'static', 'SelectionColumnMapping', 'return', 'new', 'thiscolumnSpecificationsnew', 'static', 'SelectionColumnMapping', 'simpleMappingIterableColumnMetadata', 'SelectionColumnMapping', 'mappingnew', 'for', 'ColumnMetadata', 'def', 'columnDefinitions', 'return'] ****************
# return
# def
# columndefinitions
# colspeciterablecolumnmetadata
# multimapcolumnspecificationcolumnmetadata
# new
# columnmetadata
#
# ************* ['SimpleDateType'] ****************
# ************* ['SplittingSizeTieredCompactionWriter', 'SplittingSizeTieredCompactionWriterColumnFamilyStore', 'cfsDirectories', 'directoriesLifecycleTransaction', 'txnSetSSTableReader', 'SplittingSizeTieredCompactionWriterColumnFamilyStore', 'cfsDirectories', 'directoriesLifecycleTransaction', 'txnSetSSTableReader', 'nonExpiredSSTableslong', 'double', 'potentialRatiosnew', 'double', 'for', 'int', 'i0', 'i', 'potentialRatioslength', 'i', 'int', 'for', 'double', 'ratio', 'potentialRatios', 'if', 'ratio', 'totalSize', 'smallestSSTable', 'currentBytesToWriteMathroundtotalSize'] ****************
# double
# splittingsizetieredcompactionwriter
# potentialratios
# ratio
# if
# potentialratioslength
# totalsize
#
# ************* ['HintsService', 'static', 'ImmutableMapStringObject', 'ImmutableMapBuilderStringObject', 'ParameterizedClass', 'if', 'compressionConfig', 'null', 'ImmutableMapBuilderStringObject', 'if', 'compressionConfigparameters', 'null', 'return', 'Deletes', 'all', 'hints', 'for', 'all', 'destinations', 'Doesnt', 'make', 'snapshots', 'should', 'be', 'used', 'with', 'void', 'Deletes', 'all', 'hints', 'for', 'the', 'provided', 'destination', 'Doesnt', 'make', 'snapshots', 'should', 'be', 'used', 'with', 'param', 'target', 'inet', 'address', 'of', 'the', 'target', 'void', 'deleteAllHintsForEndpointInetAddressAndPort', 'UUID', 'if', 'hostId', 'null', 'throw', 'new', 'IllegalArgumentExceptionCant', 'delete', 'hints', 'for', 'unknown', 'address', 'Deletes', 'all', 'hints', 'for', 'the', 'provided', 'destination', 'Doesnt', 'make', 'snapshots', 'should', 'be', 'used', 'with', 'param', 'address', 'inet', 'address', 'of', 'the', 'target', 'node', 'encoded', 'as', 'a', 'string', 'for', 'easier', 'JMX', 'void', 'deleteAllHintsForEndpointString', 'InetAddressAndPort', 'try', 'catch', 'UnknownHostException', 'e', 'throw', 'new', 'Cleans', 'up', 'hintsrelated', 'state', 'after', 'a', 'node', 'with', 'id', 'hostId', 'left', 'Dispatcher', 'can', 'not', 'stop', 'itself', 'isHostAlive', 'can', 'not', 'start', 'returning', 'false', 'for', 'the', 'leaving', 'host', 'because', 'this', 'method', 'is', 'called', 'by', 'the', 'same', 'thread', 'as', 'gossip', 'which', 'blocks', 'gossip', 'so', 'we', 'cant', 'simply', 'wait', 'for', 'completion', 'We', 'should', 'also', 'flush', 'the', 'buffer', 'if', 'there', 'are', 'any', 'hints', 'for', 'the', 'node', 'there', 'and', 'close', 'the', 'writer', 'if', 'any', 'so', 'that', 'we', 'dont', 'leave', 'any', 'hint', 'files', 'lying', 'around', 'Once', 'that', 'is', 'done', 'we', 'can', 'simply', 'delete', 'all', 'hint', 'files', 'and', 'remove', 'the', 'host', 'id', 'from', 'the', 'catalog', 'The', 'worst', 'that', 'can', 'happen', 'if', 'we', 'dont', 'get', 'everything', 'right', 'is', 'a', 'hints', 'file', 'or', 'two', 'remaining', 'param', 'hostId', 'id', 'of', 'the', 'node', 'being', 'void', 'exciseUUID', 'HintsStore', 'if', 'store', 'null', 'Future', 'Future', 'try', 'catch', 'InterruptedExceptionExecutionException', 'e', 'throw', 'new', 'Flush', 'the', 'buffer', 'pool', 'for', 'the', 'selected', 'target', 'nodes', 'then', 'fsync', 'their', 'param', 'hostIds', 'host', 'ids', 'of', 'the', 'nodes', 'to', 'flush', 'and', 'fsync', 'hints', 'void', 'flushAndFsyncBlockinglyIterableUUID', 'IterableHintsStore', 'return', 'HintsServiceIFailureDetector', 'File', 'int', 'writeExecutornew', 'int', 'bufferSizeMathmaxDatabaseDescriptorgetMaxMutationSize', 'bufferPoolnew', 'isDispatchPausednew', 'dispatchExecutornew', 'int', 'triggerFlushingFutureScheduledExecutorsoptionalTasksscheduleWithFixedDelay', 'metricsnew', 'Returns', 'true', 'in', 'case', 'service', 'is', 'shut', 'boolean', 'return', 'void', 'loggerinfoPaused', 'hints', 'void', 'loggerinfoResumed', 'hints', 'synchronized', 'void', 'if', 'isShutDown', 'throw', 'new', 'IllegalStateExceptionHintsService', 'is', 'shut', 'down', 'and', 'cannot', 'be', 'HintsDispatchTrigger', 'triggernew', 'Transfer', 'all', 'local', 'hints', 'to', 'the', 'hostId', 'supplied', 'by', 'hostIdSupplier', 'Flushes', 'the', 'buffer', 'to', 'make', 'sure', 'all', 'hints', 'are', 'on', 'disk', 'and', 'closes', 'the', 'hint', 'writers', 'so', 'we', 'dont', 'leave', 'any', 'hint', 'files', 'around', 'After', 'that', 'we', 'serially', 'dispatch', 'all', 'the', 'hints', 'in', 'the', 'HintsCatalog', 'If', 'we', 'fail', 'delivering', 'all', 'hints', 'we', 'will', 'ask', 'the', 'hostIdSupplier', 'for', 'a', 'new', 'target', 'host', 'and', 'retry', 'delivering', 'any', 'remaining', 'hints', 'there', 'once', 'with', 'a', 'delay', 'of', '10', 'seconds', 'before', 'param', 'hostIdSupplier', 'supplier', 'of', 'stream', 'target', 'host', 'ids', 'This', 'is', 'generallythe', 'closest', 'one', 'accord ...
# the
# hint
# we
# is
# host
# throw
# hostid
#
# ************* ['MappedBuffer', 'int', 'comparePageTolong', 'offsetint', 'lengthAbstractType', 'comparatorByteBuffer', 'return', 'MappedBuffer', 'return', 'new', 'int', 'int', 'return', 'long', 'long', 'return', 'int', 'getPageOffsetlong', 'return', 'intposition', 'pageSize', 'ByteBuffer', 'getPageRegionlong', 'positionint', 'if', 'isPageAlignedpositionlength', 'throw', 'new', 'IllegalArgumentExceptionStringformatrange', 'ss', 'wraps', 'more', 'than', 'one', 'ByteBuffer', 'int', 'slicepositionpageOffsetlimitpageOffset', 'return', 'int', 'getPagelong', 'return', 'intposition', 'short', 'short', 'return', 'short', 'getShortlong', 'if', 'isPageAlignedpos2', 'return', 'int', 'ch1getpos', 'int', 'ch2getpos', '1', 'return', 'shortch1', '8', 'byte', 'getlong', 'return', 'boolean', 'isPageAlignedlong', 'positionint', 'return', 'pageSize', 'getPageOffsetposition', 'length', 'long', 'return', 'MappedBuffer', 'limitlong', 'if', 'newLimit', 'position', 'newLimit', 'capacity', 'throw', 'new', 'return', 'MappedBufferChannelProxy', 'protected', 'MappedBufferChannelProxy', 'fileint', 'if', 'numPageBits', 'IntegerSIZE', '1', 'throw', 'new', 'IllegalArgumentExceptionpage', 'size', 'cant', 'be', 'bigger', 'than', 'pageSize1', 'pagesnew', 'MappedByteBufferintfilesize', 'pageSize', 'try', 'long', 'for', 'int', 'i0', 'i', 'pageslength', 'i', 'long', 'pageSizeMathminthispageSizecapacity', 'finally', 'MappedBufferMappedBuffer', 'MappedBufferRandomAccessReader', 'MappedBuffer', 'positionlong', 'if', 'newPosition', '0', 'newPosition', 'limit', 'throw', 'new', 'IllegalArgumentExceptionposition', 'newPosition', 'limit', 'return'] ****************
# return
# than
# intposition
# newposition
# positionint
# throw
# try
#
# ************* ['FrameEncoderLegacyLZ4', 'int', 'calculateMaxFrameLengthByteBuffer', 'int', 'int', 'blockCountpayloadLength', 'DEFAULTBLOCKLENGTH', 'payloadLength', 'DEFAULTBLOCKLENGTH', '0', '1', 'return', 'compressormaxCompressedLengthpayloadLength', 'HEADERLENGTH', 'int', 'compressBlockByteBuffer', 'frameint', 'frameOffsetByteBuffer', 'payloadint', 'payloadOffsetint', 'int', 'frameBytesRemainingframelimit', 'frameOffset', 'int', 'compressedLengthcompressorcompresspayloadpayloadOffsetblockLengthframeframeOffset', 'if', 'compressedLength', 'blockLength', 'ByteBufferUtilcopyBytespayloadpayloadOffsetframeframeOffset', 'int', 'checksumxxhashhashpayloadpayloadOffsetblockLengthXXHASHSEED', 'return', 'HEADERLENGTH', 'FrameEncoderLegacyLZ4XXHash32', 'xxhashLZ4Compressor', 'static', 'void', 'writeHeaderByteBuffer', 'frameint', 'frameOffsetint', 'compressedLengthint', 'uncompressedLengthint', 'byte', 'tokencompressedLength', 'uncompressedLength', 'TOKENNONCOMPRESSED', 'frameputLongframeOffset', 'frameputframeOffset', 'frameputIntframeOffset', 'frameputIntframeOffset', 'frameputIntframeOffset'] ****************
# int
# compressormaxcompressedlengthpayloadlength
# checksumxxhashhashpayloadpayloadoffsetblocklengthxxhashseed
# frameputframeoffset
# byte
# uncompressedlengthint
# frameputlongframeoffset
#
# ************* ['Relation', 'Checks', 'if', 'the', 'operator', 'of', 'this', 'relation', 'is', 'a', 'return', 'codetruecode', 'if', 'the', 'operator', 'of', 'this', 'relation', 'is', 'a', 'codeCONTAINSKEYcode', 'final', 'boolean', 'return', 'relationType', 'Operator', 'return', 'Converts', 'this', 'codeRelationcode', 'into', 'a', 'param', 'table', 'the', 'Column', 'Family', 'meta', 'param', 'boundNames', 'the', 'variables', 'specification', 'where', 'to', 'collect', 'the', 'bind', 'return', 'the', 'codeRestrictioncode', 'corresponding', 'to', 'this', 'throws', 'InvalidRequestException', 'if', 'this', 'codeRelationcode', 'is', 'not', 'final', 'Restriction', 'toRestrictionTableMetadata', 'tableVariableSpecifications', 'relationType', 'return', 'return', 'invalidRequestUnsupported', 'relation', 'Converts', 'the', 'specified', 'codeRawcode', 'terms', 'into', 'a', 'param', 'receivers', 'the', 'columns', 'to', 'which', 'the', 'values', 'must', 'be', 'associated', 'param', 'raws', 'the', 'raw', 'terms', 'to', 'param', 'keyspace', 'the', 'keyspace', 'param', 'boundNames', 'the', 'variables', 'specification', 'where', 'to', 'collect', 'the', 'bind', 'return', 'the', 'codeTermcodes', 'corresponding', 'to', 'the', 'specified', 'codeRawcode', 'throws', 'InvalidRequestException', 'if', 'the', 'codeRawcode', 'terms', 'are', 'not', 'final', 'ListTerm', 'toTermsList', 'extends', 'ColumnSpecification', 'receiversList', 'extends', 'TermRaw', 'rawsString', 'keyspaceVariableSpecifications', 'if', 'raws', 'null', 'return', 'ListTerm', 'termsnew', 'for', 'int', 'i0', 'mrawssize', 'i', 'm', 'i', 'return', 'Converts', 'the', 'specified', 'codeRawcode', 'into', 'a', 'param', 'receivers', 'the', 'columns', 'to', 'which', 'the', 'values', 'must', 'be', 'associated', 'param', 'raw', 'the', 'raw', 'term', 'to', 'param', 'keyspace', 'the', 'keyspace', 'param', 'boundNames', 'the', 'variables', 'specification', 'where', 'to', 'collect', 'the', 'bind', 'return', 'the', 'codeTermcode', 'corresponding', 'to', 'the', 'specified', 'throws', 'InvalidRequestException', 'if', 'the', 'codeRawcode', 'term', 'is', 'not', 'abstract', 'Term', 'toTermList', 'extends', 'ColumnSpecification', 'receiversTermRaw', 'rawString', 'keyspaceVariableSpecifications'] ****************
# the
# throws
# where
# coderawcode
# collect
# raw
# into
#
# ************* ['CompressedChecksummedDataInput', 'CompressedChecksummedDataInputChannelProxy', 'channelICompressor', 'compressorlong', 'ICompressor', 'return', 'public', 'static', 'ChecksummedDataInput', 'upgradeInputChecksummedDataInput', 'inputICompressor', 'long', 'ChannelProxy', 'channelnew', 'try', 'return', 'new', 'catch', 'Throwable', 't', 'throw'] ****************
# return
# icompressor
# compressorlong
# static
# upgradeinputchecksummeddatainput
# compressedchecksummeddatainput
# channelnew
#
# ************* ['MemoryInputStream', 'public', 'int', 'return', 'IntssaturatedCastbufferremaining', 'static', 'ByteBuffer', 'getByteBufferlong', 'offsetint', 'return', 'MemoryInputStreamMemory', 'public', 'MemoryInputStreamMemory', 'memint', 'thisoffsetmempeer', 'long', 'return', 'memsize', 'mempeer'] ****************
# return
# mempeer
# thisoffsetmempeer
# getbytebufferlong
# int
# memsize
# offsetint
#
# ************* ['IndexInfo', 'IndexInfoClusteringPrefix', 'firstNameClusteringPrefix', 'lastNamelong', 'offsetlong', 'widthDeletionTime', 'static', 'IndexInfoSerializer', 'serializerVersion', 'versionSerializationHeader', 'return', 'new', 'long', 'return', 'EMPTYSIZE', 'firstNameunsharedHeapSize', 'lastNameunsharedHeapSize', 'endOpenMarker', 'null', '0'] ****************
# return
# indexinfoclusteringprefix
# lastnamelong
# indexinfo
# emptysize
# new
# firstnameunsharedheapsize
#
# ************* ['Trie', 'Returns', 'a', 'view', 'of', 'this', 'link', 'Trie', 'of', 'all', 'elements', 'that', 'are', 'prefixedby', 'the', 'given', 'key', 'pIn', 'a', 'link', 'Trie', 'with', 'fixed', 'size', 'keys', 'this', 'is', 'essentially', 'alink', 'getObject', 'operationpFor', 'example', 'if', 'the', 'link', 'Trie', 'contains', 'Anna', 'AnaelAnalu', 'Andreas', 'Andrea', 'Andres', 'and', 'Anatole', 'then', 'a', 'lookup', 'of', 'And', 'would', 'return', 'Andreas', 'Andrea', 'and', 'prefixMapK', 'Returns', 'the', 'key', 'that', 'is', 'closest', 'in', 'a', 'bitwise', 'XOR', 'metric', 'to', 'the', 'provided', 'key', 'This', 'is', 'NOT', 'lexicographic', 'closeness', 'For', 'example', 'given', 'the', 'keys', 'ol', 'liD', '1000100', 'liH', '1001000', 'liL', '1001100', 'ol', 'If', 'the', 'link', 'Trie', 'contained', 'H', 'and', 'L', 'a', 'lookup', 'of', 'D', 'wouldreturn', 'L', 'because', 'the', 'XOR', 'distance', 'between', 'D', 'amp', 'L', 'is', 'smaller', 'than', 'the', 'XOR', 'distance', 'between', 'D', 'amp', 'return', 'The', 'key', 'that', 'is', 'closest', 'in', 'a', 'bitwise', 'XOR', 'metric', 'to', 'the', 'provided', 'K', 'selectKeyK', 'Returns', 'the', 'value', 'whose', 'key', 'is', 'closest', 'in', 'a', 'bitwise', 'XOR', 'metric', 'to', 'the', 'provided', 'key', 'This', 'is', 'NOT', 'lexicographic', 'closeness', 'For', 'example', 'given', 'the', 'keys', 'ol', 'liD', '1000100', 'liH', '1001000', 'liL', '1001100', 'ol', 'If', 'the', 'link', 'Trie', 'contained', 'H', 'and', 'L', 'a', 'lookup', 'of', 'D', 'wouldreturn', 'L', 'because', 'the', 'XOR', 'distance', 'between', 'D', 'amp', 'L', 'is', 'smaller', 'than', 'the', 'XOR', 'distance', 'between', 'D', 'amp', 'return', 'The', 'value', 'whose', 'key', 'is', 'closest', 'in', 'a', 'bitwise', 'XOR', 'metricto', 'the', 'provided', 'V', 'selectValueK', 'Returns', 'the', 'link', 'MapEntry', 'whose', 'key', 'is', 'closest', 'in', 'a', 'bitwise', 'XORmetric', 'to', 'the', 'given', 'key', 'This', 'is', 'NOT', 'lexicographic', 'closeness', 'For', 'example', 'given', 'the', 'keys', 'ol', 'liD', '1000100', 'liH', '1001000', 'liL', '1001100', 'ol', 'If', 'the', 'link', 'Trie', 'contained', 'H', 'and', 'L', 'a', 'lookup', 'of', 'D', 'wouldreturn', 'L', 'because', 'the', 'XOR', 'distance', 'between', 'D', 'amp', 'L', 'is', 'smaller', 'than', 'the', 'XOR', 'distance', 'between', 'D', 'amp', 'return', 'The', 'link', 'MapEntry', 'whose', 'key', 'is', 'closest', 'in', 'a', 'bitwise', 'XOR', 'metricto', 'the', 'provided', 'selectK', 'Iterates', 'through', 'the', 'link', 'Trie', 'starting', 'with', 'the', 'entry', 'whose', 'bitwise', 'value', 'is', 'closest', 'in', 'an', 'XOR', 'metric', 'to', 'the', 'given', 'key', 'After', 'the', 'closest', 'entry', 'is', 'found', 'the', 'link', 'Trie', 'will', 'call', 'select', 'on', 'that', 'entry', 'and', 'continuecalling', 'select', 'for', 'each', 'entry', 'traversing', 'in', 'order', 'of', 'XOR', 'closeness', 'NOT', 'lexicographically', 'until', 'the', 'cursor', 'returns', 'link', 'DecisionEXIT', 'pThe', 'cursor', 'can', 'return', 'link', 'DecisionCONTINUE', 'to', 'continue', 'traversingp', 'link', 'DecisionREMOVEANDEXIT', 'is', 'used', 'to', 'remove', 'the', 'current', 'elementand', 'stop', 'traversing', 'pNote', 'The', 'link', 'DecisionREMOVE', 'operation', 'is', 'not', 'return', 'The', 'entry', 'the', 'cursor', 'returned', 'link', 'DecisionEXIT', 'on', 'or', 'nullif', 'it', 'continued', 'till', 'the', 'selectK', 'keyCursor', 'super', 'K', 'super', 'V', 'Traverses', 'the', 'link', 'Trie', 'in', 'lexicographical', 'orderlink', 'CursorselectjavautilMapEntry', 'will', 'be', 'called', 'on', 'each', 'entrypThe', 'traversal', 'will', 'stop', 'when', 'the', 'cursor', 'returns', 'link', 'DecisionEXIT', 'link', 'DecisionCONTINUE', 'is', 'used', 'to', 'continue', 'traversing', 'andlink', 'DecisionREMOVE', 'is', 'used', 'to', 'remove', 'the', 'element', 'that', 'was', 'selectedand', 'continue', 'traversing', 'p', 'link', 'DecisionREMOVEANDEXIT', 'is', 'used', 't ...
# the
# entry
# return
# returns
# ol
# keys
# traversing
#
# ************* ['TrackedInputStream', 'long', 'return', 'int', 'read', 'throws', 'IOException', 'int', 'return', 'int', 'readbyte', 'b', 'throws', 'IOException', 'int', 'return', 'int', 'readbyte', 'bint', 'offint', 'len', 'throws', 'IOException', 'int', 'return', 'reset', 'counter', 'to', 'param', 'void', 'resetlong', 'long', 'skiplong', 'n', 'throws', 'IOException', 'long', 'return', 'TrackedInputStreamInputStream'] ****************
# int
# resetlong
# trackedinputstreaminputstream
# offint
# readbyte
# ioexception
# return
#
# ************* ['ReconnectableSnitchHelper', 'void', 'beforeChangeInetAddressAndPort', 'endpointEndpointState', 'currentStateApplicationState', 'newStateKeyVersionedValue', 'void', 'onAliveInetAddressAndPort', 'endpointEndpointState', 'VersionedValue', 'VersionedValue', 'if', 'preferLocal', 'internalIP', 'null', 'reconnectendpointinternalIPAndPorts', 'null', 'internalIPAndPorts', 'void', 'onChangeInetAddressAndPort', 'endpointApplicationState', 'stateVersionedValue', 'if', 'preferLocal', 'GossiperinstanceisDeadStateGossiperinstancegetEndpointStateForEndpointendpoint', 'if', 'state', 'ApplicationStateINTERNALADDRESSANDPORT', 'else', 'if', 'state', 'ApplicationStateINTERNALIP', 'null', 'GossiperinstancegetEndpointStateForEndpointendpointgetApplicationStateApplicationStateINTERNALADDRESSANDPORT', 'void', 'onDeadInetAddressAndPort', 'endpointEndpointState', 'void', 'onJoinInetAddressAndPort', 'endpointEndpointState', 'if', 'preferLocal', 'GossiperinstanceisDeadStateepState', 'VersionedValue', 'if', 'address', 'null', 'if', 'address', 'null', 'void', 'onRemoveInetAddressAndPort', 'void', 'onRestartInetAddressAndPort', 'endpointEndpointState', 'ReconnectableSnitchHelperIEndpointSnitch', 'snitchString', 'localDcboolean', 'static', 'void', 'reconnectInetAddressAndPort', 'publicAddressInetAddressAndPort', 'localAddressIEndpointSnitch', 'snitchString', 'if', 'new', 'OutboundConnectionSettingspublicAddresslocalAddresswithDefaultsConnectionCategoryMESSAGINGauthenticate', 'loggerdebugInternodeAuthenticator', 'said', 'dont', 'reconnect', 'to', 'on', 'if', 'snitchgetDatacenterpublicAddressequalslocalDc', 'loggerdebugInitiated', 'reconnect', 'to', 'an', 'Internal', 'IP', 'for', 'the', 'void', 'reconnectInetAddressAndPort', 'publicAddressVersionedValue', 'try', 'catch', 'UnknownHostException', 'e', 'loggererrorError', 'in', 'getting', 'the', 'IP', 'address', 'resolved'] ****************
# if
# void
# reconnectinetaddressandport
# reconnect
# the
# try
# versionedvalue
#
# ************* ['ValidationMetadata', 'ValidationMetadataString', 'partitionerdouble'] ****************
# validationmetadata
# validationmetadatastring
# partitionerdouble
#
# ************* ['LongType', 'static', 'VLVRint', 'compareLongsVL', 'leftValueAccessorVL', 'accessorLVR', 'rightValueAccessorVR', 'if', 'accessorLisEmptyleft', 'accessorRisEmptyright', 'return', 'int', 'diffaccessorLgetByteleft0', 'if', 'diff', '0', 'return', 'return', 'protected', 'long', 'toLongByteBuffer', 'return'] ****************
# return
# tolongbytebuffer
# diff
# vlvrint
# static
# long
# rightvalueaccessorvr
#
# ************* ['ReplicaPlan', 'abstract', 'int', 'ConsistencyLevel', 'return', 'E', 'return', 'boolean', 'contactsReplica', 'return', 'Keyspace', 'return', 'keyspaceConsistencyLevel', 'consistencyLevelE', 'assert', 'contacts', 'static', 'SharedForRangeRead', 'sharedForRangeRead', 'return', 'new', 'static', 'SharedForTokenRead', 'sharedForTokenRead', 'return', 'new'] ****************
# return
# consistencylevel
# int
# abstract
# sharedforrangeread
# static
# sharedfortokenread
#
# ************* ['MultiColumnRelation', 'Creates', 'a', 'multicolumn', 'IN', 'relation', 'with', 'a', 'list', 'of', 'IN', 'values', 'or', 'markers', 'For', 'example', 'SELECT', 'WHERE', 'a', 'b', 'IN', '0', '1', '2', 'param', 'entities', 'the', 'columns', 'on', 'the', 'LHS', 'of', 'the', 'param', 'inValues', 'a', 'list', 'of', 'TuplesLiteral', 'instances', 'or', 'a', 'TuplesRaw', 'return', 'a', 'new', 'codeMultiColumnRelationcode', 'static', 'MultiColumnRelation', 'createInRelationListColumnIdentifier', 'entitiesList', 'extends', 'TermMultiColumnRaw', 'return', 'new', 'Creates', 'a', 'multicolumn', 'EQ', 'LT', 'LTE', 'GT', 'or', 'GTE', 'relation', 'code', 'For', 'example', 'SELECT', 'WHERE', 'a', 'b', '0', 'param', 'entities', 'the', 'columns', 'on', 'the', 'LHS', 'of', 'the', 'param', 'relationType', 'the', 'relation', 'param', 'valuesOrMarker', 'a', 'TuplesLiteral', 'instance', 'or', 'a', 'TuplesRaw', 'return', 'a', 'new', 'codeMultiColumnRelationcode', 'static', 'MultiColumnRelation', 'createNonInRelationListColumnIdentifier', 'entitiesOperator', 'relationTypeTermMultiColumnRaw', 'assert', 'relationType', 'return', 'new', 'Creates', 'a', 'multicolumn', 'IN', 'relation', 'with', 'a', 'marker', 'for', 'the', 'IN', 'values', 'For', 'example', 'SELECT', 'WHERE', 'a', 'b', 'IN', 'param', 'entities', 'the', 'columns', 'on', 'the', 'LHS', 'of', 'the', 'param', 'inMarker', 'a', 'single', 'IN', 'return', 'a', 'new', 'codeMultiColumnRelationcode', 'static', 'MultiColumnRelation', 'createSingleMarkerInRelationListColumnIdentifier', 'entitiesTuplesINRaw', 'return', 'new', 'ListColumnIdentifier', 'return', 'MultiColumnRelationListColumnIdentifier', 'entitiesOperator', 'relationTypeTermMultiColumnRaw', 'valuesOrMarkerList', 'extends', 'TermMultiColumnRaw', 'inValuesTuplesINRaw', 'ListColumnMetadata', 'receiversTableMetadata', 'table', 'throws', 'InvalidRequestException', 'ListColumnMetadata', 'namesnew', 'int', 'for', 'ColumnIdentifier', 'id', 'getEntities', 'ColumnMetadata', 'checkTruedefisClusteringColumnMulticolumn', 'relations', 'can', 'only', 'be', 'applied', 'to', 'clustering', 'columns', 'but', 'was', 'applied', 'to', 'checkFalsenamescontainsdefColumn', 's', 'appeared', 'twice', 'in', 'a', 'relation', 'checkFalsepreviousPosition', '1', 'defposition', 'previousPosition', '1Clustering', 'columns', 'must', 'appear', 'in', 'the', 'PRIMARY', 'KEY', 'order', 'in', 'multicolumn', 'relations', 'return'] ****************
# the
# where
# creates
# or
# of
# extends
# to
#
# ************* ['QueryEvents', 'boolean', 'return', 'public', 'int', 'return', 'void', 'notifyBatchFailureListQueryHandlerPrepared', 'preparedBatchStatementType', 'batchTypeListObject', 'queryOrIdListListListByteBuffer', 'valuesQueryOptions', 'optionsQueryState', 'stateException', 'if', 'hasListeners', 'ListCQLStatement', 'statementsnew', 'ListString', 'queriesnew', 'if', 'prepared', 'null', 'preparedforEachp', 'try', 'for', 'Listener', 'listener', 'listeners', 'catch', 'Throwable', 't', 'noSpam1merrorFailed', 'notifying', 'void', 'notifyBatchSuccessBatchStatementType', 'batchTypeList', 'extends', 'CQLStatement', 'statementsListString', 'queriesListListByteBuffer', 'valuesQueryOptions', 'optionsQueryState', 'statelong', 'queryTimeMessageResponse', 'try', 'for', 'Listener', 'listener', 'listeners', 'catch', 'Throwable', 't', 'noSpam1merrorFailed', 'notifying', 'void', 'notifyExecuteFailureQueryHandlerPrepared', 'preparedQueryOptions', 'optionsQueryState', 'stateException', 'CQLStatement', 'statementprepared', 'null', 'preparedstatement', 'String', 'queryprepared', 'null', 'preparedrawCQLStatement', 'try', 'for', 'Listener', 'listener', 'listeners', 'catch', 'Throwable', 't', 'noSpam1merrorFailed', 'notifying', 'void', 'notifyExecuteSuccessCQLStatement', 'statementString', 'queryQueryOptions', 'optionsQueryState', 'statelong', 'queryTimeMessageResponse', 'try', 'for', 'Listener', 'listener', 'listeners', 'catch', 'Throwable', 't', 'noSpam1merrorFailed', 'notifying', 'void', 'notifyPrepareFailureNullable', 'CQLStatement', 'statementString', 'queryQueryState', 'stateException', 'try', 'for', 'Listener', 'listener', 'listeners', 'catch', 'Throwable', 't', 'noSpam1merrorFailed', 'notifying', 'void', 'notifyPrepareSuccessSupplierQueryHandlerPrepared', 'preparedProviderString', 'queryQueryState', 'statelong', 'queryTimeResultMessagePrepared', 'if', 'hasListeners', 'QueryHandlerPrepared', 'if', 'prepared', 'null', 'try', 'for', 'Listener', 'listener', 'listeners', 'catch', 'Throwable', 't', 'noSpam1merrorFailed', 'notifying', 'else', 'notifyPrepareFailurenullquerystatenew', 'RuntimeExceptionSuccessfully', 'prepared', 'but', 'could', 'not', 'find', 'prepared', 'statement', 'for', 'void', 'notifyQueryFailureCQLStatement', 'statementString', 'queryQueryOptions', 'optionsQueryState', 'stateException', 'try', 'for', 'Listener', 'listener', 'listeners', 'catch', 'Throwable', 't', 'noSpam1merrorFailed', 'notifying', 'void', 'notifyQuerySuccessCQLStatement', 'statementString', 'queryQueryOptions', 'optionsQueryState', 'statelong', 'queryTimeMessageResponse', 'try', 'for', 'Listener', 'listener', 'listeners', 'catch', 'Throwable', 't', 'noSpam1merrorFailed', 'notifying', 'void', 'registerListenerListener', 'void', 'unregisterListenerListener'] ****************
# listener
# stateexception
# notifying
# throwable
# if
# cqlstatement
# haslisteners
#
# ************* ['UnfilteredRows', 'UnfilteredRowsUnfilteredRowIterator', 'UnfilteredRowsUnfilteredRowIterator', 'inputRegularAndStaticColumns'] ****************
# unfilteredrowsunfilteredrowiterator
# inputregularandstaticcolumns
# unfilteredrows
#
# ************* ['RegularAndStaticColumns', 'boolean', 'includesRegularAndStaticColumns', 'return', 'staticscontainsAllcolumnsstatics', 'RegularAndStaticColumns', 'mergeToRegularAndStaticColumns', 'if', 'this', 'that', 'return', 'Columns', 'Columns', 'if', 'statics', 'thisstatics', 'regulars', 'thisregulars', 'return', 'if', 'statics', 'thatstatics', 'regulars', 'thatregulars', 'return', 'return', 'new', 'RegularAndStaticColumnsColumns', 'staticsColumns', 'assert', 'statics', 'null', 'regulars'] ****************
# return
# new
# staticscolumns
# boolean
# mergetoregularandstaticcolumns
# thatregulars
# regularandstaticcolumnscolumns
#
# ************* ['VersionedValue', 'int', 'compareToVersionedValue', 'return', 'thisversion', 'byte', 'return', 'static', 'VersionedValue', 'unsafeMakeVersionedValueString', 'valueint', 'return', 'new', 'VersionedValueString', 'VersionedValueString', 'valueint', 'assert', 'value', 'static', 'String', 'versionStringString', 'return'] ****************
# return
# string
# thisversion
# byte
# versionstringstring
# new
# assert
#
# ************* ['SASIIndexBuilder', 'void', 'completeSSTablePerSSTableIndexWriter', 'indexWriterSSTableReader', 'sstableCollectionColumnIndex', 'for', 'ColumnIndex', 'index', 'indexes', 'File', 'tmpIndexnew', 'if', 'tmpIndexexists', 'long', 'getPrimaryIndexLengthSSTable', 'File', 'primaryIndexnew', 'return', 'primaryIndexexists', 'primaryIndexlength', 'SASIIndexBuilderColumnFamilyStore', 'cfsSortedMapSSTableReaderMapColumnMetadataColumnIndex', 'long', 'for', 'SSTableReader', 'sstable', 'sstableskeySet'] ****************
# for
# file
# cfssortedmapsstablereadermapcolumnmetadatacolumnindex
# sstableskeyset
# sstable
# getprimaryindexlengthsstable
# columnindex
#
# ************* ['IndexSummaryBuilder', 'IndexSummary', 'buildIPartitioner', 'return', 'IndexSummary', 'buildIPartitioner', 'partitionerReadableBoundary', 'assert', 'entrieslength', 'int', 'countintoffsetslength', 'long', 'if', 'boundary', 'null', 'int', 'sizeAtFullSamplingintMathceilkeysWritten', 'assert', 'count', 'return', 'new', 'int', 'calculateSamplingLevelint', 'currentSamplingLevelint', 'currentNumEntrieslong', 'targetNumEntriesint', 'minIndexIntervalint', 'int', 'effectiveMinSamplingLevelMathmax1intMathceilBASESAMPLINGLEVEL', 'minIndexInterval', 'int', 'newSamplingLevelinttargetNumEntries', 'currentSamplingLevel', 'return', 'Downsamples', 'an', 'existing', 'index', 'summary', 'to', 'a', 'new', 'sampling', 'param', 'existing', 'an', 'existing', 'param', 'newSamplingLevel', 'the', 'target', 'level', 'for', 'the', 'new', 'IndexSummary', 'This', 'must', 'be', 'less', 'than', 'the', 'current', 'samplinglevel', 'for', 'param', 'partitioner', 'the', 'partitioner', 'used', 'for', 'the', 'index', 'return', 'a', 'new', 'public', 'static', 'IndexSummary', 'downsampleIndexSummary', 'existingint', 'newSamplingLevelint', 'minIndexIntervalIPartitioner', 'int', 'assert', 'currentSamplingLevel', 'assert', 'minIndexInterval', 'int', 'int', 'long', 'for', 'int', 'start', 'startPoints', 'for', 'int', 'jstart', 'j', 'existingsize', 'jcurrentSamplingLevel', 'long', 'lengthexistinggetEndInSummaryj', 'Memory', 'Memory', 'newOffsetsMemoryallocatenewKeyCount', 'Memory', 'int', 'int', 'outer', 'for', 'int', 'oldSummaryIndex0', 'oldSummaryIndex', 'existingsize', 'oldSummaryIndex', 'for', 'int', 'start', 'startPoints', 'if', 'oldSummaryIndex', 'start', 'currentSamplingLevel', '0', 'continue', 'newOffsetssetInti', 'long', 'long', 'lengthexistinggetEndInSummaryoldSummaryIndex', 'assert', 'newEntriesOffset', 'return', 'new', 'int', 'entriesAtSamplingLevelint', 'samplingLevelint', 'return', 'intMathceilsamplingLevel', 'maxSummarySize', 'Given', 'a', 'key', 'return', 'how', 'long', 'the', 'serialized', 'index', 'summary', 'entry', 'will', 'static', 'long', 'getEntrySizeDecoratedKey', 'return', 'Given', 'a', 'key', 'size', 'return', 'how', 'long', 'the', 'serialized', 'index', 'summary', 'entry', 'will', 'be', 'that', 'is', 'add', '8', 'bytes', 'to', 'accomodate', 'for', 'the', 'size', 'of', 'the', 'static', 'long', 'getEntrySizelong', 'return', 'keySize', 'ReadableBoundary', 'return', 'Build', 'an', 'index', 'summary', 'param', 'expectedKeys', 'the', 'number', 'of', 'keys', 'we', 'expect', 'in', 'the', 'param', 'minIndexInterval', 'the', 'minimum', 'interval', 'between', 'entries', 'selected', 'for', 'param', 'samplingLevel', 'the', 'level', 'at', 'which', 'entries', 'are', 'IndexSummaryBuilderlong', 'expectedKeysint', 'minIndexIntervalint', 'long', 'long', 'maxExpectedEntriesexpectedKeys', 'long', 'maxExpectedEntriesSizemaxExpectedEntries', 'if', 'maxExpectedEntriesSize', 'IntegerMAXVALUE', 'int', 'effectiveMinIntervalintMathceildoubleexpectedKeys', 'expectedEntrySize', 'maxExpectedEntriesexpectedKeys', 'maxExpectedEntriesSizemaxExpectedEntries', 'assert', 'maxExpectedEntriesSize', 'IntegerMAXVALUE', 'loggerwarnminindexinterval', 'of', 'is', 'too', 'low', 'for', 'expected', 'keys', 'of', 'avg', 'size', 'using', 'interval', 'of', 'else', 'maxExpectedEntriesMathmax1maxExpectedEntries', 'samplingLevel', 'offsetsnew', 'SafeMemoryWriter4', 'entriesnew', 'SafeMemoryWriterexpectedEntrySize', 'void', 'markDataSyncedlong', 'void', 'markIndexSyncedlong', 'IndexSummaryBuilder', 'maybeAddEntryDecoratedKey', 'decoratedKeylong', 'indexStart', 'throws', 'IOException', 'return', 'param', 'decoratedKey', 'the', 'key', 'for', 'this', 'param', 'indexStart', 'the', 'position', 'in', 'the', 'index', 'file', 'this', 'record', 'param', 'indexEnd', 'the', 'position', 'in', 'the', 'index', 'file', 'we', 'need', 'to', 'be', 'able', 'to', 'read', 'to', 'exclusive', 'to', 'read', 'this', 'param', 'dataEnd', 'the', 'position', 'in', 'the', 'data', 'file', 'we', 'need', 'to', 'be', ...
# the
# assert
# new
# of
# we
# indexsummary
# start
#
# ************* ['QueryProcessor', 'static', 'long', 'capacityToByteslong', 'return', 'cacheSizeMB', '1024', 'Clear', 'our', 'internal', 'statmeent', 'cache', 'for', 'test', 'public', 'static', 'void', 'Clears', 'the', 'prepared', 'statement', 'param', 'memoryOnly', 'code', 'true', 'if', 'only', 'the', 'in', 'memory', 'caches', 'must', 'be', 'cleared', 'code', 'false', 'public', 'static', 'void', 'clearPreparedStatementsboolean', 'if', 'memoryOnly', 'static', 'MD5Digest', 'computeIdString', 'queryStringString', 'String', 'toHashkeyspace', 'null', 'queryString', 'keyspace', 'return', 'A', 'special', 'version', 'of', 'executeLocally', 'that', 'takes', 'the', 'time', 'used', 'as', 'now', 'for', 'the', 'query', 'in', 'argument', 'Note', 'that', 'this', 'only', 'make', 'sense', 'for', 'Selects', 'so', 'this', 'only', 'accept', 'SELECT', 'statements', 'and', 'is', 'only', 'useful', 'in', 'rare', 'static', 'UntypedResultSet', 'executeInternalWithNowint', 'nowInSeclong', 'queryStartNanoTimeString', 'queryObject', 'Prepared', 'assert', 'preparedstatement', 'instanceof', 'SelectStatement', 'ResultMessage', 'assert', 'result', 'instanceof', 'return', 'static', 'UntypedResultSet', 'executeInternalWithPagingString', 'queryint', 'pageSizeObject', 'Prepared', 'if', 'preparedstatement', 'instanceof', 'SelectStatement', 'throw', 'new', 'IllegalArgumentExceptionOnly', 'SELECTs', 'can', 'be', 'SelectStatement', 'QueryPager', 'return', 'static', 'UntypedResultSet', 'executeInternalString', 'queryObject', 'Prepared', 'ResultMessage', 'if', 'result', 'instanceof', 'ResultMessageRows', 'return', 'else', 'return', 'Same', 'than', 'executeLocally', 'but', 'to', 'use', 'for', 'queries', 'we', 'know', 'are', 'only', 'executed', 'once', 'so', 'that', 'the', 'created', 'statement', 'object', 'is', 'not', 'static', 'UntypedResultSet', 'executeOnceInternalString', 'queryObject', 'CQLStatement', 'ResultMessage', 'if', 'result', 'instanceof', 'ResultMessageRows', 'return', 'else', 'return', 'static', 'UntypedResultSet', 'executeString', 'queryConsistencyLevel', 'clObject', 'values', 'throws', 'RequestExecutionException', 'return', 'static', 'UntypedResultSet', 'executeString', 'queryConsistencyLevel', 'clQueryState', 'stateObject', 'values', 'throws', 'RequestExecutionException', 'try', 'Prepared', 'ResultMessage', 'if', 'result', 'instanceof', 'ResultMessageRows', 'return', 'else', 'return', 'catch', 'RequestValidationException', 'e', 'throw', 'new', 'RuntimeExceptionError', 'validating', 'public', 'static', 'ConcurrentMapStringPrepared', 'return', 'Prepared', 'getPreparedMD5Digest', 'return', 'static', 'CQLStatement', 'getStatementString', 'queryStrClientState', 'clientState', 'throws', 'RequestValidationException', 'TracingtraceParsing', 'CQLStatementRaw', 'if', 'statement', 'instanceof', 'QualifiedStatement', 'TracingtracePreparing', 'return', 'static', 'ResultMessagePrepared', 'getStoredPreparedStatementString', 'queryStringString', 'keyspace', 'throws', 'InvalidRequestException', 'MD5Digest', 'Prepared', 'if', 'existing', 'null', 'return', 'checkTruequeryStringequalsexistingrawCQLStatementStringformatMD5', 'hash', 'collision', 'query', 'with', 'the', 'same', 'MD5', 'hash', 'was', 'already', 'prepared', 'n', 'Existing', 'ResultSetPreparedMetadata', 'ResultSetResultMetadata', 'return', 'new', 'public', 'static', 'QueryState', 'return', 'new', 'public', 'static', 'QueryOptions', 'makeInternalOptionsCQLStatement', 'preparedObject', 'return', 'static', 'QueryOptions', 'makeInternalOptionsCQLStatement', 'preparedObject', 'valuesConsistencyLevel', 'if', 'preparedgetBindVariablessize', 'valueslength', 'throw', 'new', 'IllegalArgumentExceptionStringformatInvalid', 'number', 'of', 'values', 'Expecting', 'd', 'but', 'got', 'ListByteBuffer', 'boundValuesnew', 'for', 'int', 'i0', 'i', 'valueslength', 'i', 'Object', 'AbstractType', 'boundValuesaddvalue', 'instanceof', 'ByteBuffer', 'value', 'null', 'ByteBuffervalue', 'return', 'static', 'int', 'measureObject', 'keyPrep ...
# return
# cqlstatement
# of
# null
# throw
# querystartnanotime
# prepared
#
# ************* ['OperationExecutionException', 'Creates', 'a', 'new', 'codeOperationExecutionExceptioncode', 'for', 'the', 'specified', 'param', 'operator', 'the', 'param', 'argTypes', 'the', 'argument', 'param', 'e', 'the', 'original', 'return', 'a', 'new', 'codeOperationExecutionExceptioncode', 'for', 'the', 'specified', 'static', 'OperationExecutionException', 'createchar', 'operatorListAbstractType', 'argTypesException', 'ListString', 'return', 'new', 'OperationExecutionExceptionStringformatthe', 'operation', 's', 's', 's', 'failed', 'Creates', 'an', 'codeOperationExecutionExceptioncode', 'with', 'the', 'specified', 'param', 'msg', 'the', 'error', 'OperationExecutionExceptionString'] ****************
# the
# msg
# original
# operator
# operation
# liststring
# operationexecutionexceptionstring
#
# ************* ['SimpleSSTableMultiWriter', 'SimpleSSTableMultiWriterSSTableWriter', 'writerLifecycleNewTracker'] ****************
# writerlifecyclenewtracker
# simplesstablemultiwritersstablewriter
# simplesstablemultiwriter
#
# ...
# if
# entriesidx
# clustering
# new
# listindexentry
# unfilteredrowiterator
# entriesfinal
#
# ************* ['GroupCommitLogService', 'GroupCommitLogServiceCommitLog'] ****************
# groupcommitlogservice
# groupcommitlogservicecommitlog
#
# ************* ['ClearableHistogram', 'Creates', 'a', 'new', 'link', 'comcodahalemetricsHistogram', 'with', 'the', 'given', 'param', 'reservoir', 'the', 'reservoir', 'to', 'create', 'a', 'histogram', 'ClearableHistogramDecayingEstimatedHistogramReservoir', 'void', 'try', 'Field', 'Object', 'if', 'counter', 'instanceof', 'LongAdder', 'else', 'Method', 'catch', 'Exception', 'e', 'throw', 'new', 'IllegalStateExceptionCannot', 'reset', 'the', 'comcodahalemetricsHistogram', 'count', 'This', 'might', 'be', 'due', 'to', 'a', 'change', 'of', 'version', 'of', 'the', 'metric'] ****************
# the
# create
# version
# given
# catch
# void
# be
#
# ************* ['CommitLogSegmentManagerStandard', 'CommitLogSegmentManagerStandardfinal', 'CommitLog', 'commitLogString'] ****************
# commitlogsegmentmanagerstandard
# commitlogsegmentmanagerstandardfinal
# commitlogstring
# commitlog
#
# ************* ['CompactionMetrics', 'CompactionMetricsfinal', 'ThreadPoolExecutor', 'pendingTasksMetricsregisterfactorycreateMetricNamePendingTasksnew', 'public', 'Integer', 'int', 'for', 'String', 'keyspaceName', 'SchemainstancegetKeyspaces', 'for', 'ColumnFamilyStore', 'cfs', 'KeyspaceopenkeyspaceNamegetColumnFamilyStores', 'return', 'n', 'pendingTasksByTableNameMetricsregisterfactorycreateMetricNamePendingTasksByTableNamenew', 'Override', 'public', 'MapStringMapStringInteger', 'MapStringMapStringInteger', 'resultMapnew', 'for', 'String', 'keyspaceName', 'SchemainstancegetKeyspaces', 'for', 'ColumnFamilyStore', 'cfs', 'KeyspaceopenkeyspaceNamegetColumnFamilyStores', 'int', 'if', 'taskNumber', '0', 'if', 'resultMapcontainsKeykeyspaceName', 'resultMapputkeyspaceNamenew', 'for', 'CompactionInfoHolder', 'compaction', 'CompactionManagerinstanceactivegetCompactions', 'TableMetadata', 'if', 'metaData', 'null', 'if', 'resultMapcontainsKeymetaDatakeyspace', 'resultMapputmetaDatakeyspacenew', 'MapStringInteger', 'if', 'tableNameToCountMapcontainsKeymetaDataname', 'tableNameToCountMapputmetaDatanametableNameToCountMapgetmetaDataname', 'else', 'return', 'completedTasksMetricsregisterfactorycreateMetricNameCompletedTasksnew', 'public', 'Long', 'long', 'for', 'ThreadPoolExecutor', 'collector', 'collectors', 'return'] ****************
# for
# cfs
# mapstringmapstringinteger
# int
# columnfamilystore
# long
# keyspaceopenkeyspacenamegetcolumnfamilystores
#
# ************* ['BooleanType'] ****************
# ************* ['Index', 'Return', 'a', 'task', 'to', 'be', 'executed', 'before', 'the', 'node', 'enters', 'NORMAL', 'state', 'and', 'finally', 'joins', 'the', 'param', 'hadBootstrap', 'If', 'the', 'node', 'had', 'bootstrap', 'before', 'return', 'task', 'to', 'be', 'executed', 'by', 'the', 'index', 'manager', 'before', 'joining', 'the', 'public', 'Callable', 'getPreJoinTaskboolean', 'return', 'Same', 'as', 'code', 'getBuildTaskSupport', 'but', 'can', 'be', 'overloaded', 'with', 'a', 'specific', 'recover', 'logic', 'different', 'than', 'the', 'index', 'building', 'IndexBuildingSupport', 'return', 'Returns', 'the', 'type', 'of', 'operations', 'supported', 'by', 'the', 'index', 'in', 'case', 'its', 'building', 'has', 'failed', 'and', 'its', 'needing', 'param', 'isInitialBuild', 'code', 'true', 'if', 'the', 'failure', 'is', 'for', 'the', 'initial', 'build', 'task', 'on', 'index', 'creation', 'code', 'falseif', 'the', 'failure', 'is', 'for', 'a', 'full', 'rebuild', 'or', 'LoadType', 'getSupportedLoadTypeOnFailureboolean', 'return', 'isInitialBuild', 'LoadTypeWRITE'] ****************
# the
# if
# is
# to
# code
# building
# be
#
# ************* ['GrantRoleStatement', 'GrantRoleStatementRoleName', 'nameRoleName'] ****************
# grantrolestatement
# grantrolestatementrolename
# namerolename
#
# ************* ['CompactionMetadata', 'CompactionMetadataICardinality'] ****************
# compactionmetadata
# compactionmetadataicardinality
#
# ************* ['InternodeInboundTable', 'void', 'addRowSimpleDataSet', 'dataSetInetAddressAndPort', 'addressAndPortInboundMessageHandlers', 'String', 'String', 'superTableMetadatabuilderkeyspaceinternodeinboundkindTableMetadataKindVIRTUALpartitionernew'] ****************
# string
# addrowsimpledataset
# internodeinboundtable
# addressandportinboundmessagehandlers
# void
# datasetinetaddressandport
# supertablemetadatabuilderkeyspaceinternodeinboundkindtablemetadatakindvirtualpartitionernew
#
# ************* ['Int32Type'] ****************
# ************* ['DropTriggerStatement', 'DropTriggerStatementString', 'keyspaceNameString', 'tableNameString', 'triggerNameboolean'] ****************
# keyspacenamestring
# tablenamestring
# droptriggerstatement
# triggernameboolean
# droptriggerstatementstring
#
# ************* ['SystemReplicas', 'static', 'Replica', 'createSystemReplicaInetAddressAndPort', 'return', 'new', 'static', 'EndpointsForRange', 'getSystemReplicasCollectionInetAddressAndPort', 'if', 'endpointsisEmpty', 'return', 'return', 'There', 'are', 'a', 'few', 'places', 'where', 'a', 'system', 'function', 'borrows', 'write', 'path', 'functionality', 'but', 'doesnt', 'otherwise', 'fit', 'into', 'normal', 'replication', 'strategies', 'ie', 'hints', 'and', 'batchlog', 'So', 'here', 'we', 'provide', 'a', 'replica', 'static', 'Replica', 'getSystemReplicaInetAddressAndPort', 'return'] ****************
# return
# otherwise
# borrows
# fit
# createsystemreplicainetaddressandport
# here
# normal
#
# ************* ['FileSegmentInputStream', 'FileSegmentInputStreamByteBuffer', 'bufferString', 'filePathlong'] ****************
# filesegmentinputstream
# filepathlong
# filesegmentinputstreambytebuffer
# bufferstring
#
# ************* ['StemmerFactory', 'static', 'SnowballStemmer', 'getStemmerLocale', 'if', 'locale', 'null', 'return', 'String', 'try', 'Class', 'if', 'clazz', 'null', 'return', 'Constructor', 'return', 'catch', 'Exception', 'e', 'loggerdebugFailed', 'to', 'create', 'new', 'SnowballStemmer', 'instance', 'for', 'language', 'return'] ****************
# return
# to
# class
# string
# exception
# instance
# constructor
#
# ************* ['ClientWriteRequestMetrics', 'ClientWriteRequestMetricsString'] ****************
# clientwriterequestmetricsstring
# clientwriterequestmetrics
#
# ************* ['Unfiltered', 'boolean', 'return', 'kind', 'boolean', 'return', 'kind'] ****************
# return
# kind
# boolean
# unfiltered
#
# ************* ['BaseRows', 'protected', 'Unfiltered', 'applyOneUnfiltered', 'valueTransformation', 'return', 'value', 'null', 'null', 'value', 'instanceof', 'Row', 'transformationapplyToRowRowvalue', 'extends', 'I', 'BaseRowsI'] ****************
# value
# null
# applyoneunfiltered
# baserows
# transformationapplytorowrowvalue
# baserowsi
# extends
#
# ************* ['AuditLogEntry', 'AuditLogEntryAuditLogEntryType', 'typeInetAddressAndPort', 'sourceString', 'userlong', 'timestampUUID', 'batchString', 'keyspaceString', 'scopeString', 'operationQueryOptions', 'optionsQueryState', 'UUID', 'return', 'InetAddressAndPort', 'return', 'StringBuilder', 'buildernew', 'if', 'sourceport', '0', 'if', 'batch', 'null', 'if', 'StringUtilsisNotBlankkeyspace', 'if', 'StringUtilsisNotBlankscope', 'if', 'StringUtilsisNotBlankoperation', 'return', 'String', 'return', 'String', 'return', 'QueryState', 'return', 'long', 'return', 'String', 'return'] ****************
# return
# typeinetaddressandport
# auditlogentryauditlogentrytype
# querystate
# keyspacestring
# stringutilsisnotblankscope
# stringutilsisnotblankkeyspace
#
# ************* ['ConfigurationException', 'ConfigurationExceptionExceptionCode', 'codeString', 'ConfigurationExceptionString', 'ConfigurationExceptionString', 'msgboolean', 'ConfigurationExceptionString', 'msgThrowable'] ****************
# configurationexceptionstring
# msgthrowable
# msgboolean
# codestring
# configurationexception
# configurationexceptionexceptioncode
#
# ************* ['DriverException', 'messageThrowable'] ****************
# driverexception
# messagethrowable
#
# ************* ['CommitLogMetrics', 'void', 'attachfinal', 'AbstractCommitLogService', 'servicefinal', 'AbstractCommitLogSegmentManager', 'completedTasksMetricsregisterfactorycreateMetricNameCompletedTasksnew', 'public', 'Long', 'return', 'pendingTasksMetricsregisterfactorycreateMetricNamePendingTasksnew', 'public', 'Long', 'return', 'totalCommitLogSizeMetricsregisterfactorycreateMetricNameTotalCommitLogSizenew', 'public', 'Long', 'return'] ****************
# long
# public
# servicefinal
# void
# abstractcommitlogservice
# pendingtasksmetricsregisterfactorycreatemetricnamependingtasksnew
# totalcommitlogsizemetricsregisterfactorycreatemetricnametotalcommitlogsizenew
#
# ************* ['BloomFilterTracker', 'void', 'void', 'long', 'return', 'long', 'long', 'try', 'return', 'fpc', 'finally', 'long', 'long', 'try', 'return', 'tpc', 'finally', 'long', 'return'] ****************
# long
# finally
# return
# try
# fpc
# tpc
# bloomfiltertracker
#
# ************* ['MoreRows', 'static', 'RowIterator', 'extendRowIterator', 'iteratorMoreRows', 'super', 'RowIterator', 'return', 'static', 'UnfilteredRowIterator', 'extendUnfilteredRowIterator', 'iteratorMoreRows', 'super', 'UnfilteredRowIterator', 'return', 'static', 'UnfilteredRowIterator', 'extendUnfilteredRowIterator', 'iteratorMoreRows', 'super', 'UnfilteredRowIterator', 'moreRegularAndStaticColumns', 'return'] ****************
# unfilteredrowiterator
# return
# iteratormorerows
# super
# static
# extendrowiterator
# moreregularandstaticcolumns
#
# ************* ['CorruptFileException', 'CorruptFileExceptionException', 'causeString'] ****************
# causestring
# corruptfileexception
# corruptfileexceptionexception
#
# ************* ['CharTerm', 'CharTermint', 'positionCharBuffer', 'valueTokenTreeBuilder'] ****************
# valuetokentreebuilder
# positioncharbuffer
# charterm
# chartermint
#
# ************* ['CreateTriggerStatement', 'CreateTriggerStatementString', 'keyspaceNameString', 'tableNameString', 'triggerNameString', 'triggerClassboolean'] ****************
# createtriggerstatement
# createtriggerstatementstring
# keyspacenamestring
# tablenamestring
# triggerclassboolean
# triggernamestring
#
# ************* ['AllowAllInternodeAuthenticator', 'boolean', 'authenticateInetAddress', 'remoteAddressint', 'return'] ****************
# boolean
# return
# authenticateinetaddress
# allowallinternodeauthenticator
# remoteaddressint
#
# ************* ['Filter', 'protected', 'RangeTombstoneMarker', 'applyToMarkerRangeTombstoneMarker', 'return', 'SuppressWarningsresource', 'protected', 'RowIterator', 'applyToPartitionBaseRowIterator', 'return', 'iterator', 'instanceof', 'UnfilteredRows', 'new', 'FilteredRowsthisUnfilteredRowsiterator', 'new', 'protected', 'Row', 'applyToRowRow', 'return', 'protected', 'Row', 'applyToStaticRow', 'if', 'rowisEmpty', 'return', 'return', 'row', 'null', 'RowsEMPTYSTATICROW', 'Filterint', 'nowInSecboolean'] ****************
# return
# filterint
# applytostaticrow
# null
# filter
# applytopartitionbaserowiterator
# applytorowrow
#
# ************* ['CassandraPrincipal', 'Create', 'a', 'CassPrincipal', 'with', 'a', 'username', 'param', 'name', 'the', 'username', 'for', 'this', 'exception', 'NullPointerException', 'if', 'the', 'codenamecodeis', 'CassandraPrincipalString', 'if', 'name', 'null', 'throw', 'new', 'NullPointerExceptionillegal', 'null'] ****************
# the
# if
# codenamecodeis
# cassandraprincipal
# create
# cassprincipal
# cassandraprincipalstring
#
# ************* ['AbstractIterator', 'Constructor', 'for', 'use', 'by', 'subclasses', 'Implementations', 'of', 'link', 'computeNext', 'bmustb', 'invoke', 'this', 'method', 'whenthere', 'are', 'no', 'elements', 'left', 'in', 'the', 'return', 'code', 'null', 'a', 'convenience', 'so', 'your', 'code', 'computeNextimplementation', 'can', 'use', 'the', 'simple', 'statement', 'code', 'return', 'final', 'T', 'return'] ****************
# code
# return
# your
# abstractiterator
# link
# are
# method
#
# ************* ['TransportException', 'The', 'exception', 'String'] ****************
# the
# transportexception
# exception
# string
#
# ************* ['AbstractOnHeapClusteringPrefix', 'AbstractOnHeapClusteringPrefixKind', 'kindV'] ****************
# kindv
# abstractonheapclusteringprefix
# abstractonheapclusteringprefixkind
#
# ************* ['ExcludingBounds', 'ExcludingBoundsT', 'leftT', 'assert', 'strictlyWrapsAroundleftright', 'rightisMinimum', 'leftcompareToright', '0', 'left', 'right'] ****************
# assert
# excludingbounds
# excludingboundst
# left
# leftcomparetoright
# leftt
# right
#
# ************* ['FrozenType'] ****************
# ************* ['DefaultNameFactory', 'static', 'String', 'createDefaultMBeanNameString', 'typeString', 'nameString', 'final', 'StringBuilder', 'nameBuildernew', 'if', 'scope', 'null', 'if', 'namelength', '0', 'return', 'static', 'CassandraMetricsRegistryMetricName', 'createMetricNameString', 'typeString', 'metricNameString', 'return', 'new', 'DefaultNameFactoryString', 'DefaultNameFactoryString', 'typeString'] ****************
# typestring
# cassandrametricsregistrymetricname
# createmetricnamestring
# stringbuilder
# final
# if
# null
#
# ************* ['ActiveCompactions', 'Iterates', 'over', 'the', 'active', 'compactions', 'and', 'tries', 'to', 'find', 'CompactionInfos', 'with', 'the', 'given', 'compactionType', 'for', 'the', 'given', 'sstable', 'Number', 'of', 'entries', 'in', 'compactions', 'should', 'be', 'small', '10', 'but', 'avoid', 'calling', 'in', 'any', 'timesensitive', 'CollectionCompactionInfo', 'getCompactionsForSSTableSSTableReader', 'sstableOperationType', 'ListCompactionInfo', 'compactions', 'for', 'CompactionInfoHolder', 'holder', 'compactions', 'CompactionInfo', 'if', 'compactionInfogetSSTablescontainssstable', 'compactionInfogetTaskType', 'compactionType', 'if', 'toReturn', 'null', 'toReturnnew', 'return'] ****************
# compactions
# of
# 10
# active
# with
# calling
# avoid
#
# ************* ['CreateKeyspaceStatement', 'CreateKeyspaceStatementString', 'keyspaceNameKeyspaceAttributes', 'attrsboolean'] ****************
# keyspacenamekeyspaceattributes
# createkeyspacestatement
# createkeyspacestatementstring
# attrsboolean
#
# ************* ['DropTypeStatement', 'DropTypeStatementString', 'keyspaceNameString', 'typeNameboolean'] ****************
# typenameboolean
# droptypestatement
# keyspacenamestring
# droptypestatementstring
#
# ************* ['AlterRoleStatement', 'AlterRoleStatementRoleName', 'nameRoleOptions', 'AlterRoleStatementRoleName', 'nameRoleOptions', 'optsDCPermissions'] ****************
# alterrolestatementrolename
# nameroleoptions
# alterrolestatement
# optsdcpermissions
#
# ************* ['EndpointsByReplica', 'EndpointsByReplicaMapReplicaEndpointsForRange', 'EndpointsForRange', 'getReplica', 'return'] ****************
# return
# endpointsbyreplica
# endpointsforrange
# getreplica
# endpointsbyreplicamapreplicaendpointsforrange

# %%
c = []
for i in range(len(class_name)):
      for j in range(len(acsm)):
        if i==j:
            t=[class_name[i],acsm[j]]
            c.append(t)


c = np.array(c)

# %%
df =pd.read_csv("/content/drive/MyDrive/delesmell/dataset_class/Blue-Block/blue.csv")

# %%
x= df.iloc[:, 0]

# %%
#add new column
ngList=[] #Prepare a list and store the data of the new column in it

for index in x:
#     print(index)
    q = 1
    for i in range(0,len(c)):
        st = str(c[i][0])
        st = st[1:]
#         print(st)
        if index == st:
            ngList.append(c[i][1])
            q = 0
#             print('*')
    if q==1 :
        ngList.append(1)

# %%
brainList=[] #Prepare a list and store the data of the new column in it

for index in x:
#     print(index)
    q = 1
    for i in range(0,len(c)):
        st = str(Brain_Class[i][0])
        st = st[1:]
        if index == st:
            brainList.append(Brain_Class[i][1])
            q = 0
    if q==1 :
        brainList.append('0')
        
        
print(len(brainList))
print(len(x))
# Out:
# 14
# 14

# %%
column=df.columns.tolist()

# %%
df['acsm'] = ngList 
df['is_brain'] = brainList 
df.to_csv(save_file_csv,mode = 'a',index =False)

# %%
df.head()
# Out:
#          NAME   AMW  ATDF  BOVM  BUR  CBO  CC  CM  CRIX  DAC  ...  NOA  NOAM  \
# 0     Locator  4.78    18     0    1    7   3   4   2.5    1  ...    1     0
# 1   InfoPanel  3.33     5     0    1    3   1   1   0.0    0  ...    5     0
# 2           1  1.00     0     0    1    2   0   0   0.0    0  ...    0     0
# 3        Main  1.94     6     0    1    5   6   9   0.0    2  ...    7     0
# 4  InfoWindow  1.67     8     0    1    5   1   5   0.0    4  ...    6     0
#
#    NOD  NOM  NOPA   TCC  WMC   WOC  acsm  is_brain
# 0    0    9     0  0.57   43  1.00     1         0
# 1    0    3     0  1.00   10  1.00     1         0
# 2    0    1     0  1.00    1  1.00     1         0
# 3    0   17     3  0.11   33  0.83     1         0
# 4    0    3     1  0.00    5  0.67     1         0
#
# [5 rows x 27 columns]
